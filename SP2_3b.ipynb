# %% [markdown]
# ### Sample Problems 2.3b: Definite Integral with U-Substitution

# %% [markdown]
# **Problem 1:**
#
# $\int_0^2 2x(x^2 + 1)^3dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** Choose u = $x^2 + 1$
#
# **Step 2:** Find du = $2xdx$
#
# **Step 3:** Rewrite the limits:
#     When $x=0$ , $u = 0^2 +  1$ $= 1$
#     When $x=2$ , $u = 2^2 + 1$ $= 5$
#     Then the new limits will be $u=1$ to $u=5$
#
# **Step 4:** Substitute:
# $\int_0^2 2x(x^2 + 1)^3dx$ = $\int_1^5 u^3du$
#
# **Step 5:** Integrat with u:
# $\int u^3du$ = $\frac {u^4}{4}$
#
# **Step 6:** Evaluate at $u=1$ to $u=5$
#
# $ \frac {u^4}{4} |_1^5$ = $\frac{5^4}{4} - \frac{1^4}{4}$ = $\frac {624}{4} - \frac{1}{4}$
#
# **Step 7:** Final Answer= 156
#
# </details>

# %% [markdown]
# **Problem 2:**
#
# Solve: $$\int_1^2 x^2(2x^3 + 4)^2 dx$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** Choose $u = 2x^3 + 4$
#
# **Step 2:** Find $du = 6x^2 dx \implies \frac{1}{6}du = x^2 dx$
#
# **Step 3:** Rewrite the integral: $\frac{1}{6} \int_1^2 u^2 du$
#
# **Step 4:** Integrate: $\frac{1}{6} \int_1^2 u^2 du = \frac{1}{6}(\frac{1}{3}u^3 + C \bigg|_1^2)$
#
# **Step 5:** Substitute back: $\frac{1}{6}(\frac{1}{3}(2x^3+4)^3 + C \bigg|_1^2)$
#
# **Step 6:** Plug in the bounds and simplify: $\frac{1}{6}((\frac{1}{3}(2(2)^3+4)^3) - (\frac{1}{3}(2(1)^3+4)^3)) = \frac{1}{6}(\frac{8000}{3} - 72) = \frac{1}{6}(\frac{7784}{3}) = $ $$\boxed{\frac{3892}{9}}$$
#
# </details>

# %% [markdown]
# **Problem 3:**
#
# $\int_1^2 2x(x^2+1)^3dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# u and du
# - $u = x^2+1$
# - $du = 2xdx$ -> 2xdx = du
#
# bounds
# - $u = 2$
# - $u = 5$
#
# solution
# - $\int_2^5 u^3du$
# - $\int u^3du = u^4/4|_2^5$
# - $609/4$
#
# </details>

# %% [markdown]
# **Problem 4:**
#
# u-substitution problem
#
# Example 2: $$\int_{0}^{2} \frac{2x}{x^2+1}  \ dx $$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Choose U = $$\ x^2+1 $$
#
# Step 2: Find du = $$\ 2x \ dx$$
#
# Step 3: Change bounds of Integration:$$\ u = x^2+1 \ $$
#
#
# *   When x = 1 , u = 2
# *   When x = 3 , u = 10
#
# Step 4: Rewrite Integral $$\int_{2}^{10} \frac{1}{u} du \ $$
#
# Step 5:Plug in Bounds $$ \ ln(10)-ln(2)\$$
#
# Step 6: $$\ = ln(5) \$$
#
#
#
# </details>

# %% [markdown]
# **Problem 5:**
#
# *[Create a definite integral problem]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# </details>

# %% [markdown]
# Problem 6:
# find ∫ from 0 to 1 of 6x (x**2 + 1)**2 dx
#
# Solution:
# let u = x**2 + 1
# then du = 2x dx so 3 du = 6x dx
#
# change the bounds:
# when x = 0, u = 0**2 + 1 = 1
# when x = 1, u = 1**2 + 1 = 2
#
# rewrite the integral:
# ∫_0^1 6x (x**2 + 1)**2 dx = ∫_1^2 3 u**2 du
#
# now integrate:
# ∫_1^2 3 u**2 du = 3 * [u**3/3]_1^2 = [u**3]_1^2 = 2**3 - 1**3 = 8 - 1 = 7
#
# final answer: the value of the integral is 7

# %% [markdown]
# **Problem 7:**
#
# $\int_0^1\frac{2x}{(x^2+1)^2}dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** $u=x^2+1$
#             $du=2xdx$
#
# **Step 2:** Change limits
#
# **Upper:** $x=1, u=1^2 +1=2$
#
# **Lower:** $x=0, u=0^2+1=1$
#
# **Step 3:** substitute and integrate
#
# $\int_1^2\frac{1}{u^2}du = \int_1^2 u^{-2} du$
#
# </details>

# %% [markdown]
# **Problem 8:**
#
# $\int_0^2 x(x^2+1) dx$
#
# **Solution:**
# $6$
# <details>
# <summary><b>Click to reveal solution</b></summary>
# $u=x^2+1$, $du=2xdx$= $\frac{1}{2}du=xdx$
#
# Change the Bounds:
#
# -When $x=0$, $u=0^2+1=1$
#
# -When $x=2$, $u=2^2+1=5$
#
# -Integral becomes: $\int_1^5 u(\frac{1}{2}) du$
#
# Integrate:
#
# $\frac{1}{2}\int_1^5 u du= \frac{1}{2}[\frac{u^2}{2}]_1^5=\frac{1}{4} (25-1)=\frac{24}{4}= 6$
# </details>

# %% [markdown]
# **Problem 9:**
#
# $\int_0^2 x(x^2 + 1)^3 dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# Step 1: Choose  $u$: $= x^2 + 1$
#
# Step 2: Find $du$: $= 2x dx => xdx = $$\frac{1}{2}du$
#
# Step 3: Change the limits of integration: $x = 0 => u = 0^2 + 1 = 1, x = 2 => 2^2 +1 = 5$
#
# Step 4: Rewrite it: $\int_1^5 u^3 $$(\frac{1}{2})du$
#
# Step 5: Pull out constant: $\frac{1}{2}$$\int_1^5 u^3 du$
#
# Step 6: Integrate: $\int u^3 du =$ $\frac{u^4}{4}$ => $(\frac{1}{2})$ $[\frac{u^4}{4}]_1^5$ = $\frac{1}{8}$$[u^4]_1^5$
#
# Step 7: Evaluate: $\frac{1}{8}$$(5^4-1^4) =>$ $\frac{1}{8}$$(624-1) =>$$\frac{624}{8} = 78$
#
#
# </details>

# %% [markdown]
# **Problem 10:**
#
# $\int_0^1 x(1+x^2)^4 dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
# 1. u = $1 + x^2$
# 2. du = 2x dx
# 3. x dx = $\frac{1}{2} du$
# 4. Change bounds:
#     - $When x = 0: u = 1 + 0^2 = 1$
#     - $When x = 1: u = 1 + 1^2 = 2$
# 5. Rewrite the integral in terms of u:
#     - $\int_{u = 1}^{u = 2} u^4 (\frac{1}{2} du) = \frac{1}{2} \int_1^2 u^4 du$
# 6. Integrate:
#     - $\frac{1}{2} \int_1^2 u^4 du = \frac{1}{2} (\frac{u^5}{5}) = \frac{1}{2}(\frac{2^5}{5} - \frac{1^5}{5}) = \frac{1}{2}(\frac{32}{5} - \frac{1}{5}) = \frac{1}{2} * \frac{31}{5} = \frac{31}{10}$
# 7. Answer:
#     - $\frac{31}{10}  or  3.1$
# </details>

# %% [markdown]
# **Problem 11:**
#
# *Evaluate the definite integral:*
# $$ \int_{1}^{2} \frac{2x}{x^2+1}\,dx $$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Note:** *Don't forget to change the bounds when you substitute!*
#
#
# **Step 1: Choose the substitution**
#
# Let
# $$ u = x^2 + 1. $$
#
# **Step 2: Compute \(du\)**
#
# Differentiate:
# $$ du = 2x\,dx. $$
#
# That matches the numerator $$ (2x\,dx) $$, so substitution will be straightforward.
#
# **Step 3: Change the bounds**
#
# When $$ (x=1) $$: $$ (u = 1^2 + 1 = 2.) $$
# When $$ (x=2) $$: $$ (u = 2^2 + 1 = 5.) $$
#
# So the definite integral's bounds become $$ (u=2) $$ to $$ (u=5) $$.
#
# **Step 4: Rewrite the integral in \(u\)**
#
# $$ \int_{1}^{2} \frac{2x}{x^2+1}\,dx
# = \int_{2}^{5} \frac{1}{u}\,du. $$
#
# **Step 5: Integrate**
#
# $$ \int_{2}^{5} \frac{1}{u}\,du = [\ln|u|]_{2}^{5} = \ln(5) - \ln(2). $$
#
# **Step 6: Final answer (simplify)**
#
# $$\boxed{\ln\!\left(\tfrac{5}{2}\right)} $$
#
# </details>

# %% [markdown]
# **Problem 12:**
#
# *[Create a definite integral problem]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# </details>

# %% [markdown]
# **Problem 13:**
#
# *$\int_0^2 5x(x^2 + 1)^3 dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** Choose u = $x^2+1$
#
# **Step 2:** Find du = *$2xdx$*
#
# **Step 3:** Change the bounds =
#
# $u(0) = 0^2+1=1$
# $u(2) = 2^2+1=5$
#
# **Step 4:** Rewrite in terms of u =
#
# $\int_1^5 \frac{5}{2}u^3du$
#
# **Step 5:** integrate =
#
# $\frac{5}{2} \frac{u^4}{4}=\frac{5}{8}u^4$
#
# **Step 6:** Evaluate at bounds
#
# $\frac{5}{8}(5)^4 = \frac{5}{8}(625)$
# $\frac{5}{8}(1)^4 = \frac{5}{8}(1)$
# $\frac{5}{8}(625) - \frac{5}{8}(1) = \frac{5}{8}(634) = \frac{3120}{8}$
#
# ** Solution **
# $ = 390$
#
#
# </details>

# %% [markdown]
# **Problem 14:**
#
# *$\int_0^2 \frac{3x}{\frac {3}{2}x^2+2} dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *Do u-sub. u = $\frac{3}{2}x^2+2$, which means du = $3x dx$. The integral is now $\int \frac{1}{u}du$, and when we integrate that we get $ln|u|+C$. Then you sub back u, *$ln|\frac{3}{2}x^2+2|+C$ . Now we plug in upper bound and lower bound and then subtract. $(ln|\frac{3}{2}(2)^2+2|)-(ln|\frac{3}{2}(0)^2+2|)$ Then solve, $ln|8|-ln|2|=ln|4|$ *
#
# </details>

# %% [markdown]
# **Problem 15:**
#
# *[Create a definite integral problem]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# </details>

# %% [markdown]
# **Problem 16:**
#
# *$\int_{0}^{2} x(x^2 + 1)^4 \, dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Step 1: Choose u
#
# $u = x^2 + 1$
#
# Step 2: Find du
#
# We need xdx, so rewrite:
#
# $du = 2x\,dx \quad \Rightarrow \quad x\,dx = \frac{1}{2}du$
#
# Step 3: Change the bounds:
#
# When x = 0:
#
# $u = 0^2 + 1 = 1$
#
# When x = 2:
#
# $u = 2^2 + 1 = 5$
#
# Step 4: Rewrite the integral:
#
# $\int_{0}^{2} x(x^2+1)^4 dx
# = \int_{1}^{5} u^4 \left(\frac{1}{2} du\right)
# = \frac{1}{2} \int_{1}^{5} u^4 du$
#
# Step 5: Integrate
#
# $\frac{1}{2} \left[\frac{u^5}{5}\right]_{1}^{5}$
#
# Step 6: Evaluate at the bounds:
#
# $\frac{1}{2} \left(\frac{5^5}{5} - \frac{1^5}{5}\right)
# = \frac{1}{2} \left(\frac{3125 - 1}{5}\right)
# = \frac{1}{2} \left(\frac{3124}{5}\right)$
#
# Final Answer:
# $\frac{1562}{5}$ = 312.4
# </details>

# %% [markdown]
# **Problem 17:**
#
# *[Evaluate ∫(from 0 to 2) x(x^2 + 1)^3 dx.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Step1: Set u
# u= x^2 + 1
# Step2: calculate du
# du = 2x dx; 1/2du = xdx
# Step3: rewrite limits
# u=2: 4 + 1 = 5
# u=0: 0 + 1 = 1
# Step4: rewrite integral
# ∫(from 1 to 5) (1/2)u^3 du
# Step5: integrate
# ∫(1/2)u^3 du = (1/2)((1/4)u^4) = (1/8)u^4
# Step6: Substitute
# (1/8)5^4 - (1/8)1^4 = 624/8 = 78]*
#
# **Answer:** 78
#
# </details>

# %% [markdown]
# **Problem:**
#
# *$\int_{0}^{3} (2x^3 - 5x + 4)\, dx\$*
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# Integrate
#
# - \(\int 2x^3 dx = 2 \cdot \frac{x^4}{4} = \frac{x^4}{2}\)
# - \(\int -5x dx = -5 \cdot \frac{x^2}{2} = -\frac{5x^2}{2}\)
# - \(\int 4 dx = 4x\)
#
#
# *$\F(x) = \frac{x^4}{2} - \frac{5x^2}{2} + 4x\$*
#
# Step 2:
# *$\(F(3) - F(0)\$*
#
# *$\F(3) = \frac{3^4}{2} - \frac{5 \cdot 3^2}{2} + 4(3)\$*
#
# Compute each part:
#
# - \(3^4 = 81 \Rightarrow \frac{81}{2}\)
# - \(3^2 = 9 \Rightarrow \frac{5 \cdot 9}{2} = \frac{45}{2}\)
# - \(4(3) = 12\)
#
#  combine:
#
# *$\F(3) = \frac{81}{2} - \frac{45}{2} + 12
# = \frac{36}{2} + 12
# = 18 + 12
# = 30\$*
#
# Step 4:
#
# \[
# F(0) = 0 - 0 + 0 = 0
# \]
#
# </details>

# %% [markdown]
# **Problem 18:**
#
# *$\int_1^3 2x\sqrt{x^2 -1}dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** Choose u = *$x^2 - 1$*
#
# **Step 2:** Find du =$ 2xdx$
#
# **Step 3:** Find new bounds,
#
# When $x=1, u=1^2 -1=0$
#
# When $x=3, u=3^2 - 1=8$
#
# **Step 4:** Rewrite the integral: $\int_0^8 \sqrt{u}du$
#
# **Step 5:** Integrate and solve: $\frac{2}{3}u^{\frac{3}{2}}$, $\frac{2}{3}(8)^{\frac{3}{2}} - \frac{2}{3}(0)^{\frac{3}{2}}$
#
# $\frac{2}{3}(8)^{\frac{3}{2}} = \frac{32\sqrt{2}}{3} $
#
# Final Answer: $$ \frac{32\sqrt{2}}{3} $$
#
# </details>

# %% [markdown]
# **Problem 19:**
#
# * $\int_0^2 3x^2 / 1 + x^3 dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# * $u = 1 + x^3$
# * $du = 3x^2 dx$
# * $at x=0 u=1$
# * at x=2 u=9
# * $\int_1^9 1/u du$
# * $[ln u]9 to 1 = ln(9)- ln(1) = ln(9)$
#
# </details>

# %% [markdown]
# **Problem 20:**
#
# int (ub2,lb0) 2x(x**2+1)dx
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
# u=x**2+1
# du+2xdx          when x=0, u=0**2+1=1   when x=2, u=2**2+1=5
# int(ub5,lb1) udu
# int(ub5,lb1) udu=(u**2/2)|(ub5,lb1)
# =(5**2/2)-(1**2-2)=12
# answer=12
#
# </details>

# %% [markdown]
# **Problem 21:**
#
# *[$\int_0^2 2x(x^2 + 4)^2dx $*
#
# **Solution:**
#   448/3
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *Work:
#
#  **Step 1:** Choose u = $x^2+4$
#
#  **Step 2:** Find du = 2xdx
#
#  **Step 3:** Change bounds = $u(0) = 0^2 + 4 = 4, u(2)= 2^2+4 = 8$
#
# **Step 4:** Rewrite the Integral = $\int_0^2 2x(x^2 + 4)^2dx = \int_4^8 u^2du $
#
# **Step 5:** Integrate: $[u^3/3]_4^8$
#
# **Step 6:** Evaluate with new bounds: $8^3/3-4^3/3= 512/2-64/3=448/3$
#
#
# </details>

# %% [markdown]
# **Problem 22:**
#
# *Find $\frac{d}{dx}\int_1^3 (x/x^2 + 1) dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# Let u = x^2 + 1
# du = 2xdx --> xdx = 1/2 du
#
# When x=1, u=1^2 +1 =2.
# When x=3, u=3^2 +1=10
#
# *$\frac{d}{dx}\int_1^3 (x/ x^2 + 1) dx = \frac{d}{dx}\int_(u=2)^(u=10) 1/u(1/2du) = 1/2\frac{}{}\int_2^10 (1/u) du$*
#
# *$ 1/2 \frac{}{}\int_2^10 (1/u) du = 1/2 \frac{}{}\int_2^10 (ln |u|)2 10 du$*
#
# 1/2(ln(10)−ln(2))= 1/2 ln(10/2)=1/2ln(5).
#
# Answer: 1/2 ln(5)
# </details>

# %% [markdown]
# **Problem 23:**
#
# $\int_2^4 (4x+8)4 dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Identify u
#
# *$U= 4x+8$*
#
# Step 2: Solve for du
#
# *$du= 4dx$*
#
# Step 3: Replace
#
# *$\int_2^4 (u) du$*
#
# Step 4: Integrate
#
# *$\int_2^4 \frac{1}{2}(u)^2$*
#
# Step 5: Change bounds to u and solve
#
# *$(4(4)+8) = 24$*
#
# *$(4(2)+8) = 16$*
#
# *$F(b)= \frac{1}{2}(24)^2 = 288$*
#
# *$F(a)= \frac{1}{2}(16)^2 = 128$*
#
# *$288-128 = 160$*
#
# </details>

# %% [markdown]
# **Problem 24:**
#
# $\int_0^1 2x(x^2) dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# u=x^2  ,  du=2xdx  ,  when x=0 u=0^2=0  ,  when x=1 u=1^2=1  ,  $\int_0^1 2x(x^2) dx$=$\int u du$  ,  $\int_0^1 u du$=$[u^2/2]_0^2$=(1^2)/2-(0^2)/2=1/2
#
# </details>

# %% [markdown]
# **Problem 25:**
#
# *$\int_1^3 2x(x^2 + 4)^5 dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:**
# *u = x^2 + 4*
#
# **Step 2:**
# *du = 2xdu so 2xdx = du*
#
# **Step 3:**
# *Change limits, when x=1: $u=1^2+4 = 5$, when x=3: $u=3^2+4 = 13$*
#
# **Step 4:**
# *$\int_1^3 2x(x^2 + 4)^5 dx = \int_5^13 u^5 du$*
#
# **Step 5:**
# *$\int u^5 du = \frac{u^6}{6}$*
#
# **Step 6:**
# *$\frac{u^6}{6} |_5^13 = \frac{13^6}{6} - \frac{5^6}{6}$*
#
# **Step 7:**
# *$\frac{13^6 - 5^6}{6} = 801,864$*
#
# **Step 8:**
# *$\int_1^3 2x(x^2 + 4)^5 dx$ = $\frac{13^6 - 5^6}{6} = 801,864$*
#
# *[Show complete works*
#
# </details>

# %% [markdown]
# **Problem:**
#
# $$ \int_{0}^{2} x e^{x^2} \, dx $$
#
# **Solution**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** Identify $u$, $\int_{0}^{2} x e^{x^2} \, dx$
#
# $$ u=x^2 $$
#
# **Step 2** Find $du$.
#
# $$ du = 2xdx , xdx = \frac{1}{2}du $$
#
# **Step 3:** Rewrite the integral in terms of u:
#
# $$ \int_{0}^{2} x e^{x^2} \ dx = \int_{x=0}^{x=2} e^u \cdot \frac{1}{2} \ du = \frac{1}{2} \int_{x=0}^{x=2} e^u \ du
# \ $$
#
# **Step 3:** Change the limits of integration
#
# $$ \text{When } x = 0, \, u = 0^2 = 0 $$
#
# $$ \text{When } x = 2, \, u = 2^2 = 4 $$
#
# **Thus,** $$ \frac{1}{2} \int_{0}^{4} e^u \ du $$
#
# **Step 4:** Integrate
#
# $$ \frac{1}{2} \int_{0}^{4} e^u \, du = \frac{1}{2} \big( e^u \big)_{0}^{4} $$
#
# **Step 5:** Apply Limits
#
# $$ \frac{1}{2} \big( e^4 - e^0 \big) = \frac{1}{2} ( e^4 - 1 )\ $$
#
# **Final Answer:** $$ \int_{0}^{2} x e^{x^2} \, dx = \frac{1}{2} ( e^4 - 1 ) $$

# %% [markdown]
# ### Sample Problem 2.3b: Definite Integral with U-Substitution
#
# **YOUR TASK:**  integral from 1 to 2 (4x^2-6)^3dx

# %% [markdown]
# **Problem 26:**
#
# *[ integral from 1 to 2 (4x^2-6)^3dx]*
#
# **Solution:*U= 4x^2-6 Du=4x^3/3
# int from 1 to 2 u^3 = U^4/4 =
# [(4x^2-6)^4/4 =
# (4(2)^2-6)/4 - (4(1)^2-6)/4*
# 16-6/4-(4-6)/4))
# 10/4-(-2/4)
# 8/4
# =2
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# </details>

# %% [markdown]
# **Problem 27:**
#
# *[$0-1  6x(x^2+1)^4 dx]*
#
# **Solution:93/5**
#
# <details>
# <summary><b>93/5</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[$3u^4du = 3 * u^5/5  = 3/5u^5
# 3/5u^2 |1-2  = (3/5)(2/5) - 3/5(1^5) 3/5(32)- 3/5 =96/5 - 3/5 = 93/5]*
#
# </details>

# %% [markdown]
# **Problem 28:**
#
# *[lowwer bound 0 upper bound 2 $\int 3x^2(x^3 + 1)^4 dx$] ]*
#
# **Solution:**
# u=x^3+1
# du=3x^2
# x=0 u=0^3 0+1=1
# x=2 u=2^3 8+1=9
# this changes the bounds to lowwer 1 upper 9
# (u)^4 du
# (u^5)/5
# (9^5)/5-(1^5)/5=59048/5
#
#
#
# </details>

# %% [markdown]
# **Problem 29:**
#
# *$\int_0^1 x (x^2 + 1)^3 \, dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Choose $u = x^2 + 1$, then $du = 2x \, dx \implies \frac{1}{2} du = x \, dx$.
# Step 2:Change bounds: $x=0 \implies u=1$, $x=1 \implies u=2$.
# Step 3: Rewrite integral: $\int_0^1 x (x^2 + 1)^3 dx = \frac{1}{2} \int_1^2 u^3 du$.
# Step 4: Integrate: $\frac{1}{2} \cdot \frac{u^4}{4} \Big|_1^2 = \frac{1}{8} (16 - 1)$.
# Step 5: Simplify: $\frac{15}{8}$.
# Answer: $\int_0^1 x (x^2 + 1)^3 dx = \frac{15}{8}$.
#
# </details>

# %% [markdown]
# **Problem 30:**
#
# *[Create a definite integral problem]*
# \int 0^2 4x(2x^2+1)^3dx
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Choose u=2x^2+1
#
# step 2 : finddu = 4xdx
#
# step 3: change the bounds:
#
# when x=0,u 2(0)^2+1=1
# when x+2,u=2(4)+1=9
#
# step 4: retwrite the intergral:
#
# \intx=0^x=2(2x^2+1)^3(4xdx)=\intu=1^u=9 u^3 du
#
# step 5: intergrate:
# \int_1^9 u^3du=[u^4/4]_1^9
#
# step 6: evualte :
# 9^4/4 - 1^4/4 = 6561 / 4 - 1/4 = 6560 = 1640
#
#
# </details>

# %% [markdown]
# **Problem 31:**
#
# *$\frac{d}{dx}\int_0^1 2x(1+x^2)^5 dx$*
#
# **Solution:$\frac {21}{2}$**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# ***Step 1:** Choose u = *$1+x^2$*
#
# **Step 2:** Find du = *$2x$* dx
#
# **Step 3:** Change the limits   When x= 0: u= 1
#                                 When x= 1: u= 2
#
# **Step :** Rewrite the integral: $\int_1^2 u^5 du ...$
#
# **Step :** Integrate: *$\frac {u^6}{6}$*
#
# **Step :** plug in: *$\frac{2^6}{6}-\frac{1^6}{6}$*
#
#
#
# </details>

# %% [markdown]
# **Problem 32:**
#
# *[$$\int_0^2 x(2x^ + 1) dx$$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[ Step 1: let u = $2x^ + 1$*
#
# Step 2. find du= $2x dx$
#
# Step 3. solve for x dx = $\frac{1}{2}du$
#
# Step 4. when x = 0\, $ u =0^2+1 =1$ and when x = 2\, $ u= 2^2+1 =5 $ the new integral goes from 1 to 5.
#
# Step 5. $\int_1^5 u(\frac{1}{2})du,$ factor the constant out,$ =\frac{1}{2}\int_1^5 u du $
#
# Step 6. Intergrate $ \int u du = \frac{u^2}{2} \, (\frac{1}{2})(\frac{u^2}{2})= \frac{u^2}{4} $
#
# Step 7. evaluate at the bounds, 1 and 5.$ \frac{u^2}{4} \frac{5^2}{4}= \frac{25}{4}$ and $ \frac{1^2}{4}= \frac{1}{4} $
#
# Step 8. Now subtract these two bounds. $ \frac{25}{4} - \frac{1}{4} = \frac{24}{4} = 6 $
#
# </details>

# %% [markdown]
# **Problem 33:**
#
# Find $ \int_0^1 \frac {x}{x^2+1}dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# - u = $x^2+1$
# - du = 2x dx -> $\frac{1}{2}du = xdx$
# - bounds: $ x=0 -> (0)^2+1 = 1; x=1 -> (1)^2+1=2$
# - $\int_1^2 \frac{1}{2} \frac{1}{u}du$
# - $ \frac{1}{2} lnu |_1^2$
# - $\frac {1}{2} [ln 2 -ln 1] $
# - $\frac {1}{2} ln 2 $
#
#
#
# </details>

# %% [markdown]
# **Problem 34:**
#
# *$$ \int_0^1 x(x^2 + 1)^3 (dx)$$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *$$u = x^2 + 1$$* *$$du = 2x (dx)$$* *$$ (1/2du) = x(dx)$$*
# Change bounds: when x=0 *$$u = 0^2 + 1 = 1$$* when x=1 *$$u = 1^2 + 1 = 2$$*
#
# *$$\int_0^1 x(x^2 + 1)^3$$* *$$=$$* *$$\int_1^2 u^3 (1/2(du))$$*
# *$$=$$* *$$ 1/2 \int u^3 (du)$$*
# integrate: \int u^3 (du) *$$=$$* *$$u^4/4$$*
# *$$=$$* *$$1/8(2^4-1^4) = 1/8(16-1)= 15/8$$*
#
# </details>

# %% [markdown]
# **Problem 35:**
#
# *$\int_0^5 (4x+1)^2dx$*
#
# **Solution:**
#
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
#
#
# Step 1: Find $u=4x+1$
#
# Step 2: $du=4dx$
#
# Step 3: Change the bounds into terms of u by plugging each bound into the equation for u. Lower bound: $4(0)+1=1$. Upper bound: $4(5)+1=21$.
#
# Step 4: Substitute back in: $\frac{1}{4}$$\int_{1}^{21}(u)^2du$.
#
# Step 5: Integrate: $\frac{1}{4}(\frac{u^{2+1}}{2+1})=\frac{1}{12}u^3$
#
# Step 6: Evaluate with the bounds: $\frac{1}{12}(21)^3-\frac{1}{12}(1)^3=\frac{(9261-1)}{12}=\frac{2315}{3}$
#
#
#
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[$\int_0^2 x(x^2+1)^3 dx]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[1. u= x^2+1
# 2. du=2xdx -> 1/2du=xdx
# 3. $\int_1^5 u^3 x 1/2du=1/2$\int_1^5 u^3 du
# 4. 1/2 $\int u^3du= 1/2 x u^4/4= u^4/8]*
# answer: 78
#
# </details>

# %% [markdown]
# **Problem 36:**
#
# $\int_0^1 xe^x^2 dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# Substitute: $\int_0^1 xe^x^2 dx$ = $\int_0^4 e^u * 1/2 du$
#
# = 1/2(e-1)
#
# </details>

# %% [markdown]
# **Problem 37:**
#
# Compute the definite integral
# $\displaystyle \int_0^1 x e^{x^2} \, dx$
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1: Choose $u$**
#
# Let $u = x^2$
#
#
# **Step 2: Find $du$**
#
# $$
# du = 2x \, dx \quad \Rightarrow \quad x \, dx = \frac{1}{2} du
# $$
#
#
# **Step 3: Change the bounds**
#
# - When $x = 0$, $u = 0^2 = 0$
# - When $x = 1$, $u = 1^2 = 1$
#
#
# **Step 4: Rewrite the integral in terms of $u$**
#
# $$
# \int_0^1 x e^{x^2} \, dx = \int_0^1 e^u \cdot \frac{1}{2} du = \frac{1}{2} \int_0^1 e^u \, du
# $$
#
#
# **Step 5: Integrate**
#
# $$
# \frac{1}{2} \int_0^1 e^u \, du = \frac{1}{2} \left[ e^u \right]_0^1 = \frac{1}{2} (e^1 - e^0) = \frac{1}{2} (e - 1)
# $$
#
#
# **Answer:** $\displaystyle \frac{e - 1}{2}$
#
# </details>

# %% [markdown]
# **Problem 38:**
#
# $\int_0^2x(1+x^2)^4 \,dx$
#
# **Solution:**
# $\frac{1562}{5}$
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# **Step 1:** Choose $u = 1+x^2$
#
# **Step 2:** Find $du = 2x dx$
#
# **Step 3:** Change limits: Plug in x = 0 and x = 2 into u-sub to get new limits: 1 and 5.
#
# **Step 4:** Rewrite integral: $\frac{1}{2}\int_1^5u^4 du$
#
# **Step 5:** Integrate: $\frac{1}{2}[\frac{u^5}{5}]$ from 1 to 5
#
# **Step 6:** Plug In: $\frac{1}{2}(\frac{3121}{5}-\frac{1}{5}) = \frac{3124}{10}$
#
# **Final Calculation:** $\frac{1562}{5}$
#
# </details>

# %% [markdown]
# **Problem 39:**
#
# *$ \int_0^2 4x(x^2+1)^3 dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# **Step 1:** Choose u = $x^2+1$
#
# **Step 2:** Find du = $2x$ dx
#
#                 4x du= 2 du
# **Step 3:** Change the limits
#
#     x=0 , u= 0^2+1 =1
#
#     x=2 , u= 2^2+1 =5
#
# New bounds: u = 1, 5
#
# **Step 4:** Rewrite the integral: $2\int_1^5 u^3$ du
#
# **Step 5:** Integrate: (2) $\frac{u^4}{4}$ evaluated at u= 1, 5
#
# $\frac{1}{2}(5^4-1^4)$
#
# **Step 6:** Solve: *$\frac{1}{2}(625-1)$= $\frac{624}{2}$= 312*
#
# **Final answer: 312**
#
# </details>

# %% [markdown]
# **Problem 40:**
#
# *$\int_1^2 2x(x^2 + 1)^3 dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *first we start by finding the U to sub. $u = x^2 +1$ and $du = 2x dx$. Then we use our u sub function to change our bounds of integration by plugging in our bounds to our u function and find our new bounds are 2 and 5. then we continue our integral like normal and get $(u)^4/4$ and plug in our new bounds to get $(5)^4/4 - (2)^4/4$ which we can then simplify to 152.25*
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[\int_1^3 x(x**2+4)**2 dx]*
#
# **Solution:**
#
# **1036/3**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[u=x**2+4]*
# *[du=2xdx]*
# *[du/2=x dx]*
# *[when x=1, u=5]*
# *[when x=3, u=13]*
# *[\int_5^13 u^2 du/2]*
# *[1/2\int_5^13 u^2 du]*
# *[1036/3]*
#
# </details>

# %% [markdown]
# **Problem 41:**
#
# $F(x) = \int_0^2 x^2 e^{x^3} dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# $u=x^3 \hspace{0.5cm} du=3x^2dx$
#
# $\frac{du}{3x^2}=dx$
#
# $u=(0)^3, u=(2)^3 \hspace{0.3cm} => \hspace{0.3cm} u=0, u=8$
#
# $\int_0^8 x^2 e^u \frac{du}{3x^2}$
#
# $= \frac{1}{3}\int_0^8 e^u du$
#
# $= \frac{1}{3}e^u|_0^8$
#
# $= \frac{1}{3}(e^8-e^0)$
#
# $= \frac{1}{3}(e^8-1)$
#
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Create a definite integral problem]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# </details>

# %% [markdown]
# **Problem 42:**
#
# *[$\int 2x(x^2 +1)^3 dx] bounded by [0,1] ]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[u=x^2 +1
#   du= 2xdx
#   when x=0: u=0^2 +1 =1
#   when x=1: u=1^2 +1 =2
#   so bounds become [1,2]
#   $\int u^3 du = (u^4)/4 = ((2)^4)/4 - ((1)^4)/4 = 4 - 0.25 = 3.75]*
#
# </details>

# %% [markdown]
# ### Sample Problem 2.3b: Definite Integral with U-Substitution

# %% [markdown]
# $\int_0^1 2x(x^2+3)^5 dx$
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $u=x^2+3$, $du=2xdx$
#
# =$\int u^5 du$
#
#     Change Bounds => x = 0 → u = 0² + 3 = 3, x = 1 → u = 1² + 3 = 4
#
# =$\int_3^4 u^5 du$
#
# Integrate:
#
# =$[\frac{u^6}{6}]_3^4$ = $(\frac{4096}{6}-\frac{729}{6})$
#
# Solution:
#
# =$\frac{3367}{6}$
#
# </details>

# %% [markdown]
# **Problem 43:**
#
# *[$\int_04 8x e^x^2 dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[1. choose our u: $u = x^2$
#   2. find our du: $du = 2xdx$
#   3. We have to rewrite: $8x dx = 4(2xdx) = 4 du$
#   4. Change our bounds before our substitution: $x = 0 -> u = 0^2 = 0 , x = 4 -> u = 4^2 = 16$.
#   5. integrate into a simple form: $\int 4 e^u du = 4e^u$
#   6. apply the limits: $4e^u |016]
#   7. final answer: $4( e^16 - 1)$*
#
# </details>

# %% [markdown]
# **Problem 44:**
#
# *[integral from 0 to 2 (2x + 3)^5 * 2 dx]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[u = 2x +3
# du = 2dx
#
# change limits when x = 0 u = 2(0) + 3 = 3 and when x = 2 u = 2(2) + 3 = 7 making the new bounds 2 and 7.
#
# rewrite the integral in forms of u = 3 to 7 integral of u^5 du
#
# Integrate = u^6/6 and then apply bounds
# 7^6/6 - 3^6/6 ]*
#
# *[7^6-3^6/6]*
#
# </details>

# %% [markdown]
# **Problem 45:**
#
# *[ $\int 4x(x^2+1)^3)$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[u=x^2+1, du=2xdx, 2du=4xdx  $\int 2(u)^3du $]*
#
# *[2$\int (u)^3)du$ $1/2(x^2+1)^4$  ]*
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[$\int_{1}^2 2x/(1+x^2)^3dx$]*
#
# **Solution:21/200**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Find $u$ and $du$ $u= 1+x^2$ and $du= 2x$. The bounds change $\int_{2}^5 1/(u)^3 du$ because when plugging in the bounds into $u=1+x^2$ these are the values we get for the new bound: $u=1+1^2=2$ and $u=1+2^2=5$.
# Rewrite the integral and solve: $\int_2^5 u^{-3} du = (u^{-2})/-2 = -1/2u^2$. Then evaluate from bounds 2 to 5: $-1/2(5)^2 + 1/2(2)^2 = -1/50 +1/8 = -4/200 + 25/200 = 21/200 $]*
#
# </details>

# %% [markdown]
# **Problem 46:**
#
# *[Create a definite integral problem]*
# import sympy as sp
# x= sp, symbols ('x')
# sp.integrate(6*x*(3*x**2 + 4)**5, (x, 0
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# </details>

# %% [markdown]
# **Problem:**
#
# (0,2)∫3x^2((x^3)-6)^6 dx
#
# **Solution:**
# 280064/7
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# u=((x^3)-6), du= 3x^2 dx
# Change bounds: x=0 u=((0^3)-6; u=-6
# x=2 u=((2^3)-6; u=2 --> new bounds: (-6,2)
# Definite integral: (-6,2)∫u^6 dx= (u^7)/7 |(-6,2)
# Compute: (2^7)/7 - (-6^7)/7= 128/7+ 279936/7= 280064/7
# Final Answer: 280064/7

# %% [markdown]
# **Problem 47:**
#
# *[Create a definite integral problem]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# </details>

# %% [markdown]
# **Problem 48:**
#
# $$\int_0^2 4x \sqrt{x^2 +5}dx$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# - $u= x^2 +5$
# - du = 2x
# - new bounds when $x = 0: u = 0^2 + 5 = 5$, when $x = 2u = 2^2 + 5 = 14$
# - $$ \int_0^2 4x \sqrt{x^2 +5}dx = \int_5^9 4x \sqrt{u} du/2x = 2 \int_5^9 \sqrt{u} du = 2[3/2 (u)^3/2]_5^9 = 3[(9)^3/2)] - [(5)^3/2] = 81- 15 \sqrt{5}$$
#
# </details>

# %% [markdown]
# **Problem 49:**
#
# *[Create a definite integral problem]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# </details>

# %% [markdown]
# **Problem 50:**
#
# *[Evaluate the definite integral using $u$-substitution:
# $\displaystyle \int_{0}^{2} 2x(x^2 + 1)^3 \, dx$.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[
# **Step 1: Choose $u$**
#
# Let
# $u = x^2 + 1$.
#
# Then
# $du = 2x\,dx$.
#
# Notice that $2x\,dx$ is in the integral.
#
# **Step 2: Change the bounds**
#
# When $x = 0$:
# $u = 0^2 + 1 = 1$.
#
# When $x = 2$:
# $u = 2^2 + 1 = 5$.
#
# So the new bounds are from $u = 1$ to $u = 5$.
#
# **Step 3: Rewrite the integral in terms of $u$**
#
# $\displaystyle \int_{0}^{2} 2x(x^2 + 1)^3 \, dx
# = \int_{1}^{5} u^3 \, du.$
# ]*
#
# *[**Step 4: Integrate**
#
# $\displaystyle \int u^3 \, du = \frac{u^4}{4}.$
#
# So
# $\displaystyle \int_{1}^{5} u^3 \, du = \left.\frac{u^4}{4}\right|_{1}^{5}.$
#
# **Step 5: Evaluate at the new bounds**
#
# $\displaystyle \left.\frac{u^4}{4}\right|_{1}^{5}
# = \frac{5^4}{4} - \frac{1^4}{4}
# = \frac{625}{4} - \frac{1}{4}
# = \frac{624}{4}
# = 156.$
#
# **Answer:** $156$]*
#
# </details>

# %% [markdown]
# **Problem 51:**
#
# [$\int_0^2 x(5x^2 + 1)^3 , dx$]
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[tep 1: Choose $u = 5x^2 + 1$
#
# Step 2: Find $du = 10x,dx$
# So $x,dx = \frac{1}{10}du$
#
# Step 3: Change the bounds:
# When $x = 0$, $u = 1$
# When $x = 2$, $u = 5(4) + 1 = 21$
#
# Step 4: Rewrite the integral:
# $\int_0^2 x(5x^2 + 1)^3 dx = \frac{1}{10}\int_{1}^{21} u^3 , du$
#
# Step 5: Integrate:
# $\frac{1}{10}\cdot \frac{u^4}{4} = \frac{u^4}{40}$
#
# Step 6: Evaluate using new bounds:
# $\frac{21^4}{40} - \frac{1^4}{40}$]*
#
# Final Answer:
# $\frac{21^4 - 1}{40}$
#
# </details>

# %% [markdown]
# **Problem 52:**
#
# *[∫
# 0
# 2
# 	​x(x^2+1)^4dx.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[u = x**2 + 1]
# [dx = du / (2*x)]*
#
# ∫ x*(x**2 + 1)**4 dx
# = ∫ x * u**4 * (du / (2*x))
#
# *[F(2) = (1/10)*(2**2 + 1)**5
# F(0) = (1/10)*(0**2 + 1)**5]*
#
# * answer = (1/10)*(5**5 - 1**5) *
#
# </details>

# %% [markdown]
# **Problem 53:**
#
# *[Create a definite integral problem]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# </details>

# %% [markdown]
# **Problem 54:**
#
# *[$\int_0^2 3x^2(x^3 + 5)^2 dx$]*
#
# **Solution:** [2072/3]
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[First we find the u(x^3+5) and du(3x^2). Next, you put u and du together in one integral. After that, we find the antiderivative of u^2 du, which gives us u^3/3 + C. Then we sub in the upper(2) and lower bounds(0) for x, which gets us u=5 and u=13, which would be our new bounds. Then you simply plug them into u^3/3 and minus the lower bound from the upper bound to get the final answer, which is 2072/3 ]*
#
# *[$\int 3x^2(x^3 + 5)^2 dx$]*
# *[$ u = x^3 +5 , du = 3x^2 dx$]*
# *[$\int u^2 du = u^3/3 +C$]*
# *[$ x=0: 0^3 + 5 = 5 , x=2: 2^3 + 5 = 13$]*
# *[$ u^3/3$]* from bounds *[$5 to 13$]*
# *[$13^3/3 - 5^3/3 = 2197/3 - 125/3 = 2072/3$]*
#
# </details>

# %% [markdown]
# **Problem 55:**
#
# $$\int_0^2 6x(3x^2+4)^1dx$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:**
# Choose your u
# - Let u = $3x^2+4$
#
# **Step 2:**
# Find du
# - du is the derivative of u, so it would be: $du= 6xdx$
#
# **Step 3:**
# Plug in the limits to find the new limits
#
# Plug in the lower limit (x=0) into the original expression:
# $$3(0)^2+4 = 4$$
#
# Plug in the upper limit (x=2) into the original expression:
# $$3(2)^2+4 = 16$$
#
# **Step 4:**
# Find the new integral and integrate
# - the new integral would be:
# $$\int_4^{16} u^1du$$
#
# - But then you need to integrate it so it would be:
# $$\int_4^{16} \frac{u^2}{2}$$
#
# **Step 5:**
# Apply the FTC and simplify
# $$\frac{16^2}{2} - \frac{4^2}{2}$$
# $$16^2 = 256$$
# $$4^2=16$$
# $$\frac{256}{2} - \frac{16}{2}$$
# $$128 - 8 = 120$$
# </details>

# %% [markdown]
# **Problem 56:**
#
# $\int_{0}^{2} x(x^2 + 1)^4 \, dx$
#
# **Solution:**
#
# u = $x^2$ + 1
#
# du = 2xdx
#
# xdx = $\frac{1}{2}$ du
#
# x = 0
# u = $0^2$ + 1 = 1
# x = 2
# u = $2^2$ + 1 = 5
#
# $\int_{0}^{2} x(x^2+1)^4 dx = \int_{1}^{5} u^4 \left(\tfrac{1}{2}\,du\right)
# = \tfrac{1}{2} \int_{1}^{5} u^4 \, du$
#
#
# $\int u^4 \, du = \frac{u^5}{5}$
#
# $\frac{1}{2} \cdot \frac{u^5}{5} = \frac{u^5}{10}$
#
# $\left. \frac{u^5}{10} \right|_{1}^{5}
# = \frac{5^5}{10} - \frac{1^5}{10}
# = \frac{3125}{10} - \frac{1}{10}
# = \frac{3124}{10}$
#
# Answer: $\frac{3124}{10}$
#
#
#
#
#
#
# </details>

# %% [markdown]
# **Problem 57:**
#
# *[ \int_0^2 2x(x^2 +1)^2 dx$$]*
#
# **Solution:** 124/3
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[1. Let u = x^2 + 1
# 2. Find du. du = 2x dx
# 3. Change the bounds. When x = 0: u = 1, when x = 2, u = 5
# 4. Substitute with new bounds. \int_1^5 u^2 du ]
# 5. Integrate. = u^3/3
# 6. Evaluate at bounds [1,5] = (5^3/3 - 1^3/3 = 124/3)*
#
# </details>

# %% [markdown]
# **Problem 58:**
#
# *[Compute the definite integral $\displaystyle \int_{0}^{1} (4x^3)(x^4 + 5)^{100}\,dx$.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# **Step 1:** Choose a substitution
#
# *[$u = x^4 + 5$]*
#
# Then
#
# *[$\displaystyle \frac{du}{dx} = 4x^3 \quad\Rightarrow\quad du = 4x^3\,dx$]*
#
# So
#
# *[$4x^3\,dx = du$]*
#
# **Step 2:** Change the bounds
#
# Original bounds are in terms of $x$:
#
# - When $x = 0$: *[$u = 0^4 + 5 = 5$]*
# - When $x = 1$: *[$u = 1^4 + 5 = 6$]*
#
# So the new bounds are from *[$u = 5$]* to *[$u = 6$]*.
#
# **Step 3:** Rewrite the integral in terms of $u$
#
# *[$\displaystyle \int_{0}^{1} (4x^3)(x^4 + 5)^{100}\,dx
# = \int_{5}^{6} u^{100}\,du$]*
#
# **Step 4:** Integrate and evaluate
#
# *[$\displaystyle \int_{5}^{6} u^{100}\,du
# = \left.\frac{u^{101}}{101}\right|_{5}^{6}
# = \frac{6^{101} - 5^{101}}{101}$]*
#
# **Answer:** *[$\displaystyle \frac{6^{101} - 5^{101}}{101}$]*
#
# *[Show complete work]*
#
# </details>

# %% [markdown]
# **Problem 59:**
#
# *[\int_{0}^{1}5x(2x^2+3)^4\dx]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[When \(x=0\):\(u=2(0)^2+3=3\)
# When \(x=1\):\(u=2(1)^2+3=5\)]
# \[
# \int_{0}^{1} 5x (2x^2 + 3)^4 \, dx = \int_{3}^{5} 5x \cdot u^4 \cdot \frac{du}{4x} = \int_{3}^{5} \frac{5}{4} u^4 \, du
# \]
# \[
# \int_{3}^{5} \frac{5}{4} u^4 \, du = \frac{5}{4} \cdot \frac{u^5}{5} \Big|_{3}^{5} = \frac{1}{4} \left(u^5 \Big|_{3}^{5}\right)
# \]
#
# \[
# = \frac{1}{4} (5^5 - 3^5) = \frac{1}{4} (3125 - 243) = \frac{2882}{4} = 720.5
# \]
# \[
# \boxed{720.5}
# \]*
#
# </details>

# %% [markdown]
# **Problem 60:**
#
# *$\int_2^0 x(x^2+1)^3 dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** Choose $u = x^2+1$
#
# **Step 2:** Find $du = 2x dx$ so $\frac{1}{2}du = x dx$
#
# **Step 3:** Change the bounds: $u=0^2+1=1$ and $u=2^2+1=5$
#
# **Step 3:** Rewrite the integral: $\frac{1}{2}\int_1^5 u^3 du$
#
# **Step 4:** Integrate: *$\frac{1}{2}*\frac{u^4}{4}\ + C$* which equals $\frac{u^4}{8}$
#
# **Step 5:** Evaluate: *$\frac{(5)^5}{8} - \frac{(1)^5}{8}$*
#
# $\frac{625}{8} - \frac{1}{8}$ $=$ $\frac{624}{8}$ $=$ $78$
#
# </details>

# %% [markdown]
# **Problem 61:**
#
# *[$\int_0^2 x(x^2+1)^4 dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** [$u=x^2+1$]*
#
# **Step 2:** [$du=2xdx, xdx=(1/2)du$]
#
# **Step 3:** [$x=0: u=(0)^2+1=1$ $x=2: u=(2)^2+1=5$]
#
# **Step 4:** [$\int_1^5 u^4 (1/2)du= (1/2)\int_1^5 u^4du$]
#
# **Step 5:** [$(1/2)((u^3)/5)=((u^5)/10)$]
#
# **Step 6:** [$((u^5)/10)_1^5 = ((5^5)/10)-((1^5)/10)= 312.4$]
#
# </details>

# %% [markdown]
# **Problem 62:**
#
# *$\int_0^1 x(x^2 + 1)^2 dx$*
#
# **Solution: 7/6**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Step 1 is to choose u= x^2+1, Then compute du which is du=2xdx then xdx=1/2du
# Step 2 is to change the bonds when x=0 $u=0^2+1= 1$, then when x=1 $u=1^2+1 =2$
# The integral becomes $\int_0^1 x(x^2 + 1)^2 dx$ = $\int_0^1 u^2 du$
# Step 3 is to integrate 1/2 $\int_0^1 u^2 du$= 1/2 $u^3/3$  at |$1^2$ ...
# That would get you to the final answer of 7/6
# ]*
#
# </details>

# %% [markdown]
# **Problem 63: Compute the definite integral:
#
# $$
# \int_{0}^{1} 2x \sqrt{x^2 + 1}\,dx
# $$
# **
#
#
#
# **Solution: $$
# \frac{2}{3} (2\sqrt{2} - 1)
# $$**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Step 1: Choose u
#
# Let
# $$
# u = x^2 + 1
# $$
#
# Step 2: Find du
#
# $$
# du = 2x\,dx
# $$
#
# The $2x\,dx$ in the integral matches $du$ exactly.
#
# Step 3: Change the bounds
#
# When $x = 0$,
# $$
# u = 0^2 + 1 = 1
# $$
#
# When $x = 1$,
# $$
# u = 1^2 + 1 = 2
# $$
#
# Step 4: Rewrite the integral with new bounds
#
# $$
# \int_{x=0}^{x=1} 2x \sqrt{x^2 + 1}\,dx = \int_{u=1}^{u=2} \sqrt{u}\,du
# $$
#
# Step 5: Integrate
#
# $$
# \int \sqrt{u}\,du = \int u^{1/2}\,du = \frac{2}{3} u^{3/2}
# $$
#
# Evaluate from $u=1$ to $u=2$:
#
# $$
# \frac{2}{3} (2)^{3/2} - \frac{2}{3} (1)^{3/2} = \frac{2}{3} (2\sqrt{2} - 1)
# $$
# *
#
# </details>

# %% [markdown]
# **Problem:**
#
# *∫ lower 0 upper 1 x(x^2 + 1)^3 dx*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# **Step 1:** Choose u = *(x^2+1)*
#
# **Step 2:** Find du = *2x* dx
#
# **Step 3:** Solve for x dx: 1/2 du
#
# **Step 4:** Change the limits of integration: u lower = (0)^2 + 1 = 1, u upper = (1)^2 + 1 = 2
#
# **Step 5:** Substitute back: *∫ lower 1 upper 2 (u^3)1/2 du*
#
# **Step 6:** Integrate with respect to u: 1/2 (u^4)/4
#
# **Step 7:** Use FTC part two to evaluate: 1/2 [((2)^4)/4 - ((1)^4)/4]
#
# **Step 8:** Solve: 1/2(16/4 - 1/4) = 15/8
#
# </details>

# %% [markdown]
# **Problem:**
#
# *∫0^2 3x(1+x^2)^4 dx*
#
# **937.2:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Step 1: Choose a substitution
# Let
# u = 1 + x^2
# du = 2x dx
#
# We have 3x dx in the integral, so rewrite:
# 3x dx = (3/2)(2x dx) = (3/2) du
#
# Step 2: Change the bounds
# x = 0 → u = 1 + 0^2 = 1
# x = 2 → u = 1 + 2^2 = 5
#
# Step 3: Rewrite the integral in terms of u
# ∫_0^2 3x(1 + x^2)^4 dx
# = ∫_1^5 (3/2)u^4 du
#
# Step 4: Integrate
# (3/2) ∫ u^4 du
# = (3/2) * (u^5 / 5)
#
# Step 5: Evaluate at new bounds
# (3/10)[u^5]_1^5
# = (3/10)(5^5 - 1^5)
#
# Step 6: Final answer
# (3/10)(3125 - 1)
# = (3/10)(3124)
# = 937.2*
#
# </details>

# %% [markdown]
# **Problem 64:**
#
# *[$\int_1^2 4x(x^2+8)dx$ evalute using u substitution ]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Step 1: inner function $u = x^2 +8$ so $du =2xdx$, we have 4x so rewrite as $2(2xdx)= 2du$
# Step 2: Change our limits $u= 1^2 +8 = $ and $2^2 +9 = 12$, so the integral is $\int_9^12 2udu$
# Step 3: Integrate $\int 2udu= 2 * u^2 / 2 = u^2$
# Step 4: Apply our limits $12^2 - 9^2 = 63$]*
#
# </details>

# %% [markdown]
# **Problem 65:**
#
# $\int_1^4 2x(x^2 + 1)^5 dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $\int_1^4 2x(x^2 + 1)^5 dx = \int_1^4 u^5 du = (u^6)/6|(1)(4) = ((x^2 +1)^6)/6|(1)(4) = ((4^2 +1)^6)/6 - ((1^2 +1)^6)/6 = (17^6)/6 - (2^6)/6 = 4022917.5$
#
# $u = x^2 +1$
#
# $du = 2x dx$
#
# </details>

# %% [markdown]
# **Problem 66:**
#
# $\int_0^2 2x(x^2+1) dx$
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# u=$x^2+1$
# du=2xdx
#
# x=0
# u=$0^2+1=1$
#
# x=2
# u=$2^2+1=5$
#
# $\int_0^2 2x(x^2+1) dx$= $\int_1^5 u du$
#
# =$u^2/2|_1^5$
#
# =$5^2/2$-$1^2/2$
#
# =25/2-1/2
#
# =24/2
#
# =12

# %% [markdown]
# **Problem 67:**
#
# *[$\int1^3 2x(x^2 +4)dx
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[u = x^2 +4 , du = 2xdx, x=1 u=1^2 +4=5 , x=3 u=3^2 +4 = 13 , bounds are changed to 5 to 13,   rewrite $/int5^13 udu$ udu= u^2/2 , plug in , 13^2/2 - 5^2/2 , final answer 144/2 = 72 ]*
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[INT 0-1 3x^2e^(x^3)dx]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[u=x^3, du = 3x^2dx = INT 1-0 3x^2e^x^3dx=INT 1-0e^udu = [e^u]1-0 = e^1-e^0 = e-1]*
#
# </details>

# %% [markdown]
# **Problem 68:**
#
# *[$\int_ 1^2 2x(x^2+1)^3dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[$u=x^2+1$ , $du=2xdx$]*
#
# *[$2^2+1=5$ , $1^2+1=2$]*
#
# *[$\int_ 2^5 u^3du$]*
#
# *[The integral is: $\frac {u^4}{4}$]*
#
# *[$(\frac {5^4}{4}) - (\frac {2^4}{4})$]*
#
# **Answer:** *[152.25]*
#
# </details>

# %% [markdown]
# **Problem 69:**
#
# *[Create a definite integral problem]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# </details>

# %% [markdown]
# **Problem 70:**
#
# $\int_0^1 4x(x^2+1)^3 dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# u= x^2-1
# du= 2xdx
#
# 4xdx= 2(2xdx)= 2du
#
# $\int_1^2 2u^3du$
#
# = 2 x u^4/4= u^4/2
#
# = 15/2
#
# </details>

# %% [markdown]
# **Problem 71:** \int_1^3 (2x)(x^2 +5) dx$$
#
# *[Create a definite integral problem]*
#
# **Solution:** 80
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# \int_0^4 (x^2 +2) dx$$
# 1. u = x^2 +5
# 2. du = 2xdu
# 3. x= 1 --> u = 1^2 +5 = 6, x=3 --> 3^3 +5 = 15
# 4. \int_6^14 u du$$ --> u^2 /2
# 5. (14^2 - 6^2) /2 --> (196 -36)/2 = 160/2 = 80
#
#
# </details>

# %% [markdown]
# $$_  \ \int_0^1 2x(x^2+1)^3 dx$$
# **Solution:**
#
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
#
# *[Don't forget to change the bounds when you substitute!]*
#
#
# u=x^2+1
#
# du=2xdx
#
# X=0    0+1=1    (lower x=1)
#
# x=1    1+1=2    (upper x=2)
# $$_  \ \int_1^2 u^3 du$$
# (u^4)/4
#
# (2^4)/4 -(1^4)/4
# 16/4 - 1/4 =
#
# 15/4
#
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Create a definite integral problem]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# </details>

# %% [markdown]
# **Problem 72:**
#
# Evaluate the definite integral:
# $\int_{0}^{3} x\sqrt{x^2 + 1}\, dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Choose \(u = \*\;x^2 + 1\;\*\)
#
# Step 2: Find \(du = \*\;2x\,dx\;\*\)
#
# So,
# $x\,dx = \frac{1}{2}\,du$
#
# Step 3: Change the bounds.
# Using \(u = x^2 + 1\):
#
# When \(x = 0\): \(u = 1\)
# When \(x = 3\): \(u = 10\)
#
# Rewrite the integral:
# $\int_{0}^{3} x\sqrt{x^2 + 1}\, dx
# = \int_{1}^{10} \sqrt{u}\left(\frac{1}{2}\,du\right)
# = \frac{1}{2} \int_{1}^{10} u^{1/2}\,du$
#
# Step 4: Integrate:
# $\frac{1}{2} \left[\frac{2}{3}u^{3/2}\right]_{1}^{10}
# = \frac{1}{3}\left(u^{3/2}\right)_{1}^{10}$
#
# Step 5: Evaluate at the bounds:
#
# Compute:
# $\(10^{3/2} = (\sqrt{10})^{3} = 10\sqrt{10}\)$
# $\(1^{3/2} = 1\)$
#
# So the value is:
#
# $\frac{1}{3}\left(10\sqrt{10} - 1\right)$
#
# </details>

# %% [markdown]
# **Problem 73:**
#
# *$$\int_{0}^{1} x(x^2 + 1)^4 \, dx$$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $u = x^2 + 1$
# $$  du = 2x \, dx$$
# $$\frac{1}{2} du = x \, dx$$
# - New Lower Limit ($u_a$):
# When $x = 0$: $u = (0)^2 + 1 = \mathbf{1}$
# - New Upper Limit ($u_b$):
# When $x = 1$: $u = (1)^2 + 1 = \mathbf{2}$
# $$\quad \int_{1}^{2} u^4 \cdot \frac{1}{2} du$$
# $$= \frac{1}{2} \left[ \frac{u^5}{5} \right]_{1}^{2}$$
# $$= \frac{1}{2} \left( \frac{(2)^5}{5} - \frac{(1)^5}{5} \right)$$$$= \frac{1}{2} \left( \frac{32}{5} - \frac{1}{5} \right)$$$$= \frac{1}{2} \left( \frac{31}{5} \right)$$$$= \mathbf{\frac{31}{10}} \quad \text{or} \quad \mathbf{3.1}$$
#
# </details>

# %% [markdown]
# **Problem:**
#
# Evaluate the definite integral
# $\displaystyle \int_{1}^{3} 8x(x^{2}+4), dx$
#
# **Solution:**
#
# <details> <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Choose the substitution
# Let
# $\displaystyle u = x^{2} + 4$
#
# Then
# $\displaystyle du = 2x, dx \quad \Rightarrow \quad 4,du = 8x,dx$
#
# Step 2: Change the bounds
# When $x = 1$:
# $\displaystyle u = 1^{2} + 4 = 5$
#
# When $x = 3$:
# $\displaystyle u = 3^{2} + 4 = 13$
#
# Step 3: Rewrite the integral
# $\displaystyle \int_{1}^{3} 8x(x^{2}+4), dx
# = \int_{5}^{13} 4u, du$
#
# Step 4: Integrate
# $\displaystyle \int 4u, du = 4\left(\frac{u^{2}}{2}\right) = 2u^{2}$
#
# Step 5: Evaluate from 5 to 13
# $\displaystyle 2(13^{2}) - 2(5^{2})$
# $= 2(169) - 2(25)$
# $= 338 - 50$
# $= 288$
#
# Final Answer:
# $\displaystyle \int_{1}^{3} 8x(x^{2}+4), dx = 288$
#
# </details>

# %% [markdown]
# **Problem 74:**
#
# *$\int_0^2 e^5x dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *u=5x, du=5dx, dx=1/5du, now change limits of intergration to 0 and 10(0*5 and 2*5)*
#
# *$\int_0^10 1/5(e^u) du$, now plug in 10 and 0 and get (e^10-1)/5*
#
# </details>

# %% [markdown]
# **Problem 75:**
#
# *[int 0^2, x(x^2+1)^3 dx]*
#
# **78:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[int 0^2, x(x^2+1)^3 ]*
#
# </details>

# %% [markdown]
# **Problem**: $\int_0^2 2x[x^2 +4]^2 dx$
#
# **Step 1**: Sub u in: $u=x^2 +4, du= 2xdx \to \frac {du}{2x} = dx$
#
# **Step 2**: Rewrite in terms of u:$\int_0^2 2x[u]^2 \frac {du}{2x} = \int_0^2 [u]^2 du $
#
# **Step 3**: Change bounds in terms of u:$ 0^2 + 4 =4, 2^2 + 4 = 8, \int_4^8$
#
# **Step 4**: $\int_4^8 \frac{u^3}{3} = \frac{8^3}{3} - \frac{4^3}{3} = \frac{512}{3} - \frac{64}{3} = \frac{448}{3}$
#
#
# </details>
#
#
# **Key Concept:**
# Use **u-substitution** when the integrand contains a function. Then take the derivative of that u, subbing in u for the function, which simplifies the integral after changing variables and adjusting bounds.

# %% [markdown]
# **Problem 76:**
#
# Evaluate the definite integral:
#
# $$\int_{0}^{2} 3x^2 \sqrt{x^3 + 1} \, dx$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **1. Choose $u$ and find $du$:**
#
# - Let $u = x^3 + 1$
#
# - Then $du = 3x^2 dx$
#
# **2. Change the Limits (Crucial Step!):**
#
# - When $x = 0$, $u = 0^3 + 1 = 1$
#
# - When $x = 2$, $u = 2^3 + 1 = 9$
#
# **3. Rewrite in terms of $u$:**
#
# - $\int_{1}^{9} \sqrt{u}du = \int_{1}^{9} u^{1/2}du$
#
# **4. Integrate and Evaluate (No need to go back to $x$):**
#
# - $= \left[ \frac{2}{3}u^{3/2} \right]_{1}^{9}$
#
# - $= \frac{2}{3} (9^{3/2} - 1^{3/2})$
#
# - $= \frac{2}{3} (27 - 1)$
#
# - $= \frac{52}{3}$$
# </details>

# %% [markdown]
# **Problem:**
#
# *[y= sqrt x and y= x-2]*
#
# **Solution:**
# 19/6
# <details>
# x=(x-2)^2
# x=x^2-x+4
# 0=x^2-5x+4
# 0= (x-1)(x-4)
# at x=4:
#
# </details>

# %% [markdown]
# **Problem 77:**
#
# *Evaluate $\int_0^1 \frac{2x}{(x^2 + 1)^2} \, dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *Step 1: Choose u and find duLet $u = x^2 + 1$.Then $du = 2x \, dx$. (This matches the numerator perfectly!)Step 2: Change the BoundsLower bound ($x=0$): $u = 0^2 + 1 = 1$Upper bound ($x=1$): $u = 1^2 + 1 = 2$Step 3: Rewrite Integral in terms of u$$\int_1^2 \frac{1}{u^2} du = \int_1^2 u^{-2} du$$Step 4: Integrate and EvaluateAntiderivative of $u^{-2}$ is $-u^{-1}$ (or $-1/u$).$$[-u^{-1}]_1^2 = [-\frac{1}{u}]_1^2$$$$(-\frac{1}{2}) - (-\frac{1}{1}) = -\frac{1}{2} + 1 = \frac{1}{2}$$Answer: $1/2$*
#
# </details>

# %% [markdown]
# **Problem 78:**
#
# *Evaluate the definite integral:*
#
# $\int_{0}^{2} 3x^2\sqrt{x^3 + 1}  dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1: Choose u**
#
# Let $u = x^3 + 1$
#
# **Step 2: Find du**
#
# $du = 3x^2 dx$
#
# **Step 3: Change the bounds**
#
# When $x = 0$: $u = 0^3 + 1 = 1$
#
# When $x = 2$: $u = 2^3 + 1 = 9$
#
# **Step 4: Rewrite the integral with new bounds**
#
# $\int_{0}^{2} 3x^2\sqrt{x^3 + 1}  dx = \int_{1}^{9} \sqrt{u}  du$
#
# **Step 5: Integrate**
#
# $\int_{1}^{9} u^{1/2}  du = \left[\frac{2}{3}u^{3/2}\right]_{1}^{9}$
#
# **Step 6: Evaluate**
#
# $\frac{2}{3}(9)^{3/2} - \frac{2}{3}(1)^{3/2} = \frac{2}{3}(27) - \frac{2}{3}(1) = 18 - \frac{2}{3} = \frac{52}{3}$
#
# **Final Answer:** $\frac{52}{3}$
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Create a definite integral problem]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# </details>

# %% [markdown]
# **Problem 79:**
#
# *$\int_{0}^{2} (x+1)^4 \, dx.$*
#
# *Solution: $\boxed{\frac{242}{5}}$ *
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Choose a substitution
# Let $u = x + 1.$$ Then $$du = dx.$
#
# Step 2: Change the bounds
# When \(x = 0\):
# $u = 0 + 1 = 1.$
# When \(x = 2\):
# $u = 2 + 1 = 3.$
# So the integral becomes:$\int_{1}^{3} u^4 \, du$
#
# Step 3: Integrate in terms of \(u\)
# $\int u^4 \, du = \frac{u^5}{5}$
#
# Step 4: Evaluate at the new bounds
# $\left. \frac{u^5}{5} \right|_{1}^{3}
# = \frac{3^5}{5} - \frac{1^5}{5}
# = \frac{243}{5} - \frac{1}{5}
# = \frac{242}{5}$
#
# </details>
