# %% [markdown]
# # AM 11B Project: Math Concept Review, Phase 3
# ___
# Please write the names of your group (or self) below by double-clicking on the text below. These should be the same name(s) as from Phases 1 and 2.

# %% [markdown]
# NAME(S): *Replace this text with your name(s).*

# %% [markdown]
# ## Welcome to your final review project, phase 3!
#
# As a reminder, this notebook is designed for you to create comprehensive study materials that will help the entire class review key mathematical concepts from AM 11B.
#
# One thing to note with this final phase is that we will be getting to concepts for Part 7 (below) during Week 10, so you may have to wait till then to fill in those parts.
#
# ### Your Mission:
# For each topic covered in the course, you will:
# 1. **Identify problem types** and when to use different techniques
# 2. **Create setup templates** showing the general approach
# 3. **Work through sample problems** with detailed solutions.
# 4. **Build a study guide** that your classmates can use
#
# ### Instructions:
# - Work through each section sequentially
# - Fill in the markdown cells with your explanations and work
# - Use the code cells to demonstrate techniques and check your work
# - Create clear, well-organized examples that others can follow. You must create **new** sample problems, not just repeat the examples provided.
# - Use the "reveal" pattern to hide solutions (this will help for studying!)
#
# ### Grading:
# This project will be graded on:
# - Completeness of your study materials
# - Clarity of explanations
# - Correctness of worked examples
#
# ### Note:
# This project will deployed in parts. This is to help with both grading as well as help you pace with course content.
#
# ### Useful information before you start:
# <div class="alert alert-block alert-info">
# This notebook will require you to write some math in it, not just words. You will see examples as you go, which should provide guidance. Some tips:
#
# 1. There are two types of notebook "cells" or "blocks" that make up this notebook:
#
#    <!-- <div class="alert alert-block alert-success"> -->
#
#     1. **Markdown** (regular text, for regular answers/written questions); and
#     2. **Code** (for any code that may help with visualizing or checking work). You are **not** expected to code. These parts are optional but may be helpful.
#    <!-- </div> -->
#
# 2. Double clicking on a cell makes it **editable**, so you can change things.
# 3. **Only edit cells where you are asked to do so**.
# 4. Typing math nicely requires you to use the dollar sign \$ around your math expressions. You will see examples. **It is okay if you do not do this in your answers.**
# 5. **Powers/exponents have special notation**. When written in regular text/Markdown cells, we write $x^4$ as <code>x^4</code>. But in code cells, we will use the ** notation instead of ^: <code> x**4 </code>
# </div>
#
# ___

# %% [markdown]
# ## Setup: Run this cell first
#
# This cell imports useful Python libraries for calculations and plotting.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate
import sympy as sp
from IPython.display import display, Markdown, Latex

# Configure sympy for nice mathematical output
sp.init_printing()

# Define symbolic variables we'll use throughout
x, y, z, t = sp.symbols('x y z t')
a, b, c, h, k = sp.symbols('a b c h k')

print("Setup complete! Ready to create study materials.")
# Out:
# Setup complete! Ready to create study materials.

# %% [markdown]
# ___
#
# # PART 6: APPROXIMATION AND OPTIMIZATION
#
# ## Weeks 7-9: Linear & Quadratic Approximation and Unconstrained Optimization

# %% [markdown]
# ### 6.1 Linear Approximation
#
# **YOUR TASK:** Explain linear approximation for multivariable functions.

# %% [markdown]
# **Linear Approximation Formula:**
#
# $$L(x, y) = f(a, b) + f_x(a, b)(x - a) + f_y(a, b)(y - b)$$
#
# *[Explain what this formula represents]*
#
# **When to use linear approximation:**
#
# *[Explain scenarios where we estimate function values]*
#
# **Step-by-step process:**
#
# 1. *[Fill in here]*
# 2. *[Fill in additional steps as needed]*

# %% [markdown]
# ### Sample Problem 6.1: Linear Approximation
#
# **YOUR TASK:** Create a linear approximation problem.

# %% [markdown]
# **Problem:**
#
# *[Create a problem approximating a function value near a known point]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Work through all steps systematically]*
#
# </details>

# %% [markdown]
# ### 6.2 Quadratic Approximation
#
# **YOUR TASK:** Explain quadratic approximation.

# %% [markdown]
# **Quadratic Approximation Formula:**
#
# $L(x, y) = $ *[Write what the formula is]*
#
# **Why is this useful:**
#
# *[Explain why this might be valuable]*
#
# **Step-by-step process:**
#
# 1. *[Fill in here]*
# 2. *[Fill in additional steps as needed]*

# %% [markdown]
# ### Sample Problem 6.2: Quadratic Approximation
#
# **YOUR TASK:** Create a quadratic approximation problem.

# %% [markdown]
# **Problem:**
#
# *[Create a problem approximating a function value near a known point]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Work through all steps systematically]*
#
# </details>

# %% [markdown]
# ### 6.3 Optimization: Finding Critical Points
#
# **YOUR TASK:** Create a guide for finding and classifying critical points.
#
# This is essential for optimization problems!

# %% [markdown]
# **Finding Critical Points:**
#
# *[Explain how to find critical points]*
#
# **Step-by-step process:**
#
# 1. *[Fill in here]*
# 2. *[Fill in additional steps as needed]*
#
# **Second Derivative Test:**
#
# *[Explain the discriminant]*
#
# At a critical point $(a, b)$:
# 1. *[Fill in cases here]*
# 2. *[Fill in cases here]*
# 3. *[Fill in cases here]*
# 4. *[Fill in cases here]*

# %% [markdown]
# ### Question 6.1: Quadratic Approximation and Optimization
#
# In class, we motivated the Second Derivative Test using the quadratic approximation formula. Explain why this helps us understand where local maxima and minima are by replacing the text below.

# %% [markdown]
# *[Replace this text with your explanation. Examples or referencing graphs and function behavior may be helpful.]*

# %% [markdown]
# ### Sample Problem 6.3: Unconstrained Optimization
#
# **YOUR TASK:** Create a complete optimization problem.

# %% [markdown]
# **Problem:**
#
# *[Create a problem asking to find and classify all critical points]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** Find partial derivatives
#
# *[Show $f_x$ and $f_y$]*
#
# **Step 2:** Set equal to zero and solve
#
# *[Show system of equations and solution]*
#
# **Step 3:** Find second partial derivatives
#
# *[Show $f_{xx}$, $f_{yy}$, $f_{xy}$]*
#
# **Step 4:** Apply second derivative test
#
# *[Calculate D and classify each critical point]*
#
# **Conclusion:**
#
# *[Summarize the results: where are maxima, minima, saddle points?]*
#
# </details>

# %% [markdown]
# ___
#
# # PART 7: CONSTRAINED OPTIMIZATION
#
# ## Week 10: Lagrange Multipliers

# %% [markdown]
# ### 7.1 Constrained Optimization with Lagrange Multipliers
#
# **YOUR TASK:** Create a guide to the method of Lagrange multipliers.
#
# This is the grand finale! Make it count!

# %% [markdown]
# **The Problem Type:**
#
# *[Explain what these problems look like mathematically.]*
#
# **When to use Lagrange multipliers:**
#
# *[Give examples of constrained optimization scenarios in real life. Feel free to do some research to find examples!]*

# %% [markdown]
# **The Lagrange Function:**
#
# $$L(x, y, \lambda) = f(x, y) - \lambda(g(x, y) - c)$$
#
# *[Explain what $\lambda$ represents]*

# %% [markdown]
# **The Method:**
#
# To find critical points, solve the system:
#
# 1. $\frac{\partial L}{\partial x} = f_x - \lambda g_x = 0$
# 2. $\frac{\partial L}{\partial y} = f_y - \lambda g_y = 0$
# 3. $\frac{\partial L}{\partial \lambda} = g(x, y) - c = 0$
#
# **Step-by-step template for solving a problem:**

# %% [markdown]
# 1. *[Fill in here]*
# 2. *[Fill in additional steps as needed]*

# %% [markdown]
# **Important notes:**
#
# *[Mention that we often don't need to find $\lambda$ explicitly, and explain how to compare function values]*

# %% [markdown]
# ### Sample Problem 7.1: Basic Lagrange Multipliers
#
# **YOUR TASK:** Create a straightforward Lagrange multipliers problem.

# %% [markdown]
# **Problem:**
#
# *[Create a problem, e.g., "Maximize $f(x,y) = xy$ subject to $x + y = 10$"]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** Identify $f$ and $g$
#
# *[Write clearly what each is]*
#
# **Step 2:** Set up the Lagrange equations
#
# *[Write out the three equations]*
#
# **Step 3:** Solve the system
#
# *[Show algebraic steps to find $x$ and $y$]*
#
# **Step 4:** Evaluate $f$ at critical point(s)
#
# *[Find the optimized value]*
#
# **Answer:** *[State the maximum or minimum value and where it occurs]*
#
# </details>

# %% [markdown]
# ### Optional Part:
# <div class="alert alert-block alert-success">
#
# You can check your work with Python by editing the code below to match your example. The lines to edit include this label:
#
# <code style="background:white;color:green"> # EDIT HERE </code>
# </div>

# %%
# Verify your answer with SymPy
# Example code:
lam = sp.symbols('lambda')
f = x*y # EDIT HERE
g = x + y - 10 # EDIT HERE
L = f - lam*g

# Find critical points
eqs = [sp.diff(L, x), sp.diff(L, y), sp.diff(L, lam)]
solution = sp.solve(eqs, [x, y, lam])
print(solution)

# Evaluate f at the solution
f_value = f.subs(solution)
print(f"Function value: {f_value}")
# Out:
# {lambda: 5, x: 5, y: 5}
# Function value: 25

# %% [markdown]
# ___
#
# # CONCLUSION AND REFLECTION

# %% [markdown]
# ## Reflection Questions
#
# 1. **Which topics did you find most challenging before doing these  mini-project phases?**
#
#    *[Your answer]*
#
# 2. **Which techniques do you feel most confident about now?**
#
#    *[Your answer]*
#
# 3. **What advice would you give to future students taking this course?**
#
#    *[Your answer]*
#
# 4. **What connections did you notice between different topics?**
#
#    *[Your answer]*
#
# 5. **How do you think you might use these mathematical tools in your future studies or career?**
#
#    *[Your answer]*

# %% [markdown]
# ---
#
# # SUBMISSION CHECKLIST
#
# Before submitting, verify that you have completed:
#
# - [ ] All sample problems created with detailed solutions
# - [ ] Solutions use the reveal pattern
# - [ ] Reflection questions answered
#
# ---
#
# # Submission Instructions
#
# When you have completed all sections:
#
# 1. **Run all cells** in order. Running the cells that run code is optional (as labeled).
# 2. **Check** that all your solutions and explanations are complete
# 3. **Save** your notebook
# 4. **Download** as .ipynb file (File → Download)
# 5. **Upload** the .ipynb file to Canvas by the deadline.
#
#
# **Congratulations on completing this project, and thank you for helping to create study materials for your classmates!**
#
#
# <div class="alert alert-block alert-info">
# Note: We will share out your sample problems and solutions with the class as soon as we are able to gather them all together, and hope that these materials are useful for your studying! Good luck on the final exam!
# </div>
