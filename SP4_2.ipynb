# %% [markdown]
# **Problem 1:**
#
# A colony of bacteria is growing at a rate proportional to its size. At the start of an experiment ($t=0$), the colony size is 1,200 bacteria. After 4 hours, the population has grown to 2,800 bacteria.
#
# Use the model to predict the population size after 10 hours.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $$P(10) = 1200 e^{\left(\frac{1}{4} \ln\left(\frac{7}{3}\right)\right) 10}$$$$P(10) = 1200 e^{\frac{10}{4} \ln\left(\frac{7}{3}\right)} = 1200 e^{2.5 \ln(7/3)}$$
#
# $$P(10) \approx 1200 e^{(0.2118)(10)}$$$$P(10) \approx 1200 e^{2.118}$$$$P(10) \approx 1200 (8.313)$$$$\mathbf{P(10) \approx 9976 \text{ bacteria}}$$
#
# </details>

# %% [markdown]
# **Problem: The population in City A grows at a rate of 20% per year, the population in the year 2000 is 40000. What is the population of City A in 2009?**
#
#
# *Solution:*
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *A = 40000, e = Euler's number, k = 20% t = 9 (years since 2000), therefore, P = $40000e^{0.20*9}$*
#
# *P ≈ 241986*
#
# </details>

# %% [markdown]
# **Problem 2:**
#
# A culture of bacteria starts with $400$ bacteria and grows at a rate of $8$% per hour. Find the number of bacteria after $15$ hours.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Plug in the values to the equation that we found above:
#
# $P(t) = P_0e^{kt}$
#
# $\implies P(15) = 400e^{0.08(15)}$
#
# $\implies P(15) \approx 400 * 3.3201$
#
# $\implies$ $$\boxed{P(15) \approx 1328}$$
#
# </details>

# %% [markdown]
# Problem 3:
#
# A bacteria culture begins with 800 bacteria and grows at a continuous rate of 12% per hour.
# 1. Write the exponential growth model.
# 2. Find the population after 10 hours.
# 3. Determine how long it takes for the population to triple.
#
# *Solution:*
#
# *a)* Differential equation:
#
# $\frac{dP}{dt} = kP \quad\text{with}\quad k = 0.12$
#
#
# *b)* Solve the differential equation:
#
# Separate variables:
#
# $\frac{1}{P}\,dP = 0.12\,dt$
#
#
# Integrate both sides:
#
# $\ln|P| = 0.12t + C$
#
#
# Exponentiate:
#
# $P(t) = e^{C} e^{0.12t}$
#
#
# $(e^{C} = P_0 = 800)$.
#
# ${\,P(t) = 800\,e^{0.12t}\,}$
#
#
# *c)* Population after 10 hours:
#
#
# $P(10) = 800\,e^{0.12\cdot 10} = 800\,e^{1.2}$
#
#
# Numeric approximation:
#
# $e^{1.2}\approx 3.3201169\quad\Rightarrow\quad P(10)\approx 800(3.3201169)\approx 2656\text{ cells}$
#
#
# *d)*
#
# Set $(3P_0 = P_0 e^{0.12t}):$
#
# $3 = e^{0.12t}$
#
#
# Take natural log:
#
# $\ln 3 = 0.12t \quad\Rightarrow\quad t = \frac{\ln 3}{0.12}$
#
#
# Numeric approximation:
#
# $\ln 3 \approx 1.0986123 \quad\Rightarrow\quad t \approx \frac{1.0986123}{0.12}\approx 9.155\text{ hours}$
#
#
#
#
# </details>

# %% [markdown]
# **Problem 4:**
#
# A population of butterflies in a protected garden is growing exponentially.
# The rate of change of the population is proportional to the current population: $dP/dt=0.12P$
#
# **Solution:**
#
# step 1: separate variables, integrate both sides, and simplify:
#
# $∫(1/P)dP=∫0.12dt$
#
# $ln|P|=0.12t+C$
#
# $P(t)=Ae^0.12t$
#
# step 2: Use the initial condition, plug in, and simplify
#
# at $t=0$, $P(0)=150$
#
# $150=Ae^0.12(0)$
#
# $P(t)=150e^0.12t$
#
# step 3: Find the population after 5 years by plugging in $t=5$
#
# $P(5)=150e^0.12(5)=150e^0.6$
#
# $𝑒^0.6≈1.8221$
#
# $P(5)≈150(1.8221)=273.32$
#
# $P(5)≈273$ butterflies
#
# step 4: Find when the population reaches 500 by setting $P(t)=500$, simplify, and solve for t.
#
# $150e^0.12t=500$
#
# $t=ln(10/3)/0.12≈10.033$
#
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
# Approximately 10 years.
# </details>

# %% [markdown]
# **Problem 5:**
#
# A bacterial culture has 1,000 bacteria at time t=0. The culture doubles every 5 hours. Model the population by an exponential growth equation.
#
# 1. What is the population after 20 hours?
#
# 2. After how long will the population reach 5,000?
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1: Replace variables in the original equation**
#
# $P = P_0 e^{kt} $
#
# $P(t)$, where $t=0 \to$ $P(0)=1,000$
#
# $1000=P_0e^{(k)(0)}$
#
# $P_0=1000$
#
# $P(t)=1000e^{kt}$
#
# **Step 2: Solve with regard to the doubling time**
#
# When the culture doubles every 5 hours $\to P(5)=2*1000 \to P(5)=2000$
#
# $2000=1000e^{(k)(5)}$
#
# $2=e^{5k}$
#
# $ln(2)=5k$
#
# $k= \frac{ln(2)}{5} $
#
# **Step 3: Final Model**
#
# $P(t)=1000e^{(\frac{ln(2)}{5})(t)}$
#
# $P(t)=1000(2^{t/5})$
#
# **Population after 20 hours:**
#
# $P(20) = 1000(2^{20/5}) \to 1000(2^4) \to 1000(16) \to 16000$
#
# After 20 hours, there will be 16,000 bacteria in the culture.
#
# **When the population will reach 5,000:**
#
# $P(t)=5000 \to 5000=1000(2^{\frac{t}{5}})$
#
# $5=2^{\frac{t}{5}}$
#
# Exponentiate: $ln(5)=\frac{t}{5} ln(2)$
#
# $t= 5 \frac{ln(5)}{ln(2)}$
#
# Calculate: t= 11.6
#
# The Population reaches 5,000 after approximately 11.6 hours.
#
# *[Show how to find parameters and make predictions]*
# </details>

# %% [markdown]
# **Problem 6:**
#
# *[$P_0=1200 , k=0.06, t=8yrs $]*
#
# **Solution: *[$P(8) = 1939$]**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[$dP/dt= dP=0.06P$]*
#
# *[$P(t)=P_0e^{kt}=1200e^{0.06t}$]*
#
# *[$P(8)=1200e^{0.06*8}=1200e^{0.48}=1200*1.616=1,939$]*
#
# </details>

# %% [markdown]
# **Problem:**
#
# A bacteria culture starts with 500 bacteria and grows at a continuous rate of 12% per hour.
# Find a formula for the population \(P(t)\), and predict the population after 5 hours.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1: Write the exponential growth model**
#
# \[
# P(t) = P_0 e^{kt}
# \]
#
# Given:
# - \(P_0 = 500\)
# - Growth rate \(k = 0.12\)
#
# So:
#
# \[
# P(t) = 500 e^{0.12 t}
# \]
#
# ---
#
# **Step 2: Predict the population after 5 hours**
#
# \[
# P(5) = 500 e^{0.6}
# \]
#
# \[
# P(5) \approx 500(1.8221) \approx 911
# \]
#
# ---
#
# **Final Answer:**
#
# \[
# \boxed{P(t) = 500 e^{0.12 t}}
# \]
#
# \[
# \boxed{P(5) \approx 911 \text{ bacteria}}
# \]
#
#
# </details>

# %% [markdown]
# Sample Problem
# **Problem 7:**
#
# A rare plant species is introduced to a protected area. Initially, there are 50 plants.
# After 3 years, the population has grown to 80 plants.
#
# 1. Find an exponential growth model for the population \(P(t)\), where \(t\) is in years.
# 2. Predict the population after 8 years.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1: Use the exponential model**
#
# $P(t) = P_0 e^{kt}$
#
# Given:
#
# $P_0 = 50,\quad P(3) = 80$
#
#
# Plug known point in:
#
# $80 = 50e^{3k}$
#
# Divide both sides by 50:
#
# $frac{80}{50} = e^{3k}$
#
# $1.6 = e^{3k}$
#
# Take natural logarithm:
#
# $ln(1.6) = 3k$
#
# $k = \frac{\ln(1.6)}{3}$
#
# **Exponential growth model:**
#
# $\boxed{P(t) = 50e^{\frac{\ln(1.6)}{3}t}}$
#
#
# **Step 2: Predict the population after 8 years**
#
# $P(8) = 50e^{\frac{\ln(1.6)}{3}(8)}$
#
# $= 50 \cdot 1.6^{\frac{8}{3}}
# \approx 50 \cdot 3.01
# \approx 151$
#
#
# **Final Answer:**
# $\boxed{P(8) \approx 151\ \text{plants}}$
#
#
# </details>

# %% [markdown]
# **Problem 8:**
#
# dP/dt=kP  ,  P(0)=5
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# 1/P dp=k dt  ,  ln(P)=kt+C  ,  P=e^kt+C =Ce^kt  ,  5=Ce^k0  ,  C=5  ,  P(t)=5e^kt
#
# </details>

# %% [markdown]
# **Problem 9:**
#
# a colony of bacteria grows at a rate proportional to its current size. Initially, the colony has 200 bacteria. After 3 hours, it has grown to 500 bacteria. How much bacteria will be present after 6 hours?
#
# **Solution:**
# Step 1: write the differential equation
#
#     dP/dt = CP
#
# Step 2: Seperate the Variables
#
#     integration of 1/ydP = integration of Cdt
#
# Step 3: Integrate both sides
#
#      integration of 1/ydP = integration of Cdt
#
#     1/ydP = ln|P|
#     Cdt = Ct + k
#
#     ln|P| = Ct + k
#
# Step 4: Solve for y
#
#     |P| = e^Ct + A
#
#     P(t) = Ae^Ct
#
# Step 5: use y(0) = 200 to find C
#
#     200 = Ae^k(0) = Ae^0 = A
#     A = 200
#
#     y(t) = 200e^ct
#
# Step 6: use y(3) = 500 to find k
#
#     500 = 200e^3k
#
#     500/200 = e^3k
#     2.5 = e^3k
#     ln(2.5) = 3k
#     k = ln(2.5)/3
#
#     y(t) = 200 x 2.5^t/3
#
# Step 7: Find the population after 6 hrs
#
#     y(6) = 200(2.5)^6/3 --> 200(2.5)^2
#
#     y(6) = 200 x 6.25 = 1250
#
# Final Answer: y(6) = 1250 bacteria
#
# </details>

# %% [markdown]
# **Problem 10:**
#
# *A population of insects is initially 200. After 5 hours, the population has grown to 500.*
#
# *Assuming the growth is exponential, find the growth rate $k$ and predict the population after 8 hours.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $P_0 = 200$ and $P(5) = 500$
#
# $500 = e^{5k}$
#
# $2.5 = e^{5k}$
#
# $ln(2.5) = 5k$
#
# $k = \frac{ln(2.5)}{5}$
#
# $P(t) = 200e^{\frac{ln(2.5)}{5}t}$
#
# $P(t) = 200(2.5)^{\frac{t}{5}}$
#
# Predict the population at 8 hours.
#
# $P(8) = 200(2.5)^{\frac{8}{5}}$
#
# $P(8) = 200(2.5)^{1.6} = 200(3.95)$
#
# $P(8) = 790$
#
# </details>

# %% [markdown]
# **Problem 11:**
#
# A bacteria culture starts with 200 bacteria and grows at a rate proportional to its size.
# After 2 hours, the population has increased to 450 bacteria.
#
# a) Find the growth rate constant k
#
# b) Find the population after 5 hours
#
# c) When will the population reach 2000 bacteria?
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Given: $P(t) = P_0e^{kt}$, where $P_0 = 200$
#
# From the data: $P(2) = 450$
# $450 = 200e^{2k}$
#
# a) Find growth rate constant $k$:
# $\frac{450}{200} = e^{2k}$
# $2.25 = e^{2k}$
# $\ln(2.25) = 2k$
# $k = \frac{\ln(2.25)}{2} \approx 0.4055$ per hour
#
# b) Population after 5 hours:
# $P(5) = 200e^{5 \times 0.4055} = 200e^{2.0275} \approx 200 \times 7.593 \approx 1519$ bacteria
#
# c) Time to reach 2000 bacteria:
# $2000 = 200e^{kt}$
# $10 = e^{kt}$
# $\ln(10) = kt$
# $t = \frac{\ln(10)}{k} \approx \frac{2.3026}{0.4055} \approx 5.68$ hours
# </details>

# %% [markdown]
# **Problem 12:**
#
# A certain bacteria culture grows exponentially. At time $(t = 0)$, the culture contains **200** bacteria. After **5 hours**, the culture has grown to **600** bacteria.
#
# 1. Find the exponential growth model $P(t)$.
# 2. Use your model to predict the population after **8 hours**.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Assume the model:
#
# $
# P(t) = P_0 e^{kt}
# $
#
# **Step 1: Identify known values**
#
# - Initial population: $(P_0 = 200)$
# - After 5 hours: $(P(5) = 600)$
#
# **Step 2: Plug into the model to solve for $(k)$**
#
# $
# 600 = 200 e^{5k}
# $
#
# Divide both sides by 200:
#
# $
# 3 = e^{5k}
# $
#
# Take natural log:
#
# $
# \ln 3 = 5k
# $
#
# $
# k = \frac{\ln 3}{5}
# $
#
# **Step 3: Write the model**
#
# $
# P(t) = 200 e^{(\ln 3 / 5)\, t}
# $
#
# **Step 4: Predict the population at $(t = 8)$**
#
# $
# P(8) = 200 e^{(\ln 3 / 5)\, 8}
# $
#
# Simplify exponent:
#
# $
# P(8) = 200 \, e^{\frac{8}{5}\ln 3}
# $
#
# Use the identity $(e^{\ln 3^{8/5}} = 3^{8/5})$:
#
# $
# P(8) = 200 \cdot 3^{8/5}
# $
#
# **Final numeric approximation:**
#
# $
# P(8) \approx 200 \cdot 6.240 = 1248
# $
#
# So after **8 hours**, the population will be approximately **1,248 bacteria**.
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[
# A small plant population starts with 50 plants and grows at a continuous rate of 6% per day.
# Write the exponential growth model for the population P(t)P(t)P(t), and find the number of plants after 10 days.
# ]*
#
# **Solution:P(10)=91 plants**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[initial populatipon:p_0=50]*
# *[continous growth rate:r=0.06]*
# *[time in days:t]*
# *P(t)=50e**0.06t*
# *P(10)=91*
#
# </details>

# %% [markdown]
# **Problem 13:**
#
# *a culture of bacteria has 1000 cells intially. the population grows ar a rate proportional to its size. 3 hrs later there are 2000 cells. how many cells will there be at 8 hours?*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *$$P(t) = P_0 e^{kt}$$
# $$P(0) = 1000$$
# $$1000 = P_0 e^{k(0)}$$
# $$P_0 = 1000$$
# $$2000 = 1000 e^{k(3)}$$
# $$\frac{2000}{1000} = e^{3k}$$
# $$2 = e^{3k}$$
# $$\ln(2) = \ln(e^{3k})$$
# $$\ln(2) = 3k$$
# $$k = \frac{\ln(2)}{3}$$
# $$P(8) = 1000 e^{\left(\frac{\ln(2)}{3}\right)8}$$
# $$P(8) = 1000 e^{\frac{8}{3}\ln(2)}$$
# $$P(8) = 1000 \cdot 2^{8/3}$$
# $$P(8) \approx 6350$$*
#
# </details>

# %% [markdown]
# **Problem 14:**
#
# A colony of bacteria contains 500 cells initially. The colony grows at constant rate of 8% per hour
#
# 1. write an exponential growth model for the population P(t)
#
# 2. Find the population after 6 hours
#
# 3. how long will it take for the population to double
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find parameters and make predictions]*
#
# 1.
#
# $ dP/ dt = kP --- P(t) = P_0 e^kt$
#
# given:
#
# P_0 = 500
#
# growth rate 8% = 0.08 so k=0.08
#
# P(t)= 500e^(0.008t)
#
# 2. population after 6 hours
#
# P(6)= 500e^0.08*6
#
# p(6) approx 808 cells
#
# 3. time for the population to double
#
# P(t)= 1000
#
# 1000= 500e ^0.08t
#
# 2= e^0.08t
#
# ln2= 0.08t
#
# t equals to approx 8.7 hours

# %% [markdown]
# **Problem 15:**
#
# *A bacteria culture begins with 200 cells. After 5 hours, the population has doubled to 400.
# Find the exponential growth model and predict the population after 8 hours.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# ***Step 1:** Write the differential equation: $\frac{dP}{dt} = kP$.
# **Step 2:** General solution: $P(t) = P_0 e^{kt}$ with $P_0 = 200$.
# **Step 3:** Use $P(5)=400$: $400 = 200e^{5k} \Rightarrow 2 = e^{5k} \Rightarrow k = \frac{\ln 2}{5}$.
# **Step 4 Full model: $P(t) = 200 e^{(\ln 2/5)t}$.
# **Step 5: Predict $P(8)$: $P(8) = 200 e^{(\ln 2/5)\cdot 8} = 200 \cdot 2^{8/5} \approx 606$.
#
# **Answer: Growth model: $P(t)=200 e^{(\ln 2/5)t}$; population after 8 hours $\approx 606$.*
#
# </details>

# %% [markdown]
# **Problem 16:**
#
# A culture of bacteria starts with 500 cells. The population grows at a rate proportional to its size, and after 4 hours the population has increased to 2000 cells.
# - (a) Wrtie the differential equation that models this situation
# - (b) Find the exponential growth constant k
# - (c) Find a formula for $P(t)$ , the population at time $t$
# - (d) Use the model to predict the population after 7 hours.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# - (a) Write the model: $P(t) = 500e^{kt}$
# - (b) Find the growth constant $k$: Use $P(4) = 2000$ , $k = \frac{ln4}{4} = \frac{ln2}{2} = 0.3456735903$
# - (c) Formula for $P(t) = 500$ x $4^{t/4}$
# - (d) Prediction: population after 7 hours
#     - $P(7) = 500e^{7k} = 500e^{ln4/4} * 7$
#     - $P(7) = 5,656.85$ cells
#
# </details>

# %% [markdown]
# **Problem 17:**
#
# *Bacteria grow at a rate proportional to their current population. At 2:00 pm, the culture contains 300 bacteria. At 4:00 pm, population has increased to 450 bacteria.* (kt should be together)
# $$\frac{dP}{dt}=kP,  -> P=Ce^kt$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *P(0)=300 ans P(2)=450*
#
# *300=$Ce^0$*
#
# *$\frac{450}{300}=e^2k$* -> *$\frac{3}{2}=$e^2k$*
#
# *P(t)= $300 e^kt$*
#
# *P(t)= $300\frac{3}{2}^\frac{t}{2}$*
# </details>

# %% [markdown]
# **Problem:**
#
# Bill deposited $500 into a bank account that grows at a rate proportional to the current balance. After 3 months, Bill checks his account and sees the balance has grown to $550. Write and solve a differential equation describing Bill's account balance. Solve the differential equation for y(t). Find the growth constant k and predict the balance after 6 months.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
# y0= $500, y3=$550, dy/dt=ky=> y=Ce^kt
# Apply y0: 500=Ce^k(0)-->C=500: y=500e^kt
# Apply y3 and t=3: 550=500e^k3--> 550/500= e^3k--> ln|550/500|=3k--> k=(ln|550/500|)/3= 0.0317
# Final Equation: y(t)= 500e^.0317t
# After 6 months: y(6)= 500e^(.0317)(6)= 605
# After a starting balance of $500 and a 3 month growth to $550, the balance after 6 month is $605

# %% [markdown]
# **Problem 18:**
#
# * A bacteria colony has 500 bacteria at time t = 0. The bacteria doubles every 3 hours. How many bacteria is there after 12 hours?
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# * $P'(t)= kP(t) with P(0) = 500$
# * $k=e^k(3) = 2 , k= ln(2)/3$
# * $P(t) = 500e^kt = 500e^(ln2/3)t$
# * $P(12) = 500e^(ln2/3)12 = 500e^4ln2 = 500(2^4) = 500(16) = 8000$
# * 8000 bacteria after 12 hours
#
# </details>

# %% [markdown]
# **Problem 19:**
#
# A culture of bacteria starts with 20 cells and grows proportionally to its size. After 3 hours the population has grown to 50 cells
# 1. Find the exponential growth model P(t)
# 2. Predict the population after 6 hours
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $$P(t)=P_0 e^kt$$
# - $ P_0 = 20$
# - $ P(3) = 50$
#
# 1. Find k
# - $50 = 20e^3k$
# - $\frac{50}{20}=e^3k$
# - $2.5=e^3k$
# 2. Find log
# - $ln(2.5)=3k$
# - $k=\frac{ln(2.5)}{3}=0.3054$
# 3. Final growth Model
# - $P(t)=20e^{0.3054t}$
# 4. Predict population after 6 hours
# - $P(6)=20e^{0.3054(6)} $
# 5. Compute
# - $0.3054(6) = 1.8324$
# - $P(6)=20e^{1.8324} = 20(6.25)$
# - $P(6) = 125$ cells
#
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[a colony of bacteria has 200 cells and after 3 hours the colony has grown 260 cells. ]* Find the growth parameter.
#
# **Solution:** population after 6 hours:338 cells P(t) 200e^0.0873t
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find parameters and make predictions]*
# - 260+200e^3k divide both sides by 200: 1.3 +e^3k
# - In(1.3)=3k
# - solve for k: K= in(1.3)/3
# - approximate: K+0.262/3= 0/0873
#
# </details>

# %% [markdown]
# **Problem 20:** A population of rabbits are growing at a rate proportional to its size. At time t = 0, there are 200 rabbits. After 5 days, the population has grown to 300 rabbits.
#
# *[Create a problem about exponential growth. Pro tip: try to choose relatively nice numbers in your problem.]*
#
# **Solution:** $450 rabbits$
#
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find parameters and make predictions]*
# $\frac{dP}{dt}= kP$
# $P(t) = P_0e^{kt}$
# $P(t) = 200e^{5k}$
# $300=200e^{5k}$
# $1.5=e^{5k}$
# $ln(1.5)=5k$
# $k=\frac{ln(1.5)}{5}$
#
# $P(10)=200e^{10k}$
# $P(10)=200 x 2.25 = 450$
# Ans: $k=\frac{ln(1.5)}{5}$
# 450 rabbits
#
#
# </details>

# %% [markdown]
# **Problem 21:**
#
# A towns population is currently 30,000 and grows at a continuous rate of 3% per year. How many years til the population reaches 40,000?
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# - Use formula $ P(t)=Ae^{kt}$
# - Given P(0)=30,000
# - P(t)=40,0000
# - k=0.03
#
# Plug in:
#
# $40000=30000e^{0.03t}$
#
# Divide
# $\frac {40000}{30000}=e^{0.03t} -> \frac {4}{3}=e^{0.03t} $
#
# Multiply by log:
#
# $Ln\frac{4}{3}=0.03t$
#
# Solve for t:
#
# $t=\frac{ln\frac{4}{3}}{0.03}$
#
# </details>

# %% [markdown]
# **Problem 22:**
#
# *In Santa Cruz, there are currently 10,000 college students living in the city. The student population grows at a rate proportional to its size. After 5 years, the number of college students has increased to 11,500. Predict the number of college students in Santa Cruz after 12 years.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Use the exponential growth model:
#
# $$P(t) = Ce^{kt}$$
#
# At \(t = 0\), the population is 10,000:
#
# $$P (0) = C = 10{,}000$$
#
# $$P(t)= 10{,}000\, e^{kt}$$
#
# At \(t = 5\)** population = 11,500
#
# $$11{,}500 = 10{,}000\, e^{5k}$$
#
# $$1.15 = e^{5k}$$
#
# Take the natural log:
#
# $$\ln(1.15) = 5k$$
#
# $$k = \frac{\ln(1.15)}{5}$$
#
# Solve
#
# $$k = \frac{\ln(1.15)}{5}$$
#
# Write the growth model:
#
# $$P(t) = 10{,}000\, e^{\left(\frac{\ln(1.15)}{5}\right)t}$$
#
# At \(t = 12\)**
#
# $$P(12) = 10{,}000\, e^{\left(\frac{\ln(1.15)}{5}\right)12}$$
#
# Rewrite with exponent rules
#
# $$P(12) = 10{,}000 \left( e^{\ln(1.15)} \right)^{12/5} = 10{,}000 (1.15)^{12/5}$$
#
# $$P(1.15)^{12/5} \approx 1.395$$
#
# $$P(12) \approx 10{,}000 \times 1.395 = 13{,}950$$
#
# **Final prediction:**
#
#
# $$\boxed{P(12) = approx 13{,}950}$$
#
#
# </details>

# %% [markdown]
# **Problem 23:**
#
# *In Santa Cruz, there are currently 10,000 college students living in the city. The student population grows at a rate proportional to its size. After 5 years, the number of college students has increased to 11,500. Predict the number of college students in Santa Cruz after 12 years.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Use the exponential growth model:
#
# $$P(t) = Ce^{kt}$$
#
# At \(t = 0\), the population is 10,000:
#
# $$P (0) = C = 10{,}000$$
#
# $$P(t)= 10{,}000\, e^{kt}$$
#
# At \(t = 5\)** population = 11,500
#
# $$11{,}500 = 10{,}000\, e^{5k}$$
#
# $$1.15 = e^{5k}$$
#
# Take the natural log:
#
# $$\ln(1.15) = 5k$$
#
# $$k = \frac{\ln(1.15)}{5}$$
#
# Solve
#
# $$k = \frac{\ln(1.15)}{5}$$
#
# Write the growth model:
#
# $$P(t) = 10{,}000\, e^{\left(\frac{\ln(1.15)}{5}\right)t}$$
#
# At \(t = 12\)**
#
# $$P(12) = 10{,}000\, e^{\left(\frac{\ln(1.15)}{5}\right)12}$$
#
# Rewrite with exponent rules
#
# $$P(12) = 10{,}000 \left( e^{\ln(1.15)} \right)^{12/5} = 10{,}000 (1.15)^{12/5}$$
#
# $$P(1.15)^{12/5} \approx 1.395$$
#
# $$P(12) \approx 10{,}000 \times 1.395 = 13{,}950$$
#
# **Final prediction:**
#
#
# $$\boxed{P(12) = approx 13{,}950}$$
#
#
# </details>

# %% [markdown]
# **Problem 24:**
#
# A colony of bacteria is growing in a nutrient solution. The population $P(t)$ is observed to grow exponentially.
# 1. Initially, at time $t=0$, the population is 500 bacteria.
# 2. After 4 hours $(t=4)$, the population has grown to 1000 bacteria.
# Find the formula for the population P(t) at any time t, and use it to predict the population after 10 hours.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Use formula**
#
# $P(t)=P_0^{kt}$
#
# **Step 1.** Find the inital population
#
# $P_0=500$
#
# $P(t)=500e^{kt}$
#
# **Step 2.** Find the growth constant $k$
#
# We use the second peice of data $P(4)=1000$
#
# Sub values into the model
#
# $1000+500e^{k4}$
#
# Divide
#
# $\frac{1000}{500}=e^{4k}$
#
# $2=e^{4k}$
#
# Take natural log from both sides
#
# $ln(2)=4k$
#
# Solve for $k$
#
# $k=\frac{ln(2)}{4}
#
# $P(t)=500e^{(\frac{ln(2)}{4})}t$
#
# sub in $t=10$
#
# $P(10)=500e{(\frac{ln(2)}{4})}10$
#
# Simplify
#
# $P(10)=500e^{2.5ln(2)}$
#
# Since $e^{ln(x)}=x$
#
# $P(10)= 500*2^{2.5}$
#
# $P(10)\approx 2828.4$
# </details>

# %% [markdown]
# **Problem 25:**
#
# A bacterial population grows exponentially according to the model:
#
# $$\frac{dP}{dt} = 0.5P$$
#
# If the initial population is $P(0) = 100$, find the population as a function of time.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# We are given:
#
# $$\frac{dP}{dt} = 0.5P$$
#
# Step 1: Separate variables
#
# $$\frac{1}{P} \, dP = 0.5 \,dt$$
#
# Step 2: Integrate both sides
#
# $$\int \frac{1}{P} dP = \int 0.5 \,dt$$
#
# Which gives:
#
# $$\ln |P| = 0.5t + C$$
#
# Step 3: Solve for $P$
#
# Exponentiate:
#
# $$P + e^{0.5t + C}$$
#
# Rewrite:
#
# $$P = Ce^{0.5t}$$
#
# Step 4: Apply the initial condition $P(0) = 100$
#
# $$100 = Ce^{0}$$
#
# Therefore,
#
# $$C = 100$$
#
# **Final Answer:**
#
# $$P = 100e^{0.5t}$$
#
# </details>

# %% [markdown]
# **Problem 26:**
#
# A savings account has balance $P(t)$, where $t$ is measured in years. The account starts with $P(0) = 200$. After $2$ years, the balance is $400$. Assume exponential growth so that $\dfrac{dP}{dt} = kP$.
#
# Find:
#
# The growth constant $k$.
#
# A formula for $P(t)$.
#
# The balance after $4$ years.
#
# Solution:
# <details> <summary><b>Click to reveal solution</b></summary>
#
# We use the general exponential growth formula $P(t) = P_{0}e^{kt}$.
#
# Step 1: Use the initial value.
# At $t = 0$, $P(0) = 200$.
#
# So $P_{0} = 200$, and
# $P(t) = 200e^{kt}$.
#
# Step 2: Use the second data point to find $k$.
# At $t = 2$, $P(2) = 400$.
#
# So $400 = 200e^{2k}$
# Divide both sides by $200$:
# $2 = e^{2k}$
#
# Take natural log:
# $\ln 2 = 2k$
#
# So
# $k = \dfrac{\ln 2}{2}$.
#
# Step 3: Write the full formula.
# $P(t) = 200e^{(\ln 2/2)t}$.
#
# Step 4: Find $P(4)$.
# $P(4) = 200e^{(\ln 2/2)\cdot 4}$
# $= 200e^{2\ln 2}$
# $= 200( e^{\ln 2} )^{2}$
# $= 200(2^{2})$
# $= 800$.
#
# Final Answers:
# $k = \dfrac{\ln 2}{2}$
# $P(t) = 200e^{(\ln 2/2)t}$
# $P(4) = 800$
#
# </details>

# %% [markdown]
# **Problem 27:**
#
# A population of bacteria is growing exponentially. At time \(t = 0\), the population is \(P(0) = 200\).
# After 3 hours, the population has doubled to \(P(3) = 400\).
# 1. Find the exponential growth model \(P(t)\).
# 2. Predict the population at \(t = 5\) hours.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1:
# For exponential growth
# $P(t) = P_0 e^{kt}$
# Given \(P_0 = 200\), so
# $P(t) = 200 e^{kt}$
#
# Step 2:
# We know:
# $P(3) = 400$
# Plug into the model:
# $400 = 200 e^{3k}$
# Divide both sides:
# $2 = e^{3k}$
# Take the natural log:
# $\ln 2 = 3k$
# Solve for \(k\):
# $k = \frac{\ln 2}{3}$
#
# Step 3:
# $P(t) = 200\, e^{(\ln 2/3)t}$
#
# Step 4: Predict the population at \(t = 5\)
# Plug in \(t = 5\):
# $P(5) = 200\, e^{(\ln 2/3) \cdot 5}$
# Simplify:
# $P(5) = 200 \cdot 2^{5/3}$
# Compute the value:
# $P(5) \approx 200 \cdot 2^{1.666\dots}
# \approx 200 \cdot 3.1748
# \approx 635$
#
# Final Answer:
# - Growth model:
#   $\boxed{P(t) = 200\, e^{(\ln 2/3)t}}$
# - Population at 5 hours:
#   $\boxed{P(5) \approx 635}$
#
# </details>

# %% [markdown]
# **Problem 28:**
#
# *[A small town has a population of 1,000 people. The population grows at a rate of 5% per year.
# 1. Write a differential equation that models the population P(t) at time t (in years).
# 2. Solve the differential equation for P(t).
# 3. Find the population after 10 years.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Step 1: Write the differential equation\
# $\frac{dP}{dt}$ = 0.05 P
#
# Step 2: Separate variables\
# $\frac{dP}{P}=0.05dt$
#
# Step 3: Integrate both sides\
# $\int \frac{1}{P}dP$= $\int0.05dt$
# $\implies \ln|P| = 0.05t + C$
#
# Step 4:Solve for P\
# $P = e^{0.05t + C} = e^C \cdot e^{0.05t}$
#
# Step 5: Apply initial condition\
# $P(0) = 1000 \implies 1000 = P_0 e^{0} \implies P_0 = 1000$
#
# Step 6: Find population after 10 years\
# $P(10) = 1000 e^{0.05 \cdot 10} = 1000 e^{0.5} \approx 1000 \cdot 1.6487 \approx 1649$
#
#
#     *
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[A biologist places 40 bacteria in a culture dish. The population grows by 12% per hour.
# (a) Write an exponential growth function
# P(t) that models the number of bacteria after
# t hours.
#
# (b) How many bacteria will be present after 10 hours?
#
# (c) After how many hours will the population first exceed 200 bacteria?.]*
#
# **Solution:The population exceeds 200 after about 15 hours**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[
# (a)
# P(t) = 40(1.12)^t
#
# (b)
# P(10) = 40(1.12)^10 = 40(3.10) = 124 bacteria
#
# (c)
# Solve 40(1.12)^t > 200
# (1.12)^t > 5
# t > ln(5) / ln(1.12) = 14.2
# ]*
#
# </details>

# %% [markdown]
# **Problem 29:**
#
# Diana's savings account earns an annual interest, compounded continuously. In this account, Diana initially put in 1,000 and grew to 1,350 after 4 years. Solve for k and the equation of this savings account.
#
# **Solution:**
#
# *Step 1)* Identify variables of $P(t)=Ae^{kt}$
#
#   $$A=1000 , P(t=4)= 1350, t= 4yrs$$
#
# *Step 2)* Plug in values into the formula
#
# $$1350=(1000)e^{4k}$$
#
# *Step 3)* Set up to solve for k
#
#  $$\frac {1350}{1000}= e^{4k}$$
#
# $$1.35=e^{4k}$$
#
# *Step 4)* Take the natural log of both sides to cancel out $e$
#
# $$ln(1.35)= ln(e^{4k}$$
#
# $$ln(1.35)= 4k$$
#
# *Step 5)* Solve for k
#
#  $$k = \frac {ln(1.35)}{4}$$
#
# *Step 6)* Simplify/calculate k and plug into the original formula
#
# $$y= 1000e^{\frac {ln(1.35)}{4}t}$$
#
#
# </details>

# %% [markdown]
# **Problem 30:**
#
# *[A population of 100 rabbits grows exponentially at a rate of 0.2 per month. How many rabbits will there be after 6 months]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[1. Identify parameters:
#
# ◦ Initial population  P_0 = 100
# ◦ Growth rate  r = 0.2  (per month)
#
# ◦ Time  t = 6  months
#
# 2. Apply the exponential growth formula:
#
# P(t) = P_0 e^{rt}
#
# 3. Calculate:
#
# P(6) = 100 \cdot e^{0.2 \times 6} = 100 \cdot e^{1.2} \approx 100 \times 3.320 = 332
#
# 4. Result:
# There will be approximately 332 rabbits after 6 months.]*
#
# </details>

# %% [markdown]
# **Problem 31:**
#
# *A small coffee shop starts selling a new seasonal drink. On their first day selling the drink, they sell 20 cups. The owner notices that sales seem to grow at a constant rate of 12% per day because everyone keeps posting it online and it is getting popular.
# 1. Assume the number of cups sold each day follows an exponential growth model.
# Write a differential equation that models the number of cups sold, P(t), after t days.
# 2. Solve the differential equation to find a formula for P(t).
# 3. Use your formula to estimate how many cups will be sold after 10 days.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Find Parameters:*
# - *Intial amount of cups:* *$$P_0=20$$*
# - *Growth rate:* *$$r=0.12$$*
#
# *Exponential Growth Model: *$$\frac{dP}{dt}=rP$$*
# - *Plug in r:* *$$\frac{dP}{dt}=(0.12)P$$*
#
# - *Separate Variables:*
# *$$\frac{1}{P}(dP)=0.12(dt)$$*
#
# - *Integrate both sides of Equation*
# *$$\int\frac{1}{P}(dP)=\int0.12(dt)$$* *$$=$$* *$$ln|P|=0.12t+C$$*
#
# *Solve for P: Exponentiate both sides of equation:* *$$ P = e^{0.12t+C} = e^{C} (e^{0.12t})$$*
# - *Let A=e^{C}* *$$P(t)=Ae^{0.12t}$$*
#
# - *Using intiital condition to solve for A (t=0):* *$$P(0)=A(e^{0.12-0})=A(e^{0})=A(1)=A$$* *$$A=20$$* *$$=$$* *$$P(t)=20e^{0.12t}$$*
#
# - *Prediction: Solve for P(10) to solve for amount of cups after 10 days*
# *$$P(10)=20e^{0.12(10)}=20e^{1.2}$$* *$$P(10)= about 66$$*
#
# - *After 10 days, the coffee shop will have sold 66 cups on that day*
# </details>

# %% [markdown]
# **Problem 32:**
#
#  A bacteria culture begins with 500 cells and grows at a constant rate of 12% per hour.
# Assume the population follows the exponential differential equation:
#
# dP/d𝑡=𝑘𝑃
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *We start with the exponential differential equation:
#
# 𝑑𝑃/𝑑𝑡=𝑘𝑃
# The growth rate is 12% per hour, so: 𝑘=0.12
#
# Initial population:𝑃(0)=500
#
# 2. Solve the differential equation
# General solution:$𝑃(𝑡) =𝐶𝑒^𝑘𝑡$
# Apply the initial condition:
# $500=𝐶𝑒^0$
# 𝐶=500
# So the specific model is:$𝑃(𝑡)=500𝑒^{0.12𝑡}$
# Final Step
#
# Population after 8 hours
# $P(8)=500e^{0.96}$
#
# Compute:$e^{0.96}≈2.611$
#
# $P(8)≈500×2.611≈1305.5$
# Final Answer is 1306 cells
# *
#
# </details>

# %% [markdown]
# **Problem 33:**
#
# *[Create a problem about exponential growth. Pro tip: try to choose relatively nice numbers in your problem.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find parameters and make predictions]*
#
# </details>

# %% [markdown]
# **Problem 34:**
#
# A population of rabbits is initially 50. The population grows at a rate of 8% per year.
#
# Write the exponential growth equation for the population P(t).
#
# Find the population after 5 years.
#
# **Solution:**
#
# P(5)=74.59
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *$P(0)= 50$
#
#
# Growth rate:$k=0.08$
#
#
# Time:$t=5$years
#
#
# $P(t)=P(0)e^{kt}$
#
#
#
#
# $P(5)=50e^{0.08}*5$
#
#
# $P(5)=50e^{0.4}$
#
#
# $e^{0.4}+1.4918$
#
#
# $P(5)=50*1.4918$
#
#
# </details>

# %% [markdown]
# **Problem 35:**
#
# A bacteria culture starts with 200 cells. After 3 hours, it has grown to 500 calls. Assume the populatino grows exponentially.
#
# 1. Find the exponential growth model $P(t) = P_0 e^{kt}$.
# 2. Predict the population after 6 hours.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# We use the exponential model:
#
# $P(t) = P_0 e^{kt}$
#
# - Initial amount: $P_0 = 200$
# - After 3 hours: $P(3) = 500$
#
# **1. Find k:**
#
# $500 = 200 e^{3k}$
#
# Divide both sides:
#
# $\frac{500}{200} = e^{3k}$
#
# $2.5 = e^{3k}$
#
# Take natural log:
#
# $\ln(2.5) = 3k$
#
# $k = \frac{\ln(2.5)}{3}$
#
# **Exponential growth model:**
#
# $P(t) = 200 e^{(\ln(2.5)/3)t}$
#
#
#
# **2. Predict the population at 6 hours:**
#
# $P(6) = 200 e^{(\ln(2.5)/3) \cdot 6}$
#
# Simplify the exponent:
#
# $P(6) = 200 e^{2 \ln(2.5)}$
#
# $P(6) = 200 (e^{\ln(2.5)})^2$
#
# $P(6) = 200 (2.5)^2$
#
# $P(6) = 200 \cdot 6.25$
#
# $\boxed{P(6) = 1250}$ cells
#
# </details>

# %% [markdown]
# **Problem 36:**
#
# population starts at 200, growing at 12% per hour, Find population after 5 hours
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# dP = 0.12P
# P(t) = Pe^.12t
# P(0) = 200
# P(t) = 200e^.12t
# P(5) = 200e^.12t
# P(5) is approx. 364
#
# </details>

# %% [markdown]
# **Problem 37:**
#
# *[Bacteria grows at a rate of 12% per hour. The initial starting amount of cells is 500. Write a growth model for population P(t), find the population after 6 hours, and how long will it take for the population to reach 2000 cells.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[following the formula P(t) = Pnull e^kt we replace the variables with the ones given to us in the problem. P(t)= 500e^.12t.
# Now we want to find the population after 6 hours. So we replace t with 6 so the equation looks like this: P(6)= 500e^.12*6 = 500e^.72  = 1027.2 so after 6 hours there are about 1027 cells. Now to solve for how log it takes to reach 2000 cells. 2000 = 500e^12.t we start by dividing 500 from both sides so its 4 - e^.12t Now lets take the natural log = ln4 = .12t but we want to solve for t so we divide .12 by both sides as well. t= ln4/.12. We approximate ln 4 = 1.39 so t = 1.39/.12 = 11.55. After 11.55 hours there will be 2000 cells. ]*
#
# </details>

# %% [markdown]
# **Problem 38:**
#
# *[An ant colony starts with 200 ants and grows at a rate proportional to its size. After 3 hours, the colony has grown to 260 ants. Create a model for the population P(t)P(t) and predict the population after 10 hours.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[We are told the growth is exponential, so:
# $dPdt=kPdtdP​=kP$
#
# Separate variables:
# $1P dP=k dtP1​dP=kdt$
#
# Integrate:
# $ln⁡∣P∣=kt+Cln∣P∣=kt+C$
#
# Solve for PP:
# $P(t)=AektP(t)=Aekt$
#
# Use the initial condition $P(0)=200P(0)=200:
# A=200A=200$
#
# So:
# $P(t)=200ektP(t)=200ekt$
#
# Use the second condition: $P(3)=260P(3)=260:
# 260=200e3k260=200e3k260200=e3k200260​=e3k1.3=e3k1.3=e3kk=ln⁡(1.3)3k=3ln(1.3)​$
#
# Now the model is:
# $P(t)=200 e(ln⁡(1.3)/3)tP(t)=200e(ln(1.3)/3)t$
#
# Predict the population at $t=10t=10:
# P(10)=200 e(ln⁡(1.3)/3)⋅10P(10)=200e(ln(1.3)/3)⋅10P(10)≈200×1.310/3P(10)≈200×1.310/3P(10)≈200×1.33.33≈200×2.16≈432P(10)≈200×1.33.33≈200×2.16≈432$
#
# Final answer:
# $P(10)≈432$ ants]*
#
# </details>

# %% [markdown]
# **Problem 39:**
#
# A colony of bacteria grows at a rate proportional to its size. The growth is modeled by the differential equation:
#
# $\frac{dP}{dt} =2P$
#
# If the initial population is $100$ bacteria $(P(0)=100)$, find the function $P(t)$ for the population at any time $t$.
#
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Solution:**
#
# **Step 1** Seperate the variables (move $P$ to the left and $dt$ to the right):
#
# $\frac{1}{P} dP = 2 dt$
#
# **Step 2** Integrate both sides:
#
# $\int \frac{1}{P} dP = \int 2 dt$
#
# $\ln|P| = 2t+C$
#
# **Step 3** Isolate $P$ (Exponentiate both sides to solve for $P$):
#
# $P = e^{(2t + C)} = e^C \cdot e^{2t}$
#
# Let $A = e^c$:
#
# $P(t) = A e^{2t}$
#
# **Step 4** Use intial condition (substitute $P(0) = 100$ and $t = 0$):
#
# $100 = A e^{2(0)}$
#
# $100 = A \cdot 1 \implies A = 100$
#
# **Final Answer:**
#
# $P(t) = 100 e^{2t}$
#
# </details>

# %% [markdown]
# **Problem 40:**
#
# dP / dt = kP with P(0) = 200
# P(t) = Ce^kt
# 200 = Ce^0
# C = 200
# P(t) = 200e^kt
# P(3) = 400
# 400 = 200e^3k
# 2 = e^3k
# 3k = ln2
# k = ln2 / 3
# P(t) = 200e^(ln2/3)t = 200 x 2^t/3
# p(9) = 200 x 2^9/3 = 200 x 2^3 = 200 x 8 = 1600
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find parameters and make predictions]*
#
# </details>

# %% [markdown]
# **Problem 41:**
#
# We are looking at a petri dish with 100 cells of bacteria. The population doubles every hour. How many cells will there be in 3 hours?
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# In order to find the solution to this problem, we wil use the formula
# P(t)=P₀ · 2^(t)
#
# by plugging in our values we will get 800 cells after 3 hours.
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Create a problem about exponential growth. Pro tip: try to choose relatively nice numbers in your problem.]*
#
# dP/dt = rP(1-p/k)
#
# P: population at time t
#
# t:time
#
# r:intrinsic growth rate
#
# K:Capacity
#
# when  P= K,growth stops: dP/dt = 0
#
# when P<K, population grows
#
# when P > K, population declines towards K
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find parameters and make predictions]*
#
# step 1:write a separable equation:
#
# dP/dt = rP(1- P/K)
#
# step 2:seperate variables
#
# dP/P(1-P/K) = rdt
#
# step 3: use partial fraction decomposition
#
# 1/P(1-P/K) = 1/p + 1/k /1-p/k = 1/p + 1/ k-p
#
# (1/p + 1/k-p)dP = r d t
#
# step 4: intergrate both sides
#
# ∫(1/p + 1/k-p) dP = ∫ r dt
#
# ln|p| - ln |K-P| = rt + C
#
# ln|P/K-P| = rt + C
#
# step 5: solve for p
#
# P/K-P = e^rt+C = Ae^rt (where A = e^C)
#
# p = (K-p)Ae^rt
#
# P=KAe^rt = K Ae^rt
#
# P+ P Ae^rt =  K Ae^rt
#
# P(1+Ae^rt) = KAe^rt/ 1+Ae^rt
#
# P_0 = KA/1+A
#
# P_0(1+A) = K A
#
# P_0 + P_0 A = K A
#
# P_0 = K A - P_0 A = A(K-P_0)
#
# A= P_0/K-P_0
#
# P(t) = K/ 1+(K-P_0/P_0)e^-rt
#
#
#
#
# </details>

# %% [markdown]
# **Problem 42:**
#
# *A town's population of 10,000 is growing at an annual rate of 3%. Find the population after 5 years*
# <details>
# <summary><b>Click to reveal solution</b></summary>
# Solution:
#
# $P_{0}=10,000$
#
# $r=3\%=0.03$
#
# t=5
#
# $P(5)=10000(1.03)^{5}$
#
# $P(5)\approx 11,593$
# </details>

# %% [markdown]
# **Problem 43:**
#
# *A group of bacteria is growing exponentially. At time t = 0 hours, the population is $P_0=500$. After 5 hours the population reaches 2000 bacteria cells. what is the growth model? what is the continous growth rate? Predict what will the population look like after 24 hours*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# find the growth model at P=0:
#
# $$P(t) = Ae^{Kt}, A=P_0=500$$
#
# $$P(t) = 500e^{Kt}$$
#
# find the value of K (growth rate):
#
# $$2000 = 500e^{5K}$$
#
# $$e^{5K}=4$$
#
# $$5K=ln4$$
#
# $$K=\frac{ln4}{5}$$
#
# prediction at t=24
#
# $$P(24) = 500e^{24(\frac{ln4}{5})} = 500 * ~776.046$$
#
# $$P(24) = 388023$$
#
# Final model:
#
# $$K=\frac{ln4}{5}$$ so,
#
# $$P(t) = 500e^{(\frac{ln4}{5})t}$$
# </details>

# %% [markdown]
# **Problem 44:**
#
# A city has an initial population of 10,000 that grows by 4% every year. Calculate the population of the city after 10 years.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $\frac{dp}{dt} = kP$
#
# $\frac{dp}{dt} = 0.04P$
#
# $P(t) = P_oe^{kt} -> 10000e^{(0.04)t}$
#
# $P(10) = (10000)e^{0.4}$
#
# $P(10) \approx 10000(1.492)$
#
# $P(10) \approx 14920$
#
# </details>

# %% [markdown]
# ### Sample Problem 4.2: Exponential Growth

# %% [markdown]
# **Problem 45:**
#
# A town has a population of 10,000. It grows at a constant rate of 6% per year. Write the formula for the population after t years, then find the population after 5 years.
#
# **Solution:**
#
# <details>
#
# Find the model:
#
# $P(t)=10,000(1.06)^t$
#
# Estimate for after 5 years:
#
# $P(5)=10,000(1.06)^5$
#
# Compute:
#
# $P(5)=13,380$ people
#
# </details>

# %% [markdown]
# **Problem:**
#
# A population of bacteria grows at a rate proportional to its current size. At time \(t = 0\), the culture contains 120 bacteria. After 3 hours, the culture has grown to 240 bacteria.  What is the general and particular solution given P(0) = 120 and P(3) = 240. Also, find the population after 8 hours.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1 general solution: *$\ P(t) = 120e^{kt}\$*
#
# Step 2 find k : using P(0)= 120  P(3)=240 *$\ 240 = 120e^{3k}  ,  2 = e^{3k}\ $*   take natural log  ->  *$\ln 2 = 3k\ $*  ->    *$\ k =  \frac{ln2}{3}\ $*
#
# Step 3 particular solution: plug \(k\)  into *$\ P(t)=120e^{kt}  =  P(t)=120e^{(ln2/3)t}\$*
#
# Step 4 now to find after 8 hours: *$\ (P(t)=120\cdot 2^{t/3}) , (t=8) = P(8)=120\cdot 2^{8/3}\ $*
#
# Step 5 simplify: *$\ 2^{8/3}\approx 6.3496042079\ $*  ->  *$\ P(8)\approx 120\times 6.3496042079 \approx 761.95 \$*
#
# solution: *$\ P(8)\approx 762\ \text{bacteria}\$*
#
# The bacteria population will be approximately be 762 after 8 hours.
#
# </details>

# %% [markdown]
# **Problem 46:**
#
# *![image.png](attachment:e274336b-794e-4087-8bed-5430f6eae5ca.png)*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *![image.png](attachment:8cbb8b11-a83a-4d35-bf52-3f59cffaf0af.png)*
#
# </details>

# %% [markdown]
# **Problem 47:**
#
# A small town has a population of 5,000 people. The population grows at a rate proportional to its current size. After 10 years, the population has grown to 6,000 people. Find the population in 20 years.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
#
# $P(t) = P_0 e^{kt}$
#
# $P(10) = 6000$
#
# $6000 = (5000)(e^{10k})$
#
# $\frac{6000}{5000} = e^k => 1.2 = e^{10k}$
#
# $ln(1.2) = 10k$
#
# $k = \frac{ln1.2}{10} =(about) \frac {0.1823}{10} =(about) 0.01832$ a year
#
# $P(20) = (5000)(e^{0.01832(20)}) =(about) (5000)(1.44) =(about) 7200$
#
# </details>

# %% [markdown]
# **Problem 48:**
#
# *[A city has an initial population of P0 = 20,000 people and is growing continuously at a rate of 4 percent per year. Find the population after 5 years.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[
# 1. dP/dt = 0.04P
# 2. Solve: 1/P dP = 0.04 dt
# 3. Integrate: ln|P| = 0.04t + C
# 4. Exponentiate: P = Ce^0.04t
# 5. P(0) = 20,000 = C
# 6. P(t) = 20,000e^0.04t
# 7. P(5) = 20,000e^0.04 * 5
# Solution: population = 24,428 people after 5 years
# ]*
#
# </details>

# %% [markdown]
# **Problem 49:**
#
# A population starts at 200 organisms and grows at a continuous rate of 0.03 per year. Find the population after 10 years.
#
# **Solution:**
#
# Start with the exponential growth model:
# dP/dt = kP
#
# General solution:
# P = P0 * e^(kt)
#
# Here P0 = 200 and k = 0.03.
#
# Plug in the values:
# P = 200 * e^(0.03t)
#
# Now find the population at t = 10:
# P = 200 * e^(0.3)
#
# Compute e^(0.3) ≈ 1.3499
#
# So the final value is:
# P ≈ 200 * 1.3499
# P ≈ 269.98
#
# Population after 10 years:
# P ≈ 270 organisms

# %% [markdown]
# **Problem 50:**
#
# *[A group of bacteria starts with 100 cells and grows at a rate of 5% per hour. Write the model and the population after 10 hours.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[$\frac{dP}{dt} = kP$]*
#
# *[$k = 0.05$]*
#
# *[$P(t) = P_0 e^{kt}$]*
#
# *[$P(t) = 100 e^{0.05t}$]*
#
# *[$P(10) = 100 e^{0.5}$]*
#
# *[$P(10) ≈ 164.87$]*
#
# </details>

# %% [markdown]
# **Problem 51:**
#
# $\frac{dP}{dt} = 0.07P$
#
# A population of bacteria grows according to this differential equation. What is the population after 8 minutes?
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $\frac{dP}{dt}=0.07P$
#
# $\int \frac{1}{P}=0.07dt$
#
# $ln(P)=0.07t+C$
#
# $P=Ce^{0.07t}$
#
# $120=Ce^{(0.07)(0)}$
#
# $120=C$
#
# Equation: $P=120e^{0.07t}$ (we got $k=0.074 from the original differential equation.)
#
# Plug in $t=8$: $P=120e^{(0.07)(8)}=120e^{0.56}$
#
# The population after 8 minutes is about 210.
#
#
# </details>

# %% [markdown]
# **Problem:**
#
# A colony of 5540 bacteria grows at 6.5% every hour. How long would it take for the bacteria to double in population?
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# - P=5540
# - k=0.065
# - A=?
# - T=?
#
# $2P=A$
#
# $2P=Pe^{kt}$
#
# $2=e^{kt}$
#
# $ln|2|=kt$
#
# Divide both sides by k and plug in 0.065 for k.
#
# $t=\frac{ln|2|}{0.065}$
#
# $t= ~10.66$
#
#
#
# </details>

# %% [markdown]
# **Problem:**
#
# *A bacterial culture starts with an initial population of $P_0 = 500$ cells and **doubles every 5 hours**.
# Write the exponential growth model and answer:
#
# 1. What is the population after 10 hours?
# 2. How long will it take for the population to reach 8,000 cells?*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# The exponential growth model is:
#
# $P(t) = P_0 e^{rt}$
#
# Since the population doubles every 5 hours:
#
# $P(5) = P_0 e^{5r} = 2P_0$
#
# $e^{5r} = 2$
#
# $r = \frac{\ln 2}{5}$
#
# So the model becomes:
#
# $P(t) = 500 \, e^{(\ln 2/5)t} = 500 \cdot 2^{t/5}$
#
# **1. Population after 10 hours:**
#
# $P(10) = 500 \cdot 2^{10/5}$
# $P(10) = 500 \cdot 2^2$
# $P(10) = 2000$
#
# *Answer:* $2000$ cells
#
# **2. Time to reach 8000 cells:**
#
# Solve $500 \cdot 2^{t/5} = 8000$
#
# $2^{t/5} = 16 = 2^4$
#
# $\frac{t}{5} = 4$
#
# $t = 20$
#
# *Answer:* $20$ hours
#
#
# </details>

# %% [markdown]
# **Problem 52:**
#
# *[An ant colony starts with $200$ ants. After $5$ days, the colony has grown to $300$ ants.
# Assuming the number of ants grows exponentially, find the exponential growth model and predict the number of ants after $10$ days.
# ]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[**Step 1: Write the general exponential growth formula**
#
# We use
# $$P(t) = P_0 e^{kt},$$
# where $P(t)$ is the number of ants at time $t$, $P_0$ is the initial amount, and $k$ is the growth constant.
#
# Given $P_0 = 200$, so
# $$P(t) = 200 e^{kt}.$$
#
# ---
#
# **Step 2: Use the data to find $k$**
#
# We are told that after $5$ days, $P(5) = 300$.
#
# Substitute:
# $$300 = 200 e^{5k}.$$
#
# Divide both sides by $200$:
# $$1.5 = e^{5k}.$$
#
# Take the natural log:
# $$\ln(1.5) = 5k.$$
#
# Now
# $$k = \frac{\ln(1.5)}{5}.$$
#
#
# **Step 3: Write the final model**
#
# Plug $k$ back into the formula:
# $$P(t) = 200 e^{\left(\frac{\ln(1.5)}{5}\right)t}.$$
#
# This can be written using the base $1.5$:
# $$P(t) = 200 \left(1.5^{\,t/5}\right).$$
#
# **Step 4: Predict the population at $t = 10$ hours**
#
# Compute:
# $$P(10) = 200 \cdot 1.5^{10/5}
#        = 200 \cdot 1.5^2
#        = 200 \cdot 2.25
#        = 450.$$
#
# ---
#
# **Final Answer:**
# The exponential growth model is
# $$P(t) = 200\left(1.5^{t/5}\right),$$
# and after $10$ days the colony will have approximately **$450$ ants**.
# ]*
#
# </details>

# %% [markdown]
# **Problem 53:**
# A bacterium starts with 200 cells. The population grows at a rate proportional to its size. After 3 hours, the population has doubled. Predict what the population is after 8 hours.
# **Solution:**
# 1270 cells
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# \frac{dP}{dt} = kP --> P(0) = 200 and p(3) = 400
#
# P(t) = 200e^kt
# 400 = 200e^3k
# 2 = e^3k
# ln(2) = 3k
# k = \frac{ln2}{3}
#
# P(t) = 200e^(ln2/3)t
# P(8)= 200 * 2^8/3 = 200 * 6.35 = 1270
#
# </details>

# %% [markdown]
# ### Sample Problem 4.2: Exponential Growth
#
# **Problem 54:**
#
# A bacteria culture starts with 200 bacteria and doubles every 3 hours.
# a) Find the exponential growth model
# b) How many bacteria will there be after 10 hours?
# c) When will the population reach 10,000?
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Part (a): Find the model**
# ##
# We know $P(t) = P_0 e^{kt}$ where $P_0 = 200$
# ##
# Since the population doubles every 3 hours:
# ##
# - At t = 3: P(3) = 400
# <br></br>
# Substitute into the formula:
# $$400 = 200e^{3k}$$
# ##
# $$2 = e^{3k}$$
# ##
# $$\ln(2) = 3k$$
# ##
# $$k = \frac{\ln(2)}{3} \approx 0.231$$
# ##
# Therefore: $P(t) = 200e^{0.231t}$
# <br></br>
# **Part (b): Population after 10 hours**
#
# $$P(10) = 200e^{0.231 \times 10} = 200e^{2.31}$$
# ##
# $$P(10) = 200 \times 10.07 \approx 2014$$
#
# **Part (c): When will P = 10,000?**
#
# $$10000 = 200e^{0.231t}$$
# ##
# $$50 = e^{0.231t}$$
# ##
# $$\ln(50) = 0.231t$$
# ##
# $$t = \frac{\ln(50)}{0.231} \approx \frac{3.912}{0.231} \approx 16.9 \text{ hours}$$
#
# </details>

# %%
# Parameters from our problem
P0 = 200  # initial population
k = np.log(2)/3  # growth rate

# Create time array
t = np.linspace(0, 20, 100)

# Calculate population
P = P0 * np.exp(k * t)

# Plot
plt.figure(figsize=(10, 6))
plt.plot(t, P, 'b-', linewidth=2, label='P(t) = 200e^(0.231t)')
plt.axhline(y=10000, color='r', linestyle='--', label='Target: 10,000')
plt.axvline(x=16.9, color='g', linestyle='--', label='Time to reach 10,000')
plt.scatter([3, 10], [400, 2014], color='red', s=50, zorder=5)
plt.xlabel('Time (hours)')
plt.ylabel('Number of Bacteria')
plt.title('Exponential Growth of Bacteria Culture')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# Verify calculations
print(f"Population at t=3: {P0 * np.exp(k * 3):.0f}")
print(f"Population at t=10: {P0 * np.exp(k * 10):.0f}")
print(f"Time to reach 10,000: {np.log(10000/P0)/k:.1f} hours")
# Out:
# Population at t=3: 400
# Population at t=10: 2016
# Time to reach 10,000: 16.9 hours

# %% [markdown]
# **Problem 55:**
#
# *[A population of bacteria starts at \(p(0)=1000\). After 3 hours the population has doubled to \(p(3)=2000\).
# Write the exponential growth model, find the growth constant, write the general solution, then:1. Predict the population after 5 hours,
# 2. Find how long it takes the population to reach 10,000.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Given \(P_0=1000\) and \(p(3)=2000\), plug into the solution:
# $$2000 = 1000 \, e^{3k}.$$
# Divide:
# $$2 = e^{3k}.$$
# Take natural log:
# $$\ln 2 = 3k \quad\Rightarrow\quad k = \frac{\ln 2}{3} \approx 0.231049\ \text{(per hour).}$$
#
# So the model is:
# $$\boxed{\,p(t) = 1000\,e^{(\ln 2/3)\,t}\,}$$
# or numerically \(p(t)=1000 e^{0.231049t}\).
# $$p(5)=1000 e^{(\ln 2/3)\cdot 5}
# =1000 e^{(5\ln 2)/3}.$$
# Numerical value:
# \[
# p(5)\approx 1000\cdot e^{1.155245} \approx 1000\cdot 3.1748 \approx 3174.8.
# \]
# **Answer (1):** \(\boxed{\,p(5)\approx 3175\,}\) bacteria (rounded).
# Solve \(10000 = 1000 e^{kt}\):
# $$10 = e^{kt} \quad\Rightarrow\quad \ln 10 = kt.$$
# So
# $$t = \frac{\ln 10}{k} = \frac{\ln 10}{\ln 2/3} = \frac{ \ln 10}{\ln 2}\cdot 3.$$
# Numerical value (using \(k\approx0.231049\)):
# $$t \approx \frac{2.302585}{0.231049} \approx 9.966\ \text{hours}.$$
# **Answer (2):** \(\boxed{\,t\approx 9.97\ \text{hours}\,}\)
# </details>

# %% [markdown]
# **Problem 56:**
#
# A culture of bacteria starts with 200 cells. The population grows at a continous rate of 8% per hour. Write the exponential growth equation and determine the population after 5 hours.
#
# **Solution:**
#
# ${dp}/{dt}=0.08P General soloution: P(t)=P_0e^kt Plug in the given values: P_0=200,k=0.08, P(t)=200e^0.08T Evaluating at t=5 p(5)=200e^0.4 P(5)=200(1.4918)=298.36$
#
# After 5 hours, the population is approximately 298 bacteria

# %% [markdown]
# **Problem 57:**
#
# A certain type of bacteria starts with 200 cells. The population grows at a constant proportional rate of k = 0.25 per hour. Write the exponential growth model and find the population after 2 hours.
#
# **Solution: 330 cells**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *1. We start by using the exponential growth model: $P(t) = P_0 e^{kt}$,
# and our givens $P_0 = 200$,
#  $k = 0.25$,
#  $t = 2$
#
# 2. Then we apply it to our function model and it becomes: $P(t) = 200 e^{0.25t}$
#
# 3. Then we find the population after 2 hours by plugging in 2 for t: $P(2) = 200 e^{0.5}$
#
# 4. Then the approximate value of $e^{0.5}
#  \approx 1.6487$,
# and then use the value to find our cell population,
#
# $P(2) \approx 200 \cdot 1.6487 = 329.74$
#
#
# 5. Thus, after 2 hours, the population is about **330 cells!**
#
# </details>

# %% [markdown]
# **Problem 58:**
#
# *[A bacteria culture starts with 500 bacteria cells and grows at a rate of 8% per hour. How many bacteria will there be in 10 hours?]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Step 1: follow the exponential growth equation: P(t)=P0e^(kt)
# Step 2: plug in the values for P0(500), k(0.08), t(10)
# Step 3: Simplify the numbers out and you will recieve your final answer
# Solution: After 10 hours there will be about 1,113 bacteria cells]*
#
# </details>

# %% [markdown]
# **Problem 59:**
#
# Solve the differential equation given:
#
# $\frac{dy}{dt} = 2y$, $y(0) = 3$
#
#
# **Solution:**
#
# Step 1: Separate variables
#
# $\frac{1}{y}dy = 2dt$
#
# Step 2: Integrate both sides
#
# $\int \frac{1}{y}dy$ = $\int 2dt$
#
# $ln|y|= 2t + C$
#
# Step 3: Solve for y
#
#  e^ln|y| = e^(2t+C)
#
# |y|= e^2t + C = e^C x e^2t
#
# y = Ce^2t (let C represent e^C)
#
# Step 4: Apply initial condition (ex: $y(0)= 3$)
#
# 3 = Ce^2(0) = C = 3
#
# Step 5: Finalize
#
# y(t) = 3e^2t

# %% [markdown]
# **Problem 60:**
#
# *[An investment fund has an initial value of $500 and grows exponentially at a constant rate. After 6 years the value of the fund reaches 1500. Find the value function P(t) where t is measured in years.
#
# **Solution: P(t)=500e^(ln3/6)t**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *P_0=500 and P(6)= 1500
# 1500=500e^6r
# e^6r=3
#     r=ln3/6
# If we wanted to predict the value after 10 years we would plug 1=10 into the model and after 10 years the investment would be worth about $3120*
#
# </details>

# %% [markdown]
# **Problem 61:**
#
# A bacteria culture starts with 200 cells and grows at a proportional rate to its size. After 3 hours, it has 400 cells. Find the formula P(t)
#
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:**
# - using the formula $P(t)=P(0)*e(kt)$, we know p(0) and t, so input those into our function.
#
# **Step 2:**
# - Now we have $400=200*e^{3k}$, divide both sides by 200
#
# **Step 3:**
# - ln both sides to cancel out the e: $ln(2)= ln(e^{3k})$, to get $ln(2)=3k$
#
# **Step 4:**
# - now isolate k to get our growth rate: $ln \frac{2}{3}=k$
#
# **Step 5:**
# - rewrite into our original function: $P(t)=200e^{(ln\frac{2}{3}t)}$
#
# **Solution: $P(t)=200*2^{\frac{t}{3}}$**
# </details>

# %% [markdown]
# **Problem 62:**
#
# *[A population of bacteria starts with 200 bacteria and grows at a rate proportional to its size with constant k = 0.4 per house.
# Find the exponential growth model P(t).]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[dP/dt = kP = 0.4P
#
# 1/P dP = 0.4dt
#
# Integral of 1/P dP = integral of 0.4 dt = ln |P| = 0.4t + C
#
# P(t) = Ce^0.4t
#
# Using inititial condition P(0) = 200, P(t) = 200e^0.4t meaning population after t hours]*
#
# </details>

# %% [markdown]
# ### Sample Problem 4.2: Exponential Growth

# %% [markdown]
# **Problem:**
#
# **A small town has a population of 5,000 people. The population grows at a rate of $3\%$ per year**
#
# **Step 1:** Write a function $P(t)$ that models the population $t$ years from now.
#
# **Step 2:** Find the population after 10 years.
#
# **Step 3:** Determine how long it will take for the population to double.
#
# **Step 4:** Find the population increase (segment) between year 10 and year 15.
#
# **Solution:**
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Population function:**
#
# **The formula for exponential growth is:**
#
# $$ P(t) = P_0 e^{rt} $$
#
# **where $P_0$ is the initial population, $r$ is the growth rate (as a decimal), and $t$ is time in years**
#
# $$ P_0 = 5000 and r = 0.03 $$
#
# **Thus:**
#
# $$ \boxed{P(t) = 5000 \, e^{0.03t}} $$
#
#
# **Population after 10 years:**
#
# **Substitute $t = 10$ into the population function:**
#
#
# $$ P(10) = 5000e^{0.03 \cdot 10} = 5000e^{0.3(10)} $$
#
#
#
# $$ $P(10) \approx 5000 \cdot 1.34986 = 6749.3 $$
#
#
# **So the population after 10 years is approximately:**
#
# $$ \boxed{P(10) \approx 6750 \text{ people}} $$
#
#
# **Time to double the population:**
#
# **Doubling means the population reaches:**
#
#
# $$ 2P_0 = 2 \cdot 5000 = 10000 $$
#
#
# **Set the population function equal to 10,000:**
#
# $$ 10000 = 5000 \, e^{0.03 t} $$
#
# **Solve for $t$ by:**
#
# **Divide both sides by 5000:**
#
# $$ 2 = e^{0.03 t} $$
#
# **Take the natural logarithm:**
#
# $$ ln 2 = 0.03 t $$
#
#
# **And now solve for $t$:**
#
#
# $$ t = \frac{\ln 2}{0.03} \approx \frac{0.6931}{0.03} \approx 23.1 \text{ years} $$
#
#
# **So it will take approximately:**
#
# $$ \boxed{t \approx 23.1 \text{ years}} $$
#
#
# **Population increase (segment) between year $(10)$ and year $(15)$:**
#
# **First, find $P(15)$:**
#
#
# $$ P(15) = 5000 \, e^{0.03 \cdot 15} = 5000 \, e^{0.45} $$
#
# **Using approximation** $$ e^{0.45} \approx 1.5683 $$:
#
#
# $$ P(15) \approx 5000 \cdot 1.5683 = 7841.5 $$
#
#
# **Population increase between year $(10)$ and $(15)$:**
#
#
# $$ \Delta P = P(15) - P(10) \approx 7841.5 - 6749.3 = 1092.2 $$
#
#
# **So the population increases by approximately:**
#
# $$ \boxed {P \approx 1092 \text{ people}} $$

# %% [markdown]
# **Problem 63:**
#
# *Bacteria culture starts with N(0)=500 bacteria. After 3 hours there are 2000 bacteria. Aussume the population follows the exponential growth model: $\frac{dP}{dt} = kP$. Find the growth constant, explicit formula, the population after 8 hours and the doubling time.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# - General Solution: $\frac{dP}{P} = k dt$ so $ln|P| = kt + C$ then $P(t) = Ae^kt$ so $P(t)=N_0 e^kt$
# - Find k: $2000 = 500e^3k$ = $4=e^3k$ so $k=\frac{ln4}{3}$ so $k=.462 ish$
# - Explicit Formula: $P(t)=500e^.462$
# - Population 8 hours: $P(8)=500e^{k*8}$ so $P(8)=20,158.74$
# - Doubling time: $t_double = \frac{ln2}{k}$ so $t_double = \frac{ln2}{(2ln2)/3} = 1.5 hours$
#
# </details>

# %% [markdown]
# **Problem 64:**
#
# A savings account has $600 in it and grows at 7% interest per year. Write the exponential growth equation and find the amount in the account after 10 years.
# **Solution:**
# Dp/dt= .07p
# P(t)=Poe^kt
# 600e^.07t
# P(10)=600e^.7
# P=1208.25 dollars

# %% [markdown]
# **Problem 65:**
#
# Suppose an investment of $11,000 has an annual rate of 4.3%, compounded continuously. What is the value of the account after 21 years?
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $A=11,000e^(0.043(21))$
#
# $A=11,000e^(0.903)$
#
# $11,0002.4669929998$
#
# $27,136.92$
#
# Solution: $27,136.92$
#
#
# </details>

# %% [markdown]
# **Problem 66:**
#
# *A population at t=0 numbered 100. At t=50, P = 200*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
#
#
# $P=Ce^{kt}$
#
# $100 = Ce^{k(0)}$
#
# $100=Ce^{0}$
#
# $100=C$
#
# $P=100e^{kt}$
#
# $200 = 100e^{k(50)}$
#
# $\frac{200}{100} = \frac{100e^{k(50)}}{100}$
#
# $2=e^{50k}$
#
# $ln|2| = 50k$
#
# $\frac{ln|2|}{50} = k$
#
# $P(t) = 100e^{\frac{ln|2|}{50}(t)}$
#
# $P(50) = 100e^{(\ln 2/50)\cdot 50} = 100e^{\ln 2} = 100\cdot 2 = 200$
# </details>

# %% [markdown]
# **Problem 67:**
#
# *An investment account grows continuously at a rate of 5% per year. You deposit an initial principal of $1,000.
# 1. Write the differential equation and the function $A(t)$ for the amount in the account.
# 2. How much money will be in the account after 10 years?*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *
# 1.
# - Growth rate $k = 0.05$. Initial value $P_0 = 1000$.
# - Differential Equation: $\frac{dA}{dt} = 0.05A$
# - Function Solution: $A(t) = 1000e^{0.05t}$2.
# 2. Value at $t = 10$
# - Substitute $t = 10$:$$A(10) = 1000e^{0.05(10)}$$$$A(10) = 1000e^{0.5}$$
# - Using a calculator: $e^{0.5} \approx 1.6487$$$A(10) \approx \$1,648.72$$*
#
# </details>

# %% [markdown]
# **Problem 68:**
#
# A population of bacteria starts with 500 cells and grows at a rate proportional to its size. After 4 hours, the population reaches 1,000 cells. Find the formula for P(t), the population after t hours.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# P(t) = P0e^kt
# P0 = 500
# 1000 = 500e^4k --> 2 = e^4k
# ln 2 = 4k --> ln 2/4
#
# P(t) = 500e^(ln2/4)t
# </details>

# %% [markdown]
# **Problem 69:**
#
# *$\frac{dP}{dt} = 0.5P, P(0) = 100$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *First we use our knowledge of seperable differential equations to get $ln[P] = 0.5t + C$. then we exponentiate both sides to get rid of the log function and end up with P = e^(0.5t + C) which we can then rewrite as Ae^0.5t where A is an arbitrary constant. finally we plug in the fact that at $t = 0$ we have $P = 100$ to get $100 = Ae^0$ rewritten as $100 = A(1)$ or $A = 100$. Once we have this we can plug the A back into our equation to get the exponential growth formula of P(t) = 100e^(0.5t) as our population formula.*
#
# </details>

# %% [markdown]
# **Problem:**
#
# There's a culture of bacteria with only 100 cells. However, in three hours, it's population has grown to 400 cells. Calculate the bacterial after 10 hours.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# First, we have to find k with our given data. The initial amount of bacteria is 100 at t = 0 and 400 at t = 3.
#
# 400 = 100e^k(3)
#
# Next, we work towards isolating e by dividing by 100
#
# 4 = e^3(k)
#
# We can then take natural log of both sides
#
# ln(4) = 3k
#
# Finally, we can isolate k by dividing by 3
#
# ln(4)/3 = k
#
# This makes k approximately .46
#
# We can now plug in these values to solve for 10 hours
#
# y(10) = 100e^(.46)(10)
#
# This comes out to about 9948 cells after 10 hours
#
#
#
# </details>

# %% [markdown]
# **Problem 70:**
#
# *[There are 500 bacteria initially. After 3 hours, the population has grown to 2000 bacteria. How much bacteria will there be after 5 hours? ]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[We are given P(0)=500, P(3)=2000.
# 1. We set up our equation. P(t)=500e^kt
# 2. we plug in out p(3)=2000; 2000=500e^3k --> e^3k=2000/500=4; 3k=ln4 ---> k=ln4/3=0.4621
# 3. We plug in our k and our P(5); P(5)=500e^(0.4621*5)=5040]
# We are able to say that after 5 hours, the population grew to 5040 bacteria. *
#
# </details>

# %% [markdown]
# **Problem 71:**
#
# *A bacteria culture starts with 500 bacteria and grows to 800 after 3 hours. Find the population after 7 hours.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# 1. Solve for k
# - $800 = 500e^{3k}$
# - $\frac{800}{500} = e^{3k}$ -> $1.6 = e^{3k}$
# - $ln(1.6) = e^{3k}$ -> $k = \frac{ln(1.6)}{3} = \frac{0.47}{3} = 0.157$
# - $k = 0.157$
# 2. Rewrite equation
# - $P(t) = 500e^{0.157t}$
# 3. Predict population after 7 hours
# - $P(7) = 500e^{0.157(7)}$
# - $0.157 * 7 = 1.099$ -> $P(7) = 500e^{1.099} = 1500.58168$
# - $P(7) = 1500.58$
#
# </details>

# %% [markdown]
# ### Sample Problem 4.2: Exponential Growth
#
# **Problem 72:**
#
# A bacteria culture starts with a population of 200 bacteria. After 3 hours, the population has grown to 500 bacteria.
# Assume the population grows exponentially.
#
# 1. Find the exponential growth model in the form
#    $$P(t) = P_{0}e^{kt}$$
# 2. Predict the population after 6 hours.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# We are given:
#
# - Initial population: $P_{0} = 200$
# - Population at $t = 3$: $P(3) = 500$
#
# Start with the model
# $$P(t) = P_{0}e^{kt}$$
#
# Plug in $t = 3$ and $P(3) = 500$:
# $$500 = 200e^{3k}$$
#
# Divide both sides by 200:
# $$2.5 = e^{3k}$$
#
# Take the natural log of both sides:
# $$\ln(2.5) = 3k$$
#
# Solve for $k$:
# $$k = \frac{\ln(2.5)}{3}$$
#
# So the growth model is
# $$P(t) = 200e^{(\frac{\ln(2.5)}{3})t}$$
#
# To find the population at $t = 6$:
#
# $$P(6) = 200e^{(\frac{\ln(2.5)}{3})\cdot 6}$$
#
# Simplify the exponent:
# $$P(6) = 200e^{2\ln(2.5)}$$
#
# Use $e^{2\ln(2.5)} = (e^{\ln(2.5)})^{2} = (2.5)^{2} = 6.25$
#
# So:
# $$P(6) = 200 \cdot 6.25 = 1250$$
#
# After 6 hours, the population is approximately 1250 bacteria.
#
# </details>

# %% [markdown]
# **Problem 73:**
#
# *A small tech startup has 120 users on day t=0
# The user base grows at a rate proportional to its size, and after 5 days the startup has 180 users.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *dP/dt= kP
# Initial value:
# P(0)=120
# Data point:
# P(5)=180
# P(t)=120e**kt
# Plug in t=5: 180=120e5k
# Divide:
# 180/120=e**5k   1.5=e**5k
# Take ln:
# ln(1.5)=5k
# k= ln(1.5)/5
# Final model: P(t)=120e(ln(1.5)/5)t
# Prediction after 10 days:P(10)=120e(ln(1.5)/5)10
# Simplify exponent:10/5ln(1.5)=2ln⁡(1.5)
# So:P(10)=120(1.5)**2=120×2.25=270
#
#
# </details>
