# %% [markdown]
# **Problem 1:**
#
# $f(x, y) = 4x^3 + 7x^2y^5 - 9y^2$.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# $$f_x = \frac{\partial}{\partial x}(4x^3) + \frac{\partial}{\partial x}(7x^2y^5) - \frac{\partial}{\partial x}(9y^2)$$
#
# $$\mathbf{f_x = 12x^2 + 14xy^5}$$
#
# **Finding $f_y$:**
#
# $$f_y = \frac{\partial}{\partial y}(4x^3) + \frac{\partial}{\partial y}(7x^2y^5) - \frac{\partial}{\partial y}(9y^2)$$
#
# $$\mathbf{f_y = 35x^2y^4 - 18y}$$
#
# </details>

# %% [markdown]
# **Problem:**
#
# *Let $f(x,y) = 3x^2y^3 - 4x +2y^2$. Find the partial derivatives $f_x$ (x,y) and $f_y$ (x,y).*
#
# **Solution:**
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# Differentiate with respect to $x$.
#
# - Treat $y$ as a constant.
# - Term 1 $(3x^2y^3): 3y^3$ is a constant coefficient. Derivative of $x^2$ is $2x$. Result: $(3y^3)(2x) = 6xy^3$
# - Term 2 $(-4x)$: Derivative is $-4$
# - Term 3 $(2y^2)$: This term has no $x$, so it is a constant. Derivative is $0$.
#
# $f_x (x,y)$ = $6xy^3 - 4$
#
# **Finding $f_y$:**
#
# Differentiate with respect to $y$.
#
# - Treat $x$ as a constant.
# - Term 1 $(3x^2y^3): 3x^2$ is a constant coefficient. Derivative of $y^3 is 3y^2$. Results: $(3x^2)(3y^2) = 9x^2y^2$
# - Term 2 $(-4x)$: This term has no $y$, so it is a constant. Derivative is $0$.
# - Term 3 $(2y^2)$: Derivative of $y^2$ is $2y$. Result: $2(2y) = 4y$
#
# $f_y (x,y) = 9x^2y^2 + 4y$
#
#
# </details>

# %% [markdown]
# **Problem 2:**
#
# Find $f_x$ and $f_y$ for the function: $$f(x,y) = 4x^2 + xy + 8y^3$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# Derive with respect to $x$(treat $y$ as constant)
#
# $f_x = 8x + (1)y + 0$
#
# $$\boxed{f_x = 8x + y}$$
#
# **Finding $f_y$:**
#
# Derive with respect to $y$(treat $x$ as constant)
#
# $f_y = 0 + (1)x + 24y^2$
#
# $$\boxed{f_y = x + 24y^2}$$
#
# </details>

# %% [markdown]
# Problem 3:
#
# Let $f(x, y) = 3x^2 + 5xy - 4y$. Find the partial derivatives $f_x$ and $f_y$.
#
# Solution:
#
# Click to reveal solution
#
# Finding $f_x$ :
#
# Treat y as a constant.
# $f(x, y) = 3x^2 + 5xy - 4y$
#
# Derivative with respect to x:
# $f_x = 6x + 5y$
#
# Finding $f_y$ :
#
# Treat x as a constant.
# $f(x, y) = 3x^2 + 5xy - 4y$
#
# Derivative with respect to y:
# $f_y = 5x - 4$

# %% [markdown]
# **Problem 4:**
#
# * $$ f(x,y) = x^2y+3xy^2-5y^3 $$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[Show work, treating y as constant]*
# $$ x^2y --> 2xy $$
#
# $$ 3xy^2 --> 3y^2 $$
#
# $$ -5y^3 --> 0 $$
#
#
# $$ f(x) = 2xy + 3y^2 $$
#
# **Finding $f_y$:**
#
# *[Show work, treating x as constant]*
#
# $$ x^2y --> x^2 $$
#
# $$ 3xy^2 --> 6xy $$
#
# $$ -5y^3 --> -15y^2 $$
#
# $$ f(y) = x^2 + 6xy -15y^2 $$
# </details>

# %% [markdown]
# **Problem 5:**
#
# *Given $f(x,y) = 10x^2 - 3xy + 4y^2 - 6x + 2y - 4$, find $\frac{\partial f}{\partial x}$ & $\frac{\partial f}{\partial y}$.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *$f_x = 20x - 3y + 0 - 6 + 0 - 0$*
#
# *$f_x = 20x - 3y - 6$*
#
# **Finding $f_y$:**
#
# *$f_y = 0 - 3x + 8y - 0 + 2 - 0$*
#
# *$f_y = - 3x + 8y + 2$*
#
# </details>

# %% [markdown]
# **Problem 6:**
#
# *[$f(x,y) = x^3 y^2 + 2xy - 5y^3$]*
#
# **Solution:** [$∂𝑓/∂x = 3x^2 y^2 + 2y$] and [$∂f/∂y = 2x^3 y + 2x - 15y^2$]
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[$f_x = 3x^2 y^2 + 2y$]*
#
# **Finding $f_y$:**
#
# *[$f_y = 2x^3 y + 2x - 15y^2$]*
#
# </details>

# %% [markdown]
# **Problem:**
#
# *Let \(f(x,y) = x^2y + 4x\).
# Find the partial derivatives \(f_x\) and \(f_y\).*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# **Finding \(f_x\):**
#
# *Treat \(y\) as constant.*
#
# \[
# f(x,y) = x^2y + 4x
# \]
#
# Differentiate with respect to \(x\):
#
# \[
# f_x = 2xy + 4
# \]
#
# ---
#
# **Finding \(f_y\):**
#
# *Treat \(x\) as constant.*
#
# \[
# f(x,y) = x^2y + 4x
# \]
#
# Differentiate with respect to \(y\):
#
# \[
# f_y = x^2
# \]
#
# </details>

# %% [markdown]
# **Problem 7:**
#
# *def f(x, y):
#     return x**2 * y + 3 * x * y**2*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *f = x**2 * y + 3 * x * y**2
# Derivative of x^2 * y w.r.t x: 2*x*y
# Derivative of 3 * x * y^2 w.r.t x: 3*y^2
# = 2*x*y + 3*y**2*
#
# **Finding $f_y$:**
#
# *f = x^2 * y + 3 * x * y^2
# Derivative of x^2 * y w.r.t y: x^2
# Derivative of 3 * x * y^2 w.r.t y: 6*x*y*
#
# </details>

# %% [markdown]
# **Problem 8:**
#
# f(x,y)=x^2 +3y
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# 2x+0=2x
#
# **Finding $f_y$:**
#
# 0+3=3
#
# </details>

# %% [markdown]
# **Problem 9:**
# Let f(x,y) = 3x^2 y + 4y^3	compute the partial derivatives fx, fy
#
# **Solution:**
#
# **Finding $f_x$:**
#
# fx (treat y as a constant and differentiate with respect to x)
# 				fx = ∂/∂x (3x^2 (y) + 4y^3)
# Derivative of 3x^2 y is 6xy
#
# Derivative of 4y^3 is 0
# fx = 6xy
#
#
# **Finding $f_y$:**
#
# fy (treat x as a constant and differentiate with respect to y)
# 				fy = ∂/∂y (3x^2 (y) + 4y^3)
#
# Derivative of 3x^2 y is 3x^2
#
# Derivative of 4y^3 is 12y^2
#
# f(y) = 3x^2 + 12y^2
# </details>

# %% [markdown]
# **Problem 10:**
#
# Find partial derivatives $f_x$ and $f_y$ for $f(x,y) = 3x^2y + 5xy^3$.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# $3x^2y$ becomes $6xy$
#
# $5xy^3$ becomes $5y^3$
#
# $f_x = 6xy + 5y^3$
#
# **Finding $f_y$:**
#
# $3x^2y$ becomes $3x^2$
#
# $5xy^3$ becomes $15xy^2$
#
# $f_y = 3x^2 + 15xy^2$
#
# </details>

# %% [markdown]
# **Problem 11:**
#
# *Find both first partial derivatives of the function: $f(x, y) = 3x^2y + 4xy^3 - 2x + 5y$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *$f_x = \frac{\partial}{\partial x}(3x^2y) + \frac{\partial}{\partial x}(4xy^3) - \frac{\partial}{\partial x}(2x) + \frac{\partial}{\partial x}(5y)$
# $f_x = 6xy + 4y^3 - 2 + 0$
# $f_x = 6xy + 4y^3 - 2$*
#
# **Finding $f_y$:**
#
# *$f_y = \frac{\partial}{\partial y}(3x^2y) + \frac{\partial}{\partial y}(4xy^3) - \frac{\partial}{\partial y}(2x) + \frac{\partial}{\partial y}(5y)$
# $f_y = 3x^2 + 12xy^2 - 0 + 5$
# $f_y = 3x^2 + 12xy^2 + 5$*
#
# </details>

# %% [markdown]
# **Problem 12:**
#
# Let
# $
# f(x, y) = 4x^3y + 7xy^2 - 5y.
# $
#
# Find the partial derivatives:
#
# 1. $(f_x(x, y))$
# 2. $(f_y(x, y))$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# Treat **$(y)$ as a constant**.
#
# $
# f(x, y) = 4x^3y + 7xy^2 - 5y
# $
#
# Differentiate term-by-term with respect to $(x)$:
#
# - $4x^3y \rightarrow 12x^2y$
# - $7xy^2 \rightarrow 7y^2$
# - $-5y \rightarrow 0$ (constant w/ respect to $(x)$)
#
# $
# \boxed{f_x = 12x^2y + 7y^2}
# $
#
#
# **Finding $f_y$:**
#
# Treat **$(x)$ as a constant**.
#
# $
# f(x, y) = 4x^3y + 7xy^2 - 5y
# $
#
# Differentiate term-by-term with respect to $(y)$:
#
# - $4x^3y \rightarrow 4x^3$
# - $7xy^2 \rightarrow 14xy$
# - $-5y \rightarrow -5$
#
# $
# \boxed{f_y = 4x^3 + 14xy - 5}
# $
#
# </details>

# %% [markdown]
# **Problem:**
#
# **f(x,y)=3x^2y+4xy^3**
#
# **Solution:f_x=6xy+4y^3, f_y=3x^2+12xy^2**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *3x**2 becomes 6xy*
# *4xy**3 becomes 4y**3*
# *f_x=6xy+4y**3*
# **Finding $f_y$:**
#
# *3x**2 becomes 3x**2*
# *4xy**3 becomes 12xy**2*
# *f_y=3x**2+12xy**2*
#
# </details>

# %% [markdown]
# **Problem 13:**
#
# *$f(x, y) = 3x^4 y^3 - 7x + y^5$. Find $f_x$ and $f_y$.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *$$\frac{\partial}{\partial x} \left(3x^4 y^3 - 7x + y^5\right)$$
# $$3y^3 \cdot (4x^3)$$ $$-7$$ $$+ 0$$
# $$f_x = 12x^3 y^3 - 7$$*
#
# **Finding $f_y$:**
#
# *$$\frac{\partial}{\partial y} \left(3x^4 y^3 - 7x + y^5\right)$$
# $$3x^4 \cdot (3y^2)$$ $$- 0$$ $$+ 5y^4$$
# $$f_y = 9x^4 y^2 + 5y^4$$*
#
# </details>

# %% [markdown]
# **Problem 14:**
#
# f(x,y) = $3x^2y+ 5x sin(y)$
#
# find $f_x and f_y$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# $f_x = \frac{\partial }{\partial x}$ ($3x^2y+ 5x sin(y)$) = 6xy+5sin(y)
#
# **Finding $f_y$:**
#
# $f_y = \frac{\partial }{\partial y}$ ($3x^2y+ 5x sin(y)$) = $3x^2 + 5x cos (y)$
#
# </details>

# %% [markdown]
# **Problem 15:**
#
# *Let $f(x,y) = 3x^2y + 4xy^3$.
# Find the partial derivatives $f_x$ and $f_y$.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Finding $f_x$:
#
# *** Treat $y$ as a constant.
# $\frac{\partial}{\partial x}(3x^2y) = 6xy$ and $\frac{\partial}{\partial x}(4xy^3) = 4y^3$,
# so $f_x = 6xy + 4y^3$.*
#
# **Finding $f_y$:**
#
# *Treat $x$ as a constant.
# $\frac{\partial}{\partial y}(3x^2y) = 3x^2$ and $\frac{\partial}{\partial y}(4xy^3) = 12xy^2$,
# so $f_y = 3x^2 + 12xy^2$.*
#
# </details>

# %% [markdown]
# **Problem 16:**
#
# Let $f(x,y) = 3x^2y - 4y^3 + 5x$
# - Compute
# -(a) $f_x (x,y)$
# -(b) $f_y (x,y)$
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# - (a) Compute $f_x$
# - Differeniate with respect to x: $f_x = 6xy + 5$
#
# **Finding $f_y$:**
#
# - (b) Compute $f_y$
# - Differentiate with respect to  y: $f_y = 3x^2 - 12y^2$
#
# </details>

# %% [markdown]
# **Problem 17:**
#
# *Find $f_x$ and $f_y$*  for $f(x,y)=3x^2y+5y$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *$f_x$: $6xy+0$*
#
# **Finding $f_y$:**
#
# *$f_y$:$3x^2+5$*
#
# </details>

# %% [markdown]
# **Problem:**
#
# Given f(x,y)= (4x^2)+6x-(2y^5)+7y, find fx and fy
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
# Differentate x treating y as a constant:
# 4x^2=8x
# 6x=6
# -2y^5=0
# 7y=0
# fx=8x+6
#
# **Finding $f_y$:**
# Differentiate y treating x as a constant:
# 4x^2=0
# 6x=0
# -2y^5=-10y^4
# 7y=7
# fy=-10y^4+7

# %% [markdown]
# **Problem 18:**
#
# *Let the function be*
# $$
# f(x,y) = x^2y + 3xy^2 - 4y.
# $$
# *Find the partial derivatives $f_x(x,y)$ and $f_y(x,y)$.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding \(f_x\):**
#
# *Treat \(y\) as a constant and differentiate with respect to \(x\).*
#
# We have
# $$
# f(x,y) = x^2y + 3xy^2 - 4y.
# $$
#
# Differentiate term-by-term with respect to \(x\):
#
# - $\dfrac{\partial}{\partial x}(x^2y) = 2xy$  (power rule, \(y\) is constant),
# - $\dfrac{\partial}{\partial x}(3xy^2) = 3y^2$  (since \(3y^2\) is a constant multiple of \(x\)),
# - $\dfrac{\partial}{\partial x}(-4y) = 0$  (no \(x\) in this term).
#
# So
# $$
# f_x(x,y) = 2xy + 3y^2.
# $$
#
# **Finding \(f_y\):**
#
# *Now treat \(x\) as a constant and differentiate with respect to \(y\).*
#
# Again start from
# $$
# f(x,y) = x^2y + 3xy^2 - 4y.
# $$
#
# Differentiate term-by-term with respect to \(y\):
#
# - $\dfrac{\partial}{\partial y}(x^2y) = x^2$,
# - $\dfrac{\partial}{\partial y}(3xy^2) = 6xy$,
# - $\dfrac{\partial}{\partial y}(-4y) = -4$.
#
# so
# $$
# f_y(x,y) = x^2 + 6xy - 4.
# $$
#
# </details>

# %% [markdown]
# **Problem 19:**
#
# * $h(x,y) = 3x^2y+ 4y^3$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# * $(3x^2y+ 4y^3)= 6xy + 0 = 6xy$
#
# **Finding $f_y$:**
#
# * $(3x^2y + 4^3) = 3x^2 +12y^2$
#
# </details>

# %% [markdown]
# **Problem 20:**
#
# Let $f(x,y) = x^2y + 3xy^2 - 4y$.
#
# Find the partial derivatives $f_x(x,y)$ and $f_y(x,y)$.
#
# ---
#
# Solution:
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Finding $f_x$:
#
# Start with
# $$f(x,y) = x^2y + 3xy^2 - 4y.$$
#
# To compute $f_x$, treat $y$ as a constant.
#
# - $\dfrac{\partial}{\partial x}(x^2y) = 2xy$ (power rule on $x^2$, $y$ is constant)
# - $\dfrac{\partial}{\partial x}(3xy^2) = 3y^2$ (since $3y^2$ is a constant multiple of $x$)
# - $\dfrac{\partial}{\partial x}(-4y) = 0$ (no $x$ in this term)
#
# So
# $$f_x(x,y) = 2xy + 3y^2.$$
#
# ---
#
# Finding $f_y$:
#
# Now treat $x$ as a constant.
#
# - $\dfrac{\partial}{\partial y}(x^2y) = x^2$ (since $x^2$ is constant and derivative of $y$ is $1$)
# - $\dfrac{\partial}{\partial y}(3xy^2) = 6xy$ (power rule on $y^2$)
# - $\dfrac{\partial}{\partial y}(-4y) = -4$
#
# Therefore
# $$f_y(x,y) = x^2 + 6xy - 4.$$
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[g(x,y)=e^xy+x^2y, find gx, gy]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[d/dx(e^xy)=ye^xy, d/dx(x^2y)=2xy, gx=ye^xy+2xy]*
#
# **Finding $f_y$:**
#
# *[d/dy(e^xy)=xe^xy, d/dy(x^2y)=x^2, gy=xe^xy+x^2]*
#
# </details>

# %% [markdown]
# **Problem 21:** $f (x,y) = 2x^2y + 5y^3$
#
#
# *[Give a function and ask for two partial derivatives]*
#
# **Solution:**
#
# $f_x =4xy$
#
# $f_y = 2x^2 +15y^2$
#
#
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[Show work, treating y as constant]*
#
# $f (x,y) = 2x^2y + 5y^3$
#
# $2x^2y → 4xy$
#
# $5y^3 → 0 (y is treated as a constant)$
#
# $f_x =4xy$
#
#
# **Finding $f_y$:**
#
# *[Show work, treating x as constant]*
#
# $f (x,y) = 2x^2y + 5y^3 $
#
# $2x^2y → 2x^2$
#
# $5y^3 → 15y^2$
#
# $f_y = 2x^2 +15y^2$
#
#
# </details>

# %% [markdown]
# **Problem 22:**
#
# Given $f(x,y)=4x^2y+3y^2$ find $f_x=\frac{∂f}{∂x}$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# $f_x=\frac{∂f}{∂x}$
# treat y as a constant
# $\frac{∂}{∂x}(4x^2y)=4y*2x=8xy$
# $f_x=8xy$
#
# **Finding $f_y$:**
#
# $f_y=\frac{∂f}{∂y}$
# treat x as a constant
# $\frac{∂}{∂y}(4x^2y+3y^2)=4x^2+6y$
# $f_y=4x^2+6y$
#
# </details>

# %% [markdown]
# **Problem 23:**
#
# *[Find the partial derivatives fx and fy for the function f(x,y)=3x^2y+5y^3]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# $$f(x,y) = 3x^2y + 5y^3$$
#
# $$\text{Finding } f_x \text{ (treat y as constant):}$$
#
# $$f_x = \frac{\partial}{\partial x}(3x^2y) + \frac{\partial}{\partial x}(5y^3)$$
#
# $$f_x = 6xy + 0$$
#
# $$f_x = 6xy$$
#
# **Finding $f_y$:**
#
# $$\text{Finding } f_y \text{ (treat x as constant):}$$
#
# $$f_y = \frac{\partial}{\partial y}(3x^2y) + \frac{\partial}{\partial y}(5y^3)$$
#
# $$f_y = 3x^2 + 15y^2$$
#
# </details>

# %% [markdown]
# **Problem 24:**
#
# $d(x,y)=x^4y^3+7xe^{2y}-\frac{9}{x^2}$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# Take partial derivative of $f(x,y)$ with respect to $x$, treating $y$ as a constant.
#
# $f_x(x,y)=\frac{\partial}{\partial x}(x^4y^3+7xe^{2y}-9x{-2})$
#
# **Term 1** $x^4y^3$ = $(4x^3)y^3$
#
# **Term 2** $7xe^{2y}$ = $7e^{2y}$
#
# **Term 3** $-9x^{-2}$ = $18x^{-3}$
#
# **Together** $f_x(x,y)=4x^3y^3+7e^{2y}+18x{-3}$
#
#
# **Finding $f_y$:**
#
# Take partial derivative of $f(x,y)$ with respect to $y$, treating $x$ as a constant.
#
# $f_y(x,y)=\frac{\partial}{\partial x}(x^4y^3+7xe^{2y}-9x{-2})$
#
# **Term 1** $x^4y^3$ = $x^4(3y^2)$
#
# **Term 2** $7xe^{2y}$ = Apply chain rule $\frac{d}{dy}e^u=e^u*\frac{du}{dy}$ = $7x*e^{2y}*2$
#
# **Term 3** $-9x^{-2}$ = $0$
#
# **Together** $f_y(x,y)=3x^4y^2+14xe^{2y}$
#
# </details>

# %% [markdown]
# **Problem 25:**
#
# *Find the partial derivative of x and y for the function $f(x,y) = 3x^2y +4y^3$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *$f(x,y) = 3x^2y +4y^3$*
#
# *Using the power rule for $3x^2$ we get $6x$ but y is a constant so it remains which gives us $6xy$*
#
# *Since we are treating y as a constant $4y^3$ just becomes $0$*
#
# *So the partial derivative with respect to x would be: $6xy$*
#
# **Finding $f_y$:**
#
# *Now we treat x as a constant and the first term just becomes $3x^2$ (Constant rule)*
#
# *We apply the power rule on $4y^3$ and get $12y^2$*
#
# *We combine this all together to get: $3x^2 + 12y^2$*
#
#
# </details>

# %% [markdown]
# **Problem 26:**
#
# Let $f(x,y) = x^{2} + 3y$.
#
# Find:
#
# $f_x$
#
# $f_y$
#
# Solution:
# <details> <summary><b>Click to reveal solution</b></summary>
# Finding $f_x$:
#
# Differentiate with respect to $x$, treating $y$ as a constant:
#
# $f(x,y) = x^{2} + 3y$
#
# $\dfrac{\partial}{\partial x}(x^{2}) = 2x$
# $\dfrac{\partial}{\partial x}(3y) = 0$
#
# So:
#
# $f_x = 2x$
#
# Finding $f_y$:
#
# Differentiate with respect to $y$, treating $x$ as a constant:
#
# $f(x,y) = x^{2} + 3y$
#
# $\dfrac{\partial}{\partial y}(x^{2}) = 0$
# $\dfrac{\partial}{\partial y}(3y) = 3$
#
# So:
#
# $f_y = 3$
#
# Final Answer:
# $f_x = 2x$
# $f_y = 3$
#
# </details>

# %% [markdown]
# **Problem 27:**
# Let
# $f(x, y) = 4x^2y + 3xy^3 - 5y$
# Find the partial derivatives \(f_x\) and \(f_y\).
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
# Differentiate term-by-term with respect to \(x\):
# - \(4x^2y \rightarrow 8xy\)
# - \(3xy^3 \rightarrow 3y^3\)
# - \(-5y \rightarrow 0\) (constant in \(x\))
# So:
# $f_x = 8xy + 3y^3$
#
# **Finding $f_y$:**
# Differentiate term-by-term with respect to \(y\):
# - \(4x^2y \rightarrow 4x^2\)
# - \(3xy^3 \rightarrow 9xy^2\)
# - \(-5y \rightarrow -5\)
# So:
# $f_y = 4x^2 + 9xy^2 - 5$
#
# </details>

# %% [markdown]
# **Problem 28:**
#
# *Consider the function: \
# $f(x, y) = 3x^2y + 4xy^2 + 5y$ \
# 1. Find the partial derivative of (f) with respect to (x)
# 2. Find the partial derivative of (f) with respect to (y)
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**\
# Treat (y) as a constant:\
# $f_x = \frac{\partial}{\partial x}(3x^2y + 4xy^2 + 5y) = 6xy + 4y^2 + 0 = 6xy + 4y^2$
#
#
# **Finding $f_y$:**\
# Treat (x) as a constant:\
# $f_y = \frac{\partial}{\partial y}(3x^2y + 4xy^2 + 5y) = 3x^2 + 8xy + 5$\
#
# Final Answer:\
# $f_x = 6xy + 4y^2, \quad f_y = 3x^2 + 8xy + 5$
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Let f(x, y) = x^2y + 4x*y^2. Find ∂f/∂x and ∂f/∂y.]*
#
# **Solution:
#
# ∂f/∂x = 2xy + 4*y^2
#
# ∂f/∂y = x^2 + 8x*y
#     **
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:
#     Treat y as constant.
#
# Derivative of x^2y with respect to x: 2xy
#
# Derivative of 4xy^2 with respect to x: 4y^2
#
# So ∂f/∂x = 2xy + 4*y^2
# **
#
# *[Show work, treating y as constant]*
#
# **Finding $f_y$:
#         Treat x as constant.
#
# Derivative of x^2y with respect to y: x^2
#
# Derivative of 4xy^2 with respect to y: 8xy
#
# So ∂f/∂y = x^2 + 8x*y **
#
# *[Show work, treating x as constant]*
#
# </details>

# %% [markdown]
# **Problem 29:**
#
# Find the partial derivatives of this function.
# $$f=(6x+13y)^{13}$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# Step 1) Identifying the chain rule and using u-sub. (not applicable for all problems)
#
# $$ u= 6x + 31y$$ and $$v(u)= u^{13}$$
# $$f= v(u)$$
#
# $$ so, \frac{\partial f}{\partial x} = v'(u) (\frac{\partial u}{\partial x})$$
#
# Step 2) Solve for $v'(u)$ and derivatives
#
# $$v'(u)= 13u^{12}=13(6x+31)^{12}$$
# - Treat y as a constant $$\frac{\partial u}{\partial x}=\frac{\partial}{\partial x}(6x+31y)= 6$$
#
# Step 3) Multiply it all together
#
# $$\frac{\partial f}{\partial x}= 13(6x+31y)^{12} (6)$$
# $$=78(6x+31y)^{12}$$
#
#
# **Finding $f_y$:**
#
# Step 1) Identifying the chain rule and using u-sub. (not applicable for all problems)
#
# $$ u= 6x + 31y$$ and $$v(u)= u^{13}$$
# $$f= v(u)$$
#
# $$ so, \frac{\partial f}{\partial y} = v'(v)(\frac{\partial f}{\partial y})$$
#
# Step 2) Solve for $v'(u)$ and derivatives
#
# $$v'(u)= 13u^{12}=13(6x+31)^{12}$$
# - Treat x as a constant $$\frac{\partial u}{\partial y}= 31$$
#
# Step 3) Multiply it all together
#
# $$\frac{\partial f}{\partial y}= 13(6x+31y)^{12}(31)$$
# $$=403(6x+31y)^{12}$$
# </details>

# %% [markdown]
# **Problem 30:**
#
# *[Given the function  f(x, y) = x^2 y + 3x - 2y^3 , find  f_x  and  f_y .]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[f_x = \frac{\partial}{\partial x}\left(x^2 y + 3x - 2y^3\right) = 2xy + 3]*
#
# **Finding $f_y$:**
#
# *[_y = \frac{\partial}{\partial y}\left(x^2 y + 3x - 2y^3\right) = x^2 - 6y^2]*
#
# </details>

# %% [markdown]
# **Problem 31:**
#
# Let *$$f(x,y)=2x^{2}y + 5y$$*
# Find the partial derivatives *$$f_x$$* and *$$f_y$$*
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
# *$$f(x,y)=2x^{2}y + 5y$$*
# *$$\frac{\partial}{\partial x} (2x^{2}y)= (2y) \frac{\partial}{\partial x}(x^{2}) = 2y(2x) = 4xy$$*
# *$$\frac{\partial}{\partial x} (5y) = 0$$*
# *$$f_x (x,y) = 4xy$$*
#
# **Finding $f_y$:**
# *$$f(x,y)=2x^{2}y + 5y$$*
# *$$\frac{\partial}{\partial y}(2x^{2}y)=2x^{2}(\frac{\partial}{\partial y})(y)=2x^{2}(1)=2x^{2}$$*
# *$$\frac{\partial}{\partial y}(5y)=5$$*
# *$$f_y (x,y) = 2x^{2}+5$$*
#
# </details>

# %% [markdown]
# **Problem 32:**
#
# *Function:
# f(x, y) = x²y + 3y
#
# Question:
#
# Find the partial derivative of f with respect to x, $\frac{\partial f}{\partial x}$
#
#
# Find the partial derivative of f with respect to y, $\frac{\partial f}{\partial y}$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *$f(x, y) = x^2*y + 3*y$*
# $f_x = ∂/∂x (x^2*y + 3*y) = 2*x*y + 0 = 2xy$
#
# **Finding $f_y$:**
#
# *$f_y = ∂/∂y (x^2*y + 3*y) = x^2 + 3$
#
# $f_y = x^2 + 3$
# *
#
# </details>

# %% [markdown]
# **Problem 33:**
#
# $ f(x, y) = 4x^2y + 3y^3 $
#
# Find $\frac{\partial f}{\partial x}$ and $\frac{\partial f}{\partial y}$
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# $4x^2y \;\to\; 8xy$
#
# $3y^3 \;\to\; 0$
#
# Solution
#
# $f_x = 8xy$
#
# **Finding $f_y$:**
#
# $4x^2y \;\to\; 4x^2$
#
# $3y^3 \;\to\; 9y^2$
#
# Solution
#
# $f_y = 4x^2 + 9y^2$
#
#
# </details>

# %% [markdown]
# **Problem 34:**
#
# Find partial derivatives $f_x$ and $f_y$ for the function $f(x,y) = 3x^2y - 4xy^3 + 5y$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# $f_x = \frac{\partial f}{\partial x}(3x^2y) - \frac{\partial f}{\partial x}(4xy^3) + \frac{\partial f}{\partial x}(5y)$
#
# $f_x = 6xy - 4y^3$
#
# **Finding $f_y$:**
#
# $f_y = \frac{\partial f}{\partial y}(3x^2y) - \frac{\partial f}{\partial y}(4xy^3) + \frac{\partial f}{\partial y}(5y)$
#
# $f_y = 3x^2 - 12xy^2 + 5$
#
#
#
# </details>

# %% [markdown]
# **Problem 35:**
#
# Let
# $$f(x, y) = 4x^3y^2 + 5xy - 7y^3.$$
#
# Find the partial derivatives $f_x$ and $f_y$.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Treat **y as a constant** and differentiate with respect to **x**:
#
# - Derivative of $4x^3y^2$ is $12x^2y^2$
# - Derivative of $5xy$ is $5y$
# - Derivative of $-7y^3$ is $0$ (no x)
#
# So:
#
# $$f_x = 12x^2y^2 + 5y.$$
#
# Treat **x as a constant** and differentiate with respect to **y**:
#
# - Derivative of $4x^3y^2$ is $8x^3y$
# - Derivative of $5xy$ is $5x$
# - Derivative of $-7y^3$ is $-21y^2$
#
# So:
#
# $$f_y = 8x^3y + 5x - 21y^2.$$
#
# </details>

# %% [markdown]
# **Problem 36:**
#
# f(x,y) = 4x^2*y + 3y^3 - 5x
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# 4x^2*y = 8xy
# 3y^3 = 0
# -5x = -5
#
# $f_x$ = 8xy - 5
#
# **Finding $f_y$:**
#
# 4x^2*y = 4x^2
# 3y^3 = 9y^2
# -5x = 0
#
# $f_y$ = 4x^2 + 9y^2
#
# </details>

# %% [markdown]
# **Problem 37:**
#
# *[f(x,y) = 3x^2y -4xy^3 +5y
# and compute the partial derivatives 1) fx(x,y) and fy(x,y) ]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[differentiate with respect to x treating y as a constant. 3x^2y = 6xy will then be -4xy^3 = -4y^3 and 5y = 0 so fx = 6xy -4y^3]*
#
# **Finding $f_y$:**
#
# *[ (3x^2y) = 3x^2
# -4xy^3 = -12xy^2 and 5y =5 fy= x^2 - 12xy^2 +5  fy = 3x^2 -12xy^2 + 5 ]*
#
# </details>

# %% [markdown]
# **Problem 38:**
#
# *[$f(x,y)=4x^3y-5y^2+7x$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[$f_x=12x^2y+7$]*
#
# **Finding $f_y$:**
#
# *[$f_y=4x^3-10y$]*
#
# </details>

# %% [markdown]
# **Problem 39:**
#
# Find the partial derivatives $f_x$ and $f_y$ for the function:
#
# $f(x,y) = 3x^2y + 4y^3 - 2x + 7$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# $\frac{\partial}{\partial x} 3x^2y = 3y(2x) = 6xy$
#
# $\frac{\partial}{\partial x} 4y^3 = 0$
#
# $\frac{\partial}{\partial x} -2x = -2$
#
# $\frac{\partial}{\partial x} 7 = 0$
#
# Answer for $f_x$:
#
# $f_x = 6xy - 2$
#
# **Finding $f_y$:**
#
# $\frac{\partial}{\partial y}  3x^2y = $3x^2(1) = 3x^2$
#
# $\frac{\partial}{\partial y} 4y^2 = 12y^2$
#
# $\frac{\partial}{\partial y} -2x = 0$
#
# $\frac{\partial}{\partial y} 7 = 0$
#
# Answer for $f_y$:
#
# $f_y = 3x^2 + 12y^2$
#
# </details>

# %% [markdown]
# **Problem 40:**
#
# f(x,y) = 3x^2y + 4xy^3
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# 3x^2y = 6xy
# 4xy^3 = 4y^3
#
# fsubx (x,y) = 6xy + 4y^3
#
# 3x^2y = 3x^2
# 4xy^3 = 12xy^2
#
# fsuby (x,y) = 3x^2 + 12xy^2
#
# </details>

# %% [markdown]
# **Problem 41:**
#
# f(x,y)=(3x^2)y +5y -7x
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# (3x^2)y has an x,
#
# 5y does not have an x (treat as constant),
#
#  -7x has an x
#
# 3 x 2 x y= 6xy
#
# -7 x 1=-7
#
# $f_x$: 6xy-7
#
# **Finding $f_y$:**
#
# 3x^2 y has a y,
#
#  5y has a y,
#
#   -7x does not have an x (treat as constant)
#
#   3x^2 x 1 =3x^2
#
#   5 x 1=5
#
# $f_y$: 3x^2 + 5
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Give a function and ask for two partial derivatives]*
#
# f(x,y) = 3x^2y^3 + 4xln(y) + e^2xy
#
# find the partial derivatives
#
# 1) f_x (x,y) (partical derivative with respect to x )
#
# 2) f_y (x,y) (partial derivative with respect to y)
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[Show work, treating y as constant]*
#
# f_x = ∂/∂x [3x^2Y^3 + 4xln(y) + e^2xy ]
#
# term by term :
# ∂/∂x (3x^2y^3 = 6xy^3
# (Since y^3 is constant )
#
# 2. ∂/∂x (4xln(y)) = 4ln(y)
# (since ln(y) is constant )
#
# 3.∂/∂x (e^2xy ) = 2ye^2xy
# (chain rule: derivative of e^u (∂u/∂x), and ∂/∂x(2xy) = 2y)
#
#     f_x = 6xy^3 + 4ln (y) + 2ye^2xy
#
#
#
#
#
#
# **Finding $f_y$:**.
#
# *[Show work, treating x as constant]*
#
# f_y = ∂/∂y [3x^2 y^3 + 4xln (y) + e^2xy]
#
# term by term :
#
# ∂/∂y (3x^2 y^3) = 9x^2y^2
# (since x^2 is constant)
#
# 2. ∂/∂y (4xln(y))= 4x (1/y) = 4x/y
# since ln(y) is 1/y)
#
# 3.∂/∂y(e^2xy) = 2xe^2xy
# (chain rule:  ∂/∂y (2xy)=2X)
#
# f_y = 9x^2y^2 + 4x /y + 2xe^2xy
#
#
# </details>

# %% [markdown]
# **Problem 42:**
#
# *$f(x,y)=x^{2}-3xy+2y^{2}$*
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Solution:**
#
#
# **Finding $f_x$=$2x-3y$
#
#
# **Finding $f_y$=$-3x+4y$
#
#
# </details>

# %% [markdown]
# **Problem 43:**
#
# $$f(x,y) = x^4y^2 +5x^2y$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# $$\frac{\partial f}{\partial x} = 4x^4y^2 + 10xy$$
#
# **Finding $f_y$:**
#
# $$\frac{\partial f}{\partial y} = 2yx^4 + 5x^2$$
#
# </details>

# %% [markdown]
# **Problem 44:**
#
# $f(x,y) = x^3 + 5xy + y^3$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# $f_x = \frac{\partial f}{\partial x}(x^3) + \frac{\partial f}{\partial x}(5xy) + \frac{\partial f}{\partial x}(y^3)$
#
# $f_x = 3x^2 + 5y(1) + 0$
#
# $f_x = 3x^2 +5y$
#
# **Finding $f_y$:**
#
# $f_y = \frac{\partial f}{\partial y}(x^3) + \frac{\partial f}{\partial y}(5xy) + \frac{\partial f}{\partial y}(y^3)$
#
# $f_y = 0 + 5x(1) + 3y^2$
#
# $f_y = 5x + 3y^2$
#
# </details>

# %% [markdown]
# **Problem 45:**
#
# $f(x,y)=3x^2y+5y$
#
# **Solution:**
# $f_x= 6xy$
#
# $f_y= 3x^2+5$
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# Treating y as a constant: $3x^2y + 5y$
#
# $3x^2y= 6xy$
#
# $5y= 0$
#
# **Finding $f_y$:**
#
# Treating x as a constant: $3x^2y +5y$
#
# $3x^2y= 3x^2$
#
# $5y= 5$
#
# </details>

# %% [markdown]
# **Problem:**
#
# f(x, y) = 3x^2y + 2y^3. Compute the partial derivative f with respect to x, denoted *$\frac{\partial f}{\partial x}\$*.
#
# Compute the partial derivative f with respect to y, denoted *$ \frac{\partial f}{\partial y}\$*.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
# Step 1 treat y as a constant: *$\ f(x, y) = 3x^2y + 2y^3\$*
#
# Step 2 Differentiate respect to x:
# - For \(3x^2y\): derivative is \(3 * 2x * y = 6xy\)
# - For \(2y^3\): derivative is \(0\) (since no \(x\) appears)
#
#
# Step 3: *$\frac{\partial f}{\partial x} = \frac{\partial}{\partial x}(3x^2y + 2y^3)= 6xy + 0 = 6xy\$*
#
# **Finding $f_y$:**
#
# Step 1 treat x as a constant:f(x, y) = 3x^2y + 2y^3
#
# Step 2 differentiate respect to y: \(3x^2y\): derivative is \(3x^2 * 1 = 3x^2\)
# - For \(2y^3\): derivative is \(2 * 3y^2 = 6y^2\)
#
#
# Step 3: *$\frac{\partial f}{\partial y} = \frac{\partial}{\partial y}(3x^2y + 2y^3)
# = 3x^2 + 6y^2\$*
#
# Solution:
#
#     x: 6xy
#
#     y: 3x^2+6y^2
#
# f(x,y)=(6xy,3x^2+6y^2)
#
#
# </details>

# %% [markdown]
# **Problem 46:**
#
# *![image.png](attachment:c9d1f4a3-6ebd-4cc7-9256-29224d3f164f.png)*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# ![image.png](attachment:48506a81-6f66-435a-bf67-54cb3d484c12.png)
#
# </details>

# %% [markdown]
# **Problem 47:**
#
# Find the parital derivatives in respect to x and y.
#
# $f(x,y) = x^3y^2 + 4xy - 5y^3$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# $ x^3y^2 = 3x^2y^2$
#
# $ 4xy = 4y$
#
# $ -5y^3 = 0$
#
# $f_x = 3x^3y^2 + 4y$
#
# **Finding $f_y$:**
#
# $ x^3y^2 = 2x^3y$
#
# $ 4xy = 4x$
#
# $ -5y^3 = -15y^2
#
# $F_y = 2x^3y + 4x - 15y^2$
#
# </details>

# %% [markdown]
# **Problem 48:**
#
# *[f(x,y) = 3x^2 y - 4xy^3 + 5]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[3x^2 y = 6xy \
# -4xy^3 = -4y^3 \
# 5 = 0]*
#
# **Finding $f_y$:**
#
# *[3x^2 y = 3x^2 \
# -4xy^3 = -12xy^2 \
# 5 = 0 \
# f,y (x,y) = 3x^3 - 12xy^2]*
#
# </details>

# %% [markdown]
# **Problem 49:**
#
# Let f(x,y) = 4x^2 + 3xy - y^3.
# Find f_x and f_y.
#
# **Solution:**
#
# To find f_x, treat y as a constant:
# f_x = 8x + 3y
#
# To find f_y, treat x as a constant:
# f_y = 3x - 3y^2

# %% [markdown]
# **Problem 50:**
#
# *[$f(x,y)= x^2 + y^2$ , Find $f_x$ and $f_y$ .]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[$f_x$ = $2x$]*
#
# **Finding $f_y$:**
#
# *[$f_y$ = $2y$]*
#
# </details>

# %% [markdown]
# **Problem 51:**
#
# Find $f_x$ and $f_y$ of $f(x,y)=x^2y+4xy^2+3y$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# Step 1: Which variable are we taking the derivative with respect to? $x$.
#
# Step 2: Treat $y$ as a constant.
#
# Step 3: Take the derivative with respect to $x$: $2yx+4y^2$
#
# **Finding $f_y$:**
#
# Step 1: Which variable are we taking the derivative with respect to? $y$
#
# Step 2: treat $x$ as a constant.
#
# Step 3: take the derivative with respect to $y$: $x^2+8xy+3$
# </details>

# %% [markdown]
# ### Sample Problem 5.2a: Computing Partial Derivatives
#
# $f(x,y)=x^2+2xy+4y^2-2$
#
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# $f_x :2x+2y+0+0$
#
# $f_x :2x+2y$
#
# **Finding $f_y$:**
#
# $f_y: 0+2x+8y+0$
#
# $f_y: 2x+8y$
#
# </details>

# %% [markdown]
# **Problem:**
#
# $f(x,y) = x^2y^3 + 4xy.$
#
# Compute the partial derivatives $f_x$ and $f_y$.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Finding $f_x$:*
#
# Treat $y$ as a constant and differentiate with respect to $x$:
#
# $ f_x = \frac{\partial}{\partial x}(x^2y^3 + 4xy) = 2xy^3 + 4y $
#
#
#
# *Finding $f_y$:*
#
# Treat $x$ as a constant and differentiate with respect to $y$:
#
# $ f_y = \frac{\partial}{\partial y}(x^2y^3 + 4xy) = 3x^2y^2 + 4x $
#
#
#
# </details>

# %% [markdown]
# **Problem 52:**
#
# *[Let
# $$f(x, y) = 5x^3y + 4xy^2 + 7x + 2y.$$
# Compute the partial derivatives $f_x$ and $f_y$.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[- Derivative of $5x^3y$ with respect to $x$: $15x^2y$
# - Derivative of $4xy^2$ with respect to $x$: $4y^2$
# - Derivative of $7x$ with respect to $x$: $7$
# - Derivative of $2y$ with respect to $x$: $0$
#
# So
# $$f_x = 15x^2y + 4y^2 + 7.$$]*
#
# **Finding $f_y$:**
#
# *[- Derivative of $5x^3y$ with respect to $y$: $5x^3$
# - Derivative of $4xy^2$ with respect to $y$: $8xy$
# - Derivative of $7x$ with respect to $y$: $0$
# - Derivative of $2y$ with respect to $y$: $2$
#
# So
# $$f_y = 5x^3 + 8xy + 2.$$]*
#
# </details>

# %% [markdown]
# **Problem 53:**
#
#  $$ \ f(x,y)= 3x^2y+4y $$
#
#
#
#
# *   Find the partial derivative $$\frac{\partial f}{\partial x}$$
#
# *   Find the partial derivative $$\frac{\partial f}{\partial y}$$
#
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
#
# *   For $ \ 3x^2y: y \ $ is a constant, the derivative is $ \ 3(2x): y =6xy $
# *  $ 4y $ becomes a $ 0 $ since there is no x factor
#
# *   So final answer becomes $$\frac{\partial f}{\partial x}\ = 6xy $$
#
#
#
#
#
#
#
# **Finding $f_y$:**
#
#
#
#
#
# *   For $ 3x^2y: x^2$ is a constant. The derivative remains $ 3x^2 $
# *   For $ 4y $: the derivative becomes a 4
#
# * so final answer becomes $$\frac{\partial f}{\partial x}\ = 3x^2 + 4 $$
#
#
#
#
#
# </details>

# %% [markdown]
# **Problem 54:**
#
# $$
# \[
# f(x, y) = x^2y + 3xy^2
# \]$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *\[
# f(x, y) = x^2y + 3xy^2
# \]
#
# \[
# f_x = \frac{\partial}{\partial x} (x^2y) + \frac{\partial}{\partial x} (3xy^2)
# = 2xy + 3y^2
# \]*
#
# **Finding $f_y$:**
#
# *\[
# f_y = \frac{\partial}{\partial y} (x^2y) + \frac{\partial}{\partial y} (3xy^2)
# = x^2 + 6xy
# \]
# *
#
# </details>

# %% [markdown]
# **Problem 55:**
#
# *[$f(x,y)=3x^2y-4y^3+ 5x$.
# Find the partial derivatives $f_x$ and $f_y$.
# ]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[We differentiate with respect to $x$, treating $y$ as a constant.
#
# $3x^2y$ → derivative is $6xy$ (power rule on $x^2$, $y$ is just a constant factor).
#
# $-4y^3$ → derivative is $0$ (no $x$ in this term).
#
# $5x$ → derivative is $5$.
#
# So,
# $f_x(x,y) = 6xy + 5$
#
# **Finding $f_y$:**
#
# *[Now we differentiate with respect to $y$
#
# - $3x^2y$ → derivative is $3x^2$ (now $x^2$ is the constant factor).
# - $-4y^3$ → derivative is $-12y^2$ (power rule on $y^3$).
# - $5x$ → derivative is $0$ (no $y$ in this term).
#
# So,
#
# $f_y(x,y) = 3x^2 - 12y^2.$]*
#
# </details>

# %% [markdown]
# **Problem 56:**
#
# $f(x,y)=5x+e^y$
#
# **Solution: $\frac{\partial f}{\partial y} = e^y $
# and $\frac{\partial f}{\partial x} = 5 $**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $\frac{\partial f}{\partial x} = 5 $
#
# Treat y as constant and since $e^y$ is constant with respect to x, its derivative is 0 and you only differentiate $5x$
# which is 5!
#
# $\frac{\partial f}{\partial y} = e^y $
#
# Treat x as constant and since $e^x$ is constant with respect to y, its derivative is 0 and you only differentiate $e^y$,
# which remains the same!
#
# </details>

# %% [markdown]
# **Problem 57:**
#
# *[f(x,y)=3x^2y+2xy^3-5y]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[Partial derivative with respect to x (3x^2y)=6xy
# Partial derivative with respect to x (2xy^3)=2y^3
# Partial derivative with respect to x (-5y)=0]
# So, the partial derivative with respect to x and with y as the constant equals 6xy+2y^3*
#
# **Finding $f_y$:**
#
# *[Partial derivative with respect to y (3x^2y)=3x^2
# Partial derivative with respect to x (2xy^3)=6xy^2
# Partial derivative with respect to x (-5y)=-5
# So, the partial derivative with respect to y and with x as the constant equals 3x^2+6xy^2-5]*
#
# </details>

# %% [markdown]
# **Problem 58:**
#
# *[Give a function and ask for two partial derivatives]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[Show work, treating y as constant]*
#
# **Finding $f_y$:**
#
# *[Show work, treating x as constant]*
#
# </details>

# %% [markdown]
# **Problem 59:**
#
# *[f(x,y)=4x^2y+3xy^3
# .Find the partial derivatives f_x and f_y
# .]*
#
# **Solution:**
# f_x=8xy+3y^3 and f_y=4x^2 +9xy^2
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[fx​=∂x∂​(4x2y+3xy3)]*
#
# **Finding $f_y$:**
#
# *[fy​=∂y∂​(4x2y+3xy3 ]*
#
# </details>

# %% [markdown]
# **Problem 60:**
#
# Find both derivatives (with respect to x, and with respect to y) $f(x,y)=x^2y^2$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# Step 1:
# - Identify which variable we are deriving by. In this case, it is with respect to x
#
# Step 2:
# - Swap out anything not our variable into a constant, so $y^2$ becomes a constant, so we have $f(x,y)=Ax^2$
#
# Step 3:
# - Take the derivative of our new function: $(Ax^2)'=2ax$
#
# Step 4:
# - substitute what we initially took out in step 2: $A=y^2, so f'x=2y^2x$
#
# **Finding $f_y$:**
#
# Step 1:
# - Identify which variable we are deriving by. In this case, it is with respect to y
#
# Step 2:
# - Swap out anything not our variable into a constant, so $x^2$ becomes a constant, so we have $f(x,y)=Ay^2$
#
# Step 3:
# - Take the derivative of our new function: $(Ay^2)'=2ay$
#
# Step 4:
# - substitute what we initially took out in step 2: $A=x^2, so f'y=2x^2y$
#
# </details>

# %% [markdown]
# **Problem 61:**
#
# *[f(x,y) = 3x^2 + 5y
# Find with respect to x and to y]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding the derivative with respect to x**
#
# *[Show work, treating y as constant
#  Taking derivative like normal = 6x]*
#
# **Finding the derivative with respect to y:**
#
# *[Show work, treating x as constant
# Taking derivative like normal = 5, treating 3x^2 like a constant ]*
#
# </details>

# %% [markdown]
# **What is a partial derivative?**
#
# - A partial derivative measures how **a multivariable function changes** with respect to **one variable at a time**, while holding all other variables constant.
#
# - For a function of $f(x,y)$, the partial derivative with $x$ in mind, is notated as $\frac{\partial f}{\partial x}$ meaning $f_x$
#
# - The original notation for determening derivatives is $dy/dx$, meaning that $y$ is the dependent variable and $x$ is the independent variable. Partial derivatives take the original notation and replaces $d$ with the symbol ${\partial }$
#
#
# **Notation:**
#
# - $\frac{\partial f}{\partial x}$ or $f_x$: The Partial of $f$ with respect to $x$, written as  $\frac{\partial f}{\partial x}$
# - $\frac{\partial f}{\partial y}$ or $f_y$: The partial of $f$ with respect to $y$, written as  $\frac{\partial f}{\partial y}$
#
# **How to compute partial derivatives: a step-by-step guide**
#
# 1. Identify the function $f$ and the specific variable you need to differentiate with respect to
#
# 2. Hold one variable constant and take derivatives as usual. Ignore other variables and take them as constants
#
# 3. Apply the standard rules of differentiation, such as **power rule, product rule, chain rule** to the variable you are differentiating with respect to
#
# **Interpretation:**
# - Partial Derivatives tells us how quickly the function's value changes when you only change the input, while keeping the inputs fixed
#
# **Problem:**
#
# $$f(x,y)=x^2−3xy+2y^2−4x+5y−12$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# Term: **$x^2$**
# - Derivative with respect to $x$ treating $y$ as a constant
# - Result = $2x$
#
# Term: **$-3xy$**
# - $y$ is a constant, so $-3y$ is the constant coefficient of $x$. The derivative of $Cx$ is $C$
# - Result = $-3y$
#
# Term: **$2y^2$**
# - $y$ is a constant, so $2y^2$ is a constant.
# - The derivative of a constant is $0$.
# - Result = $0$
#
# Term: **$-4x$**
# - Result = $-4$
#
# Term: **$5y$**
# - Result = $0$
#
# Term:**$-12$**
# - Result = $0$
#
#
# **Final Result:** $$f_x = 2x - 3y - 4$$
#
#
# **Finding $f_y$:**
#
# Term: **$x^2$**
# - $x$ is a constant, so $x^2$ is a constant.
# - The derivative of a constant is $0$
#
# Term: **$-3xy$**
# - $x$ is a constant, so $-3x$ is the constant coefficient of $y$. The derivative of $Cy$ is $C$
# - Result = $-3x$
#
# Term: **$2y^2$**
# - Using power rule: $\frac{d}{dy}(2y^2)$ = $2(2y) = 4y$
# - Result: $4y$
#
# Term:**$-4x$**
# - $x$ is a constant, so $-4x$ is a constant. The derivative of a constant is $0$
# - Result= $0$
#
#
# Term: **$5y$**
# - Result = $5$
#
# Term:**$-12$**
# - Result = $12$
#
# **Final Result:** $$f_x = 2x - 3y - 4$$

# %% [markdown]
# **Problem 62:**
#
# *$f(x,y)=4x^3y^2+7xy+ln(x+2y+5)$ Find $f_x(x,y) and f_y(x,y)$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# - $\frac{\partial}{\partial x}(4x^3y^2) = 12x^2y^2$
# - $\frac{\partial}{\partial x}(7xy) = 7y$
# - $\frac{\partial}{\partial x}(ln(x+2y+5)) = \frac{1}{x+2y+5}$
# - $f_x=12x^2y^2+7y+\frac{1}{x+2y+5}$
#
# **Finding $f_y$:**
#
# - $\frac{\partial}{\partial y}(4x^3y^2) = 8x^3y$
# - $\frac{\partial}{\partial y}(7xy) = 7x$
# - $\frac{\partial}{\partial y}(ln(x+2y+5)) = \frac{1}{x+2y+5}*2$
# - $f_y=8x^3y+7x+\frac{2}{x+2y+5}$
#
# </details>

# %% [markdown]
# **Problem 63:**
#
# f(x,y)=6x^2+8xy
#
# **Solution:**
# f(x)= 12x+8y
# f(y)= 8x
#
# </details>

# %% [markdown]
# $f(x,y)=2xy^3+3x-y^2+1$. Find the two partial derivatives of this function.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# Work:
#
# $f_x=2(1)y^3+3(1)-(0)^2+1$
#
# $f_x=2y^3+3$
#
#
# **Finding $f_y$:**
#
# Work:
#
# $f_y=2(3)xy^2+3(0)-(2)y$
#
# $f_y=6xy^2-2y$
#
# Solution:
#
# $f_x=2y^3+3$
#
# $f_y=6xy^2-2y$
# </details>

# %% [markdown]
# ### Sample Problem 5.2a: Computing Partial Derivatives

# %% [markdown]
# **Problem 64:**
#
# $f(x, y) = x^2y + 3xy^2$
#
# Find $f_x$ and $f_y$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# $f(x, y) = x^2y + 3xy^2$
#
# $\frac{\partial}{\partial x}(x^2y) = 2xy$
#
# $\frac{\partial}{\partial x}(3xy^2) = 3y^2$
#
# $f_x = 2xy + 3y^2$
#
# **Finding $f_y$:**
#
# $f(x, y) = x^2y + 3xy^2$
#
# $\frac{\partial}{\partial y}(x^2y) = x^2$
#
# $\frac{\partial}{\partial y}(3xy^2) = 6xy$
#
# $f_y = x^2 + 6xy$
#
# </details>

# %% [markdown]
# **Problem 65:**
#
# *Find the partial derivatives $f_x$ and $f_y$ for the function:$$f(x, y) = 3x^3y^2 + 4x - 5y$$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *
# - For $3x^3y^2$: The $3y^2$ is the constant coefficient. Derivative of $x^3$ is $3x^2$. So, $3y^2 \cdot 3x^2 = 9x^2y^2$.
# - For $4x$: Derivative is 4.
# - For $-5y$: This is a constant relative to $x$, so the derivative is 0.
# - $f_x = 9x^2y^2 + 4$*
#
# **Finding $f_y$:**
#
# *
# - For $3x^3y^2$: The $3x^3$ is the constant coefficient. Derivative of $y^2$ is $2y$. So, $3x^3 \cdot 2y = 6x^3y$.
# - For $4x$: Constant relative to $y$, derivative is 0.
# - For $-5y$: Derivative is -5.
# - $f_y = 6x^3y - 5$*
#
# </details>

# %% [markdown]
# **Problem 66:**
#
# f(x,y) = 7x^2y + 5xy^3 - 4y
# Find the partial derivatives of x and y
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# fx = 14x + 5y^3
#
# **Finding $f_y$:**
#
# 7x^2 +15xy^2  4
#
# </details>

# %% [markdown]
# **Problem 67:**
#
# *$f(x,y) = xy + 3x - 2y$ find
# $\frac{\partial f}{\partial x}$ or $f_x$*
#   and $\frac{\partial f}{\partial y}$ or $f_y$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *treating y as constant we can remove the $-2y$ completely and take the derivative of the remaining parts of the function by splitting them into parts. $xy$ is derived into simply $y$ as it is treated as a constant and the derivative of a variable times a constant is just the constant. Lastly $+3x$ is derived simply into 3 so our final result is $y + 3$*
#
# **Finding $f_y$:**
#
# *treating x as constant we can remove the $+ 3x$ completely and take the derivative of the remaining parts of the function by splitting them into parts. $xy$ is derived into simply $x$ as it is treated as a constant and the derivative of a variable times a constant is just the constant. Lastly $-2y$ is derived simply into $-2$ so our final result is $x - 2$*
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Give a function and ask for two partial derivatives]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[Show work, treating y as constant]*
#
# **Finding $f_y$:**
#
# *[Show work, treating x as constant]*
#
# </details>

# %% [markdown]
# **Problem 68:**
#
# *[f(x,y)=4x^3+xy-y^2+7. find f_x and f_y]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[f(x,y)= 4x^3+xy-y^2+7
#     f_x= 12x^2+y]*
#
# **Finding $f_y$:**
#
# *[f(x,y)= 4x^3+xy-y^2+7
#     f_y= x-2y]*
#
# </details>

# %% [markdown]
# **Problem 69:**
#
# $f(x,y) = 3x^2y+5y^2$.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# $f_x = 6xy$
#
# -> derivative of $3x^2y$ with respect to x: $3*2x = 6x$
#
# -> derivative of $5y^2$ with respect to x: $0$
#
# **Finding $f_y$:**
#
# $f_y = 3x^2 + 10y$
#
# -> derivative of $3x^2y$ with respect to y: $3x^2*1 = 3x^2$
#
# -> derivative of $5y^2$ with respect to y: $5*2y = 10y$
#
# </details>

# %% [markdown]
# ### Sample Problem 5.2a: Computing Partial Derivatives
#
# **Problem 70:**
#
# Let
# $$f(x,y) = 4x^2 + 3xy + y^2.$$
#
# Find the following partial derivatives:
#
# 1. $\frac{\partial f}{\partial x}$
# 2. $\frac{\partial f}{\partial y}$
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $\frac{\partial f}{\partial x}$**
#
# Treat $y$ as a constant.
#
# - Derivative of $4x^2$ with respect to $x$ is $8x$
# - Derivative of $3xy$ with respect to $x$ is $3y$
# - Derivative of $y^2$ with respect to $x$ is $0$ (because $y$ is constant)
#
# So:
# $$\frac{\partial f}{\partial x} = 8x + 3y.$$
#
#
# **Finding $\frac{\partial f}{\partial y}$**
#
# Treat $x$ as a constant.
#
# - Derivative of $4x^2$ with respect to $y$ is $0$
# - Derivative of $3xy$ with respect to $y$ is $3x$
# - Derivative of $y^2$ with respect to $y$ is $2y$
#
# So:
# $$\frac{\partial f}{\partial y} = 3x + 2y.$$
#
# </details>

# %% [markdown]
# **Problem 71:**
#
# *[Give a function and ask for two partial derivatives]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding $f_x$:**
#
# *[Show work, treating y as constant]*
#
# **Finding $f_y$:**
#
# *[Show work, treating x as constant]*
#
# </details>
