# %% [markdown]
# **Problem 1:**
#
# $$g(s, t) = \ln(s^2 + t^2 - 1)$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $$s^2 + t^2 - 1 > 0$$
#
# $$s^2 + t^2 > 1$$
#
# $$D = \{(s, t) \in \mathbb{R}^2 \mid s^2 + t^2 > 1\}$$
#
# $$g(s, t) = c \implies \ln(s^2 + t^2 - 1) = c$$
#
# $$e^{\ln(s^2 + t^2 - 1)} = e^c$$$$s^2 + t^2 - 1 = e^c$$
#
# $$s^2 + t^2 = 1 + e^c$$
#
# $$s^2 + t^2 = 1 + e^0$$$$s^2 + t^2 = 1 + 1$$$$\mathbf{s^2 + t^2 = 2}$$This is a circle centered at $(0, 0)$ with a radius $R = \sqrt{2}$.
#
# $$s^2 + t^2 = 1 + e^{\ln(8)}$$$$s^2 + t^2 = 1 + 8$$$$\mathbf{s^2 + t^2 = 9}$$This is a circle centered at $(0, 0)$ with a radius $R = 3$.

# %% [markdown]
# **Problem:**
#
# *$g(s,t)+s^{2}=t^{2}.$ Find the level curve when $g(s,t)$ = 4 and when $g(s,t) = 9$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
# $s^{2}+t^{2} = 4$ is a circle with a radius of 2,
# $s^{2}+t^{2}= 9$ is a circle with a radius of $3$
#
# Graphically, these will look like a bowl shape opening upwards.

# %% [markdown]
# **Problem 2:**
#
# Find the level curves of $$f(x,y) = x^2 + y$$ for the values $$c = -4, 0, 8$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step One: Setup the formula.
#
# A level curve for value $c$ is (x,y) where $x^2 + y = c$.
#
# Step Two: Solve for $c$.
#
# $x^2 + y = c$
#
# $\implies y = c - x^2$
#
# Step Three: Plug in the given $c$ values
#
# For c = -4: $$\boxed{y = -4 - x^2}$$
#
# For c = 0: $$\boxed{y = - x^2}$$
#
# For c = 8: $$\boxed{y = 8 - x^2}$$
#
# The level curves found are all downward opening parabolas with each one corresponding to a different height $c$. As $c$ increases, the parabola would shift upwards, showing that the surface gets higher as you move more positive in the $y$-direction. Because of the $x^2$, we know that the surface goes upwards as $x$ goes away from $0$. This tells us that the 3D graph is a smooth surface that slopes upwards in the $y$-direction and curves upwards in the $x$-direction.

# %% [markdown]
# **Problem 3:**
#
# Consider the function
# $g(s, t) = s^2 - 3t + 4$.
# Find the level curves of g(s, t) for the values k = 0, 2, and 6.
# Describe what these level curves tell you about the general shape of the surface $z = g(s, t)$.
#
# *Solution:*
#
# <details>
# <summary>Click to reveal solution</summary>
#
# Level curves are found by setting g(s, t) equal to a constant k.
#
# 1. For k = 0:
#    $s^2 - 3t + 4 = 0$
#    Solve for t:
#    $t = (s^2 + 4) / 3$
#
# 2. For k = 2:
#    $s^2 - 3t + 4 = 2$
#    $t = (s^2 + 2) / 3$
#
# 3. For k = 6:
#    $s^2 - 3t + 4 = 6$
#    $t = (s^2 - 2) / 3$
#
# These level curves are all vertical parabolas in the st-plane that open upward in the t direction. Each one is just shifted slightly up or down depending on the value of k.
#
# </details>

# %% [markdown]
# **Problem 4:**
#
# *[f (x,y) = $ x^2+4y$. Find the equation of the level curve when c=0. Find the equation of the level curve when c=4. ]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Step 1. set function equal to 0.
#  -$ x^2+4y=0 $
# - $ 4y= -x^2 $
# - $ y= -x^2/4 $
#
# Step 2. set function equal 4
# - $ x^2+4y=4 $
#
# - $ 4y= 4-x^2$
#
# - $ y = 1-(\frac{x^2}{4} )$]*
#
# *The level curves are downward-opening parabolas, which have the same shape, but they can be shifted up or down based on the value of c.*

# %% [markdown]
# **Problem 5:**
#
# $$ f(x,y)= x^2+y^2  $$   Level curve for C=4
#
#
# **Solution:**
# $$ x^2+y^2=4 $$
# circle of radius 2
# as c increases, circles get bigger! *
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find level curves for several values]*
#
# pick a constant c
# solve f(x,y)
# plot curve in xy plane
# repeat for different c's!
#
#
# *[Explain what these curves might say about a 3D graph]*
#
# It can determine the height and elevation of 3D graphs, slope, shape of surface, highs and lows etc.!

# %% [markdown]
# **Problem 6:**
#
# *$g(s,t)=s^2+t$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Level Curves can be found by setting the entire function to a constant value, $k$*
#
# $k=s^2+t$
#
# *we now set the equation equal to t, to display on a 2d plane
#
# $k-s^2=t$
#
# *Now, we plug in various different values for k to see what the function looks like at this particular slice*
#
# $0-s^2=t$
#
# *this is the same as $y=-x^2$, a negative parabola*
#
# $-2-s^2=t$
#
# *this is the same parabola, just shifted down the y axis by $-2$*
#
# $9-s^2=t$
#
# *this is the same parabola, just shifted up the y axis by $9$*
#
# *What we can tell from these level curves is that the function appears as a half cone shape, as if it was sliced vertically and laid out horizontally. It steadily increases across the t direction, while bending in a parabolic shape across s direction*

# %% [markdown]
# **Problem 7:**
#
# *[$g(s,t)=s^2+t^2$]*
#
# **Solution:** *[$s^2+t^2= 1$], [$s^2+t^2=4$], [$s^2+t^2=9$]*
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[$g(s,t)=c$] becomes *[$s^2+t^2=c$]*
#
# random values:1,4,9
#
# *[$s^2+t^2= 1$]* circle of radious one
#
# *[$s^2+t^2=4$]* circle of radious two
#
# *[$s^2+t^2=9$]* circle of radious three
#
# *[Each value will present a different line curve. It will always be centered at the origin, and the shape will depend on the function; for this function, it is a circle.
#
# *[The pattern is a symmetry of surface(bowl), spacing is the slope's steepness, and the shape presents how the surface behaves in the s-t plane.]*

# %% [markdown]
# **Problem:**
#
# *Consider the function \(g(s,t) = s^2 + t^2\).
# Find the level curves for the values \(k = 1,\ 4,\ 9\) and describe what they tell you about the 3D graph.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *To find level curves, set \(g(s,t) = k\):*
#
# - For \(k = 1\):
#   \(s^2 + t^2 = 1\) → a circle of radius 1
#
# - For \(k = 4\):
#   \(s^2 + t^2 = 4\) → a circle of radius 2
#
# - For \(k = 9\):
#   \(s^2 + t^2 = 9\) → a circle of radius 3
#
# *What these curves say about the 3D graph:*
# - The circles get bigger as \(k\) increases.
# - This means the height of the surface increases as you move away from the origin.
# - The 3D graph is shaped like an upward-opening bowl (a paraboloid).

# %% [markdown]
# **Problem 8:**
#
# Consider the function $g(s,t) = s^2 + t^2$.
#
# 1. Find the level curves for $c = 0, 1, 4, 9$.
# 2. Sketch or describe what these level curves look like.
# 3. What do these level curves tell you about the 3D graph of g(s,t)?
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Part 1: Find the level curves**
#
# A level curve is found by setting $g(s,t) = c$ for a constant c.
#
# For $c = 0$:
# $$s^2 + t^2 = 0$$
# This is only satisfied when $s = 0$ and $t = 0$, so the level curve is a single point at the origin.
#
# For $c = 1$:
# $$s^2 + t^2 = 1$$
# This is a circle centered at the origin with radius 1.
#
# For $c = 4$:
# $$s^2 + t^2 = 4$$
# This is a circle centered at the origin with radius 2.
#
# For $c = 9$:
# $$s^2 + t^2 = 9$$
# This is a circle centered at the origin with radius 3.
#
# **Part 2: Describe the level curves**
#
# The level curves are concentric circles (circles with the same center) centered at the origin. As c increases, the radius of the circles increases. Specifically, the radius is $r = \sqrt{c}$.
#
# **Part 3: What do these tell us about the 3D graph?**
# The level curves tell us that:
#
# - The 3D graph of $g(s,t) = s^2 + t^2$ is a paraboloid (bowl shape) opening upward.
# - The lowest point (minimum) is at the origin (0,0) where g = 0.
# - As you move away from the origin in any direction, the function value increases.
# - The function has circular symmetry around the vertical axis through the origin.
# - The surface gets steeper as you move away from the origin (since the circles get farther apart for equal increases in height).

# %% [markdown]
# **Problem 9:**
#
# g(s,t)=s^2+t^2
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# for c=1: s^2 + t^2 = 1 which is a circle with a radius of 1 and for c=4:s^2 + t^2 = 4 which is a circle with a radius of 2
#
# these curves show horizontal layers of the 3d surface which indicates how the height z=g(s,t) changes as you move away from the origin.

# %% [markdown]
# **Problem 10:**
#
# g(x,y)=x^2+y^2
#
# Determine all (x,y) values.
#
#     g(x,y)=4
#
#     g(x,y)=9
#
# **Solution:**
# Step 1:
#
# Domain={(x,y)∣x∈R,y∈R}
#
# Step 2:
#
# g(x,y)=c->x^2+y^2=c
#
# x^2+y^2=4
#
# Radius 2=(0,0)
#
# g(x,y)=9
#
# x^2+y^2=9
#
# circle radius of 3
#
# Step 3:
#
# Radius 2->g9x,y)=4, radius 3->g(x,y)=9
#
#
# g(x,y)=c
# c= any value you need to put
#
# A 3D graph of a function f(x,y) is a surface
# x and y= horizontal
# z=f(x,y)=height

# %% [markdown]
# **Problem 11:**
#
# $g(s,t) = s^2 + 4t^2$
#
# *Find the level curves for $g(s,t) = 1, 4,$ and $9$.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $s^2+4t^2=1$
#
# *For $c=1$*
#
# $s^2+4t^2=1$
#
# *This is an ellipse with a semi-major axis of 1 and a semi-minor axis of 1/2.*
#
# *For $c=4$*
#
# $s^2+4t^2=4$ *which becomes* $\frac{s^2}{4}+t^2=1$
#
# *This is an ellipse with a semi-major axis of 2 and a semi-minor axis of 1.*
#
# *For $c=9$*
#
# $s^2+4t^2=9$ *which becomes* $\frac{s^2}{9}+\frac{4t^2}{9}=1$
#
# *This is an ellipse with a semi-major axis of 3 and a semi-minor axis of 3/2.*
#
# *All of the level curves are ellipses that are centered around the origin and increase as the constant, c, increases.*

# %% [markdown]
# **Problem 12:**
#
# Consider the function: $f(x, y) = x^2 + y^2$
#
# a) Find the level curves for c = 0, 1, 4, 9
#
# b) Describe what these level curves tell us about the 3D graph
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# a) Level curves:
#
# For c = 0: $x^2 + y^2 = 0$ ⇒ point at (0,0)
#
# For c = 1: $x^2 + y^2 = 1$ ⇒ circle of radius 1
#
# For c = 4: $x^2 + y^2 = 4$ ⇒ circle of radius 2
#
# For c = 9: $x^2 + y^2 = 9$ ⇒ circle of radius 3
#
# b) What these tell us about the 3D graph:
# - The function represents a paraboloid (bowl-shaped surface)
# - Level curves are concentric circles
# - As c increases, the circles get larger
# - The surface gets steeper as we move outward from the center
# - The graph is symmetric about the z-axis

# %% [markdown]
# **Problem:g(s,t)=s^2+t, k=0,2,4**
#
# *[Create a problem about multivariable functions of two variables like g(s,t) and understanding level curves.]*
#
# **Solution:
# k=0,t=-s**2
# k=2,t=2-s**2
# k=4,t=4-s**2**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *t=k-s**2*
# *k=0,t=-s**2*
# *k=2,t=2-s**2*
# *k=4,t=4-s**2*
# *[all level curves are parabolas, as k increases, the curves shift upward. if you imagine the 3D graph, slicing it horizontally cuts through a downward curving surface]*

# %% [markdown]
# **Problem 13:**
#
# *$$h(x, y) = \ln(x^2 + y^2)$$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *if c=0:
# $$\ln(x^2 + y^2) = 0$$
# $$e^{\ln(x^2 + y^2)} = e^0$$
# $$x^2 + y^2 = 1$$
# if c=1:
# $$\ln(x^2 + y^2) = 1$$
# $$e^{\ln(x^2 + y^2)} = e^1$$
# $$x^2 + y^2 = e$$*
#
# *its origin is (0,0) and its symmetrical*

# %% [markdown]
# **Problem 14:**
#
# The temperature T (in degrees celsius) at any point (x,y) in a flat circular plate is given by the function T (x,y)= $100-x^2-y^2, where x and y are measured in meters.
#
# 1. Find and sketch the level curves for T=0, 25, 50, 75
#
# 2. Based on the level curves, describe the general shape of the graph of the temperature function T(x,y)
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# 1. Find the level curves
#
# $100- x^2 -y^2=k$
#
# $x^2+y^2=100-k$
#
# T=0
#
# $x^2+y^2=100-0=100$
#
# radius $\sqrt{100}$=10
#
# T=25
#
# $x^2+y^2=100-25=75$
#
# radius $\sqrt{75}$=8.66
#
# T=50
#
# $x^2+y^2=100-50=50$
#
# radius $\sqrt{50}$=7.07
#
# T=75
#
# $x^2+y^2=100-75=25$
#
# radius $\sqrt{25}$=5
#
#
# 2.
#
# The level curves are circles centered at the origin, with the radii decreasing as the temperature T increases. This suggests that the graph of T(x,y) is a paraboloid opending downards with its vertex at the point (0,0,100). The temperature is highest at the center of the plate and decreases as you move away from the center in any direction. The circular shape of the level curves indicates that the temperature decreases symmetrically in all directions from the center.

# %% [markdown]
# **Problem 15:**
#
# *Consider the function $g(s,t) = s^2 + 2t^2$.
# Find the level curves for the values $c = 1$, $4$, and $9$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Level curves satisfy the equation $g(s,t) = c$, which becomes $s^2 + 2t^2 = c$.
# Step 2: For $c = 1$: the level curve is $s^2 + 2t^2 = 1$.
# Step 3: For $c = 4$: the level curve is $s^2 + 2t^2 = 4$.
# Step 4: For $c = 9$: the level curve is $s^2 + 2t^2 = 9$. *
#
# *These are ellipses centered at the origin, each larger as $c$ increases. Level curves are cross-sections of the 3D surface $z = s^2 + 2t^2$ at heights $z = c$.  Because the curves are ellipses that grow outward as $c$ increases, the 3D graph is a bowl-shaped surface that opens upward.*

# %% [markdown]
# **Problem 16:**
#
# Consider the function $g(s,t) = s^2 + t^2$
# - (a) Find the level curve corresponding to the value $g(s,t) = 9$
# - (b) Sketch or describe what this level curve looks like
# - (c) What geometric shape do the level curve of this function form in general?
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# - (a) Set the function equal to 9: $s^2 + t^2 = 9$
# - (b) This is the equation of a circle of radius 3 centered at the origin
# - (c) In general, the level curves $s^2 + t^2 = c$ are circles of radiuis $\sqrt{c}$
#
# - Level curves act like contour lines on a topographic mape, allowing us to visualize a 3D function using 2D information.

# %% [markdown]
# **Problem 17:**
#
# *$g(s,t)=s^2+t$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# a) g(s,t)=4
#
# $s^2+t=4$
#
# $t=4-s^2$
#
# b) g(s,t)=0
#
# $s^t+t=0$
#
# $t=-s^2$
#
# Downward parabola for a and b
#
# This tells us:
#
# - The larger values of c, the parabola shifts upward
# - Smaller values of c, the parabola shifts downward

# %% [markdown]
# **Problem:**
# Consider f(x,y)= (x^2)+y
# Find the level curves of k=-2,0,2
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
# f(x,y)=k-->(x^2)+y=k
# k=-2:(x^2)+y=k--> y=-(x^2)-2
# k=0: (x^2)+y=k--> y=x^2
# k=2: (x^2)+y=k--> y=-(x^2)+2
#
# The curves are downward facing parabolas due to the -x^2. They reveal that the 3D surface is shaped like a parabolic ramp that rises in the
# y-direction.

# %% [markdown]
# **Problem 18:**
#
# *Consider the multivariable function*
# $$
# g(s,t) = s^2 + t^2.
# $$
# *(a) Find the level curves of \(g\) corresponding to the values \(c = 0, 1, 4, 9\).
# (b) Describe the general shape of the level curves \(g(s,t) = c\).
# (c) Based on these level curves, what does the 3D graph \(z = g(s,t)\) look like?*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Level curves are obtained by setting \(g(s,t)\) equal to a constant \(c\):*
# $$
# g(s,t) = c \quad \Longrightarrow \quad s^2 + t^2 = c.
# $$
#
# *For the specific constants:*
#
# - *If \(c = 0\), then*
#   $$
#   s^2 + t^2 = 0 \Longrightarrow s = 0,\ t = 0,
#   $$
#   *so the level curve is just the single point \((0,0)\).*
#
# - *If \(c = 1\), then*
#   $$
#   s^2 + t^2 = 1,
#   $$
#   *a circle of radius \(1\) centered at the origin in the \((s,t)\)-plane.*
#
# - *If \(c = 4\), then*
#   $$
#   s^2 + t^2 = 4,
#   $$
#   *a circle of radius \(2\) centered at the origin.*
#
# - *If \(c = 9\), then*
#   $$
#   s^2 + t^2 = 9,
#   $$
#   *a circle of radius \(3\) centered at the origin.*
#
# *In general, for \(c > 0\) the level curve*
# $$
# s^2 + t^2 = c
# $$
#
# $s^2 + t^2 = c$ is a circle of radius $\sqrt{c}$ centered at the origin. For $c < 0$ there are no level curves because $s^2 + t^2 \ge 0$ for all $(s,t)$.
#
# These level curves tell us that the 3D graph of
#
# $$
# z = g(s,t) = s^2 + t^2
# $$
#
# is an upward parobola . As $z$ increases, the cross-sections parallel to the $(s,t)$-plane are circles that have bigger radiuses

# %% [markdown]
# **Problem 19:**
#
# * $g(s,t) = s^2 + 2t$
# * find the level curves for the level values c = 0,4,8
# * describe what time these curves indicateabout the 3D graph
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# * $ s^2 + 2t = c$
# * $t= c-s^2 / 2$
# * for c= 0 $ t= c-s^2 / 2$
# * for c= 4 $ t= -s^2 / 2$
# * for c= 8 $ t= 4 - s^2 /2$
#
# * In 3D this means the graph is shaped like a parabolic bowl rising as t increases

# %% [markdown]
# **Problem 20:**
#
# Consider the function: $f(x,y) = x^2 + y^2 -4$
#
# Find the level curves of f at the values: c = -1, 0, 3
#
# Solution:
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# We set $f(x,y) = c$
#
# Therefore: $x^2 + y^2 -4 = c$
#
# = $x^2 + y^2 = c + 4$
#
# Then we plug in the values, -1, 0, and 3 in place of c.
#
# $x^2 + y^2 = (-1) + 4 = 3$
#
# $x^2 + y^2 = (0) + 4 = 4$
#
# $x^2 + y^2 = (3) + 4 = 7$
#
# Therefore, each level curve will create a circle on a 2d plane, with the indicated radiuses:
#
# $r= \sqrt{3}$
#
# $r = \sqrt{4} = 2$
#
# $r= \sqrt{7}$
#
# Each circle is a level curve with a radius that increases at a constant rate as z increases, forming a cylinder shape in a 3d place. Therefore, as z increases, the wider the cylinder opens up and becomes

# %% [markdown]
# **Problem:**
#
# *[g(s,t)= s^2+t^2/1+t, find domain, range, level curves shape
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Level curve for c=3: g(s,t)=3, s^2+t^2/1+t=3, mutiply both sides by 1+t, s^2+t^2=3+3t, s^2+t^2-3t-3=0, t^2-3t=(t-3.2)^2-9/4, substitute, combine, move to other side, s^2+(t-3/2)^2=21/4 (r) General level curves: g(s,t)=c, s^2+t^2=c(1+t), s^2+1^2 = c+ct, rearange so that it's set to equal zero, t^2-ct=(t-c/2)^2-(c/2)^2, substitute, move constants, factor: s^2+(t-c/2)^2=c(c+4)/4]*
#
# *[reveals that its a circle]*

# %% [markdown]
# **Problem 21:** $g(s,t) = s^2 - t$
#
#
# *[Create a problem about multivariable functions of two variables like g(s,t) and understanding level curves.]*
#
# **Solution:**
#
# $s^2 +2$
#
# $s^2$
#
# $s^2-3$
#
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find level curves for several values]*
# $t=s^2-k$
# $k=-2$
# $k = -2: t=s^2-(-2) = s^2 +2$
# $k = 0: t = s^2 - 0= s^2$
# $k = 3: t=s^2-3$
#
#
# *[Explain what these curves might say about a 3D graph]*
# The curves are of the form $t = s^2 - k$. This means that the 3D graph of this function resembles a wall due to the vertical parabolas.

# %% [markdown]
# **Problem 22:**
#
# Find the level curve of the function $f(x,y)=x^2+y^2$ when c=4
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $f(x,y)=c$
# $x^2+y^2=c$
# c=4
# $x^2+y^2=4$
# This is an equation of a circle centered at the origin with the radius of 2
#
# The 3D graph of this function is shaped like a bowl, 4 units high, the radius is two.

# %% [markdown]
# **Problem 23:**
#
# *[g(s,t)=s^2+t^2
# - Find the level curves of g(s,t) for the values c=1,4,9.
# - Describe what these level curves say about the shape of the 3D graph z=g(s,t).
#
# **Solution:**
#
# $$g(s,t) = s^2 + t^2$$
# $$\text{A level curve for a value } c \text{ satisfies } g(s,t) = c$$
# $$s^2 + t^2 = c$$
#
# $$\text{For } c = 1:$$
# $$s^2 + t^2 = 1$$
# $$\text{This is a circle of radius } 1 \text{ centered at the origin in the } (s,t)\text{-plane}$$
#
# $$\text{For } c = 4:$$
# $$s^2 + t^2 = 4$$
# $$\text{This is a circle of radius } 2 \text{ centered at the origin}$$
#
# $$\text{For } c = 9:$$
# $$s^2 + t^2 = 9$$
# $$\text{This is a circle of radius } 3 \text{ centered at the origin}$$
#
# $$\text{So the level curves are concentric circles with increasing radius as } c \text{ increases}$$
# $$\text{On the 3D graph } z = s^2 + t^2, \text{ this corresponds to an upward-opening paraboloid}$$
# $$\text{Moving away from the origin in the } (s,t)\text{-plane gives larger } z \text{ values}$$
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $$\text{To find a level curve, set } g(s,t) = c \text{ and solve}$$
# $$s^2 + t^2 = c$$
#
# $$\text{For } c=1: s^2 + t^2 = 1 \text{ (circle of radius 1)}$$
# $$\text{For } c=4: s^2 + t^2 = 4 \text{ (circle of radius 2)}$$
# $$\text{For } c=9: s^2 + t^2 = 9 \text{ (circle of radius 3)}$$
#
# $$\text{These circles show that the 3D graph } z = s^2 + t^2 \text{ is a paraboloid}$$
# $$\text{As the circles get bigger, } z \text{ increases upward from the origin}$$

# %% [markdown]
# **Problem 24:**
#
# $g(s,t)=s^2+t^2-4s$
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **1. Set function equal to k**
#
# $s^2+t^2-4s=k$
#
# Commplete the square for terms involving $s$
#
# $(s^2-4s+4)+t^2=k+4$
#
# $(s-2)^2+t^2=k+4$
#
# This equation $(s-h)^2+(t-v)^2=r^2$ represents a circle.
#
# -Center $(2,0)$
#
# -Radius squared: $r^2=k+4$
#
# Therefore $k>-4$
#
# **Step 2. Sketching level curve for $k=-3$
#
# Sub in $k=-3$
#
# $(s-2)^2+t^2=1$
# $(s-2)^2+t^2=1$
#
# The curve passes through the poinrs $(1,0),(3,0),(2,1),$ and $(2,-1)$
#
# These curves on a 3D would make a bowl shape.

# %% [markdown]
# **Problem 25:**
#
# For the function: $g(s,t) = s^2 - 4t^2 +6$
#
# Find the level curves at:
#
# $c=6, 10, 2$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# For $c=6$
# *$s^2 - 4t^2 +6 = 6$*
#
# *Subtract 6 from both sides*
#
# *$s^2 - 4t^2 = 0$*
#
# *Solve for one variable*
#
# *$s^2 = 4t^2$*
#
# *$s = +/- 2t$*
#
# *Repeat for other values*
#
# *$s^2 - 4t^2 +6 = 10$*
#
# *$s^2 - 4t^2 = 4$*
#
# *$s^2 - 4t^2 +6 = 2$*
#
# *$s^2 - 4t^2 = -4$*
#
#
# *Using these curves we can visualize what the 3d graph would look like at these points. For $c=6$ we know that this is the equation of two lines, one going up the other sloping down. With the other two c values we can see that it is a hyperbola with the positive one opening left and right and the negative one openung up and down.

# %% [markdown]
# **Problem 26:**
#
# Let $f(x,y) = x + y$.
#
# Find the level curve for $f(x,y) = 4$.
#
# Find the level curve for $f(x,y) = 6$.
#
# Describe the shape of these level curves.
#
# Solution:
# <details> <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Set $f(x,y)$ equal to each constant.
#
# For $f(x,y) = 4$:
# $x + y = 4$
#
# For $f(x,y) = 6$:
# $x + y = 6$
#
# Step 2: Describe the curves.
#
# $x + y = 4$ is a straight line.
# $x + y = 6$ is another straight line.
#
# Final Answer:
# Both level curves are lines.
# The line for $f(x,y) = 6$ is farther from the origin than the line for $f(x,y) = 4$.
#
# </details>

# %% [markdown]
# **Problem 27:**
#
# Consider the function
# $g(s, t) = s^2 - t^2$
# 1. Find the level curves for \(c = -4, 0, 4\)
# 2. Explain what these curves tell you about the shape of the 3D graph of \(g(s,t)\).
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find each level curve
# Level curves are defined by:
# $g(s, t) = c$
# So we solve:
# $s^2 - t^2 = c$
#
# $s^2 - t^2 = -4
# \quad\Longrightarrow\quad
# t^2 - s^2 = 4$
# This is a hyperbola opening upward and downward in the \(t\)-direction.
#
# Level curve for \(c = 0\):
# $s^2 - t^2 = 0
# \quad\Longrightarrow\quad
# s^2 = t^2
# \quad\Longrightarrow\quad
# t = \pm s$
#
# Level curve for \(c = 4\):
# $s^2 - t^2 = 4$
#
# This is a hyperbola opening left and right in the \(s\)-direction.
#
# Because the level curves alternate between hyperbolas opening in opposite directions, the surface is a saddle shape.
# - The level curve for \(c = 0\) (the lines) marks where the surface crosses height zero.
# - Positive level curves (\(c > 0\)) show the function increasing along the \(s\)-axis.
# - Negative level curves (\(c < 0\)) show the function decreasing along the \(t\)-axis.
#
# Together, these reveal the characteristic surface of a hyperbolic paraboloid (saddle).

# %% [markdown]
# **Problem 28:**
#
# Consider the function: $g(s, t) = s^2 + 2t^2$
# 1. Determine the level curves of g for g(s,t)=1,2,4.
# 2. Describe the shape of the level curves.
# 3. Explain in words what the level curves represent in terms of the function’s output.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the level curves\
# Set (g(s, t) = c for constant (c):\
# $s^2 + 2t^2 = c$
#
# Step 2: Describe the shape
# - Ellipses have semi-axis lengths:
#   - Along (s)-axis: $(\sqrt{c})$
#   - Along (t)-axis: $(\sqrt{c/2})$
# - As (c) increases, the ellipses expand outward.
#
#
# *[Explain what these curves might say about a 3D graph]*
# - Each level curve shows all \((s, t)\) points where the function has the same output \(g(s, t) = c\).
# - Moving along a level curve keeps the output constant, while moving to a different curve changes the value.

# %% [markdown]
# **Problem:**
#
# *[Identify the level curves of the following function:
# $4z+2y^2-x=0$]*
#
# **Solution: starting at $4k$ **
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[If $z=k$ : $4k+2y^2-x=0$
# rewrite this equation as $x=2y^+4k$
# ]*
#
# *[the level curve for the function will be parabolas opening to the right and starting at $4k$
# ]*

# %% [markdown]
# **Problem 29:**
#
# *[Create a problem about multivariable functions of two variables, like g(s,t,) and understanding level curves.]*
# Given function
# $$ g(s,t)= 4s^2 - 2t + 6$$
# - Find the domain and range.
# - Find the level curve corresponding to C= 0 and 6.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1) Find Domain
# - Since there is no fraction or square root, the domain is all real numbers.
#
# Step 2) Find Range
# - Since there are no restrictions, the range is all real numbers.
#
# Step 3) Find the level curve by setting the function to =C.
#
# $$4s^2 - 2t + 6 = C$$
# - Solve for t by the quadratic formula or factoring.
# $$-2t=c-4s^2-6$$
# $$t=\frac{c-4s^2-6}{-2}$$
# $$t=2s^2 + 3 - \frac{c}{2}$$
# - This helps describe the level curves of $g(s,t)=c$ as $t(s)$ and shows us that it is a parabola shape but in a 3D space since it has 3 variables.
#
# Step 4) Plug in constants
#
# $$c=0$$
# $$t= 2s^2+ 3-0$$
# $$=2s^2+3$$
#
# $$c=6$$
# $$t=2s^2 + 3 - \frac{6}{2}$$
# $$= 2s^2 +3 - 3=2s^2$$
#
# - So, one of the levels of curves is $t=2s^2 + 3$ and $=2s^2$.

# %% [markdown]
# **Problem 30:**
#
# *[Let  g(s, t) = s^2 + 2t .
#
# 1. Find the level curves of  g(s, t)  for  c = 0, 2, 4 .
#
# 2. Explain what these level curves represent in the 3D graph of  g(s, t) .]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[◦ For  c = 0 :  s^2 + 2t = 0 \implies t = -\frac{1}{2}s^2  (a downward-opening parabola).
#
# ◦ For  c = 2 :  s^2 + 2t = 2 \implies t = 1 - \frac{1}{2}s^2  (a downward-opening parabola shifted up by 1).
#
# ◦ For  c = 4 :  s^2 + 2t = 4 \implies t = 2 - \frac{1}{2}s^2  (a downward-opening parabola shifted up by 2).]*
#
# *[Each level curve corresponds to a horizontal slice of the 3D graph of  g(s, t)  (which is a paraboloid) at height  c . Plotting these curves in 2D shows the projection of the 3D surface at different elevations, making it easier to visualize the shape of the paraboloid.]*

# %% [markdown]
# **Problem 31:**
#
# *Consider the fucntion:*
# *$$g(s,t)=s^{2} + 2t$$*
# - 1. Find the level curve equation for g(s,t) = 4
# - 2. Find the level curve equation for g(s,t) = 0
# - 3. Describe what the level curves of this function look like in the s-t plane.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# - *Level curve for g(s,t)=4*
# *Set function equal to 4* *$$s^{2} + 2t = 4$$*
# *Solve for t* *$$2t = 4 - s^{2}$$* *$$t=\frac{4-s^{2}}{2}$$*
#
# - *Level curve for g(s,t)=0*
# *Set function equal to 0* *$$s^{2} + 2t = 0$$*
# *Solve for t* *$$t=-\frac{s^{2}}{2}$$*
#
# - *What the level curves represent:*
# Both of the level curves are parabolas stacked vertically. As a 3D curve, z=g(s,t)= s^2 + 2t is an upward facing bowl, facing the t direction. Higher values of c shift the parabola upwards.

# %% [markdown]
# **Problem 32:**
#
# *Function:
# g(s, t) = s² + t²
#
# Question:
# Find the level curves for g(s, t) = 1, g(s, t) = 4, and g(s, t) = 9, and explain what these curves tell you about how the function changes as s and t change.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Finding Level Curves:
#
# Set g(s, t) = k for some constant k.
#
# Example values:
#
# g(s, t) = 1 → s² + t² = 1
#
# g(s, t) = 4 → s² + t² = 4
#
# g(s, t) = 9 → s² + t² = 9
#
# These are circles centered at the origin with radius √k.
#
# What this tells us about the 3D graph:
#
# The 3D graph is like a bowl
#
# As k increases, the circles get bigger → the surface gets higher.
#
# Level curves show the height of the surface at different radii without needing a full 3D plot.

# %% [markdown]
# **Problem 33:**
#
# $g(s, t) = s^2 + t^2$
#
# Find the level curve when k = 4
#
# Find the level curve when k = 9
#
# Describe what these level curves look like in the s-t plane
#
# In one sentence, explain how level curves help us understand a multivariable function.
#
# **Solution:**
#
# At k = 4 The radius is 2
#
# $s^2$ + $t^2$ = 4
#
# At k = 9 The radius is 3
#
# $s^2$ + $t^2$ = 9
#
# Each cuirve represents all ponte where the function output is the same heigh in the 3D surface
#
# Level curves show points with same height which let us to understand a 3D surface using a 2D picture.

# %% [markdown]
# **Problem 34:**
#
# Find the level curves of $g(s,t)$ for the values $k = -2,\; 0,\; 2.$ Describe what these level curves tell you about the shape of the 3D graph of $z = g(s,t)$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding level curves:**
# A level curve is found by setting $g(s,t) = k.$
#
# So we solve: $s^2 - t = k.$
#
# Rewriting gives: $t = s^2 - k.$
#
# Now plug in all values of $k$:
#
# $k=-2$: $t = s^2 - 2$
#
# $k=0$: $t = s^2$
#
# $k=2$: $t = s^2 + 2$
#
# For all values of k, the resulting graphs are upward opening parabolas. As k increases, the level curves shift downward.

# %% [markdown]
# **Problem 35:**
#
# Consider the multivariable function
# $$g(s, t) = s^2 + t^2.$$
#
# 1. Find the level curves for $g(s,t)$ when the function takes on the values
#    $$c = 1,\; 4,\; 9.$$
# 2. Describe what these level curves tell you about the 3D surface.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# We are given:
# $$g(s, t) = s^2 + t^2.$$
#
# A level curve occurs when:
# $$g(s,t) = c.$$
#
# So we solve:
# $$s^2 + t^2 = c.$$
#
# - For **c = 1**:
#   $$s^2 + t^2 = 1$$
#   → A circle of radius 1.
#
# - For **c = 4**:
#   $$s^2 + t^2 = 4$$
#   → A circle of radius 2.
#
# - For **c = 9**:
#   $$s^2 + t^2 = 9$$
#   → A circle of radius 3.
#
# Thus the level curves are concentric circles centered at the origin.
#
#
# Since
# $$g(s,t) = s^2 + t^2$$
# opens upwards, the level curves show how the surface rises:
#
# - Each larger value of \(c\) corresponds to a larger circle.
# - As you move outward from the origin, the height increases.
# - The circles spreading outward indicate a smooth, symmetrical surface.
#
# So the 3D graph is a bowl-shaped surface where height depends only on distance from the origin.

# %% [markdown]
# **Problem 36:**
#
# g(s,t) = s^2 + t^2 , Find level curves when c = 1, 4, and 9
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# s^2 + t^2 = c   , s^2 + t^2 = 1  , s^2 + t^2 = 4  , s^2 + t^2 = 9
#
#
#
# These explain a circle of an expanding radius, a sphere centered at 0. As c increases, so does the radius of the circle and by extention the sphere itself.

# %% [markdown]
# **Problem 37:**
#
# *[g(s,t) = 4 - s^2 -2t^2
# find the level curve equation for a general value c. Descbribe the shape of the level curves. Determine whether the level curves shrink grow or stay the same size as c increases. ]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[g(s,t) = c so 4 - s^2 -2t^2 = c so solve for the relation between s and t and multiply both sides by -1 to get the equation of the level curve is s^2 + 2t^2 = 4 -c.
# The shape of level curves and the equation has the form s^2/ a^2 +t^2/b^2 =1 which describes an ellipse as long as 4-c>0. Ellipses are centered at the orgin.
# The equation s^2 + 2t^2 =4 -c as c increase 4 -c gets smaller meaning the level curves shrink as c increases. Now we plug in each value of c so when c = 4  then s^2 + st^2 = 0 (s,t) =(0,0). c=2 s^2 + 2t^2 = 2 semi axix in s is root 2 and semi axis in t is root 1. this shows a small ellipse. when c = 0 s = 2 t = root 2. this shows a pattern c gets smaller as the ellipses grow and c gets larger they shrink toward a point at the orgin.]*

# %% [markdown]
# **Problem 38:**
#
# $g(s,t)= 10-4s+2t$, $c=12$ and $c=6$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Problem 1: $c=12$, $g(s,t)=c$**
# - $10-4s+2t=12$
#     - $4s+2t=2$
#     - $2t=4s+2$
#     - $t=2s+1$
#
# **Problem 2: $c=6$, $g(s,t)=c$**
# - $10-4s+2t=6$
#     - $-4s+2t=-4$
#     - $2t=4s-4$
#     - $t=2s-2$
#
# **Solution: $t=2s+1$ and $t=2s-2$**
#
# *[It shows where the surface has a fixed height. For example, F(s,t)=12 is a slice of the 3D surface at height 12. These slices become straight lines because the surface is a plane. The distance between heights shows how quickly the plane rises or falls.]*

# %% [markdown]
# **Problem 39:**
#
# Consider the multivariable function g(s,t) representing the elevation of a hill (in meters) at coordinates $(s,t)$:
#
# $g(s, t) = 100 - s^2 - t^2$
#
# 1. Find the equation for the level curve where the elevation is 84 meters ($z = 84$)
#
# 2. Decribe the shape of this level curve.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# 1. Set the function equal to the level $z = 84$ :
#
# $84 = 100 - s^2 - t^2$
#
# 2. Rearange the equation to recognize the shape (Move $s^2$ and $t^2$ to the left, and 84 to thr right:
#
# $s^2 + t^2 = 100 - 84$
#
# $s^2 + t^2 = 16$
#
# 3. Describe the shape: This is a standar equation for a circle centered at the origin (0,0)
#
#     The radius is $\sqrt {16} = 4$
#
# **Answer**
#
# The level curve is a circle with a radius of 4.  This means if you walk along the circle 4 units away from the peak, you will stay at a constant height of 84 meters.

# %% [markdown]
# **Problem 40:**
#
# g(s,t) = s^2 + t^2
# s^2 + t^2 = c
#
# for c = 1: s^2 + t^2 = 1 (circle with radius 1)
# for c = 4: s^2 + t^2 = 4 (circle with radius 2)
# for c = 9: s^2 + t^2 = 9 (circle with radius 3)
#
# the level curves are cocentric circles around (0,0) getting bigger as c increases
# the 3d graph of the equation is an upward opening bowl with lowest point at 0,0,0
# As you move away from the origin in the st-plane, z increases (larger circles → higher elevation).
#
# The symmetry and concentric circles = surface is rotationally symmetric around the z-axis.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>

# %% [markdown]
# **Problem 41:**
#
# Consider the function
# $$
# g(s, t) = s^2 + 4t^2.
# $$
# 1. Find the **level curves** of \(g(s, t)\) for the values \(c = 1,\; 4,\; 9\).
# 2. Briefly describe what these curves tell us about the **shape of the 3D surface**.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Level Curves:**
# A level curve satisfies
# $$
# g(s, t) = c \quad \Rightarrow \quad s^2 + 4t^2 = c.
# $$
#
# For the given values:
#
# - **\(c = 1\):**
#   $$
#   s^2 + 4t^2 = 1
#   $$
#   An ellipse that is narrow in the \(t\)-direction.
#
# - **\(c = 4\):**
#   $$
#   s^2 + 4t^2 = 4
#   $$
#   A similar ellipse, scaled outward.
#
# - **\(c = 9\):**
#   $$
#   s^2 + 4t^2 = 9
#   $$
#   A larger ellipse with the same shape.
#
# ---
#
# **Interpretation:**
# These ellipses represent horizontal “slices” of the 3D graph of \(g(s, t)\).
# As \(c\) increases, the ellipses grow outward.
#
# This tells us the surface is shaped like a **bowl opening upward**—a stretched paraboloid. The level curves get larger as height increases, indicating the surface rises smoothly in all directions.

# %% [markdown]
# **Problem:**
#
# *[Create a problem about multivariable functions of two variables like g(s,t) and understanding level curves.]*
#
# g(s,t) = s^2 + t^2 / s^2 - t^2 +
#
#   for all (s,t) where the denominator is nonzero
#
#
# **Solution:**
#
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
#
# part a: Domain
#
# the only restrictions is that the denominator cannot be zero:
#
# s^2 - t^2 + 1 not equal 0
#
#     s^2 - t^2 not equal -1
#
# this is equivalane to saying (s,t) cannot lie on the hyperbola :
#
# s^2 - t^2 = -1 or t^2 - s^2 = 1
#
# domain = {(s,t0)} R^2 | s^2 - t^2 not equal - 1}
#
# part b : level curves
#
# a level curve for g (s,t) = c is given by:
#
# s^2 + t^2 / s^2 - t^2 + 1 = C
#
# s^2 - t^2  = C (s^2 - t^2 + 1)
#
# level curve for c = 0
#
# s^2 + t^2  = 0
#
# its just the orgin
# level curve : a single point (0,0)
#
# level curve for c =  1
#
# s^2 + t^2  = 1 (s^2 - t^2 + 1 )
#
# s^2+t^2 = s^2 - t^2 + 1
#
# 2t^2 = 1
#
# t^2 = 1/2
#
# t = ± 1/squared2
#
# level curve for c = 2
#
# s^2 + t^2  = 1 (s^2 - t^2 + 1 )
#
# s^2 + t^2  = 2s^2 - 2t^2 + 2
#
# s^2 + t^2 - 2s^2 + 2t^2 = 2
#
# -s^2 + 3t^2 = 2
#
# 3t^2 - s^2 = 2
#
# t^2 / 2/3 - s^2 /2 = 1
#
# is a verticle hyperbola centered at orgin, with vertices at (0, ± squared2/3) = (0,±0.816)
#
# level curve for c =  4:
#
# s^2 + t^2 = 4(s^2 - t^2 + 1 )
#
# s^2 + t^2 = 4s^2 - 4t^2 +4
#
# s^2 + t^2 - 4s^2 + 4t^2 = 4
#
# -3s^2 + 5t^2 = 4
#
# t^2 / 4/5 - s^2 / 4/3 = 1
#
# another vertical hyperbola centered at origin with vertices at (0,±squared4/5) = (0,±2/5) = (0,±0.894)
#
#
#
# *[Explain what these curves might say about a 3D graph]*
#
# each level curve g(s,t) =  c is a piece/slice of the surface at height z = c
#
# height c =0 at only one point the orgin(0,0) is at sea level
#
# height c = 1 along two parallel lines - surface is flat along these lines at height 1
#
# heights c>1 along hyperbolas - surface forms "valleys" or "ridges" along these curves

# %% [markdown]
# **Problem 42:**
#
# *The temperature on a circular metal plate is modeled by the function \(T(s,t)=s^{2}+t^{2}+10\), where \((s,t)\) is a point in the plane and \(T\) is the temperature in degrees Celsius. Find the equation for the level curve where the temperature is T=19 degrees Celsius. Identify the geometric shape of this level curve and its key properties.*
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Solution:**
#
# $19=s^{2}+t^{2}+10$
#
# $9=s^{2}+t^{2}$
#
# The equation \(s^{2}+t^{2}=9\) is the standard form of a circle centered at the origin \((0,0)\) with a radius of \(3\).
#
# *A 3D graph the point might form a circle around the origin*

# %% [markdown]
# **Problem 43:**
# Find the level curves for g(s,t) corresponding to c= -4, 0, 4
# Analyze the shape of the curves
#
# $$g(s,t) = s^2 - t^2$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Find level curves by setting g(s,t) = c
#
# $$s^2 - t^2 = c$$
#
# $$c= -4: t^2 - s^2 = 4$$
# $$c= 4: s^2 - t^2 = 4$$
# $$c=0: s^2=t^2 = s = +-t$$
#
# This will create opposing hyberbolas with straight lines down the middle
#
# on a 3d graph this would like like a saddle shape with the curve of c=0 pointing to the origin where the saddle forms.

# %% [markdown]
# **Problem 44:**
#
# $g(x,y) = \sqrt{8-2x^2-y^2}$, calculate the level curves for c = 2,1, and 0
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# 2: $\sqrt{8-2x^2-y^2}=2 \hspace{0.5cm}=>\hspace{0.5cm} 8-2x^2-y^2=4 \hspace{0.5cm}=>\hspace{0.5cm} -2x^2-y^2=-1 \hspace{0.5cm}=>\hspace{0.5cm} -1(-2x^2-y^2)=-1(-4) \hspace{0.5cm}=>\hspace{0.5cm} 2x^2+y^2 = 4$
#
# 1: $\sqrt{8-2x^2-y^2}=1 \hspace{0.5cm}=>\hspace{0.5cm} 8-2x^2-y^2=1 \hspace{0.5cm}=>\hspace{0.5cm} -2x^2-y^2=-7 \hspace{0.5cm}=>\hspace{0.5cm} -1(-2x^2-y^2)=-1(-7) \hspace{0.5cm}=>\hspace{0.5cm} 2x^2+y^2=7$
#
# 0: $\sqrt{8-2x^2-y^2}=0 \hspace{0.5cm}=>\hspace{0.5cm} 8-2x^2-y^2=0 \hspace{0.5cm}=>\hspace{0.5cm} -2x^2-y^2=-8 \hspace{0.5cm}=>\hspace{0.5cm} -1(-2x^2-y^2)=-1(-8) \hspace{0.5cm}=>\hspace{0.5cm} 2x^2+y^2=8$
#
#
# When plotting the curves, the distance between curves can indicate steepness or slope at that section of the function on a 3D plane.

# %% [markdown]
# **Problem 45:**
#
# Find $g(s,t)= 4-s^2=t^2$ when $g(s,t)=1$
#
# **Solution:**
# $\sqrt 3$
# <details>
# <summary><b>Click to reveal solution</b></summary>
# Set function equal to 1: $4-s^2-t^2=1$
#
# Solve for the relationship between s and t: $s^2+t^2=3$
#
# Circle center at the origin with radius: $\sqrt 3$
#
# - Level curves come from setting: $4-s^2-t^2=k$
# - Rearranging: $s^2+t^2=4-k$
# - Each level curve is a circle, and the radius depends on the level value k
# - Larger $k =$ bigger radius
# - Smaller $k =$ Smaller radius
# - When $k=4$, the radius is 0
#
# *[Explain what these curves might say about a 3D graph]*
#
# The level curves are circles, and as the output value increases, the circles get smaller. That tells us the 3D graph is shaped like an upside-down bowl with it's highest point in the middle, because from above, the height decreases as you move outward from the peak

# %% [markdown]
# **Problem:**
#
# g(s, t) = s^2 + 4t^2. Describe what the function represents, and find the level curve equation for the level value (k), in terms of \(s\), \(t\), and \(k\). Find for k = 1, 4, 9
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1 Identifying the function: This is an elliptic paraboloid; it opens upward because of the coefficients.
#
# Step 2 level equation: *$\ g(s,t)=k \quad\Longrightarrow\quad s^2 + 4t^2 = k\ $*
#
# -> then *$\frac{s^2}{k} + \frac{t^2}{k/4} = 1\$*
#
# -> s = *$\sqrt{k}\quad\text{(in the \(s\)-direction)},\qquad  t = \frac{\sqrt{k}}{2}\quad\text{(in the \(t\)-direction)}\$*
#
# Step 3 level curve for k=4: *$\s^2 + 4t^2 = 4 \quad\Longrightarrow\quad \frac{s^2}{4} + t^2 = 1\$*s
#
# Step 4 level curve for k=1,4,9:
#
# - \(k=1:\) ellipse with semi-axes \(1\) (in \(s\)) and \(1/2\) (in \(t\)).
# - \(k=4:\) ellipse with semi-axes \(2\) and \(1\).
# - \(k=9:\) ellipse with semi-axes \(3\) and \(3/2\).

# %% [markdown]
# **Problem 46:**
#
# *[![image.png](attachment:2de41816-b2af-432e-bcb3-f9c5e9ba240c.png)]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *![image.png](attachment:bac66f03-f568-47e8-9b97-0ceb1768b406.png)*
#
# *[Level curves are contour lines of equal elevation, in economics they appear as Indifference curves and Isoquants. They help visualize a 3d surface in 2d]*

# %% [markdown]
# **Problem 47:**
#
# $G(s,t) = s^2 + 2t^2$
#
# k = 1,2,4
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Domain = All real numbers
#
# (because there's no restrictions like $\sqrt, -, \frac {k}{0}$)
#
# g(s,t) = k
#
# k > 0
#
# $\frac {s^2}{k} + \frac {t^2}{k/s} = 1$
#
# $k = 1 => $\frac {s^2}{1} + \frac {t^2}{0.5} = 1$
#
# $k = 2 => $\frac {s^2}{2} + \frac {t^2}{1} = 1$
#
# $k = 4 => $\frac {s^2}{4} + \frac {t^2}{2} = 1$
#
# Range = $[0,oo)$
#
# (non-negative because squares afre always non-negative) no upper bound
#
# *[Explain what these curves might say about a 3D graph]*

# %% [markdown]
# **Problem 48:**
#
# *[Consider the function  g(s,t) = s^2 + t^2 \
# Find the equations of the level curves for g(s,t)g(s,t)g(s,t) when
# g(s,t) = 1 , g(s,t) = 4, g(s,t) = 9]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[s^2 + t^2 = 1 \
# s^2 + t^2 = 4 \
# s^2 + t^2 = 9]*
#
# *[The level curves tell you this 3D graph is a symmetric “bowl” where height depends only on how far you are from the origin, not the direction.]*

# %% [markdown]
# **Problem 49:**
#
# Let f(x,y) = x^2 - 4y + 2xy.
# Find the level curve where f(x,y) = 6 and explain what this curve represents on the 3D surface z = f(x,y).
#
# **Solution:**
#
# Start with the level-curve equation:
# x^2 - 4y + 2xy = 6
#
# Rearrange the equation to isolate y terms:
# 2xy - 4y = 6 - x^2
#
# Factor out y:
# y(2x - 4) = 6 - x^2
#
# Solve for y (assuming x ≠ 2):
# y = (6 - x^2) / (2x - 4)
#
# This equation describes the level curve in the xy-plane.
# It is not a line or a circle; it is a rational curve because y depends on x through a fraction involving x^2.
#
# When x = 2, the denominator becomes 0, so no finite y satisfies the equation.
# This means the level curve has a vertical asymptote at x = 2.
#
# On a 3D surface, the function f(x,y) defines a surface z = f(x,y).
# A level curve is a horizontal “slice” of this surface at a fixed height.
# Setting f(x,y) = 6 means we slice the surface at z = 6.
# The curve y = (6 - x^2) / (2x - 4) shows exactly where the surface touches the height z = 6.
# In 3D, this appears as the intersection of the surface with the horizontal plane z = 6.
# In 2D (the xy-plane), we see only the shadow of that intersection, which is why we get the curve above.

# %% [markdown]
# **Problem 50:**
#
# *[Let $(f(x, y) = x + y^2$. Find the level curves for f=0, f=2, and f=4.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[$f = 0: x + y^2 = 0$]*
# *[$x = -y^2$]*
#
# *[$f = 2: x + y^2 = 2$]*
# *[$x = 2 - y^2$]*
#
# *[$f = 4: x + y^2 = 4$]*
# *[$x = 4 - y^2$]*
#
# *[the higher the f is in this function the higher the point is. ]*

# %% [markdown]
# **Problem 51:**
#
# Given $f(x,y)=x^2+y^2$, sketch the level curves for when $f(x,y)= 16,36,81$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# If we look at $f(x,y)$, it looks like the equation of a circle, so when we set our equation equal to 16,36,81, our level curves will look like circles. The radius of these circles will be the square root of the value we set $f(x,y)$ equal to (if we set it equal to 16, the radius is 4).
#
# here is what our level curves will look like
# ![image.png](attachment:d6bdbc4f-d648-46c6-9a4e-764cbd922cc6.png)
#
# For our function, the 3d graph looks similar to a parabola, but in 3d (kind of like a bowl). When we set our function equal to a constant, imagine you are taking a slice out of the bowl horizontally at a certain height (the constant). That slice looks like a circle, which is also what our level curves look like.

# %% [markdown]
# **Problem:**
#
# $(f,y)=x^2+y^2$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $x^2+y^2=0$ ->point(0,0)
#
# $x^2+y^2=1$ ->circle radius 1 centered at (0,0)
#
# $x^2+y^2=4$ ->circle radius 2 centered at (0,0)
#
# This tells us it is a cone that starts at (0,0) and goes up and gets more wider.

# %% [markdown]
# **Problem:**
#
# Consider the function
# $
# g(s,t) = s^2 + 2t^2 - 4s + 1.
# $
#
# 1. Find the level curves of $g(s,t)$ for
#    $
#    c = 0,\; 2,\; 5,\; 10.
#    $
# 2. Describe the shapes of these level curves in the $s$–$t$ plane.
# 3. Explain what these curves suggest about the 3D graph of $z = g(s,t)$.
#
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **1. Finding the Level Curves**
#
# Level curves are defined by
# $
# g(s,t) = c.
# $
#
# So we solve
# $
# s^2 + 2t^2 - 4s + 1 = c.
# $
#
# Rearrange:
# $
# s^2 - 4s + 2t^2 + 1 = c.
# $
#
# Complete the square in $s$:
# $
# s^2 - 4s = (s-2)^2 - 4.
# $
#
# Substitute:
# $
# (s-2)^2 - 4 + 2t^2 + 1 = c,
# $
#
# $
# (s-2)^2 + 2t^2 = c + 3.
# $
#
# Now plug in the given values:
#
# - For $c = 0$:
#   $
#   (s-2)^2 + 2t^2 = 3.
#   $
#
# - For $c = 2$:
#   $
#   (s-2)^2 + 2t^2 = 5.
#   $$
#
# - For $c = 5$:
#   $
#   (s-2)^2 + 2t^2 = 8.
#   $
#
# - For $c = 10$:
#   $
#   (s-2)^2 + 2t^2 = 13.
#   $
#
#
#
# **2. Shape of the Level Curves**
#
# Each equation has the form
# $
# \frac{(s-2)^2}{A} + \frac{t^2}{B} = 1.
# $
#
# This is the equation of an **ellipse** centered at $(2,0)$.
#
# As $c$ increases:
#
# - The right-hand side ($c+3$) grows.
# - The ellipses get **larger**.
# - All ellipses remain centered at the same point $(2,0)$.
#
#
#
# **3. What the Level Curves Tell Us About the 3D Graph**
#
# The surface
# $
# z = g(s,t) = s^2 + 2t^2 - 4s + 1
# $
# can be rewritten as
# $
# z = (s-2)^2 + 2t^2 - 3.
# $
#
# This is a **paraboloid**:
#
# - It opens upward.
# - Its minimum value is located at $(s,t) = (2,0)$.
# - The level curves represent horizontal slices of this paraboloid.
#
# As $z = c$ increases, the slices get farther from the minimum, producing **expanding ellipses**, matching the results above.
#
# </details>

# %% [markdown]
# **Problem 52:**
#
# *[Consider the function
# $\displaystyle g(x, y) = x^2 + y.$
#
# Find the **level curves** for the values $k = 0,\ 2,\ 4$.
# Describe in words what these curves look like on the $xy$-plane.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[**Step 1: Set up the level curve equation**
#
# A level curve is defined by
# $\displaystyle g(x, y) = k.$
#
# So we can solve
# $x^2 + y = k.$
#
# Rewriting for $y$:
#
# $y = k - x^2.$
#
#
# Step 2: Find the level curves using the given values
#
# - **For $k = 0$:**
#   $\displaystyle y = -x^2$
#
# - **For $k = 2$:**
#   $\displaystyle y = 2 - x^2$
#
# - **For $k = 4$:**
#   $\displaystyle y = 4 - x^2$]*
#
# *[Each level curve is a upside down parabola.
# As $k$ increases, the entire parabola shifts up on the $y$-axis.
#
# Each curve is just a horizontal slice of $z = x^2 + y$.]*

# %% [markdown]
# **Problem 53:**
#
# *[Create a problem about multivariable functions of two variables like g(s,t) and understanding level curves.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find level curves for several values]*
#
# *[Explain what these curves might say about a 3D graph]*

# %% [markdown]
# **Problem 54:**
#
# Consider the function
#
# $$g(s,t)=s+2t$$
#
# **1.** Find the level curves of $g(s,t)$ for $c=0, 2, 4$
#
# **2.** Explain briefly what these level curves tell you about the shape of the surface $z=g(s,t)$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **1.** A level curve is defined by $$g(s,t) =c$$
#
# Since $$g(s,t) = s +2t$$
#
# We set: $$s+2t = c$$
#
# Now solve for $t$: $$t= \frac{c-s}{2}$$
#
# Then plug in each value $c$ :
#
# - For $c=0$ $$t= -\frac{s}{2}$$ A straight line through the origin.
#
# - For $c=2$ $$t= \frac{2-s}{2}$$ A parallel line shifted upward.
#
# - For $c=4$ $$t= \frac{4-s}{2}$$ Another parallel line, shifted even more.
# - We see that all the level curves are straight parallel lines.
#
# **2.** Because each level curve is a straight line and all of them are parallel, the function $z=s+2t$ represents a tilted plane in three dimensions.
#
# - Straight, evenly spaced level curves → the surface has a constant slope.
#
# - The fact that all the lines have the same slope means that the plane tilts in a single consistent direction.

# %% [markdown]
# **Problem 55:**
#
# \[
# g(s, t) = s^2 + t^2.
# \]
#
# 1. Find the level curves for the values \(c = 1\), \(c = 4\), and \(c = 9\).
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# \[
# g(s,t) = c.
# \]
#
#
# \[
# s^2 + t^2 = c.
# \]
# \[
#   s^2 + t^2 = 1
#   \]
#   This is a circle of radius 1.
#
#
#   \[
#   s^2 + t^2 = 4
#   \]
#   This is a circle of radius 2.
#
#
#   \[
#   s^2 + t^2 = 9
#   \]
#   This is a circle of radius 3.
# *The circls form like a bowl shaped surface that gets taller and taller*

# %% [markdown]
# **Problem 56:**
#
# *[$g(s,t)=(16-s^2-t^2)^.5$
#
# Find the level curve at $g(s,t)=0$
#
# Describe the curve in the xy plane]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[
# 1.Level curve for $g(s,t)=2$
#
# Square both sides: $4=16-s^2-t^2$
#
# Isolate s and t: $s^2+t^2=12$
#
# The level curve at 2 is $x^2+y^2=12$
#
# 2.This is a circle centered at (0,0) with a radius of $\sqrt{12}$
#
#
# This process can be repeated for several level curves like 0
#
# Ex: Square both sides: $0=16-s^2-t^2$
# Isolate s and t: s^2+t^2=16
#
# The level curve at 0 is $x^2+y^2=16$
#
# Which is a circle at g(x,y)=0 with radius 4]*
#
#
#
# *[The level curve shows us that the 3d surface is likely a sphere.]*

# %% [markdown]
# **Problem 57:**
#
# *g(x,y)= $x^2 - y$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# 1. Start by taking the initial function and setting it equal to a constant c, $x^2 - y = c $
#
# 2. Then solve for y, $ y = x^2 - c $,
# which also signifies that its an upwards opening parabolic shape!
#
# 3. Then you can take different values of c, to interpert how the curves reflect the 3d surface.
#
# Ex: If c=0, then $y= x^2$
#
# If c=3, then $y= x^2 - 3$
#
# If c=-3, then $y= x^2 + 3$
#
# The domain can be any real number since neither has any limits, as long as it has no variables that would break the math or function like a root.
#
# The range thus, would be any real number since x^2 can produce a value from 0 to infinity, and y can be any real number, which means the output can be any real number!
#
# * What the curves would say is that g(x,y) looks like a smooth parabolic bowl that opens upward, and each value of c slices it horizontally.*

# %% [markdown]
# **Problem 58:**
#
# *[The temperature on a metal plate depends on x and y. The temperature function is T(x,y)=100-x^2-y^2. Find the level curves for temperatures T=75. Give a few points (x,y) that lie on the T=50 curve.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Step 1: Set the temperature equal to a constant (75).
# Step 2: give the points to for T = 50, x^2 + y^2 = 50]*
#
# *[These curves might say that a 3D graph would be in a shape of a hill]*

# %% [markdown]
# **Problem 59:**
#
# *[Create a problem about multivariable functions of two variables like g(s,t) and understanding level curves.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find level curves for several values]*
#
# *[Explain what these curves might say about a 3D graph]*

# %% [markdown]
# **Problem 60:**
#
# *[g(s,t)=10-s^2]-t^2 and find the level curves g(s,t)=10,g(s,t)=5,g(s,t)=0.*
#
# **Solution:**
# c= 10 is a signle point at (0,0)
# c=5 is a circle radius of square root of 5
#     for c=0 is a circle radius of square root 10
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[g(s,t)=c⇒10−s2−t2=c
# s2+t2=10−c
#
# for c=10 s2+t2=10−10=0
# c=5 s2+t2=10−5=5 for c=0 s2+t2=10−0=10
# ]*
#
# *[These level curves show that:
# The function decreases as you move away from the origin.
#
# The output is largest at
# (0,0)(0,0) and shrinks as distance increases.
#
# The 3D surface is a downward-opening bowl / inverted paraboloid.
#
# Each level curve is a circle, telling us the surface is symmetric in all directions.]*

# %% [markdown]
# **Problem 61:**
#
# $$g(x,y)=e^{x-y}$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1:
# - Set the function equal to a constant--> $e^{x-y}=k$
#
# Step 2:
# - Let's solve for y by taking ln of both sides to cancel out the $e--> lne^{x-y}=ln(k)$
#
# Step 3:
# - let's isolate y by putting only y on the left side of the equation--> $y=x-ln(k)$
#
# Step 4:
# - Now let's pick 3-4 values for k like 1, 2, 1/2, 1/4 and solve for y
#
#
# Using the answers in step 4, we can infer that as the value for k decreases, the level curves start to (BLANK). On the other hand, as the value for k increases, the level curves begin to (BLANK).

# %% [markdown]
# **Problem 62:**
#
# *[f(x,y) = x + y
# Find:
# 1. f(2,3)
# 2. f(1,4)
# 3. f (0,5) What do you notice about these three answers? ]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Plug x and y values into x+y.]*
#
# *[f(2,3) = 2+3 = 5
# f(1,4) = 1+4 = 5
# f(0,5) = (0,5)= 5
# They all equal 5 meaning they are on the same level curve. All these points lie on a straight line in the xy- plane. A level curve connects all points with the same output value]*

# %% [markdown]
# ### Sample Problem 5.1b: Multivariable Functions

# %% [markdown]
# **Problem**
#
# **Consider the function**
# $$ g(s, t) = s^2 + t^2 + 2st $$
#
# **Step 1:** Find the level curves for $g(s,t)$ when $g(s,t) = 1, 4, 9$.
#
# **Step 2:** Sketch or describe what these level curves look like on the s-t plane.
#
# **Step 3:** Explain what these curves tell you about the 3D surface of $g(s,t)$.
# * A level curve is a set of points $(s, t)$ where the function "
# takes on the same constant value. Understanding level curves helps visualise the function
# without plotting the full 3D surface.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Solution:**
#
# **Step 1:** To find level curves, set $g(s,t) = k$ for different constants $k$:
# * For $$ k = 1: s^2 + t^2 + 2 s t = 1 $$
# * For $$ k = 4: s^2 + t^2 + 2 s t = 4 $$
# * For $$ k = 9: s^2 + t^2 + 2 s t = 9 $$
#
# **Step 2:** These are equations of ellipses rotated at 45° on the s-t plane. Each curve represents points where the function has the same value.
#
# **Step 3:** Interpretation
#
# * Level curves are like contour lines on a map.
# * Closer curves indicate steeper parts of the 3D surface.
# * Farther apart curves indicate flatter regions.
# * The 3D surface of $g(s,t)$ rises faster where the curves are closer together.

# %% [markdown]
# **Problem 63:**
#
# *Define $g(s,t)=s^2+4t^2$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# -$s^2+4t^2=c$
# -If c<0, $s^2+4t^2$ always >0 so level curve empty
# -If c=0, $s^2+4t^2$=0 so level set to single point (0,0)
# -If c>0, the $\frac{s^2}{c} + \frac{t^2}{c/4} = 1$
# -Ellipse centeretd at orgin with semi-axes of s-direction:$a=sqrc$ t-direction: $b=sqr{c/4}$ or $\frac{1}{2} sqrc$
# - at c=0: point at (0,0)
# - at c=1: $s^2+4t^2$=1. Semi axes: a=1, b=$\frac{1}{2}$
# - at c=4: $s^2+4t^2$=4. Semi axes: a=2, b=1
# - at c=9: $s^2+4t^2$=9. Semi axes: a=3, b=$\frac{3}{2}$
#
#
# *Graphically, all ellipses are centerate at the orgin and elongated more along the s-axis because the t-term is weighted by 4. As c increases, the ellipses grow large but maintain the same eccentricity.*

# %% [markdown]
# **Problem 64:**
#
# g(s,t)=s^2+t^2 c=16
#
#
# **Solution:**
# -s^2+t^2=16
#
# -radius is 4, and forms a bowl like thing

# %% [markdown]
# **Problem 65:**
#
# find the level curves of function $f(x,y)=-8+3x+8y$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Work:
# $c=2, y=-8+3x+8y=2$
#
# $8y=-3x+8+2$
#
# $\frac{8y}{8}=\frac{-3x+10}{8}$
#
# $y=\frac{10}(8} - \frac{3x}{8}$
#
# $c=6, y=-8+3x+8y=6$
#
# $8y=-3x+8+6$
#
# $8y=3x+14$
#
# $y=\frac{14}{8}-\frac{3x}{8}$
#
# Solution:
#
# $y=\frac{10}(8} - \frac{3x}{8}$
#
# $y=\frac{14}{8}-\frac{3x}{8}$
#
#
# *[Explain what these curves might say about a 3D graph]*

# %% [markdown]
# ### Sample Problem 5.1b: Multivariable Functions

# %% [markdown]
# **Problem 66:**
#
# $g(s,t) = s^2 + 4t^2$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $s^2 + 4t^2 = c$  *and*  $g(s,t) = c$
#
# For c = 1, 4, 9
#
# Set $c=1$
#
# $s^2 + 4t^2 = 1$
#
# $\frac{s^2}{1} + \frac{t^2}{1/4} = 1$
#
# Semi-axes: $(a = 1, b = 1/2)$
#
# Set $c=4$
#
# $s^2 + 4t^2 = 4$
#
# $\frac{s^2}{4} + \frac{t^2}{1} = 1$
#
# Semi-axes: $(a = 2, b = 1)$
#
# Set $c=9$
#
# $s^2 + 4t^2 = 9$
#
# $\frac{s^2}{9} + \frac{t^2}{9/4} = 1$
#
# Semi-axes: $(a = 3, b = 3/2)$
#
#
# Each level curve shows where the surface intersects a horizontal plane $z=c$. All elipses expand outward as $c$ increases, showing the surface rises outward like a bowl.

# %% [markdown]
# **Problem 67:**
#
# *Let the utility function be $U(x, y) = x^2 + y$. Find the equations for the level curves corresponding to $z = 1$ and $z = 4$. *
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *To find a level curve, we set $f(x,y) = $.For $ = 1$:$$1 = x^2 + y$$$$y = 1 - x^2$$This is a downward-opening parabola with a y-intercept at 1.For $z = 4$:$$4 = x^2 + y$$$$y = 4 - x^2$$This is a downward-opening parabola with a y-intercept at 4.Interpretation:As $z$ increases, the parabolas shift upwards along the y-axis.*
#
# *[Explain what these curves might say about a 3D graph]*

# %% [markdown]
# **Problem 68:**
#
# g(s,t) = s^2 + t^2
#
# Find the equation of the level curve where g(s,t) = 9
# Describe the shape of this level curve
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# g(s,t) = 9
#
# This is a circle of radius 3 centered at the origin. So the level curve consists of all points (s,t) that are exactly 3 units away from the origin.

# %% [markdown]
# **Problem 69:**
#
# *Using the same equation as above let us try to figure out the level curve of c = 1 and c = 3*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *We start off by setting our function equal to our level curves so we will start with 1. We start off by squaring both sides to get rid of the square root of $16 - x^2 - y^2$. Next we move our constants to one side and get rid of the negatives by multiplying both sides by $-1$ and our result is $x^2 + y^2 = 15$ which is a circle with a radius of the square root of 15. Now we can take the same process and apply it to different level curves this time we will try it with c = 3. after squaring and changing the signs we get $x^2 + y^2 = 7$ therefore our answer is a circle with a radius of the square root of 7*
#
# *In a 3-D perspective we can use level curves to try and visualize on a 2-D scale our graph/surface by using the level curves, c, as different elevations and thinking about the line represented by that curve on a single elevation. From our example we see that all the level curves are circles of different elevations so we can infer that our equation is a 3-D circle *

# %% [markdown]
# **Problem:**
#
# *[Create a problem about multivariable functions of two variables like g(s,t) and understanding level curves.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find level curves for several values]*
#
# *[Explain what these curves might say about a 3D graph]*

# %% [markdown]
# **Problem 70:**
#
# *[f(x,y)=e^x+2^y with example curves like 3,5,9]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[1. we want to use a constant to represent our curve levels and to only solve for one variable.
#     e^x+2^y=C ---> 2^y=c-e^x --> y=log_2(C-e^x)
#     C=3; y=log_2(3-e^x)
#     C=5; y=log_2(5-e^x)
#     C=9; y=log_2(5-e^x)
#     2. Our function is down do to the logs. Due to the level curves are bigger and bigger then the domain is growing. ]*
#
# *[The surface is always growing or increasing in both x and y. Level curves are in a constant height, so they increase x and decrease y. ]*

# %% [markdown]
# **Problem 71:**
#
# $g(s, t) = 10 − s^2 − 4t^2$. Find the level curve where $g(s, t) = 6$ and $0$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# for $g(s, t) = 6$:
# - $10 − s^2 − 4t^2 = 6$
# - $s^2 + 4t^2 = 4$
# - $−2 ≤ s ≤ 2$, $−1 ≤ t ≤ 1
#
# for $g(s, t) = 0$:
#
# - $10 − s^2 − 4t^2 = 0$
# - $s^2 + 4t^2 = 10$
# - $−\sqrt{10} ≤ s ≤ \sqrt{10}$, $−\sqrt{10}/{2} ≤ t ≤ \sqrt{10}/2$
#
# These curves say that the graph is shaped like a bowl, as the values decrease the further away you get from the center.

# %% [markdown]
# </details>

# %% [markdown]
# **Problem 72:**
#
# *Example
#
# 		g(s,t) = s^2 + 4t^2
# 	Step 1: Find the equation of the level curve corresponding to g(s,t)=9
# 	Step 2: Describe its shape
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Solution
# The curve is level
# s^2 + 4t^2 =9
# this is an ellipse centered at the origin, stretched differently in the s and t directions.
