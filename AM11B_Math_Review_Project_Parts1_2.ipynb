# %% [markdown]
# # AM 11B Project: Math Concept Review
# ___
#
# This is a project that can be done in groups or individually. Please write the names of your group (or self) below by double-clicking on the text below.

# %% [markdown]
# **NAME(S)**: *Replace this text with your name(s)*

# %% [markdown]
# **Welcome to your final review project!**
#
# This notebook is designed for you to create comprehensive study materials that will help the entire class review key mathematical concepts from AM 11B.
#
# ### Your Mission:
# For each topic covered in the course, you will:
# 1. **Identify problem types** and when to use different techniques
# 2. **Create setup templates** showing the general approach
# 3. **Work through sample problems** with detailed solutions.
# 4. **Build a study guide** that your classmates can use
#
# ### Instructions:
# - Work through each section sequentially
# - Fill in the markdown cells with your explanations and work
# - Use the code cells to demonstrate techniques and check your work
# - Create clear, well-organized examples that others can follow. You must create **new** sample problems, not just repeat the examples provided.
# - Use the "reveal" pattern to hide solutions (this will help for studying!)
#
# ### Grading:
# This project will be graded on:
# - Completeness of your study materials
# - Clarity of explanations
# - Correctness of worked examples
#
# ### Note:
# This project will deployed in parts. This is to help with both grading as well as help you pace with course content.
#
# ### Useful information before you start:
# <div class="alert alert-block alert-info">
# This notebook will require you to write some math in it, not just words. You will see examples as you go, which should provide guidance. Some tips:
#
# 1. There are two types of notebook "cells" or "blocks" that make up this notebook:
#
#    <!-- <div class="alert alert-block alert-success"> -->
#
#     1. **Markdown** (regular text, for regular answers/written questions); and
#     2. **Code** (for any code that may help with visualizing or checking work). You are **not** expected to code. These parts are optional but may be helpful.
#    <!-- </div> -->
#
# 2. Double clicking on a cell makes it **editable**, so you can change things.
# 3. **Only edit cells where you are asked to do so**.
# 4. Typing math nicely requires you to use the dollar sign \$ around your math expressions. You will see examples. **It is okay if you do not do this in your answers.**
# 5. **Powers/exponents have special notation**. When written in regular text/Markdown cells, we write $x^4$ as <code>x^4</code>. But in code cells, we will use the ** notation instead of ^: <code> x**4 </code>
# </div>
#
# ___

# %% [markdown]
# ## Setup
#
# Run the following cell to import the necessary tools.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import integrate
import sympy as sp
from IPython.display import display, Markdown, Latex

# Configure sympy for nice mathematical output
sp.init_printing()

# Define symbolic variables we'll use throughout
x, y, z, t = sp.symbols('x y z t')
a, b, c, h, k = sp.symbols('a b c h k')

print("Setup complete! Ready to create study materials.")
# Out:
# Setup complete! Ready to create study materials.

# %% [markdown]
# # PART 1: INTEGRATION FUNDAMENTALS
# ___
#
# ## Week 0-1: Antiderivatives and Definite Integration

# %% [markdown]
# ### 1.1 Antiderivatives: When and How to Use Them
#
# **YOUR TASK:** Create a reference guide for recognizing when to find antiderivatives and the basic rules.
#
# Fill in the cells below with:
# - When do we use antiderivatives? (Give 2-3 scenarios)
# - What are the key power rules, exponential rules, and special cases?
# - Common mistakes to avoid

# %% [markdown]
# **What are antiderivatives?**
#
# *[Replace this with your explanation]*
#
# **Basic Antiderivative Rules:**
#
# *[List a few of the most important antiderivative formulas here:]*
# - Power rule: $\int x^n dx = ...$
# - *[Add more rules]*
#
# **Common Mistakes:**
#
# *[List 1-2 common mistakes students make with antiderivatives]*

# %% [markdown]
# ### Sample Problem 1.1: Basic Antiderivatives
#
# **YOUR TASK:** Create a sample problem and work it out step-by-step.
#
# Create a problem that requires finding an antiderivative of a polynomial or simple function.

# %% [markdown]
# **Problem:**
#
# *[Write your problem here. Example: Find the antiderivative of $f(x) = 3x^2 - 4x + 5$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Work through your problem step by step here. Show all work clearly.]*
#
# Step 1: *[First step]*
#
# Step 2: *[Second step]*
#
# Final Answer: *[Final answer with constant of integration]*
#
# </details>

# %% [markdown]
# ### Optional Part:
#
# Python actually has a built-in integrator! So we can actually check our work with python by editing the code below. Lines you would edit are labeled by:
#
# <code style="background:black;color:white"> # EDIT HERE </code>

# %%
# Use this cell to verify your answer with SymPy
# Example code:
f = 3*x**2 - 4*x + 5 # EDIT HERE
F = sp.integrate(f, x)
display(F)
# Out:
#  3      2
# x  - 2⋅x  + 5⋅x

# %% [markdown]
# ### 1.2 Summation Notation
#
# **YOUR TASK:** Create and solve a problem involving summation notation.
#
# **Problem:**
#
# *[Write a problem asking to write out what a summation means, e.g., $\sum_{k=3}^{9} kx^2 +3k$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show or explain work]*
#
# **Answer:** *[Final  answer]*
#
# </details>

# %% [markdown]
# ### 1.3 Definite Integrals and Riemann Sums
#
# **YOUR TASK:** Explain the connection between Riemann sums and definite integrals.
#
# Create a visual guide that shows:
# - What a Riemann sum represents
# - How it relates to the definite integral
# - The notation: $\int_a^b f(x) dx$

# %% [markdown]
# **Concept of Definite Integrals:**
#
# *[Explain what the definite integral represents graphically]*
#
# **Riemann Sums Overview:**
#
# *[Explain what Riemann sums are]*
#
# **Connection to Definite Integrals:**
#
# *[Explain how the limit of Riemann sums gives us the definite integral]*
#
# **Key Formula:**
#
# $$\int_a^b f(x) dx = \lim_{n \to \infty} \sum_{i=1}^{n} f(x_i^*) \Delta x$$
#
# *[Identify which parts of the expression on the left match with the expression on the right.]*

# %% [markdown]
# ___
#
# # PART 2: INTEGRATION TECHNIQUES
#
# ## Week 2-3: FTC, Properties, and Substitution

# %% [markdown]
# ### 2.1 The Fundamental Theorem of Calculus (FTC)
#
# **YOUR TASK:** Create a clear explanation of both parts of the FTC and when to use each.

# %% [markdown]
# **Part 1 of FTC:**
#
# If $F(x) = \int_a^x f(t) dt$, then $F'(x) = f(x)$
#
# *[When do we use this?]*
#
# **Part 2 of FTC:**
#
# $$\int_a^b f(x) dx = F(b) - F(a)$$
#
# where $F$ is any antiderivative of $f$
#
# *[When do we use this?]*

# %% [markdown]
# ### Sample Problem 2.1: Computing a Definite Integral using the FTC Part 2
#
# **YOUR TASK:** Create and solve a problem involving a definite integral.

# %% [markdown]
# **Problem:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (x^2 + 1) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Show work]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]*
#
# Step 3: Subtract
#
# *[Final calculation]*
#
# **Answer:** *[Final numerical answer]*
#
# </details>

# %% [markdown]
# ### Optional Part:
#
# We can use Python's built-in integrator to check our work by editing the code below. Lines you would edit are labeled by:
#
# <code style="background:black;color:white"> # EDIT HERE </code>

# %%
# Verify your answer computationally
# Example:
result = sp.integrate(x**2 + 1, (x, 0, 2)) # EDIT HERE (function, bounds = 0,2)
print(f"Result: {result}")
# Out:
# Result: 14/3

# %% [markdown]
# ### Sample Problem 2.2: Using the FTC Part 1
#
# **YOUR TASK:** Create a problem that requires applying the FTC.

# %% [markdown]
# **Problem:**
#
# *[Create a problem, such as: Find $\frac{d}{dx}\int_1^x t^3 dt$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Work through using the appropriate part of FTC]*
#
# </details>

# %% [markdown]
# ### 2.2 Average Value of a Function
#
# **YOUR TASK:** Explain how to find and interpret the average value of a function.

# %% [markdown]
# **Average Value Formula:**
#
# $$f_{avg} = \frac{1}{b-a} \int_a^b f(x) dx$$
#
# *[Explain what this formula means and why it makes sense]*

# %% [markdown]
# ### Sample Problem 2.2: Average Value
#
# **YOUR TASK:** Create and solve an average value problem.

# %% [markdown]
# **Problem:**
#
# *[Create a problem about average value]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# </details>

# %% [markdown]
# ### 2.3 U-Substitution: Recognition and Setup
#
# **YOUR TASK:** Create a comprehensive guide for recognizing when to use u-substitution.
#
# This is one of the most important techniques! Make this section thorough.

# %% [markdown]
# **When to use u-substitution:**
#
# *[List 1-2 signs that suggest u-substitution is needed:]*
# 1. *[When you see ...]*
# 2. *[When you see ...]*
#
# **How to choose u:**
#
# *[Explain strategies for choosing the substitution]*
#
# **Step-by-step template:**
#
# 1. [first thing to do]
# 2. [next thing to do]
# 3.
#
# *[Fill in steps and add more, as needed]*

# %% [markdown]
# ### Sample Problem 2.3a: Basic U-Substitution
#
# **YOUR TASK:** Create a straightforward u-substitution problem.

# %% [markdown]
# **Problem:**
#
# *[Example: $\int 2x(x^2 + 1)^5 dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** Choose u = *[what?]*
#
# **Step 2:** Find du = *[what?]* dx
#
# **Step 3:** Rewrite the integral: $\int ...$
#
# **Step 4:** Integrate: *[show work]*
#
# **Step 5:** Substitute back: *[final answer]*
#
# </details>

# %% [markdown]
# ### Sample Problem 2.3b: Definite Integral with U-Substitution
#
# **YOUR TASK:** Create a definite integral problem requiring u-substitution.

# %% [markdown]
# **Problem:**
#
# *[Create a definite integral problem]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Don't forget to change the bounds when you substitute!]*
#
# *[Show complete work]*
#
# </details>

# %% [markdown]
# ### 2.4 Area Between Curves
#
# **YOUR TASK:** Create a guide for setting up area between curves problems.

# %% [markdown]
# **Key Concept:**
#
#  Area = Integral of (Top - Bottom)
#
# **Setup Strategy:**
#
# 1. *[How to identify which function is on top]*
# 2. *[How to find intersection points, if any]*
# 3. *[How to set up the integral]*
# 4. *[When to split into multiple integrals]*
#
# **Formula:**
#
# $$A = \int_a^b [f(x) - g(x)] dx$$
#
# where $f(x) \geq g(x)$ on $[a,b]$

# %% [markdown]
# ### Sample Problem 2.4: Area Between Curves
#
# **YOUR TASK:** Create an area problem with a sketch.

# %% [markdown]
# **Problem:**
#
# *[Create a problem finding area between two curves]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** Find intersection points
#
# *[Show work]*
#
# **Step 2:** Determine which function is on top
#
# *[Test a point or explain reasoning]*
#
# **Step 3:** Set up the integral
#
# *[Write the integral expression]*
#
# **Step 4:** Evaluate
#
# *[Show calculation]*
#
# </details>

# %% [markdown]
# ### Optional Part:
#
# You can visualize what this means by editing the code below to fit your functions from your example. Lines you would edit are labeled by:
#
# <code style="background:black;color:white"> # EDIT HERE </code>

# %%
# Use this cell to create a plot showing the curves and shaded area
# Example code:
def f(x):
    return 8-x**2 # EDIT HERE

def g(x):
    return x**2 # EDIT HERE

x_vals = np.linspace(0, 2, 100) # EDIT HERE (0 = start, 2 = stop ... change these)
y1 = f(x_vals)
y2 = g(x_vals)
plt.fill_between(x_vals, y1, y2, alpha=0.3)
plt.plot(x_vals, y1, label='f(x)')
plt.plot(x_vals, y2, label='g(x)')
plt.legend()
plt.show()

# %% [markdown]
# ___
#
# # PART 3: ADVANCED INTEGRATION
#
# ## Week 4: Additional Integration Techniques

# %% [markdown]
# ### 3.1 Integration by Parts
#
# **YOUR TASK:** Create a guide for recognizing and applying integration by parts.
#
# Note: Make sure to explain the LIATE rule for choosing u!

# %% [markdown]
# **Integration by Parts Formula:**
#
# $$\int u \, dv = uv - \int v \, du$$
#
# **When to use it:**
#
# *[Explain what types of integrals need integration by parts]*
#
# **LIATE Rule for choosing u:**
#
# *[Explain the LIATE priority: you can look this up by Googling]*
#
# **Step-by-step process:**
#
# *[Provide a template for setting up and solving]*

# %% [markdown]
# ### Sample Problem 3.1: Integration by Parts
#
# **YOUR TASK:** Create and solve an integration by parts problem.

# %% [markdown]
# **Problem:**
#
# *[Create a problem, e.g., $\int x e^x dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** Choose u and dv using LIATE
#
# *[Show choices and why]*
#
# **Step 2:** Find du and v
#
# *[Show derivatives and antiderivatives]*
#
# **Step 3:** Apply the formula
#
# *[Show substitution]*
#
# **Step 4:** Simplify
#
# *[Final answer]*
#
# </details>

# %% [markdown]
# ### 3.2 Partial Fractions
#
# **YOUR TASK:** Create a guide here for how the method works.

# %% [markdown]
# **When to use it:**
#
# *[Explain what types of integrals need integration by parts. You may find it helpful to have a big picture formula like:]*
#
# $\int \frac{polynomial}{polynomial}\, dx = $ [fill in idea here]
#
# **Step-by-step process:**
#
# *[Provide a template for setting up and solving]*

# %% [markdown]
# ### Sample Problem 3.2: Partial Fraction Decomposition
#
# **YOUR TASK:** Create and solve a partial fraction decomposition problem.

# %% [markdown]
# **Problem:**
#
# *[Create a problem, e.g., $\int \frac{1}{x^2-1} dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:**
#
# *[Show work]*
#
# **Step 2:**
# *[Show work]*
#
# **Step 3:**
# *[Show work]*
#
# **Step 4:** Simplify
#
# *[Final answer]*
#
# </details>

# %% [markdown]
# ## Submission
# Make sure you have run all cells in this notebook (in order) before running the cell below, so that all output appears. Running the cells that create graphs or use python to check answers is optional (as labeled).
#
# Then, do the following:
#
# 1. Go to File (above left menu).
# 2. Select Download (this should download the file to your downloads directory on your computer).
# 3. Upload the file on Canvas under the Project assignment. Only one person per group needs to do these steps!
#
# Thank you for completing the first 3 parts of the project!
