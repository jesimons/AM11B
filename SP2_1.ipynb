# %% [markdown]
# ### Sample Problems 2.1: Computing a Definite Integral using the FTC Part 2

# %% [markdown]
# **Problem 1:**
#
# * $\int_2^8 (6x + 5) dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# $\int_2^8 (6x + 5) dx$ = $3x^2 + 5x + C$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $(3(8)^2 + 5(8)) - (3(2)^2 +5(2))$
#
# Step 3: Subtract
#
# (192 + 40) - (12 + 10) = 232 - 22
#
# **Answer:** = 210
#
# </details>

# %% [markdown]
# **Problem 2:**
#
# Solve the definite integral: $$\int_4^8 (5x^2 - 16) dx$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# - Antiderivative: $\frac{5x^3}{3} - 16x + C$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $\frac{5x^3}{3} - 16x + C \bigg|_4^8 = F(8) - F(4)$
# \
# $\implies (\frac{(5)(8)^3}{3} - 16(8)) - (\frac{(5)(8)^3}{3} - 16(4))$
# \
# \
# $\implies \frac{2176}{3} - \frac{128}{3}$
#
# Step 3: Subtract
#
# $\frac{2176}{3} - \frac{128}{3} = \frac{2048}{3}$
#
# **Answer:** $$\boxed{\frac{2048}{3}}$$
#
# </details>

# %% [markdown]
# **Problem 3:**
#
# $\int_0^1 (x^2 + 2) dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# - $x^2$ -> $x^3/3$
# - $2$ -> $2x$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# - $F(1) = 1^3/3 + 2(1) = 1/3 + 2$
# - $F(0) = 0^3/3 + 2(0) = 0$
#
# Step 3: Subtract
#
# $F(1)−F(0) = (1/3+2) − (0) = 7/3$
#
# **Answer:** $7/3$
#
# </details>

# %% [markdown]
# **Problem 4:**
# Evaluate the definite integral of $\int_1^4 (6x^2-5x+2)dx$

# %% [markdown]
# <details>
#
# **Step 1**: Find the Antiderivative
#
# - We integrate term by term so $\int(6x^2-5x+2)dx$ becomes
#
# =$6\int x^2 dx -5\int x dx+2\int 1dx$
#
# =$6(\frac{x^3}{3})-5(\frac{x^2}{2})+2x$
#
# = $F(x)= 2x^3-\frac{5}{2}x^2+2x$
#
# **Step 2:** Apply the Fundamental Theorem of Calculus
#
# - Evaluate at $x = 4$
#
# $F(4)= 2(4^3)-\frac{5}{2}(4^2)+2(4)$
#
# $F(4)=2(64)-\frac{5}{2}(16)+8$
#
# $F(4)=128-40+8$
#
# $F(4)=96$
#
# - Evaluate at $x=1$
#
# $F(1)= 2(1^3)-\frac{5}{2}(1^2)+2(1)$
#
# $F(1)=2-\frac{5}{2}+2$
#
# $F(1)=\frac{8-5}{2}$
#
# $F(1)=1.5$
#
# **Step 3:** Subtract
#
# $F(4)-F(1)$
#
# = $96 - 1.5$
#
# = $94.5$
#
# **Answer=** $94.5$
#
#
#
#
#
#
#
# <summary><b>Click to reveal solution</b></summary>
#
# </details>

# %% [markdown]
# **Problem 5:**
#
# *[Write a problem asking to compute a definite integral,  $\int_1^4 (3x^2-2x+1) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[$\int_1^4 (3x^2-2x+1) dx$ = $x^3$-$x^2$+x+C]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[F(4)=52, F(1)=1]*
#
# Step 3: Subtract
#
# *[$\int_1^4 (3x^2-2x+1) dx$ = F(4)-F(1) = 52-51 =51]*
#
# **Answer:** *[Final numerical answer]*
#
# <51>

# %% [markdown]
# Problem 6: Compute the definite integral ∫ from 0 to 3 of (4x - 1) dx
#
# Solution:
#
# Step 1: Find an antiderivative F(x) of f(x) = 4x - 1
# - For 4x, an antiderivative is 2x**2  (since d/dx of 2x**2 = 4x)
# - For -1, an antiderivative is -x So we can take F(x) = 2x**2 - x
#
# Step 2: Use FTC Part 2:
# ∫_0^3 (4x - 1) dx = F(3) - F(0)
# F(3) = 2*(3**2) - 3 = 2*9 - 3 = 18 - 3 = 15
# F(0) = 2*(0**2) - 0 = 0
#
# Step 3: Subtract
# F(3) - F(0) = 15 - 0 = 15
#
# Final answer: the value of the integral is 15

# %% [markdown]
# **Problem 7:**
#
# **Problem 8:**
# Compute the definite integral:
#
# $\int_{1}^{2} (3x^2 + 4x) \, dx$
#
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# Apply power rule and Integrate each term separately
#
# $3x^2=x^3$
#
# $4x=2x^2$
#
# $F(x)=x^3+2x^2$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# **Upper:** $F(2)=(2)^3+2(2)^2= 8+8=16$
#
# **Lower** $F(1)=(1)^3+2(1)^2=1+2=3$
#
# Step 3: Subtract
#
# $16-3$
#
# **Answer:**
#
# $13$
#
# </details>

# %% [markdown]
# **Problem 9:**
#
# $\int_0^3 2x+1 dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
# $\frac{2x^{1+1}}{1+1}$
# = $\frac{2x^2}{2}$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $[\frac{2x^2}{2}]_0^3$
# = $\frac{2(3)^2}{2}$ - $\frac{2(0)^2}{2}$
#
# Step 3: Subtract
#
# = $9-0$
#
# **Answer: $9$
# </details>

# %% [markdown]
# **Problem 10:**
#
# Compute this definite integral $\int_1^3 (2x + 1) dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# $\int 2x dx = x^2, \int 1dx = x$
#
# $(2x+1)dx=x^2+x+C$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $F(3) - F(1)$
#
# $F(3)=3^2+3=9+3=12, F(1)=1^2+1=1+1=2$
#
#
# Step 3: Subtract
#
# $F(3)−F(1)=12−2=10$
#
# **Answer:** $10$
#
# </details>

# %% [markdown]
# **Problem 11:*$\int_0^3 (2x^3 - 5x) dx$*
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# - $\int (2x^3 - 5x)dx = \int 2x^3 dx - \int 5x dx$
# - $\int 2x^3 dx = 2* \frac{x^4}{4} = \frac{x^4}{2}$
# - $\int 5x dx = 5 * \frac{x^2}{2} = \frac{5x^2}{2}$
#
# Anti derivative: F(x) = $\frac{x^4}{2} - \frac{5x^2}{2}$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $\int_0^3 (2x^3 - 5x)dx = F(3) - F(0)$
#
# F(3) = $\frac{3^4}{2} - \frac{5(3^2)}{2} = \frac{81}{2} - \frac{45}{2} = 18$
#
# F(0) = $\frac{0^4}{2} - \frac{5(0^2)}{2} = 0$
#
# Step 3: Subtract
#
# F(3) - F(0) = 18 - 0 = 18
#
#
# **Answer:** *[18]*
#
# </details>

# %% [markdown]
# **Problem 12:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (x^2 + 1) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Show work]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]*
#
# Step 3: Subtract
#
# *[Final calculation]*
#
# **Answer:** *[Final numerical answer]*
#
# </details>

# %% [markdown]
# **Problem 13:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (x^2 + 1) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Show work]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]*
#
# Step 3: Subtract
#
# *[Final calculation]*
#
# **Answer:** *[Final numerical answer]*
#
# </details>

# %% [markdown]
# **Problem 14:**
#
# *$\int_2^5 [7x-4]dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$\frac{7x^2}{2}-4x$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $\frac{7(5)^2}{2}-4(5) = 40$
#
#
# $\frac{7(2)^2}{2}-4(2) = 6$
#
# Step 3: Subtract
# $40 - 6$
#
#
# **Answer:** *54*
#
# </details>

# %% [markdown]
# **Problem 15:**
#
# *$\int_0^3 (3x^2 + 2) dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$\int 3x^2+2dx=x^3+2x$+C*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *$((3)^3+2(3)) - ((0)^3+2(0))$ *
#
# Step 3: Subtract
#
# *33-0*
#
# **Answer:** *33*
#
# </details>

# %% [markdown]
# **Problem 16:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (x^2 + 1) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Show work]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]*
#
# Step 3: Subtract
#
# *[Final calculation]*
#
# **Answer:** *[Final numerical answer]*
#
# </details>

# %% [markdown]
# **Problem 17:**
#
# *$\int_0^3 (x^2 - 2x + 4) dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$F(x) = \frac{x^3}{3} - x^2 + 4x$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $\int_{0}^{3} (x^2 - 2x + 4)\,dx = F(3) - F(0)$
#
# $F(3) = \frac{27}{3} - 9 + 12 = 9 - 9 + 12 = 12$
#
# $F(0) = 0$
#
# Step 3: Subtract
#
# *$F(3) - F(0) = 12 - 0 = 12$*
#
# **Answer:** $\int_{0}^{3} (x^2 - 2x + 4)\,dx = 12$
#
# </details>

# %% [markdown]
# **Problem 18:**
#
# *[Compute $\int_1^3 (2x^2 + 4) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Anitderivative of 2x^2 = 2/3x^3, and antiderivative of 4 is 4x.
# So, F(x)=2/3x^3 + 4x.]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[F(3)= 2/3(3)^3+4(3)= 18 + 12 = 30
# F(1)= 2/3(1)^3+4(1)= 2/3 + 4 = 14/3]*
#
# Step 3: Subtract
#
# *[30 - 14/3 = 90/3 - 14/3 = 76/3]*
#
# **Answer:** *[76/3]*
#
# </details>

# %% [markdown]
# **Problem:**
#
# *$\int_{1}^{4} (3x^2 - 2x + 5)\, dx\$*
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$\int (3x^2-2x+5)\ , dx\ = x^3 - x^2 + 5x + C$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *$\ F(4) = 4^3 - 4^2 + 5(4) = 64 -16 +20 = 68$*
#
# *$\ F(1) = 1^3 - 1^2 + 5(1) = 1 - 1 + 5 = 5$*
#
# Step 3: Subtract
#
# *$\ F(4) - F(1) = 68 - 5 = 63$*
#
# **Answer:** *63*
#
# </details>

# %% [markdown]
# **Problem 19:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^4 (3x^3 + 5) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$\int 3x^3 + 5 dx = \frac{9x^4}{4} +5x$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *$\frac{3(4)^4}{4} + 5(4) - [\frac{3(0)^4}{4} + 5(0)]$*
#
# Step 3: Subtract
#
# *$\frac{768}{4} + 5(4)$*
#
# **Answer:** *212*
#
# </details>

# %% [markdown]
# **Problem 20:**
#
# *$\int_1^3 (2x^3 - x) dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$\int_1^3 (2x^3 - x) dx$ = x^4/2 - x^2/2 + C*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *(3^4/2 - 3^2/2) - (1^4/2 - 1^2/2)*
#
# Step 3: Subtract
#
# * (81/2 - 9/2) - (1/2 -1/2) = 72/2 = 36
#
# **Answer:** 36
#
# </details>

# %% [markdown]
# **Problem 21:**
#
# nt (upper bound 4 and lower bound 1) (2x**2-3x+1)dx
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *(2/3x3)-(3/2x2)+x+C*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *F(4)= (2/3)(43)-(3/242)+4= (128/3)-20 F(1)= (2/3)(1)-(3/2)(1)+1=1/6*
#
# Step 3: Subtract
#
# *(128/3)-20)-1/6*
#
# **Answer:** *45/2*
#
# </details>

# %% [markdown]
# **Problem 22:**
#
# *[Evaluate the definite integral, $\int_0^3 (8x^2 + 6x) dx$]*
#
#
# **Solution:**
#   $99$
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$\int_0^3 (8x^2 + 6x) = 8(x^3/3)+6(x^2/2)= 8x^3/3+6x^2/2= 8x^3/3+3x^2$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[$F(3)=8/3(3^3)+3(3^2)=8/3(27)+3(9)=72+27=99, F(0)=0$]*
#
# Step 3: Subtract
#
# *[$99-0=99$]*
#
# **Answer:** *$99$*
#
# </details>

# %% [markdown]
# **Problem 23:**
#
# *$\int_ (3x^2 - 2x + 5) dx $*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$\int_ (3x^2 - 2x + 5) dx $* =x3−x2+5x
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# [x3−x2+5x]1 -->  4
#
# Step 3: Subtract
# (43−42+5⋅4)−(13−12+5⋅1)
#
# *[Final calculation]*
# (64−16+20)−(1−1+5)=68−5
#
# **Answer:** *63*
#
# </details>

# %% [markdown]
# **Problem 24:**
#
# * $\int_4^8 (x^3 + 1) dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# * $1/4 * x^4 + x$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# * F(B)= $1/4 * (8)^4 + (8) = 1032$
# * F(A)= $1/4 * (4)^4 + (4) = 68$
#
# Step 3: Subtract
#
# $1032-68$
#
# **Answer:** $964$
#
# </details>

# %% [markdown]
# **Problem 25:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (2x) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# integral 2x=x^2
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# applying limits for x^2 = 2^2-0^2
#
# Step 3: Subtract
#
# 4-0
#
# **Answer:** 4
#
# </details>

# %% [markdown]
# **Problem 26:**
#
# * $\int_1^3 (2x^2 -4x + 1) dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$\int2x^2dx = 2x^3/3$  $\int-4xdx = -2x^2$  $\int1dx = x$  so   $F(x) = 2x^3/3 - 2x^2 + x$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# - *$ F(3) = 2(3)^3/3 - 2(3)^2 + 3 = 2(27)/3 - 18 + 3 = 3$*
# - *$ F(1) = 2(1)^1/3 - 2(1)^2 + 1 = 2/3 - 2 + 1 = -1/3$*
#
# Step 3: Subtract
#
# *F(3) - F(1) = 3 - (-1/3)*
#
# **Answer:** *10/3*
#
# </details>

# %% [markdown]
# **Example:** $$ \int_{1}^{3}(2x^2-3x+4)dx $$
#
# **Step 1:** Integrate term by term using the power rule for integration:
# $$ \int 2x^2dx=\frac{2x^3}{3} $$
# $$ \int-3xdx=\frac{-3x^2}{2} $$
# $$ \int 4dx=4x $$
#
# **Step 2:** Combine terms and evaluate the funtion: $$ \frac{2x^3}{3}-\frac{3x^2}{2}+4x\big|_{1}^{3} $$
#
# **Step 3:** Apply FTC Part 2 $F(b)-F(a) $: $$ \frac{2(1)^3}{3}-\frac{3(1)^2}{2}+4(1)- \frac{2(3)^3}{3}-\frac{3(3)^2}{2}+4(3)= \frac{40}{3}$$
#
# Final answer: $$ \boxed{\int_{1}^{3}(2x^2-3x+4)dx=\frac{40}{3}} $$

# %% [markdown]
# **Problem 27:**
#
# *[$\int_0^2 (x^2 + 1) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>(2/3)x^3 -4x </b></summary>
#
# Step 1: Find the antiderivative
#
# *[$(2x^2 - 4)dx= 2 $x^2dx-4 $1dx= 2(x^3/3 -4 = 2x^3 - 4x]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[The bounds are the exponents so  x=3 and x= 1]*
#
# Step 3: Subtract
#
# *[(2/3)x^3 -4x]*
#
# **Answer:** *[9.3333333333333]*
#
# </details>

# %% [markdown]
# **Problem 28:**
#
# *, , $\int_0^5 (x^4 + 7) dx$]*
#
# **660:**
#
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[(X^5)/5+7x]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[5^5/5+35=660 (0^5)/5+0=0]*
#
# Step 3: Subtract
#
# *[660-0=660]*
#
# **Answer:** *[660]*
#
# </details>

# %% [markdown]
# **Problem 29:**
#
# *$\int_1^3 (2x + 1) dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$\int (2x + 1) dx = x^2 + x$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *Evaluate at bounds: $(3^2 + 3) - (1^2 + 1)$*
#
# Step 3: Subtract
#
# *$12 - 2 = 10$*
#
# **Answer:** *$\int_1^3 (2x + 1) dx = 10$*
#
# </details>

# %% [markdown]
# **Problem 30:**
#
#
#    $\int_1^3 (4x^3 -2x) dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Show work]*
#
# -∫4x3dx=x^4
#
#
# -∫−2xdx=−x2
#
#
# -F(x)=x4−x2
#
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]*
#
# F(3)=34−32=81−9=72
#
# F(1)=14−12=1−1=0
#
#
#
# Step 3: Subtract
#
# F(3)−F(1)=72−0=72
#
# *[Final calculation]*
#
# **Answer:** *[Final numerical answer]*
#
# 72
#
# </details>

# %% [markdown]
# **Problem 31:**
#
# *$\int_0^2 (5x^4 + x) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$\frac{5}{5}x^5+\frac{x^2}{2}$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *$\int_0^2 (5x^4 + x) dx$=F(2)-F(0)*
#
# Step 3: Subtract
#
# *$(2^5+(\frac{1}{2})*2^2)-(0^5+(\frac{1}{2})*0^2)$
# f(2)=34 & f(0) =0
# *
#
# **Answer:** *34*
#
# </details>

# %% [markdown]
# **Problem 32:**
#
# *[$$\int_1^3 (x^2 + 2) dx$$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[$$\int_ (x^2 + 2) dx= \frac{x^3}{3}+2x $$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[ evaluate your bounds using this equation $$\frac{x^3}{3}+2x$$ solve by plugging your bounds into x. $$\frac{1^3}{3}+2(1)$$ \, $$\frac{3^3}{3}+2(3)$$ ]*
#
# Step 3: Subtract
#
# *[$$\frac{3^3}{3}+2(3)= 15 - \frac{7}{3}= \frac{45}{3}-\frac{7}{3}= \frac{38}{3} $$]*
#
# **Answer:** *[$$\frac{38}{3} $$]*
#
# </details>

# %% [markdown]
# **Problem 33:**
#
# *Compute the definite integral, $\int_2^8 (3x^2-4x+1) dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# - $\int \frac{3(3)x^3}{3} -\frac {4(2)x^2}{2}+x |_2^8$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# - $\int \frac {9(8)^3}/{3} - \frac {8(8)^2}{2} +8 - [\frac {9(2)^3}/{3} - \frac {8(2)^2}{2} +2]$
#
# Step 3: Subtract
#
# - 1536 - 256 + 8 - 24 + 16 - 2 *
#
# **Answer:** *1278*
#
# </details>

# %% [markdown]
# **Problem 34:**
#
# *$\int_2^4 (2x^2 + 2) dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$$F(x)=(2x^2+1/3)+ 2x + C$$*
# *$$F(x)= (2x^3/3) + 2x + C$$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *$$F(4)= 2(4)^3/3) + 2(4)= (128/3) + (24/3)= 152/3$$*
# *$$F(2)= 2(2)^3/3) + 2(2)= (16/3) + (12/3)= 28/3$$*
#
# Step 3: Subtract
#
# *$$(152/3) - (28/3) = 124/3$$*
#
# **Answer:** *$$124/3$$*
#
# </details>

# %% [markdown]
# **Problem 35:**
#
# $\int_1^4 (2x+3) dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# The antiderivative of $2x+3=x^2+3x$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $[x^2 + 3x]_{1}^{4}$
#
# Step 3: Subtract
#
# $((4)^2+3(2))-((1)^2+3(1))=(16+12)-(1+3)=28-4=24$
#
# Final Answer: 24

# %% [markdown]
# **Problem:**
#
# *[$\int_1^5 (2x+3)dx]*
#
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *antiderivative of 2x+3: F(x)=x^2+3x*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[$\int_1^5 (2x+3)dx= F(5)-F(1)
# F(5)=5^2+3(5)= 25+15=40]*
#
# Step 3: Subtract
#
# *[40-4=36]*
#
# **Answer:** *[$\int_1^5 (2x+3)dx= 36]*
#
# </details>

# %% [markdown]
# **Problem 36:**
#
# $\int_0^3 (2x^2 + 1) dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# = $(2x^3)/3 + x + C
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# at x = 3 F(3) = 54/3 = 21
#
# at x = 0 F(0) = 0/3 + 0 = 0
#
# Step 3: Subtract
#
# 21 - 0 = 21
#
# 21
#
# </details>

# %% [markdown]
# ## **Problem 37:**
#
# Compute the definite integral
# $\int_0^2 (x^2 + 1)\, dx$.
#
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# The antiderivative of $x^2 + 1$ is:
# $\int (x^2 + 1)\, dx = \frac{x^3}{3} + x + C$
#
#
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# Evaluate the antiderivative at the bounds $x=2$ and $x=0$:
#
# - At $x = 2$: $\frac{2^3}{3} + 2 = \frac{8}{3} + 2 = \frac{14}{3}$
# - At $x = 0$: $\frac{0^3}{3} + 0 = 0$
#
#
#
# Step 3: Subtract
#
# $\int_0^2 (x^2 + 1)\, dx = F(2) - F(0) = \frac{14}{3} - 0 = \frac{14}{3}$
#
#
#
# **Answer:** $\frac{14}{3}$
#
# </details>

# %% [markdown]
# **Problem 38:**
#
# $\int_0^5 (x^4)+3 \,dx$
#
# **Solution:**
#  640
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# $\frac{x^5}{5} + 3x$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $\frac{x^5}{3(5)} - \frac{0^5}{5+3(0)}$
#
# Step 3: Subtract
#
#  640 - 0
#
# 640
#
# **Answer:** 640
#
# </details>

# %% [markdown]
# **Problem 39:**
#
# *Compute the definite integral $\int_1^4 (2x^3 -x + 5) dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$\frac{2x^4}{4} - \frac{x^2}{2} + 5x$ Evaluated at x=1 and x=4*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *F(4)=$\frac{2(4)^2}{4} - \frac{4^2}{2} +5(4)=140$
# F(1)=$\frac{2(1)^2}{4} - \frac{1^2}{2} +5(1)=5$*
#
# Step 3: Subtract
#
# *F(4)-F(1)=135*
#
# **Answer:** *135*
#
# </details>

# %% [markdown]
# **Problem 40:**
#
# * $\int_0^4 (3x^2 + 3) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[x^3 + 3x]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[(4)^3 + 3(4) = 76. (0)^3 + 3(0) = 0]*
#
# Step 3: Subtract
#
# *[76 - 0 = 76]*
#
# **Answer:** *[76]*
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (x^2 + 1) dx$]*
#
# *$\int0^3 (2x**2-4x+5)dx$*
#
# **Solution:15**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Show work]*
#
# *[2/3**3-2x**2+5x]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]*
#
# *[2/3(27)-2(9)+5(3)]*
# *[0-0+0]
#
# Step 3: Subtract
#
# *[Final calculation]*
#
#   *[15-0]*
# **Answer:** *[15]*
#
# </details>

# %% [markdown]
# **Problem 41:**
#
# $\int_1^4 (2x-5)dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# $x^2-5x$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $((4)^2-5(4))-((1)^2-5(1))$
#
# Step 3: Subtract
#
# $(16-20)-(1-5)$
#
# $-4+4 = 0$
#
# **Answer:** 0
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (x^2 + 1) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Show work]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]*
#
# Step 3: Subtract
#
# *[Final calculation]*
#
# **Answer:** *[Final numerical answer]*
#
# </details>

# %% [markdown]
# **Problem 42:**
#
# *[$\int_1^3 (2x^2 -4x) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[F(x)= ((2x^3)/3)-2x^2 +C]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[((2(3)^3)/3)-2(3)^2 - (((2(1)^3)/3)-2(1)^2)]*
#
# Step 3: Subtract
#
# *[0-(-4/3)]*
#
# **Answer:** *[4/3]*
#
# </details>

# %% [markdown]
# **Problem 43:**
#
# $\int_0^1 2x^2+1 dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# =$\frac{2x^{2+1}}{2+1}$
#
# =$\frac{2x^3}{3}$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# =$[\frac{2x^3}{3}]_0^1$
#
# =$(\frac{2(1)^3}{3})-(\frac{2(0)^3}{3})$
#
# Step 3: Subtract
#
# =$(\frac{2}{3})-(0)$
#
# **Answer: $\frac{2}{3}$
#
# </details>

# %% [markdown]
# **Problem 44:**
#
# *[$\int_0^4 (3x^4 - 6x^2 - 7) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[$\int 3x^4 dx = 3x^5/x^5 = 3/5 x^5$
#  $\int -6x^2 dx = -6x^3/3 = -2x^3$
#  $\int -7 dx =  -7x$]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[\$int_0^4 (3x^4 - 6x^2 - 7)dx = F(4) - F(0)$
#  $F(4)= 3/5 (4^5) - 2(4^2) - 7(4)$
#      $= 3/5 (1024) - 2(64) - 28$
#      $= 614.4 - 165$
# $F(4) = 458.4$
# $f(0) = 3/5 (0^5) - 6(0^2) - 7(0)$
# $F(0) = 0$]*
#
# Step 3: Subtract
#
# *[485.4 - 0 = 458.4]*
#
# **Answer:** *[485.4]*
#
# </details>

# %% [markdown]
# **Problem 45:**
#
# *[Compute the definite integral from 0 to 2 (3x^2 -4x +1) dx]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[3x^2 = 3* x^3/3 = x^3
# -4x= -2x^2
# 1 = x
# = x^3-2x^3 + x]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[F(2)=(2)^3 + 2(2)^2 + 2 = 2
# f(0) = (0)^3- 2(0)^2+0]*
#
# Step 3: Subtract
#
# *[2-0= 2]*
#
# **Answer:** *[2]*
#
# </details>

# %% [markdown]
# **Problem 46:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (x^2 + 1) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Show work]* $1/3 x^3 +x$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]* F(2)=14/3,F(0)=0
#
# Step 3: Subtract
#
# *[Final calculation]* 14/3-0
#
# **Answer:** *[Final numerical answer]*14/3
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[$\int_{-3}^1 (6x^2 -5x +2) dx$]*]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[$6x^2-5x+2$ which equals to $2x^3-5/2x^2+2x$]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[We then evaluate at the bounds by plugging them into the antiderivative. At F(1):
# $2(1)^3-5/2(1)^2+2(1) = 2-5/2+2 =3/2$.
# At F(-3):
# $2(-3)^3-5/2(-3)^2+2(-3) = -54-45/2-6 = -165/2$]*
#
# Step 3: Subtract
#
# *[Subtract
# We then subtract $F(b)-F(a)$ : $(3/2) - (-165/2)$ = 84]*
#
# **Answer:** *[84]*
#
# </details>

# %% [markdown]
# **Problem 47:**
# integral 5 to 2 (4x^3 -6x + 1)dx
#
# Step 1: find the antiderivatives
#      4x^3 = x^4
#      -6x = -3x^2
#      1 = x
#
# step 2: apply FTC Part 2
#
#     Integral 5 to 2 (4x^3 -6x + 1)dx = F(5) - F(2)
#
# Step 3: evaluate
#
#     F(5) = 5^4 - 3(5)^2 + 5 = 555
#     F(2) = 2^4 - 3(2)^2 + 2 + 6
#
# Step 4: Compute F(5) - F(2)
#
#     555 - 6 = 549

# %% [markdown]
# **Problem:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (x^2 + 1) dx$]*
# ∫(0,1) 2x^2+6x dx
#
# **Solution:11/3
#
# Step 1: Find the antiderivative
#
# ∫2/2+1x^2+1 dx + ∫6/1+1 x^1+1 dx =2/3x^3 + 3x^2
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# |^1 2/3 (1)^3 + 3(1)^2 - 2/3 (0)^3 + 3(0)^2
# ^0
# Step 3: Subtract
# (2/3 + 3) - 0
#
# **Answer:** 11/3

# %% [markdown]
# **Problem 48:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (x^2 + 1) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Show work]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]*
#
# Step 3: Subtract
#
# *[Final calculation]*
#
# **Answer:** *[Final numerical answer]*
#
# </details>

# %% [markdown]
# **Problem 49:**
#
# $\int_0^4 (3x^2 - 2x + 5) dx$
#
# Solution:
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# $x^3 - x^2 +5x$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $[x^3 - x^2 +5x]$ bounded from 0 to 4
#
# Step 3: Subtract
#
# $[(4)^4 - (4)^2 + 5(4)] - [0]$
#
# Answer: 68
#
# </details>

# %% [markdown]
# **Problem 50:**
#
# *$\int_0^3 (x^3 + 2) dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$\int x^3 +2 dx = \frac{x^4}{4} +2x+C$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *At $F(3)= \frac{3^4}{4} +2(3)$
#
# Which is equivalent to $\frac{81}{4}+6$
#
# Then at $F(0)= \frac{0^4}{4} +2(0)$
#
# Which is 0
#
# Step 3: Subtract
#
# *$F(3)-F(0)=\frac{81}{4}+6$*
#
# **Answer:** *$\frac{105}{4}$*
#
# </details>

# %% [markdown]
# **Problem 51:**
#
# 1 int 3 (2x+5)dx
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# = x^2 + 5x
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# at x=3
# 3^2 + 5(3) = 24
#
# at x=1
# 1^2 + 5(1) = 6
#
# Step 3: Subtract
#
# 24 - 6 = 18
#
# **Answer:** *[Final numerical answer]*
#
# </details>

# %% [markdown]
# **Problem 52:**
#
# *[Compute the definite integral:
# $\displaystyle \int_{0}^{3} (3x^2 + 4x + 1)\,dx$.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[
# We notice that the derivative of $x^3 + 2x^2 + x$ is:
#
# - $\dfrac{d}{dx}(x^3) = 3x^2$
# - $\dfrac{d}{dx}(2x^2) = 4x$
# - $\dfrac{d}{dx}(x) = 1$
#
# So:
#
# $$\dfrac{d}{dx}(x^3 + 2x^2 + x) = 3x^2 + 4x + 1,$$
#
# which means an antiderivative is
#
# $$F(x) = x^3 + 2x^2 + x.$$
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds:
#  Evaluate $F(x)$ at $x = 3$ and $x = 0$:
#
#  $$F(3) = 3^3 + 2 \cdot 3^2 + 3 = 27 + 18 + 3 = 48,$$
#
#  $$F(0) = 0^3 + 2 \cdot 0^2 + 0 = 0.$$]*
#
# Step 3: Subtract
#
# *[$$\int_{0}^{3} (3x^2 + 4x + 1)\,dx = F(3) - F(0) = 48 - 0 = 48.$$]*
#
# **Answer:** *[$$48$$]*
#
# </details>

# %% [markdown]
# **Problem 53:**
#
# *[Compute the definite integral $\int_0^2 (3x^2 + 1),dx$.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[$\int (3x^2 + 1),dx = x^3 + x + C$]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[$F(2) - F(0)$*
#
# Step 3: Subtract
#
# *[$(2^3 + 2) - (0^3 + 0) = 10$]*
#
# **Answer:** *[$10$]*
#
# </details>

# %% [markdown]
# **Problem 54:**
#
# *∫02​(x2+1)dx*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[∫(x^2+1)dx=x^3/3​+x+C]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# * [x^3/3​+x]0to2​ *
#
# Step 3: Subtract
#
# *[(8/3​+2)−(0)=8/3​+6/3​=14/3​]*
#
# **Answer:** *[14/3]*
#
# </details>

# %% [markdown]
# **Problem 55:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (x^2 + 1) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Show work]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]*
#
# Step 3: Subtract
#
# *[Final calculation]*
#
# **Answer:** *[Final numerical answer]*
#
# </details>

# %% [markdown]
# **Problem 56:**
#
# *[$\int_0^6 (3x^2 + 9) dx$]*
#
# **Solution:** 270
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Find the integral of each term. Take out the constant for 3x^2 and apply the power rule to find the antiderivative of x^2. Then for 9, because it is a constant, just add an x.]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Sub in 0 and 6 for x. That gives 0 for x=0 and 270 for x=6. Then, subtract the upper bound from the lower bound.]*
#
# Step 3: Subtract
#
# *[270-0 = 270]*
#
# **Answer:** *[270]*
#
# </details>

# %% [markdown]
# **Problem 57:**
#
# Compute the definite integral: $$ F(x) = \int_0^2 (x^3+5)dx $$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** *Find the antiderivative of $x^3+5$*
#
# - First apply the power rule: $\frac{x^{n+1}}{n}$
# - Then apply = $\frac{x^4}{4}$
# - Then find the antiderivative of 5 which should be 5x
#
# So your final function should be: $\frac{x^4}{4} + 5x$
#
#
# **Step 2:** *Apply the Fundamental Theorem of Calculus*
#
# Now that we have our antiderivative: $$\frac{x^4}{4} + 5x + C$$. We need to evaluate the bounds.
#
# - First, we need to plug in both values into x, plugging in 2 and 0.
# - We'll start with plugging in 2
#
# $$\frac{2^4}{4} + 5(2) = \frac{16}{4} + 10 = 4 + 10 = 14$$
#
# - Then, we'll plug in 0
#
# $$\frac{0^4}{4} + 5(0) = \frac{0}{4} + 0 = 0+0 = 0$$
#
#
# **Step 3:** *Subtract*
#
# Now that we have our two values from plugging in the numbers, we need to subtract the values from each other
#
# $14-0=...$
#
# **Answer:**
# $14$
#
# </details>

# %% [markdown]
# **Problem 58:**
#
# compute a definite integral $\int_0^3 (2x + 4) dx$
#
# **Solution:**
#
#
# Step 1: Find the antiderivative
#
#  - $\int (2x+4) dx$ = $\int 2x dx$ + $\int 4x dx$
#
#    = 2 * $\frac{x^2}{2}$ + 4x
#
#  F(x)  = $x^2$ + 4x
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
#   F(3) - F(0)
#
# Step 3: Subtract
#   F(3) = $3^2$ + 4(3) = 9 + 12 = 21
#
#   F(0) = $0^2$ + 4(0) = 0
#
#   21 - 0 = 21
#
#
# **Answer:**
#
#  $\int_0^3 (2x + 4) dx$ = 21

# %% [markdown]
# **Problem 59:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_2^5 (4) dx$]*
#
# **Solution: 12**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Antiderivative of 4 = 4x]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Plug in bounds F(5) = 20, F(2)= 8]*
#
# Step 3: Subtract
#
# *[20-8 = 12]*
#
# **Answer:** *[12]*
#
# </details>

# %% [markdown]
# **Problem 60:**
#
# *[Compute the definite integral $\displaystyle \int_{2}^{3} (8x^3 + 3x^2 + 6x)\,dx$.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[$\displaystyle F(x) = \int (8x^3 + 3x^2 + 6x)\,dx = 2x^4 + x^3 + 3x^2$]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *$\displaystyle F(3) = 2(3^4) + 3^3 + 3\cdot 3^2 = 216$*
# *$\displaystyle F(2) = 2(2^4) + 2^3 + 3\cdot 2^2 = 52$*
#
# Step 3: Subtract
#
# *[$\displaystyle F(3) - F(2) = 216 - 52 = 164$]*
#
# **Answer:** *[$164$]*
#
# </details>

# %% [markdown]
# **Problem 61:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_1^4 (3x+2) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$$F(x)=\frac{3}{2}x^2+2x$$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *$$F(4)=\frac{3}{2}(4^2)+2(4)=24+8=32$$
# $$F(1)=\frac{3}{2}(1^2)+2(1)=\frac{3}{2}+2=\frac{7}{2}$$*
#
# Step 3: Subtract
#
# *$$F(4)-F(1)=32-\frac{7}{2}=\frac{57}{2}$$*
#
# **Answer:** *$$\frac{57}{2}$$*
#
# </details>

# %% [markdown]
# **Problem 62:**
#
# *Compute the definite integral  $\int_{1}^{3} (3x^2 - 4)\, dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$x^3 - 4x + C$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *$[3^3-4(3)] - [1^3-4(1)]$*
#
# Step 3: Subtract
#
# *$15-(-3)$*
#
# **Answer:** *$18$*
#
# </details>

# %% [markdown]
# **Problem 63:**
#
# *[$\int_1^3 (2x+4) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[$F(x)=x^2+4x$]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[$F(3)=(3)^2+4(2)=21,$
# $F(1)=(1)^2+4(1)=5$]*
#
# Step 3: Subtract
#
# *[$21-5$]*
#
# **Answer:** *[$16$]*
#
# </details>

# %% [markdown]
# **Problem 64:**
#
# *$\int_0^3 (2x + 1) dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# **[f(x)= 2x+1]*
# *The Anti derivitive is F(x)= x^2+x *
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# **[[ $\int_0^3 (2x + 1) dx$]= F(3)- F(0)
# F(3)= 3^2+3=12
# F(0)= 0^2+0+=0*
# *
#
# Step 3: Subtract
#
# *[F(3)- F(0) = 12-0=12]*
#
# **Answer:** *12*
#
# </details>

# %% [markdown]
# **Problem 65: Compute the definite integral:
#
# $$
# \int_{1}^{3} (2x^2 + 3)\,dx
# $$**
#
# **Solution:$$
# \frac{56}{3}
# $$**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *Use the power rule:
#
# $$
# \int 2x^2 \, dx = 2 \cdot \frac{x^3}{3} = \frac{2x^3}{3}
# $$
#
# $$
# \int 3 \, dx = 3x
# $$
#
# So the antiderivative is:
#
# $$
# F(x) = \frac{2x^3}{3} + 3x
# $$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *Evaluate $F(x)$ at the upper and lower bounds:
#
# $$
# F(3) = \frac{2 \cdot 3^3}{3} + 3 \cdot 3 = \frac{54}{3} + 9 = 18 + 9 = 27
# $$
#
# $$
# F(1) = \frac{2 \cdot 1^3}{3} + 3 \cdot 1 = \frac{2}{3} + 3 = \frac{2}{3} + \frac{9}{3} = \frac{11}{3}
# $$
# *
#
# Step 3: Subtract
#
# *$$
# F(2) - F(0) = \left( \frac{8}{3} + 2 \right) - 0
# $$
#
# Combine terms:
#
# $$
# F(3) - F(1) = 27 - \frac{11}{3} = \frac{81}{3} - \frac{11}{3} = \frac{70}{3}
# $$
# *
#
# **Answer:** *$$
# \frac{70}{3}
# $$*
#
# </details>

# %% [markdown]
# **Problem:**
#
# *∫ upper 1 lower 3 (4x^3−2x+5)dx*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *(4/4)x^4 - (2/2)x^2 + 5x + C*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *F(3) - F(1) = F(3)=(3)4−(3)2+5(3) - F(1)=(1)4−(1)2+5(1)*
#
# Step 3: Subtract
#
# *87-5*
#
# **Answer:** *∫ upper 1 lower 3 (4x^3−2x+5)dx = 82*
#
# </details>

# %% [markdown]
# **Problem:**
#
# *∫ of 0 to 3 for(2x+4)dx*
#
# **21:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *∫(2x+4)dx=x^2+4x+C*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *F(3)=3^2+4(3)=9+12=21 and F(0)=02+4(0)=0*
#
# Step 3: Subtract
#
# *F(3)−F(0)*
#
# **Answer:** *[21]*
#
# </details>

# %% [markdown]
# **Problem 66:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (x^2 + 4) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[∫(x2+4)dx= $x^3 / 3 +4x$]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[$\int_0^2 (x2+4)dx$ = F(2)- F(0)
# Evaluate at 2 $F(2) = 2^3 / 3 +4(2) = 8/3 +24/3 = 32/3$
# Evaluate at 0 $F(0)= 0$]*
#
# Step 3: Subtract
#
# *[32/3 - 0]*
#
# **Answer:** *[32/3]*
#
# </details>

# %% [markdown]
# **Problem 67:**
#
# $\int_0^5 (3x^2 + 3) dx$]
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# $x^3 + 3x$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $5^3 + 3(5) - 0^3 + 3(0)$
#
# Step 3: Subtract
#
# $5^3 + 3(5)$
#
# **Answer:** 140
#
# </details>

# %% [markdown]
# **Problem 68:**
#
# * $\int_1^3 (3x^2 + 2x) dx$*
#
# **Solution:**
#
#
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# F(x)=$\int (3x^2 + 2x) dx$= $x^3+x^2+C$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $\int_1^3 (3x^2 + 2x) dx$= F(3)-F(1)
#
# F(3)= $(3)^3+(3)^2=27+9=36$
#
# F(1)= $(1)^3+(1)^2=1+1=2$
#
# Step 3: Subtract
#
# F(3)-F(1)=36-2=34
#
# **Answer:** 34
#
# </details>

# %% [markdown]
# **Problem 69:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_1^5 (x^3 + 4) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[integrate terms seperately, x^3dx= x^4 /4  4dx= 4x , = 4^4 / 4 +4x]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[F(5) - F(1) , so 5^4 /4 +4*5 = 705/4  and 1^4/4 + 4*1 = 17/4 ]*
#
# Step 3: Subtract
#
# *[705/4 - 17/4 = 688/4 ]*
#
# **Answer:** *[172]*
#
# </details>

# %% [markdown]
# **Problem:**
#
# * $\int_1^4 (2x + 3) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[show work ]* antiderivative of 2x is x^2, antiderivative of 3 is 3x
# antiderivative is : $f(x)=x^2+3x
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]* F(4)= 4^2+3(4)=16+12= 28   F(1)+1^2+3(1)=1+3= 4
#
# Step 3: Subtract
#
# *[$\int_1^4 (2x+3)dx$= 28-4+24]*
#
# **Answer:** *[24]*
#
# </details>

# %% [markdown]
# **Problem 70:**
#
# *[$\int_0^2 \frac{1}{2} x^3 dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[$\frac{1}{8}x^4+C$]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[$(\frac{2^4}{8}) - (\frac{0^4}{8})$]*
#
# Step 3: Subtract
#
# *[$2-0=2$]*
#
# **Answer:** *[2]*
#
# </details>

# %% [markdown]
# **Problem 71:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (x^2 + 1) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Show work]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]*
#
# Step 3: Subtract
#
# *[Final calculation]*
#
# **Answer:** *[Final numerical answer]*
#
# </details>

# %% [markdown]
# **Problem 72:**
#
# Solve the definite integral $\int_1^3 (3x^2-2x+5)dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# $\int3x^2dx$ = 3(x^3/3) =x^3
# $\int-2xdx$ = -2(x^2/2)= -x^2
# $\int5dx$ = 5x
# F(x)= x^3-x^2+5x
# Step 2: Apply the Fundamental Theorem of Calculus
#
# F(x) at the upper bound x=3:
# F(3)= (3)^3-(3)^2+5(3)
# F(3)= 27-19+15
# F(3)= 33
#
# Lower Bound x=1:
#
# F(1)= (1)^3-(1)^2+5(1)
# F(1)= 1-1+5
# F(1)= 5
#
# Step 3: Subtract
#
# $\int_1^3 (3x^2-2x+5)dx$= F(3)-F(1)
# 33-5= 28
#
# **Answer:** *[28]*
#
# </details>

# %% [markdown]
# **Problem 73:** $\int_0^3 (4x^3-2x+1) dx$
#
#
#
# **Solution:** 75
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# $\int_0^3 (4x^3-2x+1) dx$ = x^4 -x^2 +x
#
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# F(3) = 3^4 -3^2 +3 = 81 - +3 = 75
# F(0)= 04 −02 +0 =0
#
# Step 3: Subtract
#
# 75 -0 = 75
#
# **Answer:** *[Final numerical answer]*
#
# </details>

# %% [markdown]
# **Problem 74:**
#
#  $\int_0^3 (x^3 + x) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative (integrate)
#
# (x^3+1)/4 +(x^1+1)/2 =
#
# (x^4)/4 + (x^2)/2
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# x=3, x=0
#
# (3^4)4 + (3^2)/2 - (0^4)/4 + (0^2)/2
#
# Step 3: Subtract
#
# 81/4 + 9/2 - 0 - 0 or 81/4 + 18/4
#
# 99/4
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (x^2 + 1) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Show work]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]*
#
# Step 3: Subtract
#
# *[Final calculation]*
#
# **Answer:** *[Final numerical answer]*
#
# </details>

# %% [markdown]
# **Problem 75:**
#
# $\int_0^3 (2x^2 - 4)\,dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# $\int (2x^2 - 4)\,dx = \frac{2}{3}x^3 - 4x + C$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $\left[\frac{2}{3}x^3 - 4x\right]_0^3
# = \left(\frac{2}{3} \cdot 27 - 12\right) - (0 - 0)$
#
# Step 3: Subtract
#
# $\left[\frac{2}{3}x^3 - 4x\right]_0^3
# = \left(\frac{2}{3} \cdot 27 - 12\right) - (0 - 0)$
#
# **Answer:** $6$
#
# </details>

# %% [markdown]
# **Problem 76:**
#
# *$$\int_{1}^{4} (3x^2 + 2x) \, dx$$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# $$F(x) = x^3 + x^2 \quad \text{(We omit the } + C \text{ for definite integrals)}$$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $$\int_{1}^{4} (3x^2 + 2x) \, dx = \left[ x^3 + x^2 \right]_{1}^{4} = F(4) - F(1)$$
#
# Step 3: Subtract
#
# $$F(4) - F(1) = 80 - 2 = \mathbf{78}$$
#
# **Answer:** *78*
#
# </details>

# %% [markdown]
# **Problem:**
#
# Compute the definite integral
# $\displaystyle \int_{0}^{3} (2x + 1), dx$
#
# **Solution:**
#
# <details> <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find an antiderivative of the integrand.
# An antiderivative of $2x + 1$ is:
# $\displaystyle F(x) = x^{2} + x$
#
# Step 2: Apply FTC Part 2:
# $\displaystyle \int_{0}^{3} (2x + 1), dx = F(3) - F(0)$
#
# Compute each:
# $F(3) = 3^{2} + 3 = 9 + 3 = 12$
# $F(0) = 0^{2} + 0 = 0$
#
# Final Answer:
# $\displaystyle \int_{0}^{3} (2x + 1), dx = 12$
#
# </details>

# %% [markdown]
# **Problem 77:**
#
# *$\int_1^4 (2x^3 - 3x + 5) dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *1/2^4 - 3/2x^2 + 5x*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *substitute 4 and 1*
#
# Step 3: Subtract
#
# *(1/2(4)^4 - 3/2(4)^2 + 5(4)) - (1/2(1)^4 - 3/2(1)^2 + 5(1))*
#
# **Answer:** *120*
#
# </details>

# %% [markdown]
# **Problem 78:**
#
# *[int_1^3 (2x + 5) dx$]*
#
# **Solution:*18*
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[int (2x+5)dx=x^2]+ 5x + C*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds 1 and 3
# F(3)= 3^2]+5(3) =9+15=24
# F(1)=1^2*+5=6
#
# Step 3: Subtract
#
# *[24-6=18]*
#
# **Answer:** *[18]*
#
# </details>

# %% [markdown]
# **Problem 79:**
#
# *$\int_1^4 (3x^2 - 2) dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$\int (3x^2-1)dx = x^3 -2x$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *$(4)^3-2(4) = 64 - 8 = 56$*
#
# *$(1)^3-2(1) = 1 - 2 = -1$*
#
# Step 3: Subtract
#
# *$56- (-1) = 57$*
#
# **Answer:** *$57$*
#
# </details>

# %%
# Verify your answer computationally
# Example:
result = sp.integrate(x**2 + 1, (x, 0, 2)) # EDIT HERE (function, bounds = 0,2)
print(f"Result: {result}")
# Out:
# Result: 14/3

# %% [markdown]
# **Problem 80:**
#
# $\int_1^3 (3x^2 + 2) dx$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1: Find the antiderivative**
#
# Use the power rule for integration. $\int x^n dx$ = $\frac{x^{n+1}}{n+1}$
#
# - The antiderivative of $3x^2$ is $\frac{3x^3}{3} = x^3$
#
# - The antiderivative of $2$ is $2x$
#
# - So, $F(x) = x^3 + 2x$
#
# **Step 2: Apply the Fundamental Theorem of Calculus Part 2**
#
# - Upper Bound $(b=3):
#
#     $F(3) = (3)^3 + 2(3) = 33$
#
#
# - Lower Bound $(a=1)$:
#
#     $F(1) = (1)^3 + 2(1) = 3$
#
#
# **Step 3: Subtract**
#
# $33-3 = 30$
#
#
# **Answer:**
#
# $\int_1^3 (3x^2 + 2)dx = 30$
# </details>

# %% [markdown]
# **Problem:**
#
# $\int_0^7 (3x + 5) dx$]*
#
# **Solution:** 1835.75
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[3x^3]--> (3/4x^4)*
#
# 5 --> 5x
#
# (3/4x^4) + 5x
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]*
#
#    * $\int_0^7 (x^4/4+5x)]
# * ((3/4)0^4 + 5(0)) = 0
# * ((3/4)7^4 + 5(7)) --> 1800.75 + 35 = 1835.75
#
# Step 3: Subtract
#
# *[Final calculation]*
#
#    *f(7) - f(0) = 1835.75
#
# **Answer:**
#      *1835.75
#
# </details>

# %% [markdown]
# **Problem 81:**
#
# *Evaluate the definite integral:$$\int_1^2 (4x^3 - 6x) \, dx$$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *$F(x) = \int (4x^3 - 6x) dx = x^4 - 3x^2$*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *$$[x^4 - 3x^2]_1^2$$*
#
# Step 3: Subtract
#
# * $F(2) = (2)^4 - 3(2)^2 = 16 - 12 = 4$
# - $F(1) = (1)^4 - 3(1)^2 = 1 - 3 = -2$
# - $F(2) - F(1) = 4 - (-2) = 4 + 2 = 6$*
#
# **Answer:** *6*
#
# </details>

# %% [markdown]
# **Problem 82:**
#
#
#
# Evaluate the following definite integral using the Fundamental Theorem of Calculus:
#
#
# $\int_{0}^{2}(x^2 + 1) dx$
#
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
#
# $F(x) = \int (x^2 + 1) dx = \frac{x^3}{3} + x$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# $F(b) - F(a) = F(2) - F(0) = \left[\frac{2^3}{3} + 2\right] - \left[\frac{0^3}{3} + 0\right]
# $
#
# Step 3: Subtract
#
# $= \left[\frac{8}{3} + 2\right] - [0] = \frac{8}{3} + \frac{6}{3} = \frac{14}{3}$
#
# **Answer:** $\\frac{14}{3}\$
# </details>

# %% [markdown]
# **Problem:**
#
# *[Write a problem asking to compute a definite integral, e.g., $\int_0^2 (x^2 + 1) dx$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
#
# *[Show work]*
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# *[Evaluate at bounds]*
#
# Step 3: Subtract
#
# *[Final calculation]*
#
# **Answer:** *[Final numerical answer]*
#
# </details>

# %% [markdown]
# **Problem 83:**
#
# $$\int_{1}^{5} (4x^3 - 2x + 7)\, dx.$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the antiderivative
# $$
# \int (4x^3 - 2x + 7)\, dx
# = x^4 - x^2 + 7x
# $$
#
# Step 2: Apply the Fundamental Theorem of Calculus
#
# Evaluate at the upper bound \(x = 5\):
#
# $$
# F(5) = 5^4 - 5^2 + 7(5)
# = 625 - 25 + 35
# = 635
# $$
#
# Evaluate at the lower bound \(x = 1\):
# $$
# F(1) = 1^4 - 1^2 + 7(1)
# = 1 - 1 + 7
# = 7
# $$
#
# Step 3: Subtract
# $$
# \int_{1}^{5} (4x^3 - 2x + 7)\, dx
# = 635 - 7
# = 628
# $$
#
# **Answer:**$$\boxed{628}$$
#
# </details>
