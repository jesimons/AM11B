# %% [markdown]
# ### Sample Problems 2.2: Average Value

# %% [markdown]
# **Problem 1:**
#
# Find the Average value of...
# $f(x)= 3x^2 - 2x + 5$ on the interval [1,4]
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1) Use $$f_{avg} = \frac{1}{b-a} \int_a^b f(x) dx$$
#
# $a = 1$ and $b = 4$
#
# $f_{avg} = \frac{1}{4-1} \int_1^4 3x^2 - 2x + 5 dx$
#
# Step 2) Integrate the function
#
# $\int3x^2 - 2x + 5 dx$ = $x^3 - x^2 + 5x$
#
# Step 3) Evaluate interval [1, 4]
#
# $x^3 - x^2 + 5x|_1^4$   =    $(4^3 - 4^2 + 5(4)) - (1^3 - 1^2 +5(1))$
#
#
# Step 4) Simplify
#
# $(64 - 16 + 20) - (1 - 1 + 5)$
# =$ 68 - 5 = 63$
#
#
# Step 5) Multiply by $\frac {1}{3}$
#
# $f_{avg} = \frac {1}{3} (63) = 21$
#
# </details>

# %% [markdown]
# **Problem 2:**
#
# Find the average value of the function $$\int_4^8 x^3 dx$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# The formula to find this would be:
# \
# $\frac{1}{8-4} \int_4^8 x^3 dx$
# \
# We can simplify this to:
# \
# $\frac{1}{4} \int_4^8 x^3 dx$
# \
# If we solve the integral we get:
# \
# $\frac{1}{4}x^4 + C \bigg|_4^8$
# \
# $= (\frac{1}{4}8^4) - (\frac{1}{4}4^4)$
# \
# $= 1024 - 64$
# \
# $= 960$
# \
# If we take this integral and divide it by $b-a$ we get:
# \
# $$\frac{960}{4} = \boxed{240}$$
#
# </details>

# %% [markdown]
# **Problem 3:**
#
# Find the average value of $f(x) = x^2$ on the interval $[0,2]$.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# - $f(x)dx = 1/(2-0) \int_2^0 x^2 dx$
# - $\int_2^0 x^2 dx = [x^3/3]_2^0 = 2^3/3 - 0 = 8/3$
# - $1/2(8/3) = 4/3$
#
# </details>

# %% [markdown]
# **Problem 4:**
#
# Find the average value of $f(x) = 3x$ on the interval $[0, 4]$.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** Identify the function and interval
#
# We have $f(x) = 3x$, $a = 0$, and $b = 4$.
#
# <br></br>
#
# **Step 2:** Set up the average value formula
#
# $$f_{avg} = \frac{1}{4-0} \int_0^4 3x \, dx$$
#
# #
# #
# $$f_{avg} = \frac{1}{4} \int_0^4 3x \, dx$$
#
#
# **Step 3:** Evaluate the integral
#
# $$\int_0^4 3x \, dx = 3 \int_0^4 x \, dx = 3 \left[\frac{x^2}{2}\right]_0^4$$
#
# <br></br>
# #
# #
# $$= 3 \left(\frac{16}{2} - 0\right) = 3(8) = 24$$
#
# #
# #
# **Step 4:** Calculate the average value
#
# $$f_{avg} = \frac{1}{4} \cdot 24 = 6$$
#
# #
# #
# <br></br>
# **Interpretation:** The average value of $f(x) = 3x$ on the interval $[0, 4]$ is $6$. This means that a rectangle with height $6$ and width $4$ has the same area ($24$ square units) as the region under the line $y = 3x$ from $x = 0$ to $x = 4$.
#
# </details>

# %% [markdown]
# **Problem 5:**
#
# *[Create a problem about average value]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# </details>

# %% [markdown]
# find the average value of f(x) = x**2 + 1 on the interval [0,2]
#
# Solution: use formula f_avg = (1/(b - a)) * ∫_a^b f(x) dx here a = 0 and b = 2
# compute the integral
#
# ∫_0^2 (x**2 + 1) dx = [x**3/3 + x] from 0 to 2 = (8/3 + 2) - 0 = 14/3 now plug into the formula
# f_avg = (1/(2 - 0)) * 14/3 = (1/2)*14/3 = 7/3
# average value of f on [0,2] is 7/3

# %% [markdown]
# **Problem 6:**
#
# Find the $average$ value of $f(x)3x^2$ on the interval $[0,2]$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** Apply $Average$ value formula
#
# $f_{avg} =\frac{1}{2-0}\int_{0}^{2}3x^2dx$
#
# **Step 2:** Integrate
#
# $\int_{0}^{2}3x^2dx=\left[x^3 \right]_0^2=(2)^3-(0)^3=8$
#
#
# **Step 3:** Divide
#
# $f_{avg} =\frac{1}{2}*8=4$
#
# </details>

# %% [markdown]
# **Problem 7:**
#
# $f_{avg}=\frac{1}{5-1}\int_5^1 x^2+3x dx$
#
# **Solution:**
# $f_{avg}= \frac{58}{3}$
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $f_{avg}=\frac{1}{4}[\int_5^1 x^2 dx + \int_5^1 3x$
#
# =$\int_5^1 x^2 dx = [\frac{x^3}{3}]_1^5 =\frac{125}{3} - \frac{1}{3}= \frac{124}{3}$
#
# =$\int_1^5 3x dx [\frac{x^2}{2}]_1^5 = \frac{3}{2}(25-1)=\frac{3}{2}(24)=36$
#
# =$\frac{124}{3} + 36=\frac{124}{3}+\frac{108}{3}=\frac{232}{3}$
#
# =$\frac{1}{4}(\frac{232}{3})=\frac{232}{12}=\frac{58}{3}$
#
# $f_{avg}=\frac{58}{3}$
#
# </details>

# %% [markdown]
# **Problem 8:**
#
# Find $f(x) = x^2 + 2x$ on the interval $[1,3]$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: $a = 1, b = 3$
#
# Step 2: = $\frac{1}{3-1}$ = $\frac{1}{2}$, $f(x) dx = (x^2 + 2x)dx$
#
# Step 3: $\frac{1}{2}$ $\int_1^3 (x^2 +2x)dx$
#
# Step 4: $\int_1^3$ $\frac{x^3}{3} + x^2$
#
# Step 5: $(\frac{3^3}{3} + 3^2)$ - $(\frac{1^3}{3} + 1^2)$
#
# Step 6: $\frac{27}{3}$$ + 9 = 9 + 9 = 18$, $\frac{1}{3}$$ + 1 = $$\frac{1}{3}$$4 + 1 = $$\frac{4}{3}$
#
# Step 7: $18 - $$\frac{4}{3}$$ = $$\frac{54}{3}$$ - $$\frac{4}{3}$$ = $$\frac{50}{3}$
#
# Step 8: $\frac{50}{3}$ - $\frac{1}{2}$ = $\frac{25}{3}$
#
#
#
#
# </details>

# %% [markdown]
# **Problem 9:* The temperature 𝑇 ( 𝑡 ) T(t) (in °C) of a cup of coffee t minutes after it was poured is modeled by: $T(t) = 90e^{-0.1t}+10$.
# Where t is between 0 and 20 minutes. Find the average temperature of the coffee during the first 20 minutes.*
#
# *[Create a problem about average value]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
# - $$f_{avg} = \frac{1}{b-a} \int_a^b f(x) dx$$
# - F(x) = $T(t) = 90e^{-0.1t}+10$
# - Interval: a = 0, b = 20
# -  $$T_{avg} = \frac{1}{20-0} \int_0^{20} (90e^{-0.1t} + 10) dt$$
# - $\int_0^{20} (90e^{-0.1t} + 10) dt = \int_0^{20} 90e^{-0.1t} dt + \int_0^{20} 10 dt$
# - $\int 90e^{-0.1t} dt = 90 \int e^{-0.1t} dt = 90 * \frac{e^{-0.1t}}{-0.1} = - First Integral: 900e^{-0.1t}$
# - Evaluate from 0 to 20: $-900(e^{-0.1(20)} - e^{-0.1(0)}) = 900(1-e^{-2}) = 778.23$
# - Second Integral: $\int_0^{20} 10 dt = 10* (20-0) = 200$
# - Add Resualts: $\int_0^{20} (90e^{-0.1t} +10)dt = 778.23 + 200 = 978.23$
# - Divide by interval length: $T_{avg} = \frac{1}{20} * 978.23 = 48.91$
# - Solution: $T_{avg} = 48.91°C$
#     The average temperature of the coffee during the first 20 minutes is about 48.9°C. This means that if the coffee had stayed the same temperature during the entire 20 minutes, it would have been 48.9°C.
# </details>

# %% [markdown]
# **Problem 10:**
#
# *[Create a problem about average value]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# </details>

# %% [markdown]
# **Problem 11:**
#
# *$f(x) =  2x^3 - 3x^2 + 4$ on the interval [0,2] *
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Find the antiderivative:*
# $\frac{1}{2}x^4-x^3+4x$
#
# Evaluate F(2) - F(0):
#
# $\frac{1}{2}(16)-8+8=8$
#
# $F(0) = 0$
#
# Divide by interval length 2:
#
# $\frac{8}{2} = 4$
#
# $F_{avg} = 4$
#
# </details>

# %% [markdown]
# **Problem 12:**
#
# *$f_{avg} = \int_0^4 6x^5+5dx$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
# *The Problem 13:*
#
# *$f_{avg} = \int_0^4 6x^5+5dx$*
#
# *Find the integral of the function above:
#
# *$\int_0^4 6x^5+5dx = x^6+5x |_0^4$*
#
# *Evaluate at the upper and lower bounds*
#
# *$((4)^6+5(4)) - ((0)^6+5(0)$*
#
# *$ =(4096 +20) - (0+0)$*
#
# *$ =4116$*
#
# *Plug this back into the formula to find the average value*
#
# *$f_{avg} =\frac{\int_0^4 6x^5+5dx}{b-a}= \frac{4116}{4-0}$*
#
# *Final Answer*
# *$f_{avg} = 1029 $*
#
# </details>

# %% [markdown]
# **Problem 14:**
#
# *[Create a problem about average value]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# </details>

# %% [markdown]
# **Problem 15:**
#
# *Find the average value of the function $f(x)=x^2$ on the interval [1,4]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# We must first use the average value formula:
#
# $f_{\text{avg}} = \frac{1}{b - a} \int_a^b f(x)\,dx$
#
# Plug in: $(a = 1), (b = 4), (f(x) = x^2)$
#
# **Step 1: Set up the formula**
#
# $f_{\text{avg}} = \frac{1}{4 - 1} \int_1^4 x^2\,dx$
#
# **Step 2: Compute the integral**
#
# $\int_1^4 x^2\,dx = \left[\frac{x^3}{3}\right]_1^4
# = \frac{4^3}{3} - \frac{1^3}{3}
# = \frac{64}{3} -  \frac{1}{3} = 21$
#
# **Step 3: Divide by the interval length**
#
# $f_{\text{avg}} = \frac{1}{3} \cdot 21 = 7$
#
# Final Answer:
#
# $f_{\text{avg}} = 7$

# %% [markdown]
# **Problem 16:**
#
# *[Find the average value of f(x) = x^2 + 1 in the interval [0,3].]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Step1: plug in formula
# favg = 1/(3-0) ∫(0 to 3) x^2 + 1 dx
# Step2: antiderivative
# ∫(x^2 + 1) dx = (1/3)x^3 + x
# Step3: calculate
# x=3 (1/3)(27)+3= 12
# x=0 = 0
# 12-0=12
# Step4: Apply
# 1/(3-0)(12)= 4.]*
#
# **Answer:** 4
#
# </details>

# %% [markdown]
# **Problem:**
#
# Find the average value of the function:
# *$\ f(x) = 3x^2 + 2x\ $*
# on the interval \[1, 4]\.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1 plug in formula: *$\
# f_{\text{avg}} = \frac{1}{b - a} \int_a^b f(x)\ dx\$* =
#
# *$\ f_{\text{avg}} = \frac{1}{4 - 1} \int_1^4 (3x^2 + 2x)\, dx\ $*
#
# Step 2 integrate: *$\int (3x^2 + 2x)\ dx = x^3 + x^2\$*
#
# Step 3 evaluate : *$\left[x^3 + x^2\right]_1^4 = (4^3 + 4^2) - (1^3 + 1^2)\ = (64 + 16) - (1 + 1)
# = 80 - 2 = 78 \$*
#
# Step 4 divide: *$\ f_{\text{avg}} = \frac{1}{3} \cdot 78\ \ f_{\text{avg}} = 26\$*
#
# Solution: 26
#
# Interpretation: The average value of the function *$\ f(x) = 3x^2 + 2x\ $* on the interval \[1, 4] , can be intepreted as the y axis equals 26 and has the same area under it over the stated interval.
#
# </details>

# %% [markdown]
# **Problem 17:**
#
# *Find the average value of f(x) = x^3 + 9, on the interval [1,4].*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
# $$
# \frac{1}{4-1}\int_1^4 x^3 + 9 dx
#     $$
# $$
#     (\frac{1}{3}) (\frac{1}{4}x^4 + 9x |(1,4))
#     $$
#     $$
#  (\frac{1}{3}) [(\frac{1}{4}(4)^4 + 9(4) - (\frac{1}{4}(1)^4 + 9(1))]
#     $$
#     $$
# (\frac{1}{3}) (90.75)
#     $$
#     FINAL ANSWER:
#     $$
# 30.25
#     $$
# </details>

# %% [markdown]
# **Problem 18:**
#
# * f(x) = x^3 - 2x + 4  on [1,4] *
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# * $f_{avg} = 1/4 -1 \int_1^4 (x^3 - 2x + 4)dx$
# * = $\int (x^3 -2x + 4) = x^4/4 -x^2 + 4x$
# * = 256/4 - 16 + 16 = 64
# * 1/4 - 1 + 4 = 13/4
# * 64 - 13/4 = 256/4 - 13/4 = 243/4
# * 1/3 x 243/4 = 81/4
#
# </details>

# %% [markdown]
# **Problem 19:**
#
# *f(x)=(x**2)+2x* on interval [0,3]
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *On the interval [0,3], the function behaves in average like a constant function with height 6. The total area under the actual curve is the same as the area of the rectangle of width 3 and height 6.*
#
# </details>

# %% [markdown]
# **Problem 20:**
#
# *Find the average value of $f(x) = 5x^2 on [0,4]$ *
#
# **Solution:**
#   80/3
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# Step 1: Plug in values
#
# $f_{avg} = \frac{1}{4-0} \int_0^4 5x^2 dx$
#
# Step 2: Evaluate integral
#
# $\int_0^4 5x^2 dx = 5x^3/3$
#
# $5(4^3)/3 - 5(0^3)/3 = 320/3$
#
# Step 3: Divide by interval length
#
# $f_{avg}= 1/4(320/3)=320/12 = 80/3$
#
# The average value of f(x) = 5x^2 on [0,4] is 80/3. This means that if the function were replaced by a constant function equal to 80/3 over the interval[0,4], it would produce the same total accumulated value as the original function. In other words 80/3 represents the average height of the curve over this interval.
#
#
#
# </details>

# %% [markdown]
# **Problem 21:**
#
# f(x) = x^2 + 4 on [1, 5]
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $$f_{avg} = \frac{1}{b-a} \int_a^b f(x) dx$$
# $$f_{avg} = \frac{1}{5-1} \int_1^5 (x^2 + 4) dx$$
# $$_{} = \frac{1}{4} \int_1^5 (x^2 + 4) dx$$
# $$_{} = \frac{}{} \int_1^5 (x^2 + 4) dx = x^3 / 3 + 4x$$
# (125/3 + 20)−(1/3 + 4)
# 1/4 * 172/3 = 172/12 = 43/3
#
# The function f(x) = x^2 + 4 varies in height from x= 1 to x=5. The average value 43/3 ≈ 14.33 represents the height of a horizontal line that would give the same total area over the interval [1,5] as the original function.
#
# </details>

# %% [markdown]
# **Problem 22:**
#
# What is the avergae value for the integral of $\int_4^8 2x + 4 dx$ ?
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Integrate
#
# * $ x^2 + 4x$
#
# Step 2: Plug in A and B values
#
# * $ F(b)= 8^2 + 4*8 = 96$
# * $ F(a)= 4^2 + 4*2 = 24$
#
# Step 3: Subtract
#
# * $96-24 = 72$
#
# Step 4: Find the average interval and multiply
#
# * $\frac{1}{b-a} = \frac{1}{8-4} = \frac{1}{4}$
# * $\frac{1}{4} * 72 = 18$
#
# Step 5: Understand
#
# This shows us that over the interval of 4 units from 4 to 8 the average value of area inbetween each unit is 18.
#
# </details>

# %% [markdown]
# **Problem 23:**
#
# $$f_{avg} = \frac{1}{2-0} \int_2^0 x dx$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# 1/2[x^2/2]from 0 to 2=1/2 * 4/2=1
#
# </details>

# %% [markdown]
# **Problem 24:**
#
# *Find the average value of the function $f(x)=x^2$ on the interval [0,3]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *$$f_{avg} = \frac{1}{b-a} \int_a^b f(x) dx$$*
# *$$f_{avg} = \frac{1}{3-0} \int_0^3 x^2dx = \frac{1}{3} \int_0^3 x^2 dx$$*
# *$$\int_0^3 x^2 dx = \frac{x^3}{3} |_0^3 = \frac{3^3}{3} - \frac{0^3}{3} = 9$$*
# *$$f_{avg} = \frac{1}{3} * 9 = 3$$*
# *$$f_{avg} = 3$$*
#
# </details>

# %% [markdown]
# **Problem:**
#
# $$ \int_{0}^{2}(2x^3-x)dx $$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** Integrate each term,
#
# $$ \int2x^3dx=\frac{x^4}{2} $$
#
# $$ \int-xdx=\frac{x^2}{-2} $$
#
# **Step 2:** Combine terms and evaluate the function at the points given,
#
#
# $$ \frac{x^4}{2}-\frac{x^2}{2}\big|_{0}^{2} $$
#
#
# $$ \frac{2^4}{2}-\frac{2^2}{2}-( \frac{0^4}{2}-\frac{0^2}{-2})
# =6-0= 6 $$
#
# **Step 3:** Multiply by the average factor $$ \frac{1}{b-a} $$.
#
# $$ \frac{1}{2-0}=\frac{1}{2} × 6 = 3 $$
#
# **Final answer:** $$ \boxed{f_{\text{avg}} =3} $$
#
# </details>

# %% [markdown]
# **Problem 25:**
#
# *[f_ave=1/2-(-1) integral from 2 to -1 1+X^2]*
#
# **1/3[(2+1/3x^3)]:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[[x^2]2 to -1=2-(-1)=3
# [x^3/3]2 to -1= 2^3/3 - (-1)^3/3=3
# Total integral = 6
# Now divide by interval lengthe 1/3 * 6=2
# The average value of the function is 2 which means that the area under f(x) over -1,2 is the same as the funtion g(x)=2*
#
# </details>

# %% [markdown]
# **Problem 26:**
#
# *[T(t) = -2t^2 +12t +20]*
#
# **Solution:t=0 to t=5**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[1/5-0 $0-5  (-2t^2 + 12t + 20)dt = 1/5 $0-5  (-2t^2 + 12t + 20)dt
# = -2/3t^3 + 6t^2 +20t
# bounds = $0-5 (-2t^2+12t+20)dt = F(5)-F(0) = 500/3
# =33.33C]*
#
# </details>

# %% [markdown]
# **Problem 27:**
#
# * Find the avg value of x^3 on the interval 0,2*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[(2^4)/4-0=16/4=4, favg=(1/2-0)4=2]*
#
# </details>

# %% [markdown]
# **Problem 28:**
#
# *Find the average value of the function $f(x) = x^2 + 1$ on the interval $[0, 2]$.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Use the average value formula: $f_{avg} = \frac{1}{b-a} \int_a^b f(x) dx$.
# Step 2: Substitute the function and interval: $f_{avg} = \frac{1}{2-0} \int_0^2 (x^2 + 1) dx = \frac{1}{2} \int_0^2 (x^2 + 1) dx$.
# Step 3: Compute the definite integral: $\int_0^2 (x^2 + 1) dx = \frac{8}{3} + 2 = \frac{14}{3}$.
# Step 4: Divide by the interval length: $f_{avg} = \frac{1}{2} \cdot \frac{14}{3} = \frac{7}{3}$.
# Interpretation: The average height of $f(x) = x^2 + 1$ over $[0,2]$ is $\frac{7}{3}$.
# Answer: $f_{avg} = \frac{7}{3}$*
#
# </details>

# %% [markdown]
# **Problem 29:**
#
# Find the average value of the function f(x)=3x^2-2x+5 on the interval [1,4],and find the number c in [1,4]such that f(c)= f_avg
#
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# -Step 1: Apply the average value formula
# f_avg = 1/4-1 \int_4^1(3x^2-2x+5)dx
#
# -Step 2: Compute the integral
# \int(3x^2-2x+5)dx=x^3-x^2+5x
#
#     evaulate from 1 to 4:
# at x = 4:
# 64 -16+20=68
# at x =1:
# 1-1+5=5
# \int_4^1(3x^2-2x+5)dx=68-5=63
#
# step 3: Divide by interval length
# f_avg=1/3(63)=21
#
# Step 4: Find c such that f(c)=21
# 3c^2-2c+5=21
#
# 3c^2-2c-16=0
#
# c= 2+-squared 4+192/6 = 2+- 14/6
#
# c=16/6=8/3 or c=-2
#
# only c = 8/3 is in [1,4]
#
#
# Interpretation:
# the avgrage height of f(x) on in [1,4] is 21
# by the mean value therom for integrals,s ince f is continous there exisits c = 8/3 in [1,4] where the function equals its avg value
#
# f_avg = 21 , c=8/3
#
# </details>

# %% [markdown]
# **Problem 30:**
#
# *$$f_{avg} = \frac{1}{2-0} \int_0^2 x^2 dx$$*
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **$\frac{1}{2-0}*\frac{8}{3}=\frac{4}{3}$**
#
#
#     **Solution:
#   $\frac{4}{3}$**
# </details>

# %% [markdown]
# **Problem 31:**
#
# *Find the average value of the function
# $$f(x) = 3x^2 - 2x + 1$$
# on the interval \([0, 3]\).*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *$$
# f_{\text{avg}} = \frac{1}{b-a} \int_a^b f(x)\,dx
# $$*
# We need to plug in the values from our function into the average value formula
# - \(a = 0\)
# - \(b = 3\)
# - \(f(x) = 3x^2 - 2x + 1\)
#
# Now we need to compute the integral
#     $$
# \int_0^3 (3x^2 - 2x + 1)\,dx
# = \left[x^3 - x^2 + x\right]_0^3
# $$
#
# Now we need to plug in our bounds and subtract them from each other
#
# $$
# (3^3 - 3^2 + 3) - (0^3 - 0^2 + 0)
# = (27 - 9 + 3)
# = 21
# $$
#
#
# </details>

# %% [markdown]
# **Problem 32:**
#
# Find average value of f on the interval [1,4] $ f_{avg} = 2x+1$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $f_{avg} = \frac{1}{4-1} \int_4^1 2x+1 dx$
# $ = \frac{1}{3} \frac{2x^2}{2}+x|_1^4$
# $ = \frac{1}{3} [(\frac {2(4)^2}{2}+4) - (\frac {2(1)^2}{2}+1)$
# $ = \frac{1}{3} [20 - 2]$
# $ = \frac{18}{3}
# $ = 6
#
#
#
# </details>

# %% [markdown]
# **Problem 33:**
#
# *Let $$f(x) = x^2$$
# on the interval $$([0,2])$$. Find the **average value** of f(x) on [0,2]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *$$a=0, b=2, f(x)=x^2$$*
# *$$1/2-0, x^2(dx)$$*
# *$$x^2(dx) = x^3/3$$*
# *$$2^3/3-0^3/3 = 8/3$$*
# plug integral back into avg. value formula *$$(1/2)(8/3) = 4/3$$ *
# *$$ c^2=sqr.root(4/3) = +/- 2/sqr.root(3)$$*
# *$$ Interval [0,2]$$* So, *$$c=2/sqr.root(3)$$*
#
# </details>

# %% [markdown]
# **Problem 34:**
#
# Find the average value of $f(x)=x^2+2x$ on the interval $[0,3]$
#
# **Solution:**
#
# Set up: $\frac{1}{3-0}\int_{0}^{3}x^2+2xdx$
#
# Integrate: $\int_{0}^{3}x^2+2xdx= [\frac{x^3}{3}+x^2]_{0}^{3}$
#
# $\frac{3^3}{3}+3^2=\frac{27}{3}+9=18$
#
# Divide by the interval: $\frac{18}{3-0}=\frac{18}{3}=6$
#
# The average value of $f(x)=x^2+2x$ on $[0,3]$ is 6.
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[f(x)=4-x]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[a=0 b=2  F(x)= $\int_2^0(4-x)dx  $\int(4-x)dx=4x-x^2/2
# =(8-2)=6
# =1/2 x 6 =3]*
#
# </details>

# %% [markdown]
# **Problem 35:**
#
# f(x) = x^2 + 2x for [0,4], Find the Average Value
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Apply the formula: $\int x^2 + 2x dx = x^3/3 + x^2$
#
# At x = 4:  112/3
# At x = 0:  0
#
# Divide: (1/4)(112/3) = 28/3
#
# </details>

# %% [markdown]
# **Problem 36:** Find the average value of the function
#
# $$
# f(x) = x^2 + 1
# $$
#
# on the interval $[0, 2]$.
# **
#
#
# **Solution:$$
# f_{\text{avg}} = \frac{7}{3}
# $$**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *The formula for the average value of a function on $[a, b]$ is:
#
# $$
# f_{\text{avg}} = \frac{1}{b-a} \int_{a}^{b} f(x)\,dx
# $$
#
# Here, $a = 0$ and $b = 2$, so:
#
# $$
# f_{\text{avg}} = \frac{1}{2-0} \int_{0}^{2} (x^2 + 1)\,dx = \frac{1}{2} \int_{0}^{2} (x^2 + 1)\,dx
# $$
#
# Step 1: The antiderivative is,
#
# $$
# F(x) = \frac{x^3}{3} + x
# $$
#
# Evaluate at the bounds:
#
# $$
# F(2) = \frac{2^3}{3} + 2 = \frac{8}{3} + 2 = \frac{14}{3}
# $$
#
# $$
# F(0) = 0
# $$
#
# So:
#
# $$
# \int_{0}^{2} (x^2 + 1)\,dx = F(2) - F(0) = \frac{14}{3}
# $$
#
# Step 2: Divide by the length of the interval
#
# $$
# f_{\text{avg}} = \frac{1}{2} \cdot \frac{14}{3} = \frac{7}{3}
# $$
#
# Interpretation: The average value of $f(x) = x^2 + 1$ over $[0, 2]$ is $\frac{7}{3}$. If the function were constant at this value, the area under the curve would be the same as the area under $f(x)$ on $[0,2]$.
# *
#
# </details>

# %% [markdown]
# **Problem 37:**
#
# *[Create a problem about average value]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# </details>

# %% [markdown]
# **Problem 38:**
#
# *Find the average value of the function $f(x) = x^2+3$ on the interval (1,4)*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Set up the integral
#
# $f_{avg} = \frac{1}{4-1} \int_1^4 x^2+3x dx$
#
# Step 2: Integrate and evaluate
#
# $\frac{x^3}{3}+\frac{3x^2}{2}$ evaluated at x=1 and x=4
#
# x=4 $\frac{4^3}{3}+\frac{3(4)^2}{2}$=$\frac{64}{3}+24$
#
# x=1 $\frac{1^3}{3}+\frac{3(1)^2}{2}$=$\frac{1}{3}+\frac{2}{3}$
#
# Step 3: Subtract
#
# $(\frac{64}{3}+ 24)-(\frac{1}{3}+\frac{2}{3})$= $\frac{87}{2}$
#
# Step 4: Divide by the integral length
#
# $\frac{1}{3} (\frac{87}{2})$ = 14.5
#
# **Final Answer: $f_{avg} = 14.5$**
#
# </details>

# %% [markdown]
# **Problem 39:**
#
# *$\int_0^2 3x^2$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *first we take the difference as a constant out front $1/2-0$ which is the equivalent to the amount of points taken when calculating an average. then we take the integral to get $x^3$ and plug in the endpoints. $(2)^3 = 8 and (0)^3 = 0$ and take the difference $8 - 0 = 8$. This is the area of the integral or the total sum of all the points. then we combine everything and get $8/2$ to get 4.*
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Create a problem about average value]*
# *[f(x)=x**2+2x on the interval[0,4]]*
#
# **Solution:28/3**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# *[\int_0^4 x**2+2x]*
# *[x**3/3+x**2+C]*
# *[(4)**3/3+4**2]*
# *[0+0]*
# *[112/3-0]*
# *[1/4*112/3]*
# </details>

# %% [markdown]
# **Problem 40:**
#
# $f_{avg} = \frac{1}{3-0} \int_0^3 x^3 dx$
#
# **Solution:**
#
# $f_{avg} = \frac{1}{3-0} = \frac{1}{3}$
#
# $\frac{1}{3} \cdot \int_0^3 x^3 dx = \frac{1}{4}x^4 \bigg|_0^3$
#
# $= \frac{1}{3} \cdot \frac{1}{4}(3)^4 - \frac{1}{4}(0)^4$
#
# $= \frac{1}{3} \cdot \frac{81}{4}-0 = \frac{27}{4}$
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# The complete interpretation is that if the result was to replace the curve of $f(x) = x^3$ over [0,3] with a horizontal line (constant function) of height 6.75, the area under that constant function over the interval would exactly be the same as the area under the curve $f(x) = x^3$.
#
# Area Under the curve $f(x) = x^3$:
#
# $\int_0^3 x^3dx = \frac{81}{4} = 20.25$
#
# Area of average height:
#
# $f_{avg} \cdot (b-a) = \frac{27}{4} \cdot (3-0) = \frac{81}{4} = 20.25$
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Create a problem about average value]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# </details>

# %% [markdown]
# **Problem 41:**
#
# *[Find the average value of of this function on the interval [0,2] f(x)=x^2 +1 ]*
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Step 1: Compute the integral and evaluate within the bounds. Step 2:Apply the average value formula. Final Answer is (7/3). The average value of f(x) is 7/3 ]*
#
# </details>

# %% [markdown]
# ### Sample Problem 2.2: Average Value

# %% [markdown]
# **Problem 42:**
#
# $f_{avg}=\frac{1}{4-1}\int_1^4 3x^2 dx$
#
# **Solution:**
# $f_{avg}=21$
#
# <details>
#
# $\frac{1}{3}\int_1^4 3x^2 dx$
#
# = $\frac{1}{3}[x^3]_1^4$
#
# =$\frac{1}{3}(4^3-1^3)$
#
# =$\frac{1}{3}(63)$
#
# </details>

# %% [markdown]
# **Problem 43:**
#
# *[Find the average value of f(x) = x^2/1+x on the interval [0,3]]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[simplfy the function:
#   $x^2/1+x = x - 1  + 1/1+x$
#   $\int_03 (x - 1 + 1/1+x)dx$
# We find the anti-derivative:
# $\int (x - 1 + 1/1+x) dx$
# $= x^2/2 - x + ln(1+x) + C$
# plug in 0 and 3:
# $x=3: 3^2/2 - 3 + ln4$
#   $= 9/2 - 3 + ln4$
#     $= 3/2 + ln4$
# $x=0: 0 - 0 + ln1$
#  $= 0$
# $\int_03 x**2/1+x dx = 3/2 + ln4$
# $f_{avg} = 1/3 (3/2 + ln4) = 1/2 + ln4/3$
# $f_{avg} = 0.5 + 1.38629436/3 = 0.96210$
# $= 0.96210$
#
# Our final answer is the height value under the curve. We were able to solve for the area under the curve, then divide by 3 to give us the height of a rectangle at our given interval.
# ]*
#
#
# </details>

# %% [markdown]
# **Problem 44:**
#
# *[Find the AVG value of f(x) = x^2 + 3x on the interval [1,4]]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[ Write it out 1/4-1 integral 1 to 4 (x^2 + 3x) dx = 1/3 integral 1 to 4 (x^2 + 3x) dx
# Find the antiderivative : integral (x^3 + 3x) dx = x^3/3 + 3x^2/2
# evaluate at F(4) and F(1)
# F(4) = 4^3 / 3 + 3(4^2) / 2 = 64/3 + 24
# F(1) = 1/3 + 3/2
# F(4)-F(1)=43.5
# then divide by 1/3 and the avg = 14.5]*
#
# </details>

# %% [markdown]
# **Problem 45:**
#
# *[Create a problem about average value]* Find the average value of f(x)=2x+3 on the interval [1,4].
#
# **Solution:** a=1, b=4 b-a=3 Compute the integral:
#  \int_1^4 (2x + 3)dx = \left[ x^2 + 3x \right]_1^4 = (4^2 + 3 \cdot 4) - (1^2 + 3 \cdot 1) = (16 + 12) - (1 + 3) = 28 - 4 = 24
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]* first identify a,b and then compute the intergal and at the last calculate the average value
#
# </details> the avg 1/3*24=8

# %% [markdown]
# **Problem:**
#
# *[Determine $f_{avg}$ for this function on the given interval: $f(x) = 8x-3+5e^{2-x}$ on $[0,2]$]*
#
# **Solution:$1/2 (5+5e^2)$**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[To solve, we plug in values into the average function value formula. $a=0$ and $b=2$. So:
#     $f_{avg} = 1/(2-0) \int_0^2 (8x-3+5e^{2-x} dx$
# Then, find the antiderivative of $f(x)$: $1/2(4x^2-3x-5e^{2-x}$.
#                                           Then, find $F(b)-F(a) = 1/2(5+5e^2)$
# so, $f_{avg} = 1/2(5+5e^2)$]*
#
# </details>

# %% [markdown]
# **Problem 46:**
#  f(x) = 3x^2 -2x + 4 at (1,5)
#  a = 1
#  b = 5
# **Solution:**
#
# step 1: find the antiderivative
#  3x^2dx = x^3
#  -2xdx = -x^2
#  4dx = 4x
#
# F(x) = x^3 -x^2 + 4x
#
# Step 2: evalute the integral at F(5) and F(1)
#
#  F(5) = 5^3 - 5^2 + 4(5) = 120
#  F(1) = 1^3 - 1^2 + 4(1) = 4
#
#     120 - 4 = 116
#
# step 3: divide by b-a
#
#  favg = 1/4(116
#
# *[Show complete solution with interpretation]*
#
# </details>

# %% [markdown]
# **Problem:**
#
# A cyclist rides along a straight road, and its speed (in miles per hour) at time t hours is given by: v(t)=2t+3
# Find the average speed of the cyclist over the time interval t=0 to t=4 hours.
#
# **Solution: 7
#
# Average value=1/b-a∫(bounds:(a,b) f(t)dt: f(t)= 2t+3 b=4, a=0
# 1/4-0 ∫(bounds:(0,4) (2t+3) dt
# = 1/4 ∫(bounds:(0,4) t^2+ 3t
# (t^2+ 3t) (0,4)= (4)^2+3(4)-(0)^2+ 3(0)= 16+12=28
# (1/4)(28)=7
# The average speed of the car over the 4 hours is 7 miles per hour

# %% [markdown]
# **Problem 47:**
#
# *[Create a problem about average value]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# </details>

# %% [markdown]
# **Problem 48:**
#
# Find the average value of the function: $f(x)= x^2 +3x with the given interval
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# - $$f_{avg} = \frac{1}{b-a} \int_a^b f(x) dx$$
#
# - $$f{avg} = \frac{1}{5-1} \int_1^5 x^2 + 3x dx$$
#
# - $$1/4 [x^3 / 3 + 3x^2 / 2 ] 5/1 = 1/4 [(5)^3 / 3 + 3(5)^2 / 2 ] - [(1)^3 / 3 +3(1)^2 / 2 ] = 1/4 [125/3 + 75/2 ] - [1/3 + 3/2] = (1/4) 232/12 = 58/3 $$
#
# </details>

# %% [markdown]
# **Problem 49:**
#
# Find the average value of  𝑓(𝑥)=𝑥+2 over the interval  [0,3].
#
# **Solution: 3.5**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *If we graphed this function it would show a trapezoid on its side with a starting point of 2 on y and end of 8 at y, with x starting at 0 and ending at 3. Plugging in the equation into the formula you would get $$f_{avg} = \frac{1}{3-0} \int_0^3 f(x+2) dx$$
#
# Which would use the average start method with evaluating at 0 which makes it 0 and then do 3 which would be $9/2 + 6 = 21/2$
#
# Which we would then multiply by the 1/3 outside, which would result in 3.5 which is essentially the average height
#
# </details>

# %% [markdown]
# **Problem 50:**
#
# f(x) = 2x-1 on [1,5]
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# = 1/5-1 (1 int/ 5) (2x-1)
# = int/ 2x-1dx = x^2-x
# = 20/4 = 5
#
# the average value of 2x-1 over [1,5] is 5
#
# </details>

# %% [markdown]
# **Problem 51:**
#
# *[Find the average value of the function $f(x) = 2x + 4$ on the interval $[0, 5]$.
# ]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Step 1: Use the average value formula
#
# $$f_{\text{avg}} = \frac{1}{b-a} \int_a^b f(x)\,dx.$$
#
# Here, $a = 0$, $b = 5$, and $f(x) = 2x + 4$.
#
# Step 2: Compute the integral
#
# $$\int_0^5 (2x + 4)\,dx
# = \left[x^2 + 4x\right]_0^5
# = (25 + 20) - 0
# = 45.$$
#
# Step 3: Multiply by $\frac{1}{b-a} = \frac{1}{5}$
#
# $$f_{\text{avg}} = \frac{1}{5} \cdot 45 = 9.$$
#
# **Answer:** $9$
#
# **Interpretation:**
# The function has an average height of **$9$** over the interval $[0,5]$, meaning the horizontal line $y=9$ produces the same total area over the interval as the function $f(x)$.
#
# ]*
#
# </details>

# %% [markdown]
# **Problem 52:**
#
# *[Find the average value of $f(x) = 2x + 1$ on the interval $[1,3]$.]*
#
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Use $f_(avg) = \dfrac{1}{b-a}\int_a^b f(x)\,dx$ with $a=1$ and $b=3$: $f_(avg) = \dfrac{1}{3-1}\int_1^3 (2x+1)\,dx = \dfrac{1}{2}(10) = 5$, so the average value is 5.]*
# </details>

# %% [markdown]
# **Problem 53:**
#
# *[ f(x)=x2+3 ]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[
# favg​=325​.
#    ]*
#
# </details>

# %% [markdown]
# **Problem 54:**
#
# *[Create a problem about average value]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# </details>

# %% [markdown]
# **Problem 55:**
#
# *[$$f_{avg} = \frac{1}{4-2} \int_2^4 x^2 dx$$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[We find the antiderivative of the x^2 inside the integral. This would lead to our answer being x^3/3. After that, we would plug in our upper and lower bounds, which would give us 64/3 and 8/3, respectively. Then, we would subtract the lower bound from the upper bound. You would end up with 56/3 and then bring the 1/2 to multiply it by 56/3. Lastly, you would end up with 56/6, but then you would simplify to 28/3. ]*
#
# </details>

# %% [markdown]
# **Problem 56:**
#
# Find the average value of the function $$f(x) = x^2 +2x$$ over the interval [1,4]
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:**
# - We first need to apply the average value formula to our equation and plug in our values:
# $$f_{avg} = \frac{1}{b-a} \int_a^b f(x) dx$$
#
# $$f_{avg} = \frac{1}{4-1}\int_1^4 (x^2+2x) dx = \frac{1}{3}\int_1^4 (x^2+2x) dx $$
#
# **Step 2:**
# - Then we need to find the antiderivative of the function
# $\int(x^2+2x)dx$
#
# - To find the antiderivate, we need to use the power rule once again to get:
# $\frac{x^3}{3} + x^2$
#
# **Step 3:**
# - We then need to evaluate the upper limit (x=4)
# $$\frac{4^3}{3}+4^2 = \frac{64}{3}+16 = \frac{64}{3}+\frac{48}{3} = \frac{112}{3}$$
#
# **Step 4:**
# - We then need to evaluate the lower limit (x=1)
# $$\frac{1^3}{3}+1^2 = \frac{1}{3} + 1 = \frac{4}{3}$$
#
# **Step 5:**
# - Then after we get the two values, we need to subtract the upper limit from the lower limit
# $$\frac{112}{3} - \frac{4}{3} = \frac{108}{3} = 36$$
#
# **Step 6:**
# - We then need to multiply the integral result by the $\frac{1}{b-a}$ factor:
# $\frac{1}{3} * 36 = ...$
#
# **Answer:**
# $12$
#
# </details>

# %% [markdown]
# **Problem 57:**
#
# Find the averga value of the function f(x) = $x^2$ +2 on the interval $[1,4]$
#
#
# **Solution:**
#
# Step 1
# $$f_{avg} = \frac{1}{b-a} \int_a^b f(x) dx$$
#
# a = 1 b =4
#
# $$f_{avg} = \frac{1}{4-1} \int_a^b (x^2+2) dx$$
# Step 2
#
# $\int_a^b (x^2+2) dx$ = $\frac{x^3}{3}$ + 2x
#
# Step 3
#
# $\left[ \frac{x^3}{3} + 2x \right]_{1}^{4}$
#
# F(4) = $\frac{4^3}{3}$ + 2(4) = $\frac{64}{3}$ + 8
#
# F(1) = $\frac{1}{3}$ + 2
#
# ($\frac{64}{3}$ + 8) - $\frac{1}{3}$ + 2
#
# = ($\frac{63}{3}$) + 6 = 21 + 6 = 27
#
# $f_{avg} = \frac{1}{3}$ * 27 = 9
#
# Answer:
#
# $f_{avg}$ = 9

# %% [markdown]
# **Problem 58:**
#
# *[Find the average value of f(x) = 2x on the interval of [0,4]*
#
# **Solution:4 **
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[1. Average value = 1/{b-a} \int_a^b f(x) dx$$*
#      1/{4-0} \int_0^4 2x dx$$
# 2. Antiderivative of 2x is x**2
# 3. Plug in the bounds
# (1/4)[(4)**2 - (0)**2]
# = (1/4)(16-0)
# = 1(1/4)(16) = 4
#
# </details>

# %% [markdown]
# **Problem 59:**
#
# *[Find the average value of $f(x) = x^3 + 0$ on the interval $[0,10]$.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Write the average value formula
#
# *[$\displaystyle f_{\text{avg}} = \frac{1}{b-a}\int_a^b f(x)\,dx$]*
#
# Here $a = 0$, $b = 10$, and $f(x) = x^3 + 0 = x^3$, so
#
# *[$\displaystyle f_{\text{avg}} = \frac{1}{10-0}\int_0^{10} x^3\,dx$]*
#
# Step 2: Compute the integral
#
# *[$\displaystyle \int_0^{10} x^3\,dx
# = \left.\frac{x^4}{4}\right|_{0}^{10}
# = \frac{10^4}{4} - 0
# = \frac{10000}{4}
# = 2500$]*
#
# Step 3: Divide by the length of the interval
#
# *[$\displaystyle f_{\text{avg}} = \frac{1}{10}\cdot 2500 = 250$]*
#
# **Answer:** *[$250$]*
#
# </details>

# %% [markdown]
# **Problem 60:**
#
# *v(t)=10t+40, 0<=t<=2*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *50 mph, the cars average speed over 2 hours is 50 mph. %0 mph represnts the "average height" of the speed fnction on the interval*
#
# </details>

# %% [markdown]
# **Problem 61:**
#
# *Find the average value of the function $f(x)=x^2+2x$ on the interval $[0,3]$.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *$f_{avg} = \frac{1}{3-0} \int_3^0 (x^2+2x) dx$*
#
# *$= \frac{1}{3} \int_3^0 (x^2+2x) dx]$*
#
# *$= \frac{1}{3}\ * (\frac{x^3}{3}+x^2)$*
#
# *$= \frac{1}{3}\ * (\frac{27}{3}\ + 9)$*
#
# *$= \frac{1}{3}\ * 18$*
#
# $=6$
#
# </details>

# %% [markdown]
# **Problem 62:**
#
# *[$f(x)=x^2+3$, on the interval $[1,4]$]
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1:** [$favg=1/(4-1) \int_1^4 (x^2+3)dx$]
#
# **Step 2:** [$\int_1^4(x^2+3)dx = (x/3)^3+3x$]
#
# **Step 3:** [$(4/3)^3+3(4)-(1/3)^3+3(1)=30$]
#
# **Step 4:** [$favg=(1/(4-1))(30)=10$]
#
# </details>

# %% [markdown]
# **Problem 63:**
#
# *Find the average value of
# f(x)=x on the interval [0,2]
# *
#
# **Solution:1**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *$$f_{avg} = \frac{1}{2-0} \int_0^2 x dx$$ *
# When computing the integral, we end up with 4/2-,0 which =2
# Then dividing the length of the interva,l we get 2/2 which is 1
#     Final answer =1
# *
#
# </details>

# %% [markdown]
# **Problem 64: Find the average value of the function
#
# $$
# f(x) = x^2 + 1
# $$
#
# on the interval $[0, 2]$.
# **
#
#
# **Solution:$$
# f_{\text{avg}} = \frac{7}{3}
# $$**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *The formula for the average value of a function on $[a, b]$ is:
#
# $$
# f_{\text{avg}} = \frac{1}{b-a} \int_{a}^{b} f(x)\,dx
# $$
#
# Here, $a = 0$ and $b = 2$, so:
#
# $$
# f_{\text{avg}} = \frac{1}{2-0} \int_{0}^{2} (x^2 + 1)\,dx = \frac{1}{2} \int_{0}^{2} (x^2 + 1)\,dx
# $$
#
# Step 1: The antiderivative is,
#
# $$
# F(x) = \frac{x^3}{3} + x
# $$
#
# Evaluate at the bounds:
#
# $$
# F(2) = \frac{2^3}{3} + 2 = \frac{8}{3} + 2 = \frac{14}{3}
# $$
#
# $$
# F(0) = 0
# $$
#
# So:
#
# $$
# \int_{0}^{2} (x^2 + 1)\,dx = F(2) - F(0) = \frac{14}{3}
# $$
#
# Step 2: Divide by the length of the interval
#
# $$
# f_{\text{avg}} = \frac{1}{2} \cdot \frac{14}{3} = \frac{7}{3}
# $$
#
# Interpretation: The average value of $f(x) = x^2 + 1$ over $[0, 2]$ is $\frac{7}{3}$. If the function were constant at this value, the area under the curve would be the same as the area under $f(x)$ on $[0,2]$.
# *
#
# </details>

# %% [markdown]
# **Problem:**
#
# *Find the average value of the function f(x) = x^2 + 1 over the interval [1,4].*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Set up the formula average value = 1/(4-1) \int_1^4 (x^2 + 1)
#
# Step 2: Find the antiderivative integral of (x^2 +1) dx = 1/3 x^3 + x
#
# Step 3: Use FTC Part 2 F(4) - F(1)
#
# Step 4: Calculate the difference between the fuctions F(4) - F(1) = ((4^3)/3 + 4) - ((1^3)/3 + 1) = 24
# </details>

# %% [markdown]
# **Problem:**
#
# *Find the average value of the function f(x) = 4x − 2 on the interval [1, 3].*
#
# **6:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Step 1: Write the average value formula
# f_avg = (1 / (3 − 1)) ∫ from 1 to 3 of (4x − 2) dx
#
# Step 2: Compute the integral
# ∫ (4x − 2) dx = 2x² − 2x
# Now evaluate at 3 and 1:
#
# F(3) = 2(3²) − 2(3) = 18 − 6 = 12
# F(1) = 2(1²) − 2(1) = 2 − 2 = 0
#
# So the definite integral is:
# 12 − 0 = 12
#
# Step 3: Plug into the formula
# f_avg = (1 / 2) * 12 = 6*
#
# </details>

# %% [markdown]
# **Problem 65:**
#
# *[Let $f(x)=4x^2$. Find the average value of $f$ on the interval [2,5]]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Set up the formula $favg​ = 1 /5-2 \int_2^5 4x^2dx=1/3\int_2^5 4x^2dx$
# Find the integral: $\int_4x^2dx = 4/3 x^2$
# Evaluate from 2 to 5 $4/3 (5^3)- 4/3(2^3) = 156$
# Multiply by the prefactor $1/3 (156=52$]*
#
# </details>

# %% [markdown]
# **Problem 66:**
#
# $$\int_1^5 3x^2 + 2x dx$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $$f_{avg} = (\int_1^5 3x^2 + 2x dx)/5-1 = (x^3 + x^2|(5) (1))/4 = (5^3 + 5^2 -(1^3 + 1^2))/4 = (150 -2)4 = 148/4 = 37$$
#
# </details>

# %% [markdown]
# **Problem 67:**
#
# f(x)=x+2 on the interval [0,4][0,4]
#
# **Solution:**
#
#
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# $$f_{avg} = \frac{1}{4-0} \int_0^4 f(x+2) dx$$
#
# $\int_0^4 (x+2)dx = [x^2/2+2x]_0^4$
#
# =(16/2+8)-0=8+8=16
#
# $f_{avg}=16/4=4$
#
# $f_{avg}=4$

# %% [markdown]
# **Problem 68:**
#
# *[$$f_{avg} = \frac{1}{4-1} \int_1^4 f(3x+1) dx$$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[(3x+1)dx=3x^2/ 2 +x
# , plug in 1 and 4  3(4)^2/2  +4 - (3(1)^2 /2 +1) , x=4 = 28 and x=1=5/2 subtracting 28-5/2 = 56/2 - 5/2 = 51/2 , then divide that by interval length, 1/3 * 51/2 = 51/6 = 17/2 = 8.5 ]*
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[$f(x)=x^2+2x on the interval (0,4)]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[step by step template]
# Step 1: use the average value formula
# a=0, b=4
# Step 2 : Compute the intregal
# X^3/3+x^2 (4^3/3+4^2)-(0^3/3+0^2)=(64/3+16)+64/3+48/3+112/3
# Step 3: divide by the width of the interval
# 1/4-0 (112/3) = 112/2= 28/3= 9.33
#
# Solution: 9.33
#
#
# </details>

# %% [markdown]
# **Problem 69:**
#
# *[$\int_a^b 5x^4+2x-3 dx$ with the interval (1,2)]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[$\frac{\int_1^2 5x^4+2x-3dx}{2-1}$]*
#
# *[The integral of the function is $x^5+x^2-3x+C$]*
#
# *[$\frac{31}{2-1} = 31$]*
#
# **Answer:** *[31]*
#
# </details>

# %% [markdown]
# **Problem 70:**
#
# *[Create a problem about average value]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# </details>

# %% [markdown]
# **Problem 71:**
#
# Find the average value of the function: f(x)=3x^2-2x+1 on the interval [1,4]
#
# Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# favg= 1/b-a $\int_a^b f(x)dx$
#
# f(x)=3x^2-2x+1, a=1, b=4
# Compute the integral:
#
# $\int_1^4 (3x^2-2x+1)dx$= x^3-x^2+x
#
# Evaluate from 1-4:
#
# [x^3-x^2+x]
# At x=4:
# 4^3-4^2+4= 64-16+4=52
# At x=1:
# 1-1+1= 1
#
# Difference:
# 52-1=51
#
# Divide interval length:
# favg= 1/4-1 x 51= 1/3 x 51= 17
#
# Average value of the function on [1,4] is: 17
#
# </details>

# %% [markdown]
# **Problem 72:**
#
# f(x) x^2 +2 on the interval [0, 4]
#
# **Solution:** 22/4
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $$f_{avg} = \frac{1}{4-0} \int_0^4 (x^2 +2) dx$$
#
# \frac{1}{4-0} \int_0^4 (x^2 +2) dx$$ = \frac{1}{4-0} \int_0^4 (x^3 /3) +2x)
#
# x= 4 = 4^3/3 + 2(4) = 64/3 + 8 = 64/3 + 24/3 = 88/4
#
# x= 0 = 0^3/3 + 2(0) = 0
#
# on the interval from [0, 4] = 88/3 - 0 = 88/0
#
# average: 88/3 ** 1/4 = 22/3
#
# </details>

# %% [markdown]
# **Problem 73:**
#
# $$f_{avg} = \frac{1}{2-0} \int_0^2 x^2 +1dx$$
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $$f_{avg} = \frac{1}{2} \int_0^2 x^2 +1dx$$
#
# $$\int_0^2 x^2 +1dx$$ =1/2 (x^3)3 + x + C
#
# ((2)^3)/3 + 2 +0 +0 =
# 8/3 +6/3=
#
# 14/3 x 1/2=
#
# 7/3
#
# </details>

# %% [markdown]
# **Problem 74:**
# Find the average value of
# $
# f(x) = x^2 + 2x
# $
# on the interval $([0, 3])$.
#
# **Solution:**
# <details>
# <summary>Click to reveal solution</summary>
#
# Compute the integral:
# $
# \int_{0}^{3} (x^2 + 2x)\, dx
# = \left[\frac{x^3}{3} + x^2\right]_{0}^{3}
# = \left(9 + 9\right) - 0 = 18.
# $
#
# Now divide by the interval length:
# $
# f_{\text{avg}} = \frac{1}{3 - 0}(18) = 6.
# $
#
# The average value is **6**.
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Create a problem about average value]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# </details>

# %% [markdown]
# **Problem 75:**
#
# Find the average value of the function
#
# $f(x) = x^2 +2x$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Use the formula:
#
# $f_{\text{avg}} = \frac{1}{4 - 0} \int_{0}^{4} (x^2 + 2x)\,dx$
#
# Step 1: Compute the integral
#
# $\int (x^2 + 2x)\,dx = \frac{x^3}{3} + x^2$
#
# Apply the bounds:
#
# $\left[\frac{x^3}{3} + x^2\right]_{0}^{4}
# = \left(\frac{64}{3} + 16\right) - 0$
#
# Simplify:
#
# $\frac{64}{3} + 16
# = \frac{64}{3} + \frac{48}{3}
# = \frac{112}{3}$
#
# Step 2: Divide the interval length:
# $f_{\text{avg}} = \frac{1}{4} \cdot \frac{112}{3}
# = \frac{112}{12}
# = \frac{28}{3}$
#
# Final Answer:
#
# $f_{\text{avg}} = \frac{28}{3}$
# </details>

# %% [markdown]
# **Problem 76:**
#
# *Find the average value ($f_{avg}$) of the function $f(x) = 4x^3$ over the interval $[1, 2]$.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *$$f_{avg} = \frac{1}{2-1} \int_1^2 4x^3 \, dx$$*
#
# *$F(x) = x^4$.
# ($\int 4x^3 \, dx = 4 \frac{x^4}{4} = x^4$)*
#
# $$f_{avg} = \left[ x^4 \right]_{1}^{2} = F(2) - F(1)$$$$f_{avg} = (2)^4 - (1)^4$$$$f_{avg} = 16 - 1$$$$f_{avg} = \mathbf{15}$$
#
# </details>

# %% [markdown]
# **Problem:**
#
# Find the average value of $f(x) = x + 2$ on the interval $[0,4]$.
#
# **Solution:**
#
# <details> <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Use the formula
# $\displaystyle f_{\text{avg}} = \frac{1}{b-a} \int_{a}^{b} f(x), dx$
#
# Here, $a = 0$, $b = 4$.
#
# Step 2: Compute the integral
# $\displaystyle \int_{0}^{4} (x + 2), dx$
#
# Antiderivative:
# $\displaystyle \frac{x^{2}}{2} + 2x$
#
# Evaluate from 0 to 4:
# At $4$: $\displaystyle \frac{4^{2}}{2} + 2(4) = 8 + 8 = 16$
# At $0$: $\displaystyle 0$
#
# So the integral equals 16.
#
# Step 3: Divide by $b - a = 4 - 0 = 4$
# $\displaystyle f_{\text{avg}} = \frac{16}{4} = 4$
#
# Final Answer:
# $\displaystyle f_{\text{avg}} = 4$
#
# </details>

# %% [markdown]
# **Problem 77:**
#
# *Find the average value of the function $f(x) = x^2 + 4$ on the interval $[0, 3]$.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *7*
#
# </details>

# %% [markdown]
# **Problem 78:**
#
# *[f(x)=2x^2]+3 on [1,4]*
#
# **17:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[The average value of f(x)=2x^2]+3 on [1,4] is 17, meaning that if the function were flattened to a constant height, the height would be 17 to have the same total area under the curve over the interval*
#
# </details>

# %% [markdown]
# **Problem 79:**
#
# *Find the average value of $f(x)=4x^3+3$ between $[1,5]$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *First, we will compute the interval using FTC part 2*
#
# *$\int_1^5 f(x) dx = \int_1^5 4x^3+3 dx$*
#
# *$\int_1^5 4^3+3 dx = x^4+3x$*
#
# *$(5)^4+3(5) = 625 + 15 = 640$*
#
# *$(1)^4+3(1) = 1 + 3 = 4$*
#
# *$640-4 = 636$*
#
# *Next, we will solve the fraction $\frac{1}{b-a}$*
#
# $\frac{1}{b-a} = \frac{1}{5-1} = \frac{1}{4}$
#
# Finally, we will multiply our fraction by the value of our integral (net area)
#
# *$(\frac{1}{4})(636)= \frac{636}{4} = 159$*
#
# $f_{avg} = 159$
#
#
# </details>

# %% [markdown]
# **Problem 80:**
#
# Find the average value of $ f(x) = 3x^2 +1$ on the interval $[0,2)$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# - **Step one:** Set up the formula using $f_{avg} = \frac{1}{b-a} \int_a^b f(x)dx$ with $a = 0$ and $b = 2$
#
# $f_{avg} = \frac{1}{2 - 0} \int_{0}^{2} (3x^2 + 1) dx$
#
# - **Step two:** Simplify the fraction and integrate.
#
# $f_{avg} = \frac{1}{2} \left[ \frac{3x^3}{3} + x \right]_{0}^{2}$
#
# $f_{avg} = \frac{1}{2} \left[ x^3 + x \right]_{0}^{2}$
#
# - **Step  three:** Evaluate using the FTC.
#
# $f_{avg} = \frac{1}{2} \left( (2^3 + 2) - (0^3 + 0) \right)$
#
# $f_{avg} = \frac{1}{2} (8 + 2)$
#
# - **Answer**
#
# $ f_{avg} = 5 $
# </details>

# %% [markdown]
# **Problem:**
#
# *[Create a problem about average value]*
# f(x) = x^3+2x at the interval [0,2]
# **Solution:** 4
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# a = 0  b = 2
#
# $$f_{avg} = \frac{1}{2-0} \int_0^2 x^3+2x  dx$$
#
#  $$f_{avg} = 1/2(\int_0^2 x^3+2x)  dx$$
#
#  $$f_{avg} = (\int_0^2 x^3+2x) --> x^4/4 + x^2 dx$$
#
# $$f_{avg} =  2^4/4 + 2^2
# dx$$ = 8
#
# $$f_{avg} =  0^4/4 + 0^2
# dx$$ = 0
#
# divide by length
#
#     1/2 (8) = 4
# </details>

# %% [markdown]
# **Problem 81:**
#
# *Find the average value of $f(x) = 3x^2 - 2$ on the interval $[-1, 3]$.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Step 1: Set up the formula$a = -1, b = 3$, so the width is $3 - (-1) = 4$.$$f_{avg} = \frac{1}{4} \int_{-1}^3 (3x^2 - 2) \, dx$$Step 2: Evaluate the integralAntiderivative of $3x^2 - 2$ is $x^3 - 2x$.$$\int_{-1}^3 (3x^2 - 2) dx = [x^3 - 2x]_{-1}^3$$Evaluate at 3: $(3)^3 - 2(3) = 27 - 6 = 21$Evaluate at -1: $(-1)^3 - 2(-1) = -1 + 2 = 1$Integral value $= 21 - 1 = 20$.Step 3: Multiply by 1/(b-a)$$f_{avg} = \frac{1}{4} (20) = 5$$Answer: The average value is 5.*
#
# </details>

# %% [markdown]
# **Problem 82:**
#
# *Find the average value of the function $f(x) = 2x + 1$ on the interval $[0, 4]$.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Step 1: Write the average value formula**
#
# $f_{\text{avg}} = \frac{1}{b - a} \int_a^b f(x) dx$
#
# **Step 2: Substitute the given values**
#
# $f_{\text{avg}} = \frac{1}{4 - 0} \int_0^4 (2x + 1) dx$
#
# **Step 3: Evaluate the integral**
#
# $\int_0^4 (2x + 1) dx = \left[x^2 + x\right]_0^4$
# $= (16 + 4) - (0 + 0) = 20$
#
# **Step 4: Calculate the average value**
#
# $f_{\text{avg}} = \frac{1}{4} \times 20 = 5$
#
# **Step 5: Interpret the result**
#
# The average height of the function $f(x) = 2x + 1$ between $x = 0$ and $x = 4$ is 5. This means a rectangle from $x = 0$ to $x = 4$ with height 5 would have the same area as the area under the curve.
#
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Create a problem about average value]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show complete solution with interpretation]*
#
# </details>

# %% [markdown]
# **Problem 83:**
# $$f(x) = 2x^2 - x + 4$$  on the interval $$[2, 6].$$
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
# Step 1: Write the average value formula**
# $$
# f_{\text{avg}} = \frac{1}{b-a} \int_a^b f(x)\, dx
# $$
#
# $a = 2$, $b = 6$, and $f(x) = 2x^2 - x + 4$.
#
# So:
# $$
# f_{\text{avg}} = \frac{1}{6-2} \int_2^6 (2x^2 - x + 4)\, dx
# $$
#
# **Step 2: Find the antiderivative**
#
# $$
# \int (2x^2 - x + 4)\, dx
# = \frac{2}{3}x^3 - \frac{1}{2}x^2 + 4x
# $$
#
# *Step 3: Apply the Fundamental Theorem of Calculus*
#
# Evaluate at $x = 6$:
#
# $$
# F(6) = \frac{2}{3}(6^3) - \frac{1}{2}(6^2) + 4(6)
# = \frac{2}{3}(216) - 18 + 24
# = 144 - 18 + 24
# = 150
# $$
#
# Evaluate at $x = 2$:
#
# $$
# F(2) = \frac{2}{3}(8) - \frac{1}{2}(4) + 4(2)
# = \frac{16}{3} - 2 + 8
# = \frac{16}{3} + 6
# = \frac{34}{3}
# $$
#
#
# *Step 4: Subtract*
#
# $$
# \int_2^6 (2x^2 - x + 4)\, dx
# = 150 - \frac{34}{3}
# = \frac{450}{3} - \frac{34}{3}
# = \frac{416}{3}
# $$
#
#
# *Step 5: Divide by the interval length*
#
# Interval length:
# $$6 - 2 = 4$$
#
# So:
# $$
# f_{\text{avg}} = \frac{1}{4} \cdot \frac{416}{3}
# = \frac{416}{12}
# = \frac{104}{3}
# $$
#
# </details>
