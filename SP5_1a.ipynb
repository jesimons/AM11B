# %% [markdown]
# **Problem 1:**
#
# $$f(x, y) = \frac{\sqrt{x - y}}{x}$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# The domain is restricted by two conditions:Square Root: The expression under the square root must be non-negative: $x - y \geq 0 \implies y \leq x$.Fraction: The denominator cannot be zero: $x \neq 0$.The domain $D$ is the set of all points $(x, y)$ such that:$$D = \{(x, y) \in \mathbb{R}^2 \mid y \leq x \text{ and } x \neq 0\}$$
#
# To find the range, let $z = f(x, y) = \frac{\sqrt{x - y}}{x}$. Since the numerator $\sqrt{x-y}$ is always non-negative (zero or positive) and the denominator $x$ must be non-zero, the sign of $z$ depends only on $x$.From the domain $y \leq x$, we can rewrite the function as:$$z = \frac{\sqrt{x - y}}{x}$$Since $x = y + (x-y)$, and $x-y$ is the quantity under the square root, let $u = \sqrt{x-y}$ (so $u \geq 0$). Then $x = y + u^2$.
#
# </details>

# %% [markdown]
# **Problem:**
#
# *$f(x,y)=sqrt(16-x^{2}-y^{2})$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Domain: since the function is within a square root, it must be positive. $16-x^{2}+y^{2} >= 0$, therefore $x^{2}+y^{2}<= 16$. The domain is all points inside a circle with a radius of 4
#
# Range: the smallest possible value is $0$ and the largest possible value is $4$. $0<=f(x,y)<=4$
#
# </details>

# %% [markdown]
# **Problem 2:**
#
# Find the domain and range of: $$f(x,y) = \sqrt{x + y^2}$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Domain:**
#
# Because there is a square root, $x + y^2$ must be nonnegative. Thus making the domain: $$\boxed{x + y^2 \ge 0}$$
#
# **Range:**
#
# Since square roots can only output nonnegative numbers, the minimum value must be 0. Thus making the range: $$\boxed{[0, \infty)}$$
#
# </details>

# %% [markdown]
# **Problem 3:**
#
# Consider the multivariable function
#
# $f(x,y) = \sqrt{9 - x^2 - y^2} \;+\; \ln(x+y+5)$
#
# *(a)* Determine the *domain* of $(f(x,y))$.
# *(b)* Determine the *range* of $(f(x,y))$.
#
# *Solution:*
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
#  Finding the Domain
#
# The function has two expressions that impose restrictions:
#
# 1. $9 - x^2 - y^2 \ge 0 \quad\Rightarrow\quad x^2 + y^2 \le 9.$
#
# 2. The natural log requires  $x + y + 5 > 0 \quad\Rightarrow\quad x + y > -5$
#
#
# Thus, the *domain* is the set of all $((x,y))$ inside or on the circle $(x^2 + y^2 \le 9)$ and on the side of the line $(x+y>-5)$
#
#
# Finding the Range
#
# - The square root part satisfies
#
#   $0 \le \sqrt{9 - x^2 - y^2} \le 3$
#
#
# - The logarithm satisfies
#
#   $\ln(x+y+5)$
#
#   where:
#   - its minimum approaches $(-\infty)$ as $(x+y+5 \to 0^+)$,
#   - its maximum occurs when $(x+y)$ is maximized inside the disk.
#
# Inside the disk $(x^2 + y^2 \le 9)$, the maximum value of $(x+y)$ occurs along the line $(x=y)$, giving
#
# $x=y=\frac{3}{\sqrt{2}}\quad\Rightarrow\quad x+y = \frac{6}{\sqrt{2}} = 3\sqrt{2}$.
#
#
# Thus the maximum of the log term is
#
# $\ln(3\sqrt{2}+5)$
#
#
# Adding the maximum of the square root (which is 3), the overall maximum of (f) is
#
# $f_{\max} = 3 + \ln(3\sqrt{2}+5)$
#
#
# Since the log term can go to $(-\infty)$,
#
# $f_{\min} = -\infty$
#
#
# Final Range
#
# $(-\infty,\; 3 + \ln(3\sqrt{2}+5)]$.
#
#
# </details>

# %% [markdown]
# **Problem 4:**
#
# *$ f(x,y) = \sqrt{9-x^2-y^2} $*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[1. Find the domain:
#  - Because of the square root, the function inside must be positive, $ \ge 0$
#  - Rearrange the function. $ x^2-y^2 \ge 9 $
#  - then $ \sqrt{x^2-y^2} \ge \sqrt{ 9 }$
#  - (x,y) are the set points inside or on the circle with a radius of 3 at the orgin
# 2. Find the range:
# - The maximum occurs at (x,y)=(0,0)
# - f(0,0)=$ \sqrt{ 9 }= 3 $
# - minimum occurs when $9-x^2-y^2= 0$
# - f= 0, range = [0,3]
# *
#
# </details>

# %% [markdown]
# **Problem 5:**
#
# $$ F(x,y)= 100x+80y-x^2-y^2 $$
#
# **Solution:**
# Domain: {(x,y)x>0, y>0
# Range: (-oo,4100)
#
# *[Show how to find domain and range]*
#
# take partial derivatives of the function
# find max and plug it into function
# F(50,40)

# %% [markdown]
# **Problem 6:**
#
# *$f(x,y) = \sqrt{4-x^2-y^2}$*
#
# *Find the domain and range of the function*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *First, since we know that domain is all possible points that lead to an output, we look at the function*
#
# *$f(x,y) = \sqrt{4-x^2-y^2}$*
#
# *and see that because it is a square root, the inner values must combine to greater than or equal to 0, meaning*
#
# *$0=< 4-x^2-y^2$ which can also be written as $4>=x^2+y^2$, which is our domain*
#
# *To find range, we need to evaluate all possible outputs of the function*
#
# *$f(x,y) = \sqrt{4-x^2-y^2}$*
#
# *Using our domain of $4>=x^2+y^2$ we can find that our inner function can output a maximum value of 4, and a minimum value of 0*
#
# *if we use the minimum and maximum possible inner function values and square root them, we get a range of $[0,2]$*
#
# </details>

# %% [markdown]
# **Problem 7:**
#
# *[$f(x,y)= \sqrt{9-x^2-y^2}$]*
#
# *Solution: Range:[$0,3$]*, Domain:*[$x^2+y^2≤9$]**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[$x^2+y^2≤9$]*(Domain)
# *[$\sqrt{9}=3$ = max value] [min value = $0$] so : [$0,3$]*(Range)
#
#
# </details>

# %% [markdown]
# **Problem:**
#
#
# *Consider the function \(f(x,y) = \sqrt{9 - x^2 - y^2}\).
# Find the domain and range of this multivariable function.*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *To find the domain:*
# The expression inside the square root must be ≥ 0:
#
# \[
# 9 - x^2 - y^2 \ge 0
# \]
#
# \[
# x^2 + y^2 \le 9
# \]
#
# So the domain is all points \((x,y)\) inside or on a circle of radius 3.
#
# *To find the range:*
# The smallest value of the square root is 0 (at the boundary).
# The largest value is:
#
# \[
# \sqrt{9} = 3
# \]
#
# So the range is:
#
# \[
# 0 \le f(x,y) \le 3
# \]
#
# **Final Answer:**
# Domain: all \((x,y)\) such that \(x^2 + y^2 \le 9\).
# Range: \(0 \le f(x,y) \le 3\).
#
# </details>

# %% [markdown]
# **Problem 8:**
#
# Consider the function $f(x,y) = \sqrt{9 - x^2 - y^2}$.
#
# 1. Find the domain of f(x,y).
# 2. Describe the domain geometrically.
# 3. Find the range of f(x,y).
# 4. Evaluate f(1,2) if it exists.
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Part 1: Find the domain**
#
# For the square root to be defined, we need:
# $$9 - x^2 - y^2 \geq 0$$
# $$x^2 + y^2 \leq 9$$
#
# **Domain**: $\{(x,y) : x^2 + y^2 \leq 9\}$
#
# **Part 2: Describe the domain geometrically**
#
# The domain is a disk (circle and its interior) centered at the origin with radius 3. This includes all points on and inside the circle $x^2 + y^2 = 9$.
#
# **Part 3: Find the range**
#
# Since $x^2 + y^2 \leq 9$, we have:
# $$9 - x^2 - y^2 \geq 0$$
# $$\sqrt{9 - x^2 - y^2} \geq 0$$
#
# The maximum value occurs when $x^2 + y^2 = 0$ (at the origin):
# $$f(0,0) = \sqrt{9 - 0 - 0} = 3$$
#
# The minimum value occurs when $x^2 + y^2 = 9$ (on the boundary):
# $$f(x,y) = \sqrt{9 - 9} = 0$$
#
# **Range**: $[0, 3]$
#
# **Part 4: Evaluate f(1,2)**
#
# First check if (1,2) is in the domain:
# $$1^2 + 2^2 = 1 + 4 = 5 \leq 9$$ ✓
#
# So (1,2) is in the domain. Now evaluate:
# $$f(1,2) = \sqrt{9 - 1 - 4} = \sqrt{4} = 2$$
# </details>

# %% [markdown]
# **Problem 9:**
#
# f(x,y)=x+y
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# domain and range is all real numbers
#
# </details>

# %% [markdown]
# **Problem 10:**
#
# Q(L,K)= square root of 100-L^2-K^2
#
# Find all possible values of Q(L,K) and determine all L and K
#
# **Solution:**
#
# Step 1:
# 100-L^2-K^2>=0
#   L^2+K^2<=100
#
# Step 2:
#   0->Qmin=0 smallest
#   100->Qmax=Square root 100=10
#
# Range: Q(L,K)=[0,10]
#     L=6,K=8
#     Q(6,8)= Square root 100-6^2-8^2= square root 100-36-64= Square root =0=0
#
# Domain:
#     Square root->inside>=0
#     Denominators-> cant be 0
#     Logs->arguement>0
#
# Range:
#     Put high points from the domain
#     find the smallest and largest outputs

# %% [markdown]
# **Problem 11:**
#
# *[Create a problem about multivariable functions and understanding their domain and range.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find domain and range]*
#
# </details>

# %% [markdown]
# **Problem 12:**
#
# Consider the function: $f(x, y) = \sqrt{9 - x^2 - y^2}$
#
# a) Find the domain of f(x, y)
# b) Find the range of f(x, y)
# c) Evaluate f(1, 2)
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# a) Domain:
# For $\sqrt{9 - x^2 - y^2}$ to be defined: $9 - x^2 - y^2 \geq 0$ = $x^2 + y^2 \leq 9$
#
# This is a disk centered at (0,0) with radius 3.
#
# Domain: $\{(x, y) | x^2 + y^2 \leq 9\}$
#
#
# b) Range:
# When $x^2 + y^2 = 0$: $f(0, 0) = \sqrt{9} = 3$ (maximum)
# When $x^2 + y^2 = 9$: $f(x, y) = \sqrt{0} = 0$ (minimum)
# Range: $[0, 3]$
#
# c) Evaluate f(1, 2):
# $f(1, 2) = \sqrt{9 - 1^2 - 2^2} = \sqrt{9 - 1 - 4} = \sqrt{4} = 2$
#
# </details>

# %% [markdown]
# **Problem 13:**
#
# Consider the function
# $
# f(x,y) = \sqrt{9 - x^2 - y^2}.
# $
#
# 1. Determine the **domain** of $(f(x,y))$.
# 2. Determine the **range** of $(f(x,y))$.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **1. Domain**
#
# The square root requires the inside to be **nonnegative**:
#
# $
# 9 - x^2 - y^2 \ge 0
# $
#
# $
# x^2 + y^2 \le 9
# $
#
# This is the **closed disk of radius 3** centered at the origin.
#
# $
# \boxed{\text{Domain} = \{(x,y) : x^2 + y^2 \le 9\}}
# $
#
# **2. Range**
#
# Inside the square root, the smallest value is 0 (when $(x^2 + y^2 = 9)$) and the largest is 9 (when $(x = y = 0)$).
#
# So:
# - Minimum of $(f)$: $(\sqrt{0} = 0)$
# - Maximum of $(f)$: $(\sqrt{9} = 3)$
#
# $
# \boxed{\text{Range} = [0,\,3]}
# $
#
# The function describes the **upper hemisphere** of a sphere of radius 3.
#
# </details>

# %% [markdown]
# **Problem:f(x,y)=x+y**
#
# *[Create a problem about multivariable functions and understanding their domain and range.]*
#
# **Solution:any real number**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Domain:there are no restrictions on x or y so the domain is all real numbers
# Range: since x and y can be any real numbers, their sum can also be any real number]*
#
# </details>

# %% [markdown]
# **Problem 14:**
#
# *$f(x, y) = \sqrt{100 - x^2 - y^2}$ *
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *$$100 - x^2 - y^2 \ge 0$$
# $$100 \ge x^2 + y^2$$
# D = $$x^2 + y^2 \le 100$$
# min value has to be 0 cause squares and max is 10 because 10^2 is 100
# R = [0,10]*
#
# </details>

# %% [markdown]
# **Problem 15:**
#
# $f(x,y) = \sqrt{9-x^2-y^2}$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find domain and range]*
#
# $9-x^2-y^2 > 0$
#
# $x^2+y^2 < 9$
#
# domain: $x^2+y^2<9$
#
# range: $0<z<3$

# %% [markdown]
# **Problem 16:**
#
# Consider the function $f(x,y) = \sqrt{9 - x^2 - y^2}$. Find the domain and range of the function.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1 (Domain): Require the expression inside the square root to be nonnegative: $9 - x^2 - y^2 \ge 0$.
# Step 2: Rearranging gives $x^2 + y^2 \le 9$, which is all points inside or on a circle of radius 3.
# Domain: $\{(x,y) \mid x^2 + y^2 \le 9\}$.
#
# Step 3 (Range): The minimum value of the square root is $0$ (on the boundary), and the maximum is $\sqrt{9}=3$ at $(0,0)$.
# Range: $0 \le f(x,y) \le 3$.
# </details>

# %% [markdown]
# **Problem 17:**
#
# Consider the function: $f(x,y) = 2x^2 + xy -5$
# - (a) Determine the domain of $f(x,y)$
# - (b) Compute the value of the function at this point (3,-2)
# - (c) Describe the range of the function.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# - (a) Domain, This function is a polynomial in $x$ and $y$. Polynomials have no restrictions. So the domain is $R^2$ (all real pairs ($x$,$y$)).
# - (b) Evaluate at ($3, $-2)
# - $f(3, -2) = 2(3)^2 + (3) (-2) -5 = 2(9) - 6 - 5 = 18 - 6 - 5 = 7$
# - (c) Range, Because the function includes $2x^2$, which can grow arbitrarily large, there is no highest or lowest bound, so the range is $R$ (all real numbers).
#
#
#
# </details>

# %% [markdown]
# **Problem 18:** Find the Domain and Range
#
# $f(x,y)=\sqrt{9-x^2-y^2}$.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Domain:** All points (x,y) inside or on the circle of radius 3
#
# *$9-x^2-y^2$$\ge$0*
#
# *$x^2+y^2 \le 9$*
#
# *$x+y\le3$*
#
# **Range:**
#
# *$f(0,0) = \sqrt{9} =3$*
#
# *$0\le f(x,y)\le3$*
# </details>

# %% [markdown]
# **Problem:**
# Consider the function f(x,y)= √(4-(x^2)-y)
# Find the domain and range of the function.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
# Domain={(x,y):y≤4−x^2} Whats inside the square root must be nonnegative: 4-(x^2)-y≥0; y≤4-(x^2)
# This describes the region on or below the parabola:y=4-(x^2)
# Domain={(x,y):y≤4−x^2}
# Range-[0,∞): A square root can never give a negative number which means the smallest value of the function is 0. If we choose a very large negative value for y, then −y becomes a very large positive number. This means the function can produce any positive number, implying infnity.

# %% [markdown]
# **Problem 19:**
#
# *Consider the multivariable function*
# $$
# f(x,y) = \sqrt{4 - x^2 - y^2}.
# $$
# *(a) Find the domain of \(f\).
# (b) Find the range of \(f\). Explain your reasoning.*
#
# **Solution:**
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *To find the domain, we need the expression inside the square root to be nonnegative:*
# $$
# 4 - x^2 - y^2 \ge 0
# \iff x^2 + y^2 \le 4.
# $$
# *So the domain is*
# $$
# D = \{(x,y)\in \mathbb{R}^2 \mid x^2 + y^2 \le 4\},
# $$
#
# *To find the range, notice that for any point in the domain we have*
# $$
# 0 \le 4 - x^2 - y^2 \le 4.
# $$
# *Taking square roots gives*
# $$
# 0 \le f(x,y) = \sqrt{4 - x^2 - y^2} \le 2.
# $$
# *The maximum value \(2\) occurs at \((0,0)\), and the minimum value \(0\) occurs on the boundary where \(x^2 + y^2 = 4\).
# Therefore, the range is*
# $$
# \text{range}(f) = [0,2].
# $$
#
# </details>

# %% [markdown]
# **Problem 20:**
#
# * $f(x,y) = ln(9 - x^2 - y^2)$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# * Domain $ 9- x^2 - y^2 > 0$
#     * $ x^2 + y^2 < 9$
# * the domain is the interior of a circle of a radius 3, centered at the orgin
#
# * Range $ x^2 +y^2 , 9^-$
# * the inside of the log approaches $0^+$
# * $ln(9 - x^2- y^2) , -inf$
# * $f(0,0) = ln(9) = ln9$
# * Range: $(-inf, ln9)$
#
# </details>

# %% [markdown]
# **Problem 21:**
#
# Find the domain and range for the following function:
#
# $f(x,y) = \sqrt{9-x^2-y^2}$
#
# Solution:
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Domain:
#
# The square root cannot be negative, therefore we can set the inside of the square root, equal to or greater than 0.
#
# $9-x^2-y^2 \geq 0$
#
# $x^2 + y^2 \leq 0$
#
# Range:
#
# Since the function is valid where, $x^2 + y^2 = 9$, we must take the square root of this interval.
#
# $\sqrt{0}$ = $0$
#
# $\sqrt{9}$ = $3$
#
# Therefore, the range is $0 \leq f(x,y) \leq 3$
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[f(x,y)=x+y/x^2+y^2-9, find domain, range, find level curve c=1 ]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Domain: x^2+y^2-9 cannot equal zero --> x^2+y^2 cannot equal 9 --> (x,y): x^2+y^2 cannot equal 9, Range: since the denominator approaches 0, the value of function approaches +-oo.  (-oo,oo), set f(x,y)=1: 1=x+y/x^2+y^2-9,x^2+y^2-9=x+y, x^2-x+y^2-y-9=0, x^2-x=(x-1/2)^2-1/4, y^2-y=(y-1/2)^2=1/4, (x-1/2)^2+(y-1/2)^2=9.5 ]*
#
# </details>

# %% [markdown]
# **Problem 22:** $f(x,y)= sqrt(9-x^2-y^2)$
#
# *[Create a problem about multivariable functions and understanding their domain and range.]*
#
# **Solution:** Domain: All points (x,y) inside or on a circle of radius 3 centered at the origin
# Range: $0 (greater than or equal to) f(x,y) (greater than or equal to) 3$
#
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find domain and range]*
#
# $f(x,y)= sqrt{9-x^2-y^2}
# $9-x^2-y^2 (greater than or equal to) 0$
# $x^2+y^2 (greater than or equal to) 9%
#
# Min: $9-x^2-y^2=0$
# $f=0$
# Max:$x=0, y=0$
#  $0 (greater than or equal to) f(x,y) (greater than or equal to) 3$
#
#
# </details>

# %% [markdown]
# **Problem 23:**
#
# Find the domain and range of $g(x,y)=ln(x-y^2)$
#
# **Solution:**
#
# <details>can
# <summary><b>Click to reveal solution</b></summary>
#
# Find domain:
# On the natural log graph, there are only positive inputs
# $x-y^2>0 -> x>y^2$
#
# Find Range:
# Since $x>y^2$ can be any positive real number
# $(-\infty \,\infty)$
#
# </details>

# %% [markdown]
# **Problem 24:**
#
# *f(x,y)=9−x2−y2*
# - What is the domain of this function?
# - What is the range of this function?
# - Is the point (2,2) in the domain? Explain.
#
# **Solution:**
#
# $$\text{The function is } f(x,y) = \sqrt{9 - x^2 - y^2}$$
#
# $$\text{Because of the square root, the expression inside must be nonnegative}$$
#
# $$9 - x^2 - y^2 \ge 0$$
#
# $$x^2 + y^2 \le 9$$
#
# $$\text{So the domain is all points } (x,y) \text{ inside the circle of radius 3}$$
#
# $$\text{The maximum value of the function occurs when } x = 0, y = 0$$
#
# $$f(0,0) = \sqrt{9} = 3$$
#
# $$\text{The square root cannot be negative, so the minimum value is } 0$$
#
# $$\text{Thus the range is } [0, 3]$$
#
# $$\text{Check the point } (2,2):$$
#
# $$2^2 + 2^2 = 4 + 4 = 8 \le 9$$
#
# $$\text{Since } x^2 + y^2 \le 9 \text{ is true, the point (2,2) is in the domain}$$
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $$\text{We are given the function } f(x,y) = \sqrt{9 - x^2 - y^2}$$
#
# $$\text{To find the domain, we require the inside of the square root to be nonnegative}$$
#
# $$9 - x^2 - y^2 \ge 0$$
#
# $$x^2 + y^2 \le 9$$
#
# $$\text{So the domain is all points } (x,y) \text{ inside or on the circle of radius 3}$$
#
# $$\text{To find the range, we note that } f(x,y) = \sqrt{9 - x^2 - y^2} \ge 0$$
#
# $$\text{The smallest possible value is } 0$$
#
# $$\text{The largest value occurs when } x = 0,\, y = 0$$
#
# $$f(0,0) = \sqrt{9} = 3$$
#
# $$\text{So the range is } [0,3]$$
#
# </details>

# %% [markdown]
# **Problem 25:**
#
# $f(x,y)=\sqrt{16-x^2-y^2}$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **1. Find the domain**
#
# $16-x^2-y^2\ge0$
#
# $16\ge x^2+y^2$
#
# $x^2+y^2\le16$
#
# **Domain:** ${(x,y)|x^2+y^2\le16}$
#
# **2. Find the Range**
#
# $f(x,y)=\sqrt{16-x^2-y^2}$
#
# -Since the square root is always non-negative, the smallest possible value for $z$ occurs when the expression under the root is maximmized
#
# -The largest value of $16-x^2-y^2$ takes place when $x^2+y^2$ is minimmized at $x=0$ and $y=0$
#
# $z_{max}=\sqrt{16}=4$
#
# $z_{min}\sqrt{16-16}=0$
#
# **Range** $[0,4]$
# </details>

# %% [markdown]
# ## Sample Problem 5.1a: Multivariable Functions
#
# **Problem 26:**
#
# Consider the function
# $$f(x,y) = \sqrt{16 - x^2 - y^2}.$$
#
# a) Find the domain of $f$.
# b) Find the range of $f$.
# c) Is the point $(3,1)$ in the domain? What about $(4,3)$?
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **a) Domain**
#
# The expression inside the square root must be nonnegative:
#
# $$16 - x^2 - y^2 \ge 0 \quad\Longrightarrow\quad x^2 + y^2 \le 16.$$
#
# So the domain is all points $(x,y)$ in the plane with $x^2 + y^2 \le 16$.
# Geometrically, this is the disk of radius 4 centered at the origin (including the boundary circle).
#
# ---
#
# **b) Range**
#
# Inside the square root we have $16 - x^2 - y^2$.
#
# From the domain condition $x^2 + y^2 \le 16$, the smallest value of $16 - x^2 - y^2$ is $0$ (when $x^2 + y^2 = 16$), and the largest value is $16$ (when $x^2 + y^2 = 0$).
#
# So:
#
# - Minimum inside the root: $0 \Rightarrow f(x,y) = \sqrt{0} = 0$.
# - Maximum inside the root: $16 \Rightarrow f(x,y) = \sqrt{16} = 4$.
#
# Therefore, the range is
#
# $$0 \le f(x,y) \le 4,$$
#
# or in interval notation: $[0,4]$.
#
# ---
#
# **c) Checking specific points**
#
# - For $(3,1)$:
#
#   $$3^2 + 1^2 = 9 + 1 = 10 \le 16,$$
#
#   so $(3,1)$ is in the domain.
#
# - For $(4,3)$:
#
#   $$4^2 + 3^2 = 16 + 9 = 25 > 16,$$
#
#   so $(4,3)$ is not in the domain (it would make the square root negative).
#
# </details>

# %% [markdown]
# **Problem 27:**
#
# Let $f(x,y) = \sqrt{10 - x - y}$.
#
# Describe the domain of $f(x,y)$.
#
# Describe the range of $f(x,y)$.
#
# Solution:
# <details> <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Find the domain.
#
# Since the square root requires a nonnegative expression, we must have:
#
# $10 - x - y \ge 0$
#
# Rewrite:
#
# $x + y \le 10$
#
# So the domain is all points $(x,y)$ such that:
#
# $x + y \le 10$
#
# This describes a region in the $xy$-plane below and including the line $x + y = 10$.
#
# Step 2: Find the range.
#
# The smallest value of $f(x,y)$ happens when the expression inside the square root is $0$:
#
# $10 - x - y = 0$
# $f(x,y) = 0$
#
# There is no upper limit on $10 - x - y$, so the square root can grow without bound.
#
# So the range is:
#
# $f(x,y) \ge 0$
#
# Final Answer:
# Domain: $x + y \le 10$
# Range: $f(x,y) \ge 0$
#
# </details>

# %% [markdown]
# **Problem 28:**
#
# Consider the function
# $$
# f(x, y) = \sqrt{9 - x^2 - y^2}.
# $$
# 1. Find the domain of the function.
# 2. Find the range of the function.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
# Step 1: Find the domain
# The square root requires the inside to be nonnegative:
# $9 - x^2 - y^2 \ge 0$
# Rearrange:
# $x^2 + y^2 \le 9$
# So the domain is all points \((x, y)\) inside or on the circle of radius 3:
# \[\text{Domain} = \{(x, y) : x^2 + y^2 \le 9\}.\]
#
#   Step 2: Find the range
# The expression inside the square root varies between:
# -maximum when \(x^2 + y^2 = 0\):
# \[f(0,0) = \sqrt{9} = 3\]
# -minimum when \(x^2 + y^2 = 9\):
# \[f = \sqrt{0} = 0\]
# Since the square root outputs all values between 0 and 3:
# \[\text{Range} = [0, 3]\]
#
# Final Answer:
# - Domain:
#   \[\{(x, y): x^2 + y^2 \le 9\}\]
# - Range:
#   [0, 3]
#
# </details>

# %% [markdown]
# **Problem 29:**
#
# Consider the function: $f(x, y) = \sqrt{9 - x^2 - y^2}$\
# 1. Determine the domain of f.\
# 2. Determine the range of f.
# 3. Explain in words what the domain and range represent for this function.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Step 1: Domain\
# $9 - x^2 - y^2 \ge 0 \implies x^2 + y^2 \le 9$ \
# Domain: $\{(x, y) \in \mathbb{R}^2 \mid x^2 + y^2 \le 9\}$
#
#
# Step 2: Range\
# 0 \le f(x, y) \le 3\
# Range: [0, 3]
#
# Step 3: Interpretation
# - Domain: all points (x, y) inside or on the circle of radius 3 centered at the origin.
# - Range: all function outputs from 0 to 3, where 3 occurs at the center (0,0) and 0 occurs on the boundary of the circle.
#
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Find the Domain and Range of the following function:
# $f(x,y)=\sqrt{x^2-2y}$ ]*
#
# **Solution: $x^2-2y >=0$ **
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[We can't have negative numbers under a square root so $x^2-2y$ has to be greater than $0$]*
#
# </details>

# %% [markdown]
# **Problem 30:**
#
# Find the Domain and Range of
#
# $$f(x,y,z)=$$ $$\frac {\sqrt{7z-28}}{16x^2 -y^2}$$
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1) Find Domain
# - Identify that the value in the square root and the denominator don't equal zero.
#
# $$7z-28 \geq 0$$
# $$7z \geq 28$$
# $$ z \geq 4$$
#
# $$and$$
#
# $$16x^2 - y^2 \ne 0$$
# $$so$$ $$Domain: (x,y,z)$$ ***is all real numbers but*** $$z \geq 4 and 16x^2 - y^2 \ne 0$$
#
# Step 2) Find the Range
# -  Solve for all possible outputs, but this equation, since it has a square root inside a fraction, we use u-sub
#
# $$u=\sqrt{7z-28} , u \geq 0$$
# $$ v = 16x^2 -y^2 \ne 0$$
# - so find possible outcomes of $u/v$, and since $u/v$ can equal any numbers, then the range is all real numbers.
#
#
#
# </details>

# %% [markdown]
# **Problem 31:**
#
# *[Consider the multivariable function  f(x, y) = \sqrt{4 - x^2 - y^2} .
#
# 1. Determine the domain of  f(x, y) .
#
# 2. Determine the range of  f(x, y) .]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[1. Domain:
# The square root requires the expression inside to be non-negative:
#
# 4 - x^2 - y^2 \geq 0 \implies x^2 + y^2 \leq 4
#
# The domain is all points  (x, y)  lying on or inside the circle of radius 2 centered at the origin (a subset of  \mathbb{R}^2 ).]*
#
# </details>

# %% [markdown]
# **Problem 32:**
#
# *Consider this Multivariable Function:* *$$f(x,y)=\frac{x+y}{4-x^{2}}$$*
# - 1. Find the domain of f(x,y).
# - 2. Find the range of f(x,y).
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# - 1. Domain
# *$$4-x^{2} \neq 0$$* *$$=$$*
# *$$x^{2}\neq4$$* , *$$x\neq2$$* *$$x\neq-2$$*
# Domain = all (x, y) such that *$$x \neq 2$$* and *$$x \neq -2$$*
#
# - 2. Range
# *Using a simple value of x, x=0* *$$f(0,y)=\frac{0+y}{4-0^{2}} = \frac{y}{4}$$*
# *Given any real number, z* *$$z=\frac{y}{4}$$* *$$=$$* *$$y=4z$$*
# For every real number z, if using x=0 and y=4z : * *$$f(0,4z)=z$$*
# Range = *$$(-\infty,\infty)$$*
#
#
#
# </details>

# %% [markdown]
# **Problem 33:**
#
# *Function:
# f(x, y) = 10 - x² - y²
#
# Question:
# Find the domain and the range of this function.*
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Solution:
#
# Domain: x and y can be any real numbers because there’s no square root or division by zero.
#
# Range:
#
# Maximum occurs at x = 0, y = 0 → f(0,0) = 10
#
# As x² + y² gets bigger, f(x,y) gets smaller → goes to -∞
#
# So range is (-∞, 10]*
#
# </details>

# %% [markdown]
# **Problem 34:**
#
#
# $$f(x, y) = \sqrt{9 - x^2 - y^2}$$
#
# find the domain and range
#
# **Solution:**
#
# At (0,0) = $\sqrt{9 - 0 - 0}$ = 3
#
# At (3,0) = $\sqrt{9 - 9 - 0}$ = 3
#
# At (2,2) = $\sqrt{9 - 4 - 4}$ = 1
#
# $x^2 + y^2 \le 9$
#
# $0 \le f(x, y) \le 3$

# %% [markdown]
# **Problem 35:**
#
# Find the domain and range of the function
# $f(x,y) = \sqrt{9 - x^2 - y^2}.$
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Finding the domain:**
# The square root must not have a negative value inside of it, so we need to make sure that $9 - x^2 - y^2 ≥ 0$.
#
# So our demain is all $(x,y)$ satisfying $9 ≥ x^2 + y^2$
#
# **Finding the range:**
# To find the range, look at the expression under the square root: $9 − x^2 − y^2$
#
# This is largest when $x^2 + y^2$ is smallest, giving a
# maximum value of $\sqrt{9} = 3$
#
# It is smallest when $x^2 + y^2$ is largest, giving a
# minimum value of $\sqrt{0} = 0.$
#
# So the range is [0, 3].
#
# </details>

# %% [markdown]
# **Problem 36:**
#
# Consider the multivariable function
# $$f(x, y) = \sqrt{9 - x^2 - y^2}.$$
#
# 1. Find the domain of the function.
# 2. Find the range of the function.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $$f(x, y) = \sqrt{9 - x^2 - y^2}.$$
#
# The expression inside the square root must be **nonnegative**:
#
# $$9 - x^2 - y^2 \ge 0$$
#
# Rearrange:
#
# $$x^2 + y^2 \le 9$$
#
# **Domain:**
# All points inside or on the circle of radius 3 centered at the origin.
#
# Since
# $$f(x, y) = \sqrt{9 - x^2 - y^2}$$
#
# - The smallest value occurs when the inside is $0$:
#   $$f = 0$$
#   (on the boundary where $x^2 + y^2 = 9$)
#
# - The largest value occurs at the center:
#   $$f(0,0) = \sqrt{9} = 3$$
#
# **Range:**
# $$0 \le f(x, y) \le 3$$
#
# **Final Answer**
# - **Domain:** the filled circle $x^2 + y^2 \le 9$
# - **Range:** $[0, 3]$
#
# </details>

# %% [markdown]
# **Problem 37:**
#
# f(x,y) = 1/x+y, Find Domain and Range
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Domain: x+y ≠ 0 , (-oo,0)(0,oo)
# Range: f(x,y) ≠ 0
#
# </details>

# %% [markdown]
# **Problem 38:**
#
# *[f(x,y) = root(4-x^2-y^2 Please determine the domain and range of the function. describe the level curves of the function.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Domain = 4-x^2-Y^2 greater than 0 which equals x^2 + y^2 is less than or equal to 4. The domain is all points inside or on a circle of radius 2 centered at the origin. Domain is x,y|x^2 + y^2 less than 4
# Range is when f(0,0) = root 4 = 2 range is 0 less than or equal to f(x,y) less than or equal to 2.
#
# Level curves when root 4- x^2 -y^2 = c so you square both sides so you get x^2 + y^2 =4 -c^2. The level curves are circles of radius = root 4-c^2]*
#
# </details>

# %% [markdown]
# **Problem 39:**
#
# *[$f(x, y) = √(x + 4y)$]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Domain:**
# - $x+4y≥0$ Square root = inside must be ≥ 0
#
# **Solution**
# - ${(x,y)∣x+4y≥0}$
#
# **Range**
# - $√(x+4y)≥0$ Square root = always outputs non-negative values
# - Smallest value = √(0) = 0
#
#  **Solution**
# - No upper bound so range = $[0,∞)$
# </details>

# %% [markdown]
# **Problem 40:**
#
# Consider the function:
#
#   $f(x, y) = \sqrt{9 - x^2 - y^2}$
#
# Find the domain and range.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Part 1: Domain** For the squre root to be defined, the expression inside must be non-negative:
#
# $9 - x^2 - y^2 \ge 0$
#
# Rearranging the inequality:
#
# $9 \ge x^2 + y^2$
#
# or
#
# $x^2 + y^2 \le 9$
#
# This inequality escribes a filled in circlecentered at the origin $(0,0)$ with a radius of 3
#
#     - Domain:
#         the set of all points $(x,y)$ inside and on the boundry line
#
#
# **Part 2: Range** We know that the squareroot function produces non-negative values.
#
# - The smallext value occurs when $x^2 + y^2 = 9$ , so $f(x,y) = \sqrt {0} = 0$
#
# - The largest value occurs when $x = 0$ any $y = 0$ , so $f(0,0) = \sqrt {9} = 3$
#
#     - Range:
#
#         $0 \le z \le 3$ or in interval notation as $[0,3]$
# </details>

# %% [markdown]
# **Problem 41:**
#
# f(x,y) = sqrt(9-x^2-y^2)
# 9-x^2-y^2 (greater than or equal to) 0
# x^2 + y^2 (less than or equal to) 9
# domain  = (x,y) E R^2 : x^2 + y^2 less than or equal to 9
# range = [0,3]
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find domain and range]*
#
# </details>

# %% [markdown]
# **Problem 42:**
#
# Consider the function
# $$
# f(x, y) = \sqrt{9 - x^2 - y^2}.
# $$
# 1. Find the **domain** of \(f(x, y)\).
# 2. Determine the **range** of \(f(x, y)\).
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Domain:**
# The expression inside the square root must be nonnegative:
# $$
# 9 - x^2 - y^2 \ge 0.
# $$
# So the domain is all points inside (and on) the circle
# $$
# x^2 + y^2 \le 9.
# $$
#
# **Range:**
# The square root output satisfies
# $$
# 0 \le f(x, y) \le 3,
# $$
# because the smallest the expression inside the root can be is 0, and the largest is 9.
#
# So the range is
# $$
# [0,\, 3].
# $$
#
# </details>

# %% [markdown]
# **Problem:**
#
# *[Create a problem about multivariable functions and understanding their domain and range.]*
#
# f(9x,y) = ln (4-x^2 - y^2 ) + 1 / squared x+y
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find domain and range]*
#
# part a: domain
#
# step 1 identify restrictions from each part of funcation
#
# first term: ln(4-x^2-y^2)
#
# for the natural logarithm to be defined:
#
# 4-x^2 -y^2 > 0
#
# x^2 + y^2 < 4
#
#
# second term: 1/ squared x + y
#
# for this to be defined:
#
# 1. the square root requires: x + y > 0
# the denominator cannot be zero : x + y does not equal 0
# coming : x+ y > 0
#
# step 2: combine restriction
#
# we need points satisfying both condtions :
#
# inside circle: x^2 + y^2 < 4
#
# above line : x + y > 0
#
# domain = {(x,y) | x^2 + Y^2 < 4 and x + y > 0}
#
# Range:
#
# step 1: analyze the behavior of first term ln ( 4- x^2 - y^2)
#
# since 0 < 4 - x^2 - y^2 < 4 in the domain:
#
# as x^2 + y^2 = 4^- (approach boundary circle): 4-x^2 - y^2 = 0^+ = ln(small postive) = -∞
#
# part B : 1/ squared x+ y
#
# this depends on x + y
#
# when x + y is tiny (close to 0):  squared x+ y tiny  = 1 / tiny = huge (∞)
#
# when x+y is large : squared x+ y large = 1/ large = small (close to 0 )
#
# our domain restricts x + y > 0 and inside circle x^2 + y^2 < 4
#
# max x+y inside circle ? at boundary point (sqaured 2 , sqaured 2) : x + y = 2 squared 2 = 2.828
#
# so x + y ranges from just above 0 to 2.828
#
# therefore:
#
# Minimum 1 / squared  x + y = 1/ sqaured 2.828 = 0.595
#
# Max = ∞ (as x + y = 0^postive)
#
# range : (-∞, ∞)
#
# </details>

# %% [markdown]
# **Problem 43:**
#
# *$f(x,y)=x^{3}-3xy+y^{3}$*
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **Solution:**
#
# (0, 0) is a saddle point.
# (1, 1) is a local minimum.
#
# $f_{x}(x,y)=\frac{\partial f}{\partial x}=3x^{2}-3y$
#
# $f_{y}(x,y)=\frac{\partial f}{\partial y}=-3x+3y^{2}$
#
# $f_{xx}=\frac{\partial ^{2}f}{\partial x^{2}}=6x$
#
# $f_{yy}=\frac{\partial ^{2}f}{\partial y^{2}}=6y$
#
# $f_{xy}=\frac{\partial ^{2}f}{\partial x\partial y}=-3$
#
# $D(x,y)=(6x)(6y)-(-3)^{2}=36xy-9$
#
# *[Show how to find domain and range]*
#
# </details>

# %% [markdown]
# **Problem 44:**
#
# *Find the domain and range of $$f(x,y) = \sqrt(9-x^2 - y^2)$$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Domain: for the square root to be defined, the expression must not be negative
#
# $$ 9-x^2 - y^2 >= 0 $$
#
# $$ x^2 - y^2 <= 9 $$
#
# so the domain is all points (x,y) that $$ x^2 - y^2 <= 9 $$
#
# Range: the square root function outputs value greater than or equal to zero, therefore the maximum value occurs when x^2 and y^2 are at their minimums (0,0) and is at the minimum value when x^2 + y^2 = 9
#
# $$f(0,0)=\sqrt(9-0-0) = 3$$
#
# so the Range is [0,3]
# </details>

# %% [markdown]
# **Problem 45:**
#
# $f(x,y) = x^3 -2y + 4$ Evaluate $f(1,2)$ and $f(3,1)$. Find the domain and range of f.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $f(1,2) = (1)^3 - 2(2) + 4 => 1-4+4 = 1 \hspace{1.0cm}$ Domain: All real pairs. D of f is $\mathbb{R}^2$
#
# $f(3,1) = (3)^3 - 2(1) + 4 => 27+2+4 = 29 \hspace{1.0cm}$ Range: All real numbers. R of f is $\mathbb{R}$
#
# </details>

# %% [markdown]
# **Problem 46:**
#
# $f(x,y)= \sqrt{9-x^2-y^2}$
#
# **Solution:**
#
# -Domain: $x^2-y^2 \le 9$
#
# -Range: $0 \le f(x,y) \le 3$
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Finding Domain:
#
# 1. Set up the condition: $9-x^2-y^2 \ge 0$
#
# 2. Rearrange it: $x^2+y^2 \le 9$
#
# Finding Range:
#
# 1. Look at the smallest and largest values: $x=y=0$
#
# $= \sqrt{9-0-0} = \sqrt{9} = 3$
#
# 2. The outputs go from 0 up to 3(range): = $0\le f(x,y) \le 3$
# </details>

# %% [markdown]
# **Problem:**
#
# *$\ f(x, y) = \sqrt{9 - x^2 - y^2}\ $* where (x) and (y) are real numbers. Find the domain and range of f(x,y).
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1 find domain: *$\ 9 - x^2 - y^2 \ge0\ $*        ->     *$\ x^2 + y^2 \le9\ $*   , domain all real numbers so, *$\ x^2 + y^2 \le9\ $*
#
# Step 2 find the range: *$\ f(x, y)_{\min} = 0\ $*
# then, f(0,0) = *$ \sqrt{9 - 0 - 0} = 3 \ $*  =  [0,3]
#
#
# **solution:**
#
# domain: *$\{(x, y) \in \mathbb{R}^2 \mid x^2 + y^2 \le 9\}\$*
#
#
# range: *$\ f(x, y) \in [0, 3]\ $*
#
#
# </details>

# %% [markdown]
# **Problem 47:**
#
# *![image.png](attachment:4bbb7901-7603-44d5-bb62-e704c198b3bf.png)*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *![image.png](attachment:3be2911a-c263-4e8c-8b58-9c413ea20ad9.png)*
#
# </details>

# %% [markdown]
# **Problem 48:**
#
# $f(x,y) = \sqrt{9 - x^2 - y^2}$
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find domain and range]*
#
# Domain:
#
# $9-x^2-y^2 >=$(more than or equal to) $0$
#
# $x^2-y^2 >=$(less than or equal to) $9$
#
# {(x,y) | $x^2 + y^2$ <=(less than or equal to) 9}
#
# Range:
#
# Minimum: $x^2 +y^2 = 0 => f(x,y) = \sqrt 0 = 0$
#
#
# Maximum: $x^2 +y^2 = 9 => f(x,y) = \sqrt 9 = 3$
#
# $[0,3]$
#
#
# </details>

# %% [markdown]
# **Problem 49:**
#
# *[Consider the function   f(x,y)=x^2 + 3y   … plug in x = 2 and y = -1 ]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[f(2,-1) = 2^2 + 3(-1) = 1          … plug in x = 0, y = 4 \
# f(0,4) = 2^0 + 3(4) = 12]*
#
# </details>

# %% [markdown]
# **Problem 50:**
#
# Let f(x,y) = x^2 + 3y.
# Find the domain and the range of this function.
#
# **Solution:**
#
# The formula x^2 + 3y works for all real x and all real y, so the domain is all pairs (x,y).
# To find the range, we know that x^2 is always greater than or equal to 0 and 3y can be any real number.
# By choosing large positive or negative values of y we can make the output as large or small as we want.
# So the range is all real numbers.

# %% [markdown]
# **Problem 51:**
#
# *[$f(x, y) = \sqrt{9 - x^2 - y^2}$. Find domain and range.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Domian:]*
#
# *[$9 - x^2 - y^2 >= 0$]*
#
# *[$x^2 + y^2 <= 9$]*
#
# *[Range:]*
#
# *[$0 <= f(x, y) <= 3$]*
#
# </details>

# %% [markdown]
# **Problem 52:**
#
# Find the domain and range of $f(x,y)=\sqrt{x^2+y^2}$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Domain: We know that the domain for $f(x)=\sqrt{x}$ can't be negative. The same thing applies for $f(x,y)=\sqrt{x^2+y^2}$. However, since both x and y are squared, they are never negative, which means our domain is all real numbers or $(-\infty, \infty)$.
#
# Range: For $f(x)=\sqrt{x}$, our output/range is always zero or greater. This is the same for $f(x,y)=\sqrt{x^2+y^2}$. So our range is $[0,\infty)$.
#
# </details>

# %% [markdown]
# **Problem:**
#
# $f(x,y)=x\sqrt{y}$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# $\sqrt{y}$ cannot be less than 0 because that makes it undefined. But x can be anything. Therefore, domain is y>=0 and range is all real numbers because of x.$
#
# </details>

# %% [markdown]
# **Problem 53:**
#
# *[Consider the function
# $\displaystyle f(x, y) = \ln(x) + y^2.$
#
# 1. Find the **domain** of $f(x, y)$.
# 2. Find the **range** of $f(x, y)$.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[**Step 1: Find the domain**
#
# The only restriction comes from $\ln(x)$:
#
# - For $\ln(x)$ to be defined, we must have $x > 0$.
# - There is **no restriction** on $y$ (any real number works).
#
# So the **domain** is
#
# $D = \{(x, y) : x > 0,\; y \in \mathbb{R}\}$
#
# In interval notation for each variable:
#
# - $x \in (0, \infty)$
# - $y \in (-\infty, \infty)$
#
#
# **Step 2: Find the range**
#
# - $\ln(x)$ can take **any real value** as $x$ runs over $(0, \infty)$.
# - $y^2 \ge 0$ for all $y$.
#
# Since $\ln(x)$ can be very negative or very positive, and we can add any nonnegative number $y^2$, the sum $\ln(x) + y^2$ can be **any real number** as well.
#
# So the **range** is
#
# $R = (-\infty, \infty)$
#
# </details>

# %% [markdown]
# **Problem 54:**
#
# f(x, y) = sqrt (9 - x^2 - y^2)
# **Solution:**
#
# Domain: x^2 + y^2 less than or equal to 9
# Range: 0 less than or equal to f(x, y) less than or equal to 3
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Domain: (x, y) = x^2 + y^2 < 9
#
# Range: f(x, y) = c
#
# - Maximum occurs when x^2 + y^2 = 0
#
# - f(0, 0) = sqrt 9 = 3
#
# - Minimum occurs when inside the root is 0 (on the boundary x^2 + y^2 = 9) =
#
# - f = 0
#
# </details>

# %% [markdown]
# **Problem 55:**
#
# Consider the function $$f(x,y)= \sqrt{9-x^2-y^2}$$
#
# **1.** Describe the Domain of the function.
#
# **2.** Find the Range of the function.
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# **1.** **Domain**
#
# Because of the square root, the expression inside must be nonnegative:
#
#  $$9-x^2-y^2 \ge 0$$
#
#  $$x^2 + y^2 \le 9$$
#
#  So the domain is all points inside or on a circle of radius 3 in the $xy$-plane.
#
# **2.** **Range**
#
# The smallest value inside the square root is $0$ (on the boundary $x^2 + y^2 =9$), and the largest value occurs at $(x,y)=(0,0)$:
#
# $$f(0,0)= \sqrt 9 =3$$
#
# Therefore the Range is
#
# $$0 \le f(x,y) \le 3$$
#
# </details>

# %% [markdown]
# **Problem 56:**
#
# *Consider the function
# \[
# f(x, y) = \sqrt{x + y}.
# \]
#
# 1. Find the **domain** of the function.
# 2. Find the **range** of the function.
# *
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
# **Domain: **
# \[
# x + y \ge 0.
# \]
# All pairs \((x, y)\) such that \(x + y \ge 0\).
#
# **Range:**
# \[
# \sqrt{0} = 0.
# \]
# There is **no largest value** because \(x + y\) can be as big as we want.
# \[
# [0,\ \infty)
# \]
# </details>

# %% [markdown]
# **Problem 57:**
#
# *[  $f(x,y)=(16-x^2-y^2)^.5$   ]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[ **Step 1**
#
# Solve for domain:
#
# We need the square root to be defined
#
# $(16-x^2-y^2)^.5\ge0$
#
# $16≥x^2+y^2$
#
# Domain: $x^2+y^2\le16$]*
#
# **Step 2**
#
# Solve for Range:
#
# $(16-x^2-y^2)^.5=c$
#
# $16-x^2-y^2=c^2$
#
# $16-c^2=x^2+y^2$
#
# $0≤16-c^2≤0$
#
# $4≥c≥0$
#
# Range:[0,4]
#
#
# </details>

# %% [markdown]
# **Problem 58:**
#
# A bag maker, makes two bags, the hermis and the kally. With the monthly cost for producing them is the following function:
#
# f(x,y)= 2x + 3y +5
#
# With x representing the amount of hermis bags made and y  the amount of kally bags made. Using this information, find the domain utilizing x and y values, and range utilizing the domain!
#
# **Solution: Domain = $(x,y): x≥0, y≥0$.
#  Range = $f(x,y): f(x,y) ≥ 5 $**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# 1. To find domain, start by understanding that since the bags are products that are made they cannot be negative! Which means that the domain for both x and y can start at 0, and be infinite with respect to the function's story paramters,
# Domain = $(x,y): x≥0, y≥0$
#
# 2. To find range, knowing that at (0,0) our base value would be 5, 5 would be the starting point and since no negative bags can be made the range would start at 5 and be infinite. Since 5 is the lowest cost possible! Resulting in,
#  Range = $f(x,y): f(x,y) ≥ 5 $
# and or can be written as $[5, \infty)$

# %% [markdown]
# **Problem 59:**
#
# *[P(x,y)=5x+3y]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[For domain find all the possible inputs for x and y.For range find all the possible outputs]*
#
# </details>

# %% [markdown]
# **Problem 60:**
#
# *[Create a problem about multivariable functions and understanding their domain and range.]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Show how to find domain and range]*
#
# </details>

# %% [markdown]
# **Problem 61:**
#
# *[f(x,y)= square root of 4-x^2 - y^2.]*
#
# **Solution:**
#   1. Domain: 4-x^2
# - y^2 ≥0⇒x2+y2≤4.
#     Range: x=0,y=0⇒f(0,0)=4
# ​=2
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[1. Domain: 4-x^2
# - y^2 ≥0⇒x2+y2≤4.
#     Range: x=0,y=0⇒f(0,0)=4
# ​=2]*
#
# </details>

# %% [markdown]
# **Problem 62:**
#
# $$f(x,y)= sqrt(9-x^2-y^2)$$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# How to find doman and range using the function above
#
# **Domain**
# Step 1:
# - Take the function (minus the square root) and put it euqal to 0--> $9-x^2-y^2>=0$
#
#
# Step 2:
# - Then isolate both the varriables to one side of the equation--> $x^2+y^2<=9$
#
# Step 3:
# - Since we have a square root, the expression inside can't be negative, so $x^2+y^2<=9$
#
# **Range**
# Step 1:
# - The range is the set of possible values in f(x,y) so we can infer that:
#
# - the smallest value inside the square root is 0
#
# - the largest value inside the square root is 9 (when x and y are both 0)
#
# - f(minimum):square root 0=0
#
# - f(maximum):square root 9=3
#
# - So the range is R=[0,3]
#
# </details>

# %% [markdown]
# **What are multivariable functions?**
#
# *[Multivariable functions are functions that depend on two or more input variables]*
#
# **Examples from economics:**
#
# *[1. Total revenue R(p,q) price x quantity
# 2. Total cost C(x,y) x = units of product a, y = units of product b, C= total cost]*
#
# **Domain and range:**
#
# *[Domain: what combinations of (x,y) are allowed (input)
# Range: what z-values are possible (output)]*
#
# **Level curves:**
#
# *[A level curve connects all points where a function has the same output value ]*
#
# ?**
#
# *[Multivariable functions are functions that depend on two or more input variables]*
#
# **Examples from economics:**
#
# *[1. Total revenue R(p,q) price x quantity
# 2. Total cost C(x,y) x = units of product a, y = units of product b, C= total cost]*
#
# **Domain and range:**
#
# *[Domain: what combinations of (x,y) are allowed (input)
# Range: what z-values are possible (output)]*
#
# **Level curves:**
#
# *[A level curve connects all points where a function has the same output value ]*
#
# ### Sample Problem 5.1a: Multivariable Functions
#
# **YOUR TASK:** Create a basic problem exploring multivariable functions

# %% [markdown]
# **Problem 63:**
#
# *[C(b,a) = 12p +3a
# b = number of burgers
# a = number of apple juices
# C = total cost in dollars
# What is the domain of this function. If you must buy at least 2 burgers and at least 2 apple juices, what is the restricted domain?]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[Domain:you can't buy negative quantities. b & a are greater than or equal to 0 for domain.
# Range: b & a are greater or equal to 2 since you need at least 2 of each item. ]*
#
# </details>

# %% [markdown]
# **Problem**
#
# **Step 1: Determine when the function is defined**
#
# **We are given the function**
#
# $$ f(x,y) = \ln(4 - x^{2} - y) $$
#
# **The natural logarithm is only defined when its input is strictly positive.**
#
# **So we require**
#
#
# $$ 4 - x^{2} - y > 0 $$
#
#
# **This inequality tells us which points $(x,y)$ are allowed.**
#
#
# **Step 2: Solve the inequality (find the domain)**
#
# **Starting from**
#
# $$ 4 - x^{2} - y > 0 $$
#
# **solve for $y$:**
#
#
# $$ -x^{2} - y > -4 $$
#
#
# $$ -y > -4 + x^{2} $$
#
#
# **Multiply both sides by $-1$ (and reverse the inequality):**
#
#
# $$ y < 4 - x^{2} $$
#
#
# **Therefore, the domain is:**
#
# $$ (x,y) in \mathbb{R}^{2} : y < 4 - x^{2}\} $$
#
#
# **This means all points below the parabola $y = 4 - x^{2}$.**
#
#
#
# **Step 3: Find the range**
#
# **Let:**
#
# $$ u = 4 - x^{2} - y. $$
#
# **From the domain, we know that $u>0$.**
#
# **As $y$ approaches the boundary $y = 4 - x^{2}$ from below,**
#
#
# **As** $$y \to -\infty $$
#
#
# $$ u = 4 - x^{2} - y \to +\infty \quad \text{and} \quad \ln(u) \to +\infty. $$
#
#
# **So the function takes every real value.**
#
# **Thus, the range is**
#
# $$ (-\infty,\, \infty) $$
#
# **Final Answers:**
#
# **Domain:** $$ \{(x,y)\in\mathbb{R}^{2} : y < 4 - x^{2}\} $$
#
#
# **Range:** $$(-\infty,\, \infty) $$

# %% [markdown]
# **Problem 64:**
#
# *f(x,y)=ln(4-x-2y)*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# - 4-x-2y>0
# - x+2y<4 so $D= (x,y) ∈ R^2 : x+2y<4$
# - f(x,y) = $lnu$ so ranges over $(-inf, inf)$
#
# </details>

# %% [markdown]
# **Problem 65:**
#
# f(x,y)= 5x+2y
# **Solution:**
#
# Domain and range are all real values there are no square roots or aything preventing and inputs or outputs
#
# so it is all real numbers for each
#
#
# </details>

# %% [markdown]
# **Problem 66:**
#
# f (x, y) = 4x2+ 2xy - 8x + 5. Evaluate this function at the point (1, 2).
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
#
# Work:
#
# Step 1: plug in the respective x and y value into this function.
#
# => f (1,2) = 4(1)2+ 2(1)(2) - 8(1) + 5
#
# => f (1,2) = 4 + 2 - 8 +5
#
# Solution:
#
# f (1, 2) = 3
#
#
# </details>

# %% [markdown]
# ### Sample Problem 5.1a: Multivariable Functions

# %% [markdown]
# **Problem 67:**
#
# *$f(x, y) = \sqrt{9 - x^2 - y^2}$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
# Domain: Expression must be non negative
#
# $9 - x^2 - y^2 \ge 0$
#
# $x^2 + y^2 \le 9$
#
# Domain is a disc with a radius of 3 centered at:
#
# $(x,y) : x^2 + y^2 \le 9$
#
# Range:
#
# - The minimum value is $0$, which occurs when $x^2 + y^2 = 9$.
# - The maximum value is $3$, which occurs at $(0,0)$.
# so Range = $(0,3)$
#
# </details>

# %% [markdown]
# **Problem 68:**
#
# *Consider the production function $f(x, y) = \sqrt{16 - x^2 - y^2}$.
# 1. Describe and sketch the domain of this function.
# 2. What is the range?*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *1. Domain  For the square root to be defined, the term inside must be non-negative:$$16 - x^2 - y^2 \ge 0$$$$16 \ge x^2 + y^2$$This describes a solid disk in the $xy$-plane centered at $(0,0)$ with a radius of 4. The domain includes the interior and the boundary of this circle.
# 2. Range
# - The maximum value occurs at $(0,0)$, where $f(0,0) = \sqrt{16} = 4$.
# - The minimum value occurs at the boundary where $x^2 + y^2 = 16$, so $f(x,y) = 0$.
# - Range: $[0, 4]$.*
#
# </details>

# %% [markdown]
# **Problem 69:**
#
# f(x,y) = sqrt(16-x^2-y^2)
# determine the domain and range
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Domain: 16 - x^2 - y^2 >= 0 --> x^2 + y^2 <= 16
#
# the domain is all (x,y) inside or on the circle of radius 4
#
# Range: f(0,0) = sqrt(16) = 4
# f = sqrt(0) = 0
#
# range is 0 <= f(x,y) <= 4
#
# </details>

# %% [markdown]
# **Problem 70:**
#
# *Find the domain and range of $f(x,y) =$ square root of $(16 - x^2 - y^2)$*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *First we find the domain by looking at the right side of the equation and get the square root of $(16 - x^2 - y^2)$ whose solution cannot be negative due to the nature of square roots so therefore we can rewrite it as $x^2 + y^2 =< 16$ and this becomes our domain which is all real numbers that fulfill that equation. Visually this reflects as a circle with a radius of 4 and to find the range we start by taking a point at the boundry of the doamin which in this case is $x^2 + y^2 = 16$. plugging this into our $f(x,y)$ function gives us an answer of 0. Then we take the domain when $x^2_0 + y^2_0 = 0$ or $x_0 = 0$ and $y_0 = 0$ and plugging into our initial function gives us the square root of 16 which is equal to 4. Therefore the range is any values between 0 and 4 which we write as [0, 4]*
#
# </details>

# %% [markdown]
# **Problem:**
#
# f(x,y) = sqrt(16 - x^2 - y^2) Find the domain and range
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# To find the domain, we must consider that since there is a square root, it has to be equal to or greater than 0
#
# x^2 - y^2 < or = 16
#
# As the square root of 16 is 4, we find that the domain can only be 0 to 4
#
# We can also
#
# </details>

# %% [markdown]
# **Problem 71:**
#
# *[f(x,y)=ln(9-x^2-4y^2)]*
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *[1. we find the domain
#     x^2+4y^2=0 but only when x is 0 and y is 0.
#     All real numbers except (0,0)
# 2. x^2+4y^2 >0 so this would say our range would be (-inf, inf)so all real numbers]*
#
# </details>

# %% [markdown]
# **Problem 72:**
#
# $f(x, y) = \sqrt{9 − x^2 − y^2}$
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# 1) Domain: $x^2 + y^2 ≤ 9$.
#
# 2) Range: Smallest value is $0$ when $x^2 + y^2 = 9$, so $f = 0$.
# Largest value is $9$ when $x$ and $y = 0$, so $f = 3$.
#
# Range: $0$ through $3$.
#
# </details>

# %% [markdown]
# ### Sample Problem 5.1a: Multivariable Functions
#
# **Problem 73:**
#
# Consider the function
# $$f(x,y) = x^2 + 2y.$$
#
# 1. Identify the domain of this function.
# 2. Identify the range of this function.
#
# Solution:
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# Step 1: Domain
#
# The function is
# $$f(x,y) = x^2 + 2y.$$
#
# There are no restrictions on $x$ or $y$:
#
# - We can plug in any real number for $x$.
# - We can plug in any real number for $y$.
#
# So the domain is all pairs $(x,y)$ of real numbers:
#
# $$\text{Domain} = (-\infty,\infty)\times(-\infty,\infty)$$
#
# We write the domain as $(-\infty,\infty)\times(-\infty,\infty)$ because the function has two input variables. Each interval $(-\infty,\infty)$ represents all possible real values for one variable. The $\times$ symbol indicates that we take all possible pairs $(x,y)$ from both intervals, since $x$ and $y$ can vary independently.
#
# Step 2: Range
#
# The output is
# $$f(x,y) = x^2 + 2y.$$
#
# - The term $x^2$ is always greater than or equal to 0.
# - The term $2y$ can be any real number, positive or negative.
#
# Since we can make $2y$ very large or very negative, and $x^2$ only adds nonnegative values, the function can produce any real number.
#
# So the range is:
#
# $$\text{Range} = (-\infty,\infty).$$
#
# Conclusion
#
# For this multivariable function:
#
# - The domain is every possible pair of real numbers.
# - The range is every possible real output.
#
# This function is simple but shows how multivariable inputs can produce a wide variety of outputs.
# </details>

# %% [markdown]
# **Problem 74:**
#
# *Consider the function
#
# 	F(x,y)= 2x+xy-y^2
# Step 1 → Find the domain of f
# Step 2 → find the range of f
#
#
# **Solution:**
#
# <details>
# <summary><b>Click to reveal solution</b></summary>
#
# *Domain
# 	The formula uses only addition, multiplication, and powers, all of which are defined for all real numbers. So the domain is
#
# 						R^2
#
# Range
# 	Because the expression includes a negative quadratic term −y^2 and linear/mixed terms, the function can take arbitrarily large positive and negative values depending on x and y.Thus the range is
#
# 						(-oo,oo)
#
#
#
# </details>
